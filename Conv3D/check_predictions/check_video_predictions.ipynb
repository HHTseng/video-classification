# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 1000)

# %%
df = pd.read_pickle('./UCF101_videos_prediction.pkl')

# %%
df
# Out:
#                            filename                   y              y_pred
# 0            v_PlayingSitar_g09_c06        PlayingSitar   VolleyballSpiking
# 1            v_PlayingPiano_g17_c02        PlayingPiano        PlayingPiano
# 2                v_LongJump_g03_c03            LongJump            LongJump
# 3                  v_TaiChi_g16_c02              TaiChi              TaiChi
# 4            v_ParallelBars_g01_c04        ParallelBars        ParallelBars
# 5            v_PlayingCello_g06_c05        PlayingCello        PlayingCello
# 6            v_PizzaTossing_g17_c03        PizzaTossing        PizzaTossing
# 7            v_MoppingFloor_g23_c04        MoppingFloor        MoppingFloor
# 8              v_BenchPress_g25_c06          BenchPress          BenchPress
# 9               v_GolfSwing_g12_c01           GolfSwing           GolfSwing
# 10               v_HighJump_g02_c03            HighJump            HighJump
# 11                 v_Typing_g06_c01              Typing              Typing
# 12         v_WritingOnBoard_g01_c02      WritingOnBoard      WritingOnBoard
# 13              v_Hammering_g17_c05           Hammering           Hammering
# 14                 v_Biking_g05_c07              Biking              Biking
# 15             v_PlayingDaf_g25_c05          PlayingDaf          PlayingDaf
# 16          v_BaseballPitch_g23_c05       BaseballPitch       BaseballPitch
# 17           v_FrisbeeCatch_g17_c04        FrisbeeCatch            LongJump
# 18           v_BabyCrawling_g03_c02        BabyCrawling        BabyCrawling
# 19           v_ShavingBeard_g24_c03        ShavingBeard        ShavingBeard
# 20                  v_Punch_g14_c07               Punch               Punch
# 21        v_FloorGymnastics_g15_c03     FloorGymnastics     FloorGymnastics
# 22                 v_Skiing_g22_c03              Skiing              Skiing
# 23           v_PlayingPiano_g14_c02        PlayingPiano        PlayingPiano
# 24           v_PlayingFlute_g05_c02        PlayingFlute        PlayingFlute
# 25             v_IceDancing_g08_c03          IceDancing          IceDancing
# 26               v_JumpRope_g09_c05            JumpRope            JumpRope
# 27                v_PullUps_g07_c01             PullUps             PullUps
# 28                v_Bowling_g01_c07             Bowling             Bowling
# 29           v_FrisbeeCatch_g17_c03        FrisbeeCatch        FrisbeeCatch
# 30              v_GolfSwing_g04_c01           GolfSwing           GolfSwing
# 31             v_UnevenBars_g18_c03          UnevenBars          UnevenBars
# 32              v_HorseRace_g21_c02           HorseRace           HorseRace
# 33          v_BaseballPitch_g09_c02       BaseballPitch       BaseballPitch
# 34                 v_Typing_g08_c02              Typing              Typing
# 35           v_PizzaTossing_g12_c03        PizzaTossing         HorseRiding
# 36     v_FieldHockeyPenalty_g13_c02  FieldHockeyPenalty         BlowDryHair
# 37             v_StillRings_g23_c02          StillRings          StillRings
# 38         v_CricketBowling_g12_c04      CricketBowling      CricketBowling
# 39              v_GolfSwing_g04_c04           GolfSwing           GolfSwing
# 40                v_Fencing_g17_c02             Fencing             Fencing
# 41            v_CricketShot_g18_c05         CricketShot         CricketShot
# 42             v_FrontCrawl_g06_c05          FrontCrawl          FrontCrawl
# 43                 v_Skiing_g17_c02              Skiing             Surfing
# 44         v_MilitaryParade_g13_c02      MilitaryParade      MilitaryParade
# 45          v_SkateBoarding_g24_c02       SkateBoarding        BabyCrawling
# 46               v_Knitting_g10_c01            Knitting         HorseRiding
# 47             v_StillRings_g17_c01          StillRings          StillRings
# 48           v_BabyCrawling_g01_c01        BabyCrawling        BabyCrawling
# 49          v_SkateBoarding_g13_c04       SkateBoarding       SkateBoarding
# 50         v_WalkingWithDog_g02_c05      WalkingWithDog      WalkingWithDog
# 51               v_Kayaking_g05_c04            Kayaking            Kayaking
# 52                v_Surfing_g24_c01             Surfing             Surfing
# 53            v_CricketShot_g11_c07         CricketShot         CricketShot
# 54                  v_Swing_g17_c02               Swing               Swing
# 55                v_Shotput_g19_c01             Shotput             Shotput
# 56                v_PushUps_g05_c04             PushUps             PushUps
# 57           v_BabyCrawling_g09_c03        BabyCrawling        BabyCrawling
# 58                v_Shotput_g10_c03             Shotput             Shotput
# 59          v_ApplyLipstick_g06_c03       ApplyLipstick       ApplyLipstick
# 60             v_IceDancing_g14_c04          IceDancing          IceDancing
# 61         v_CricketBowling_g19_c06      CricketBowling        MoppingFloor
# 62                 v_Skiing_g24_c06              Skiing              Skiing
# 63          v_BaseballPitch_g19_c01       BaseballPitch         ThrowDiscus
# 64           v_JavelinThrow_g05_c05        JavelinThrow        JavelinThrow
# 65                v_PushUps_g15_c02             PushUps             PushUps
# 66          v_BaseballPitch_g18_c04       BaseballPitch       BaseballPitch
# 67           v_FrisbeeCatch_g10_c05        FrisbeeCatch        FrisbeeCatch
# 68                v_PushUps_g20_c03             PushUps              Lunges
# 69                v_Shotput_g09_c05             Shotput             Shotput
# 70            v_WallPushups_g20_c06         WallPushups         WallPushups
# 71                v_Surfing_g24_c03             Surfing             Surfing
# 72           v_PlayingSitar_g06_c06        PlayingSitar        PlayingSitar
# 73                 v_Rowing_g15_c04              Rowing      MilitaryParade
# 74             v_IceDancing_g02_c01          IceDancing          IceDancing
# 75                v_Bowling_g11_c02             Bowling             Bowling
# 76             v_StillRings_g01_c05          StillRings          StillRings
# 77                 v_Skiing_g02_c01              Skiing              Skiing
# 78                 v_Typing_g03_c06              Typing              Typing
# 79             v_StillRings_g10_c02          StillRings      BlowingCandles
# 80          v_BrushingTeeth_g20_c04       BrushingTeeth       BrushingTeeth
# 81                v_PullUps_g11_c02             PullUps             PullUps
# 82               v_JumpRope_g13_c05            JumpRope            JumpRope
# 83          v_BrushingTeeth_g12_c06       BrushingTeeth      ApplyEyeMakeup
# 84           v_JavelinThrow_g18_c01        JavelinThrow        JavelinThrow
# 85      v_TrampolineJumping_g09_c04   TrampolineJumping   TrampolineJumping
# 86         v_MilitaryParade_g01_c06      MilitaryParade      MilitaryParade
# 87                 v_TaiChi_g01_c01              TaiChi              TaiChi
# 88                 v_Biking_g04_c04              Biking               Swing
# 89           v_MoppingFloor_g15_c01        MoppingFloor        MoppingFloor
# 90            v_BalanceBeam_g17_c04         BalanceBeam         BalanceBeam
# 91           v_PlayingFlute_g15_c01        PlayingFlute        PlayingFlute
# 92              v_Nunchucks_g04_c01           Nunchucks           Nunchucks
# 93                v_Shotput_g18_c01             Shotput             Shotput
# 94         v_CricketBowling_g02_c01      CricketBowling      CricketBowling
# 95           v_RopeClimbing_g05_c05        RopeClimbing            LongJump
# 96           v_FrisbeeCatch_g08_c01        FrisbeeCatch              Lunges
# 97                 v_Diving_g04_c05              Diving              Diving
# 98          v_BaseballPitch_g05_c03       BaseballPitch       BaseballPitch
# 99          v_PlayingViolin_g17_c02       PlayingViolin       PlayingViolin
# 100          v_ParallelBars_g11_c06        ParallelBars        ParallelBars
# 101              v_Drumming_g12_c01            Drumming            Drumming
# 102      v_BodyWeightSquats_g15_c01    BodyWeightSquats    BodyWeightSquats
# 103             v_HorseRace_g24_c05           HorseRace           HorseRace
# 104            v_PlayingDaf_g05_c01          PlayingDaf          PlayingDaf
# 105        v_CricketBowling_g08_c03      CricketBowling      CricketBowling
# 106                v_Skiing_g12_c02              Skiing              Skiing
# 107          v_PlayingTabla_g04_c05        PlayingTabla        PlayingTabla
# 108         v_BaseballPitch_g15_c02       BaseballPitch       BaseballPitch
# 109            v_Basketball_g04_c02          Basketball          Basketball
# 110               v_Shotput_g10_c04             Shotput             Shotput
# 111           v_PlayingDhol_g05_c01         PlayingDhol              Diving
# 112                v_Typing_g18_c02              Typing              Typing
# 113        v_CricketBowling_g09_c03      CricketBowling      BasketballDunk
# 114             v_Billiards_g12_c01           Billiards           Billiards
# 115             v_HorseRace_g08_c04           HorseRace           HorseRace
# 116     v_VolleyballSpiking_g07_c01   VolleyballSpiking   VolleyballSpiking
# 117           v_CricketShot_g12_c03         CricketShot         CricketShot
# 118             v_SalsaSpin_g24_c03           SalsaSpin           SalsaSpin
# 119          v_PlayingTabla_g01_c04        PlayingTabla        PlayingTabla
# 120      v_HandstandWalking_g03_c02    HandstandWalking    HandstandWalking
# 121                v_Skiing_g25_c05              Skiing              Skiing
# 122             v_GolfSwing_g05_c02           GolfSwing           GolfSwing
# 123                  v_YoYo_g16_c03                YoYo                YoYo
# 124            v_UnevenBars_g12_c03          UnevenBars          UnevenBars
# 125             v_Billiards_g15_c02           Billiards           Billiards
# 126        v_WalkingWithDog_g23_c02      WalkingWithDog      WalkingWithDog
# 127                 v_Swing_g20_c01               Swing               Swing
# 128              v_JumpRope_g19_c04            JumpRope            JumpRope
# 129     v_TrampolineJumping_g11_c04   TrampolineJumping   TrampolineJumping
# 130               v_Archery_g13_c05             Archery             Archery
# 131               v_PullUps_g19_c03             PullUps             PullUps
# 132              v_JumpRope_g03_c01            JumpRope            JumpRope
# 133           v_BlowDryHair_g18_c05         BlowDryHair         BlowDryHair
# 134          v_FrisbeeCatch_g08_c03        FrisbeeCatch            Kayaking
# 135              v_Drumming_g24_c06            Drumming            Drumming
# 136        v_WalkingWithDog_g23_c01      WalkingWithDog      WalkingWithDog
# 137          v_JavelinThrow_g07_c05        JavelinThrow        JavelinThrow
# 138           v_BlowDryHair_g10_c02         BlowDryHair         BlowDryHair
# 139          v_BabyCrawling_g21_c01        BabyCrawling        BabyCrawling
# 140     v_VolleyballSpiking_g16_c02   VolleyballSpiking   VolleyballSpiking
# 141              v_Kayaking_g09_c04            Kayaking            Kayaking
# 142         v_BaseballPitch_g24_c01       BaseballPitch       BaseballPitch
# 143        v_WritingOnBoard_g15_c03      WritingOnBoard      WritingOnBoard
# 144           v_BlowDryHair_g11_c07         BlowDryHair         BlowDryHair
# 145               v_Haircut_g08_c04             Haircut             Haircut
# 146          v_JavelinThrow_g24_c03        JavelinThrow        JavelinThrow
# 147         v_BrushingTeeth_g19_c05       BrushingTeeth       BrushingTeeth
# 148              v_JumpRope_g21_c04            JumpRope            JumpRope
# 149         v_JugglingBalls_g07_c02       JugglingBalls   BoxingPunchingBag
# 150             v_Nunchucks_g16_c01           Nunchucks           Nunchucks
# 151          v_ShavingBeard_g18_c01        ShavingBeard        ShavingBeard
# 152              v_HulaHoop_g15_c05            HulaHoop            HulaHoop
# 153           v_CricketShot_g21_c01         CricketShot         CricketShot
# 154          v_PlayingCello_g12_c02        PlayingCello        PlayingCello
# 155      v_HandstandPushups_g20_c01    HandstandPushups    HandstandPushups
# 156              v_JumpRope_g04_c05            JumpRope            JumpRope
# 157                v_Biking_g17_c02              Biking           Hammering
# 158          v_RopeClimbing_g25_c03        RopeClimbing        RopeClimbing
# 159         v_PlayingGuitar_g21_c01       PlayingGuitar       PlayingGuitar
# 160              v_Kayaking_g07_c01            Kayaking            Kayaking
# 161                v_Skijet_g17_c02              Skijet              Skijet
# 162        v_BoxingSpeedBag_g04_c06      BoxingSpeedBag      BoxingSpeedBag
# 163           v_WallPushups_g07_c05         WallPushups         WallPushups
# 164           v_PlayingDhol_g12_c05         PlayingDhol         PlayingDhol
# 165             v_Hammering_g09_c07           Hammering           Hammering
# 166           v_HorseRiding_g02_c02         HorseRiding         HorseRiding
# 167               v_PullUps_g22_c04             PullUps             PullUps
# 168                 v_Swing_g19_c03               Swing        BandMarching
# 169            v_IceDancing_g04_c04          IceDancing                YoYo
# 170                  v_YoYo_g09_c05                YoYo                YoYo
# 171              v_JumpRope_g21_c06            JumpRope            JumpRope
# 172    v_FieldHockeyPenalty_g09_c05  FieldHockeyPenalty  FieldHockeyPenalty
# 173             v_Billiards_g03_c05           Billiards           Billiards
# 174     v_BoxingPunchingBag_g23_c07   BoxingPunchingBag   BoxingPunchingBag
# 175         v_BrushingTeeth_g24_c04       BrushingTeeth       BrushingTeeth
# 176                v_Biking_g03_c03              Biking              Biking
# 177                v_TaiChi_g04_c03              TaiChi        BabyCrawling
# 178           v_CricketShot_g04_c01         CricketShot         CricketShot
# 179               v_Haircut_g15_c02             Haircut             Haircut
# 180          v_BabyCrawling_g22_c02        BabyCrawling          PlayingDaf
# 181        v_SoccerJuggling_g22_c04      SoccerJuggling        MoppingFloor
# 182           v_HammerThrow_g22_c04         HammerThrow         HammerThrow
# 183          v_BreastStroke_g05_c02        BreastStroke        BreastStroke
# 184     v_BoxingPunchingBag_g16_c03   BoxingPunchingBag   BoxingPunchingBag
# 185     v_BoxingPunchingBag_g14_c02   BoxingPunchingBag   BoxingPunchingBag
# 186           v_HorseRiding_g07_c02         HorseRiding         HorseRiding
# 187             v_SkyDiving_g23_c04           SkyDiving           SkyDiving
# 188          v_ShavingBeard_g03_c04        ShavingBeard      ApplyEyeMakeup
# 189             v_Hammering_g21_c03           Hammering           Hammering
# 190    v_FieldHockeyPenalty_g03_c02  FieldHockeyPenalty  FieldHockeyPenalty
# 191          v_FrisbeeCatch_g03_c03        FrisbeeCatch        FrisbeeCatch
# 192          v_PizzaTossing_g15_c03        PizzaTossing        PizzaTossing
# 193          v_PizzaTossing_g06_c01        PizzaTossing        PizzaTossing
# 194          v_MoppingFloor_g06_c04        MoppingFloor        MoppingFloor
# 195            v_StillRings_g09_c03          StillRings          StillRings
# 196          v_BandMarching_g07_c03        BandMarching        BandMarching
# 197           v_HammerThrow_g06_c05         HammerThrow         HammerThrow
# 198           v_CliffDiving_g24_c04         CliffDiving         CliffDiving
# 199            v_Basketball_g21_c04          Basketball          Basketball
# 200                v_Typing_g24_c01              Typing              Typing
# 201        v_CricketBowling_g03_c01      CricketBowling      CricketBowling
# 202           v_JumpingJack_g06_c02         JumpingJack         JumpingJack
# 203           v_TennisSwing_g25_c01         TennisSwing         TennisSwing
# 204          v_PizzaTossing_g11_c03        PizzaTossing        PizzaTossing
# 205          v_PlayingCello_g20_c01        PlayingCello        PlayingCello
# 206           v_CricketShot_g21_c06         CricketShot         CricketShot
# 207         v_BaseballPitch_g10_c03       BaseballPitch       BaseballPitch
# 208      v_CuttingInKitchen_g06_c04    CuttingInKitchen    CuttingInKitchen
# 209              v_Drumming_g05_c02            Drumming            Drumming
# 210        v_BoxingSpeedBag_g10_c04      BoxingSpeedBag              Diving
# 211          v_ParallelBars_g08_c02        ParallelBars        ParallelBars
# 212           v_BlowDryHair_g09_c01         BlowDryHair         BlowDryHair
# 213                v_Typing_g03_c01              Typing              Typing
# 214             v_Nunchucks_g19_c02           Nunchucks      WalkingWithDog
# 215                v_Skiing_g01_c03              Skiing              Skiing
# 216               v_Haircut_g01_c01             Haircut        BabyCrawling
# 217         v_SkateBoarding_g12_c01       SkateBoarding         CliffDiving
# 218         v_SoccerPenalty_g11_c03       SoccerPenalty       SoccerPenalty
# 219        v_MilitaryParade_g22_c01      MilitaryParade      MilitaryParade
# 220               v_Haircut_g15_c04             Haircut             Haircut
# 221          v_ParallelBars_g07_c05        ParallelBars        PizzaTossing
# 222                  v_YoYo_g04_c04                YoYo                YoYo
# 223                v_Diving_g07_c02              Diving              Diving
# 224                v_Diving_g15_c02              Diving              Diving
# 225              v_LongJump_g11_c05            LongJump            LongJump
# 226          v_BreastStroke_g10_c02        BreastStroke        BreastStroke
# 227      v_HandstandPushups_g15_c04    HandstandPushups    HandstandPushups
# 228            v_Basketball_g10_c05          Basketball          Basketball
# 229            v_UnevenBars_g09_c02          UnevenBars          UnevenBars
# 230               v_Surfing_g08_c07             Surfing             Surfing
# 231            v_StillRings_g05_c04          StillRings          StillRings
# 232            v_UnevenBars_g15_c06          UnevenBars          UnevenBars
# 233            v_PlayingDaf_g05_c04          PlayingDaf          PlayingDaf
# 234          v_BandMarching_g14_c02        BandMarching        BandMarching
# 235           v_PlayingDhol_g24_c01         PlayingDhol         PlayingDhol
# 236          v_PlayingSitar_g08_c02        PlayingSitar        PlayingSitar
# 237             v_HorseRace_g01_c01           HorseRace           HorseRace
# 238             v_Nunchucks_g21_c05           Nunchucks           Nunchucks
# 239                 v_Punch_g18_c05               Punch               Punch
# 240                 v_Swing_g15_c02               Swing               Swing
# 241        v_BlowingCandles_g08_c03      BlowingCandles      BlowingCandles
# 242           v_PommelHorse_g22_c02         PommelHorse         PommelHorse
# 243          v_PizzaTossing_g04_c01        PizzaTossing        PizzaTossing
# 244                 v_Punch_g01_c05               Punch               Punch
# 245          v_PlayingTabla_g24_c04        PlayingTabla        PlayingCello
# 246          v_PlayingFlute_g20_c02        PlayingFlute        PlayingFlute
# 247                v_Biking_g06_c04              Biking      MilitaryParade
# 248         v_SoccerPenalty_g16_c01       SoccerPenalty       SoccerPenalty
# 249         v_PlayingGuitar_g04_c01       PlayingGuitar       PlayingGuitar
# 250       v_TableTennisShot_g19_c01     TableTennisShot     TableTennisShot
# 251           v_PommelHorse_g18_c04         PommelHorse        PlayingFlute
# 252                v_Diving_g15_c05              Diving              Diving
# 253               v_Bowling_g23_c04             Bowling             Bowling
# 254               v_Surfing_g16_c02             Surfing             Surfing
# 255              v_HighJump_g11_c06            HighJump            HighJump
# 256          v_BandMarching_g18_c02        BandMarching        BandMarching
# 257           v_HeadMassage_g10_c03         HeadMassage         HeadMassage
# 258                v_Typing_g06_c02              Typing              Typing
# 259            v_FrontCrawl_g17_c01          FrontCrawl             Shotput
# 260           v_HammerThrow_g01_c03         HammerThrow         HammerThrow
# 261    v_RockClimbingIndoor_g20_c03  RockClimbingIndoor  RockClimbingIndoor
# 262               v_Rafting_g16_c01             Rafting             Rafting
# 263                  v_YoYo_g07_c01                YoYo        PlayingFlute
# 264              v_Knitting_g14_c03            Knitting            Knitting
# 265               v_Archery_g25_c07             Archery   TrampolineJumping
# 266        v_BasketballDunk_g21_c02      BasketballDunk      BasketballDunk
# 267             v_SalsaSpin_g03_c03           SalsaSpin           SalsaSpin
# 268             v_GolfSwing_g22_c03           GolfSwing           GolfSwing
# 269          v_CleanAndJerk_g24_c01        CleanAndJerk        CleanAndJerk
# 270          v_PizzaTossing_g04_c03        PizzaTossing        PizzaTossing
# 271          v_FrisbeeCatch_g02_c01        FrisbeeCatch        FrisbeeCatch
# 272          v_PlayingTabla_g19_c01        PlayingTabla        PlayingTabla
# 273                v_Mixing_g04_c01              Mixing              Mixing
# 274           v_WallPushups_g25_c01         WallPushups         WallPushups
# 275              v_HighJump_g14_c02            HighJump         HorseRiding
# 276             v_SkyDiving_g02_c03           SkyDiving           SkyDiving
# 277           v_PlayingDhol_g23_c07         PlayingDhol         PlayingDhol
# 278          v_PlayingCello_g05_c05        PlayingCello        PlayingCello
# 279            v_FrontCrawl_g14_c01          FrontCrawl          FrontCrawl
# 280       v_FloorGymnastics_g07_c04     FloorGymnastics     FloorGymnastics
# 281            v_BenchPress_g05_c07          BenchPress          BenchPress
# 282             v_SalsaSpin_g07_c01           SalsaSpin           SalsaSpin
# 283           v_HorseRiding_g23_c04         HorseRiding         HorseRiding
# 284           v_CricketShot_g05_c04         CricketShot         CricketShot
# 285                v_Mixing_g15_c02              Mixing              Mixing
# 286               v_Archery_g07_c06             Archery             Archery
# 287               v_Surfing_g07_c01             Surfing             Surfing
# 288         v_PlayingGuitar_g21_c03       PlayingGuitar       PlayingGuitar
# 289                v_Biking_g16_c05              Biking              Biking
# 290         v_JugglingBalls_g07_c05       JugglingBalls      ApplyEyeMakeup
# 291    v_FieldHockeyPenalty_g25_c01  FieldHockeyPenalty          Basketball
# 292          v_PlayingPiano_g08_c01        PlayingPiano        PlayingPiano
# 293           v_TennisSwing_g14_c02         TennisSwing    HandstandWalking
# 294          v_BandMarching_g20_c06        BandMarching        BandMarching
# 295           v_JumpingJack_g21_c01         JumpingJack            JumpRope
# 296           v_BlowDryHair_g21_c06         BlowDryHair         BlowDryHair
# 297          v_PizzaTossing_g19_c04        PizzaTossing        PizzaTossing
# 298          v_BandMarching_g20_c04        BandMarching        BandMarching
# 299       v_TableTennisShot_g16_c03     TableTennisShot     TableTennisShot
# 300         v_SkateBoarding_g20_c02       SkateBoarding       SkateBoarding
# 301             v_HorseRace_g21_c05           HorseRace           HorseRace
# 302        v_WritingOnBoard_g11_c06      WritingOnBoard      WritingOnBoard
# 303           v_HorseRiding_g04_c01         HorseRiding            Kayaking
# 304               v_Bowling_g04_c04             Bowling         CliffDiving
# 305                v_Skijet_g21_c04              Skijet              Skijet
# 306             v_SalsaSpin_g17_c01           SalsaSpin           SalsaSpin
# 307                v_Typing_g14_c03              Typing              Typing
# 308          v_JavelinThrow_g11_c02        JavelinThrow        JavelinThrow
# 309        v_BoxingSpeedBag_g05_c05      BoxingSpeedBag      BoxingSpeedBag
# 310                v_Mixing_g10_c04              Mixing              Mixing
# 311         v_SoccerPenalty_g10_c05       SoccerPenalty       SoccerPenalty
# 312          v_BreastStroke_g09_c04        BreastStroke        BreastStroke
# 313                v_Skijet_g25_c02              Skijet              Skijet
# 314         v_BaseballPitch_g08_c05       BaseballPitch       BaseballPitch
# 315         v_SumoWrestling_g05_c01       SumoWrestling               Punch
# 316         v_PlayingGuitar_g05_c05       PlayingGuitar       PlayingGuitar
# 317              v_Kayaking_g24_c03            Kayaking            Kayaking
# 318         v_BaseballPitch_g01_c03       BaseballPitch         JumpingJack
# 319                v_Biking_g16_c04              Biking              Biking
# 320                 v_Swing_g02_c02               Swing               Swing
# 321           v_HammerThrow_g23_c06         HammerThrow         HammerThrow
# 322           v_WallPushups_g03_c05         WallPushups         WallPushups
# 323         v_JugglingBalls_g16_c04       JugglingBalls       JugglingBalls
# 324           v_TennisSwing_g20_c01         TennisSwing         TennisSwing
# 325                v_Skiing_g12_c01              Skiing              Skiing
# 326    v_FieldHockeyPenalty_g06_c02  FieldHockeyPenalty  FieldHockeyPenalty
# 327                v_Rowing_g04_c05              Rowing              Skijet
# 328              v_Drumming_g13_c04            Drumming            Drumming
# 329         v_SkateBoarding_g10_c06       SkateBoarding       SkateBoarding
# 330        v_BasketballDunk_g11_c03      BasketballDunk      BasketballDunk
# 331           v_CricketShot_g04_c02         CricketShot      CricketBowling
# 332    v_FieldHockeyPenalty_g14_c06  FieldHockeyPenalty  FieldHockeyPenalty
# 333           v_HammerThrow_g14_c05         HammerThrow         HammerThrow
# 334                v_Diving_g10_c04              Diving              Diving
# 335        v_BlowingCandles_g22_c04      BlowingCandles             Shotput
# 336                 v_Punch_g05_c04               Punch               Punch
# 337          v_BandMarching_g24_c02        BandMarching        BandMarching
# 338         v_SkateBoarding_g18_c04       SkateBoarding       SkateBoarding
# 339          v_CleanAndJerk_g19_c04        CleanAndJerk        CleanAndJerk
# 340    v_RockClimbingIndoor_g12_c02  RockClimbingIndoor  RockClimbingIndoor
# 341            v_FrontCrawl_g11_c07          FrontCrawl          FrontCrawl
# 342         v_ApplyLipstick_g16_c01       ApplyLipstick       ApplyLipstick
# 343          v_PlayingFlute_g23_c01        PlayingFlute        PlayingFlute
# 344           v_HammerThrow_g05_c03         HammerThrow         HammerThrow
# 345                v_Mixing_g10_c01              Mixing              Mixing
# 346           v_BalanceBeam_g19_c02         BalanceBeam        MoppingFloor
# 347         v_BrushingTeeth_g07_c02       BrushingTeeth       BrushingTeeth
# 348             v_Billiards_g15_c07           Billiards           Billiards
# 349              v_HighJump_g16_c05            HighJump            HighJump
# 350     v_BoxingPunchingBag_g20_c04   BoxingPunchingBag   BoxingPunchingBag
# 351     v_BoxingPunchingBag_g04_c03   BoxingPunchingBag   BoxingPunchingBag
# 352          v_PizzaTossing_g06_c05        PizzaTossing        PizzaTossing
# 353                v_Typing_g17_c01              Typing              Typing
# 354                v_Rowing_g01_c01              Rowing              Rowing
# 355          v_PlayingSitar_g04_c06        PlayingSitar        PlayingSitar
# 356         v_SoccerPenalty_g23_c05       SoccerPenalty       SoccerPenalty
# 357               v_Rafting_g06_c02             Rafting               Swing
# 358             v_PoleVault_g20_c04           PoleVault           PoleVault
# 359                v_Mixing_g02_c02              Mixing              Mixing
# 360         v_JugglingBalls_g07_c04       JugglingBalls      ApplyEyeMakeup
# 361          v_PlayingSitar_g17_c01        PlayingSitar        PlayingSitar
# 362               v_Shotput_g08_c04             Shotput             Shotput
# 363           v_BalanceBeam_g07_c02         BalanceBeam         BalanceBeam
# 364           v_HeadMassage_g19_c05         HeadMassage         HeadMassage
# 365                v_Mixing_g23_c04              Mixing              Mixing
# 366               v_Rafting_g24_c01             Rafting             Rafting
# 367          v_PlayingCello_g06_c01        PlayingCello        PlayingCello
# 368         v_SumoWrestling_g25_c03       SumoWrestling       SumoWrestling
# 369           v_HorseRiding_g13_c04         HorseRiding         HorseRiding
# 370          v_PlayingTabla_g22_c03        PlayingTabla        PlayingTabla
# 371          v_BandMarching_g01_c05        BandMarching        BandMarching
# 372           v_PlayingDhol_g15_c01         PlayingDhol         PlayingDhol
# 373          v_PlayingTabla_g12_c04        PlayingTabla        PlayingTabla
# 374                 v_Punch_g16_c04               Punch               Punch
# 375          v_JavelinThrow_g14_c06        JavelinThrow        JavelinThrow
# 376            v_BenchPress_g13_c07          BenchPress          BenchPress
# 377         v_PlayingGuitar_g14_c01       PlayingGuitar       PlayingGuitar
# 378       v_TableTennisShot_g18_c04     TableTennisShot     TableTennisShot
# 379              v_LongJump_g11_c01            LongJump          FrontCrawl
# 380             v_Billiards_g24_c03           Billiards           Billiards
# 381                v_Skijet_g12_c04              Skijet              Skijet
# 382                v_Lunges_g10_c05              Lunges              Lunges
# 383          v_RopeClimbing_g09_c03        RopeClimbing        RopeClimbing
# 384          v_ParallelBars_g09_c01        ParallelBars        ParallelBars
# 385        v_ApplyEyeMakeup_g13_c02      ApplyEyeMakeup         PlayingDhol
# 386             v_GolfSwing_g03_c03           GolfSwing           GolfSwing
# 387          v_PizzaTossing_g25_c01        PizzaTossing        PizzaTossing
# 388        v_CricketBowling_g24_c04      CricketBowling      CricketBowling
# 389               v_Fencing_g24_c02             Fencing             Fencing
# 390              v_Knitting_g05_c04            Knitting            Knitting
# 391             v_Billiards_g04_c07           Billiards           Billiards
# 392            v_UnevenBars_g03_c03          UnevenBars          UnevenBars
# 393        v_ApplyEyeMakeup_g24_c04      ApplyEyeMakeup      ApplyEyeMakeup
# 394          v_PlayingFlute_g10_c04        PlayingFlute        PlayingFlute
# 395         v_ApplyLipstick_g06_c05       ApplyLipstick       ApplyLipstick
# 396              v_HighJump_g04_c01            HighJump        FrisbeeCatch
# 397          v_PlayingPiano_g06_c01        PlayingPiano        PlayingPiano
# 398           v_JumpingJack_g13_c06         JumpingJack         JumpingJack
# 399       v_FloorGymnastics_g22_c03     FloorGymnastics            Knitting
# 400                v_Skiing_g02_c04              Skiing              Skiing
# 401          v_PlayingSitar_g23_c07        PlayingSitar        PlayingSitar
# 402            v_IceDancing_g13_c04          IceDancing          IceDancing
# 403        v_BoxingSpeedBag_g17_c04      BoxingSpeedBag      BoxingSpeedBag
# 404               v_Bowling_g13_c02             Bowling             Bowling
# 405        v_ApplyEyeMakeup_g10_c05      ApplyEyeMakeup      ApplyEyeMakeup
# 406        v_MilitaryParade_g07_c02      MilitaryParade      MilitaryParade
# 407        v_ApplyEyeMakeup_g07_c03      ApplyEyeMakeup          Basketball
# 408         v_SkateBoarding_g10_c07       SkateBoarding         CricketShot
# 409             v_PoleVault_g06_c04           PoleVault              Skijet
# 410        v_CricketBowling_g04_c05      CricketBowling      CricketBowling
# 411               v_Bowling_g20_c06             Bowling             Bowling
# 412    v_RockClimbingIndoor_g05_c05  RockClimbingIndoor  RockClimbingIndoor
# 413              v_HighJump_g24_c03            HighJump            HighJump
# 414         v_SoccerPenalty_g09_c05       SoccerPenalty       SoccerPenalty
# 415             v_PoleVault_g17_c06           PoleVault         HammerThrow
# 416            v_StillRings_g01_c01          StillRings          StillRings
# 417            v_BenchPress_g01_c01          BenchPress          BenchPress
# 418                 v_Punch_g19_c06               Punch               Punch
# 419                v_Rowing_g03_c07              Rowing              Rowing
# 420           v_PlayingDhol_g11_c01         PlayingDhol      ApplyEyeMakeup
# 421         v_SoccerPenalty_g22_c05       SoccerPenalty       SoccerPenalty
# 422                v_Lunges_g08_c04              Lunges              Lunges
# 423           v_JumpingJack_g12_c02         JumpingJack         JumpingJack
# 424             v_Hammering_g24_c05           Hammering           Hammering
# 425           v_ThrowDiscus_g07_c02         ThrowDiscus         ThrowDiscus
# 426      v_CuttingInKitchen_g12_c02    CuttingInKitchen        BabyCrawling
# 427              v_Drumming_g11_c07            Drumming            Drumming
# 428           v_HeadMassage_g15_c03         HeadMassage         HeadMassage
# 429         v_PlayingViolin_g06_c01       PlayingViolin       PlayingViolin
# 430                v_Lunges_g15_c02              Lunges        MoppingFloor
# 431        v_SoccerJuggling_g05_c03      SoccerJuggling      SoccerJuggling
# 432               v_PushUps_g04_c03             PushUps             PushUps
# 433        v_SoccerJuggling_g14_c03      SoccerJuggling      SoccerJuggling
# 434                v_Skiing_g06_c01              Skiing                YoYo
# 435              v_Drumming_g17_c03            Drumming            Drumming
# 436           v_BalanceBeam_g18_c02         BalanceBeam         BalanceBeam
# 437             v_GolfSwing_g04_c02           GolfSwing           GolfSwing
# 438           v_BalanceBeam_g06_c03         BalanceBeam         BalanceBeam
# 439                v_Skijet_g23_c01              Skijet        FrisbeeCatch
# 440         v_JugglingBalls_g10_c02       JugglingBalls       JugglingBalls
# 441          v_PlayingCello_g23_c06        PlayingCello        PlayingCello
# 442          v_JavelinThrow_g10_c04        JavelinThrow        JavelinThrow
# 443         v_PlayingViolin_g23_c04       PlayingViolin       PlayingViolin
# 444         v_JugglingBalls_g03_c07       JugglingBalls       JugglingBalls
# 445                v_Mixing_g24_c02              Mixing              Mixing
# 446                v_Typing_g08_c05              Typing              Typing
# 447            v_StillRings_g11_c04          StillRings        MoppingFloor
# 448        v_WalkingWithDog_g02_c04      WalkingWithDog      WalkingWithDog
# 449                 v_Punch_g10_c06               Punch               Punch
# 450           v_CliffDiving_g22_c04         CliffDiving             Surfing
# 451            v_Basketball_g23_c01          Basketball          Basketball
# 452                v_Skijet_g25_c01              Skijet              Skijet
# 453        v_ApplyEyeMakeup_g23_c05      ApplyEyeMakeup      ApplyEyeMakeup
# 454           v_JumpingJack_g12_c01         JumpingJack         JumpingJack
# 455      v_HandstandPushups_g11_c06    HandstandPushups    HandstandPushups
# 456      v_BodyWeightSquats_g14_c04    BodyWeightSquats    BodyWeightSquats
# 457        v_WritingOnBoard_g13_c02      WritingOnBoard        BabyCrawling
# 458                v_Skiing_g13_c02              Skiing              Skiing
# 459        v_SoccerJuggling_g11_c06      SoccerJuggling      SoccerJuggling
# 460               v_Rafting_g11_c01             Rafting             Rafting
# 461            v_BenchPress_g03_c04          BenchPress            Drumming
# 462               v_Rafting_g22_c04             Rafting             Rafting
# 463          v_PizzaTossing_g22_c01        PizzaTossing        PizzaTossing
# 464                v_Skiing_g18_c01              Skiing              Skiing
# 465            v_BenchPress_g17_c03          BenchPress          BenchPress
# 466     v_BoxingPunchingBag_g07_c03   BoxingPunchingBag   BoxingPunchingBag
# 467         v_ApplyLipstick_g14_c04       ApplyLipstick       ApplyLipstick
# 468        v_BoxingSpeedBag_g15_c01      BoxingSpeedBag         BlowDryHair
# 469               v_Surfing_g08_c06             Surfing             Surfing
# 470           v_ThrowDiscus_g01_c03         ThrowDiscus         ThrowDiscus
# 471              v_JumpRope_g09_c02            JumpRope            JumpRope
# 472           v_PommelHorse_g13_c04         PommelHorse          StillRings
# 473             v_SalsaSpin_g02_c02           SalsaSpin              Lunges
# 474       v_FloorGymnastics_g16_c02     FloorGymnastics     FloorGymnastics
# 475         v_SumoWrestling_g05_c02       SumoWrestling       SumoWrestling
# 476    v_RockClimbingIndoor_g16_c03  RockClimbingIndoor           Hammering
# 477      v_BodyWeightSquats_g16_c01    BodyWeightSquats    BodyWeightSquats
# 478              v_HulaHoop_g09_c01            HulaHoop            HulaHoop
# 479           v_BalanceBeam_g13_c03         BalanceBeam         BalanceBeam
# 480             v_HorseRace_g24_c02           HorseRace           HorseRace
# 481                v_Biking_g20_c04              Biking              Biking
# 482        v_BoxingSpeedBag_g11_c06      BoxingSpeedBag      BoxingSpeedBag
# 483         v_SkateBoarding_g25_c02       SkateBoarding       SkateBoarding
# 484      v_CuttingInKitchen_g05_c01    CuttingInKitchen    CuttingInKitchen
# 485         v_PlayingGuitar_g20_c03       PlayingGuitar       PlayingGuitar
# 486            v_BenchPress_g13_c06          BenchPress          BenchPress
# 487           v_HorseRiding_g14_c04         HorseRiding              Lunges
# 488                v_Typing_g07_c01              Typing              Typing
# 489     v_TrampolineJumping_g03_c02   TrampolineJumping   TrampolineJumping
# 490        v_WritingOnBoard_g20_c06      WritingOnBoard      WritingOnBoard
# 491               v_PushUps_g21_c02             PushUps             PushUps
# 492         v_SkateBoarding_g12_c06       SkateBoarding       SkateBoarding
# 493           v_PommelHorse_g05_c04         PommelHorse        BabyCrawling
# 494           v_TennisSwing_g22_c04         TennisSwing         TennisSwing
# 495           v_PlayingDhol_g01_c06         PlayingDhol         PlayingDhol
# 496       v_TableTennisShot_g23_c02     TableTennisShot     TableTennisShot
# 497               v_PushUps_g10_c03             PushUps             PushUps
# 498               v_Fencing_g06_c04             Fencing             Fencing
# 499              v_HighJump_g22_c04            HighJump            JumpRope
# ...                             ...                 ...                 ...
# 12820              v_Biking_g09_c03              Biking              Lunges
# 12821              v_Diving_g06_c07              Diving              Diving
# 12822         v_PommelHorse_g02_c03         PommelHorse         PommelHorse
# 12823    v_BodyWeightSquats_g24_c03    BodyWeightSquats    BodyWeightSquats
# 12824        v_ShavingBeard_g20_c02        ShavingBeard        ShavingBeard
# 12825           v_SkyDiving_g04_c04           SkyDiving           SkyDiving
# 12826           v_HorseRace_g15_c01           HorseRace           HorseRace
# 12827         v_HammerThrow_g08_c01         HammerThrow         HammerThrow
# 12828         v_WallPushups_g06_c07         WallPushups         WallPushups
# 12829             v_PullUps_g23_c03             PullUps              Diving
# 12830              v_TaiChi_g22_c04              TaiChi              TaiChi
# 12831             v_Archery_g07_c01             Archery             Archery
# 12832           v_Billiards_g25_c03           Billiards           Billiards
# 12833         v_BalanceBeam_g11_c03         BalanceBeam         BalanceBeam
# 12834      v_BoxingSpeedBag_g09_c01      BoxingSpeedBag      BoxingSpeedBag
# 12835          v_IceDancing_g19_c07          IceDancing          IceDancing
# 12836             v_PushUps_g21_c04             PushUps             PushUps
# 12837        v_BreastStroke_g14_c01        BreastStroke        BreastStroke
# 12838          v_IceDancing_g11_c01          IceDancing          IceDancing
# 12839       v_ApplyLipstick_g24_c01       ApplyLipstick       ApplyLipstick
# 12840             v_PullUps_g12_c01             PullUps             PullUps
# 12841             v_Surfing_g15_c02             Surfing             Surfing
# 12842            v_Knitting_g15_c05            Knitting            Knitting
# 12843         v_HeadMassage_g25_c05         HeadMassage         HeadMassage
# 12844             v_Archery_g10_c05             Archery             Archery
# 12845         v_TennisSwing_g06_c06         TennisSwing         TennisSwing
# 12846               v_Swing_g24_c04               Swing               Swing
# 12847       v_PlayingGuitar_g13_c06       PlayingGuitar       PlayingGuitar
# 12848        v_FrisbeeCatch_g09_c05        FrisbeeCatch        FrisbeeCatch
# 12849       v_SkateBoarding_g07_c02       SkateBoarding       SkateBoarding
# 12850           v_PoleVault_g08_c04           PoleVault           PoleVault
# 12851           v_SalsaSpin_g22_c01           SalsaSpin           SalsaSpin
# 12852            v_LongJump_g18_c03            LongJump            LongJump
# 12853         v_ThrowDiscus_g09_c05         ThrowDiscus         ThrowDiscus
# 12854         v_PommelHorse_g23_c03         PommelHorse         PommelHorse
# 12855        v_RopeClimbing_g14_c01        RopeClimbing        RopeClimbing
# 12856   v_VolleyballSpiking_g08_c04   VolleyballSpiking   VolleyballSpiking
# 12857             v_Surfing_g15_c04             Surfing             Surfing
# 12858            v_Knitting_g04_c01            Knitting            Knitting
# 12859          v_Basketball_g20_c04          Basketball         HorseRiding
# 12860          v_Basketball_g25_c07          Basketball          Basketball
# 12861         v_CliffDiving_g15_c03         CliffDiving         CliffDiving
# 12862          v_PlayingDaf_g10_c07          PlayingDaf          PlayingDaf
# 12863              v_Lunges_g23_c01              Lunges              Lunges
# 12864           v_Nunchucks_g10_c04           Nunchucks           Nunchucks
# 12865  v_FieldHockeyPenalty_g11_c04  FieldHockeyPenalty  FieldHockeyPenalty
# 12866      v_BoxingSpeedBag_g09_c03      BoxingSpeedBag      BoxingSpeedBag
# 12867            v_Knitting_g08_c03            Knitting        PlayingTabla
# 12868        v_FrisbeeCatch_g25_c03        FrisbeeCatch        FrisbeeCatch
# 12869        v_RopeClimbing_g17_c01        RopeClimbing         HeadMassage
# 12870         v_HorseRiding_g25_c05         HorseRiding         HorseRiding
# 12871             v_Shotput_g03_c03             Shotput             Shotput
# 12872    v_HandstandPushups_g18_c05    HandstandPushups    HandstandPushups
# 12873        v_CleanAndJerk_g19_c02        CleanAndJerk        CleanAndJerk
# 12874             v_PullUps_g25_c04             PullUps             PullUps
# 12875          v_FrontCrawl_g07_c05          FrontCrawl          FrontCrawl
# 12876        v_MoppingFloor_g01_c02        MoppingFloor        MoppingFloor
# 12877       v_BaseballPitch_g04_c05       BaseballPitch       BaseballPitch
# 12878           v_HorseRace_g18_c03           HorseRace           HorseRace
# 12879        v_JavelinThrow_g04_c02        JavelinThrow        JavelinThrow
# 12880              v_TaiChi_g08_c01              TaiChi              TaiChi
# 12881            v_Kayaking_g19_c03            Kayaking            Kayaking
# 12882           v_SalsaSpin_g05_c06           SalsaSpin           SalsaSpin
# 12883     v_TableTennisShot_g15_c03     TableTennisShot     TableTennisShot
# 12884         v_HorseRiding_g06_c02         HorseRiding         HorseRiding
# 12885          v_FrontCrawl_g20_c06          FrontCrawl          FrontCrawl
# 12886    v_CuttingInKitchen_g17_c01    CuttingInKitchen    CuttingInKitchen
# 12887           v_PoleVault_g22_c01           PoleVault           PoleVault
# 12888        v_PlayingCello_g25_c02        PlayingCello        PlayingCello
# 12889   v_VolleyballSpiking_g19_c04   VolleyballSpiking   VolleyballSpiking
# 12890      v_WalkingWithDog_g12_c01      WalkingWithDog        BabyCrawling
# 12891           v_SalsaSpin_g11_c06           SalsaSpin           SalsaSpin
# 12892         v_PlayingDhol_g25_c03         PlayingDhol         PlayingDhol
# 12893       v_JugglingBalls_g03_c03       JugglingBalls       JugglingBalls
# 12894              v_Skijet_g01_c01              Skijet              Skijet
# 12895         v_HammerThrow_g19_c04         HammerThrow         HammerThrow
# 12896         v_CliffDiving_g20_c01         CliffDiving         CliffDiving
# 12897         v_CricketShot_g05_c06         CricketShot         CricketShot
# 12898          v_UnevenBars_g25_c01          UnevenBars          UnevenBars
# 12899     v_FloorGymnastics_g07_c03     FloorGymnastics      BasketballDunk
# 12900   v_TrampolineJumping_g07_c01   TrampolineJumping         HorseRiding
# 12901   v_VolleyballSpiking_g10_c01   VolleyballSpiking   VolleyballSpiking
# 12902          v_StillRings_g09_c01          StillRings          StillRings
# 12903   v_TrampolineJumping_g23_c04   TrampolineJumping   TrampolineJumping
# 12904             v_PullUps_g23_c02             PullUps             PullUps
# 12905        v_PlayingPiano_g03_c03        PlayingPiano        PlayingPiano
# 12906          v_BenchPress_g15_c02          BenchPress          BenchPress
# 12907        v_RopeClimbing_g01_c03        RopeClimbing        RopeClimbing
# 12908             v_Fencing_g15_c04             Fencing             Fencing
# 12909        v_CleanAndJerk_g06_c03        CleanAndJerk        CleanAndJerk
# 12910         v_ThrowDiscus_g07_c05         ThrowDiscus         ThrowDiscus
# 12911      v_BasketballDunk_g17_c06      BasketballDunk      BasketballDunk
# 12912         v_PlayingDhol_g01_c04         PlayingDhol         PlayingDhol
# 12913          v_PlayingDaf_g19_c01          PlayingDaf          PlayingDaf
# 12914         v_CliffDiving_g06_c06         CliffDiving         CliffDiving
# 12915             v_Shotput_g10_c05             Shotput             Shotput
# 12916       v_SkateBoarding_g06_c01       SkateBoarding             Rafting
# 12917         v_PlayingDhol_g12_c01         PlayingDhol         PlayingDhol
# 12918          v_Basketball_g16_c05          Basketball          Basketball
# 12919      v_MilitaryParade_g02_c03      MilitaryParade      MilitaryParade
# 12920  v_RockClimbingIndoor_g03_c07  RockClimbingIndoor  RockClimbingIndoor
# 12921      v_CricketBowling_g12_c02      CricketBowling        FrisbeeCatch
# 12922                v_YoYo_g13_c04                YoYo                YoYo
# 12923             v_Surfing_g17_c06             Surfing             Surfing
# 12924   v_TrampolineJumping_g23_c03   TrampolineJumping   TrampolineJumping
# 12925        v_FrisbeeCatch_g04_c04        FrisbeeCatch        FrisbeeCatch
# 12926       v_JugglingBalls_g12_c05       JugglingBalls       JugglingBalls
# 12927          v_BenchPress_g09_c07          BenchPress          BenchPress
# 12928        v_BandMarching_g11_c04        BandMarching               Swing
# 12929          v_PlayingDaf_g07_c02          PlayingDaf          PlayingDaf
# 12930            v_JumpRope_g18_c07            JumpRope            JumpRope
# 12931      v_SoccerJuggling_g25_c01      SoccerJuggling      SoccerJuggling
# 12932      v_BoxingSpeedBag_g17_c06      BoxingSpeedBag      BoxingSpeedBag
# 12933         v_PlayingDhol_g17_c03         PlayingDhol         PlayingDhol
# 12934           v_HorseRace_g14_c02           HorseRace           HorseRace
# 12935        v_BandMarching_g08_c02        BandMarching        BandMarching
# 12936       v_ApplyLipstick_g16_c05       ApplyLipstick       ApplyLipstick
# 12937           v_SkyDiving_g19_c01           SkyDiving           SkyDiving
# 12938        v_PlayingFlute_g24_c05        PlayingFlute         PlayingDhol
# 12939         v_BalanceBeam_g16_c02         BalanceBeam         BalanceBeam
# 12940              v_TaiChi_g13_c02              TaiChi              TaiChi
# 12941         v_PommelHorse_g04_c03         PommelHorse         PommelHorse
# 12942       v_ApplyLipstick_g05_c05       ApplyLipstick       ApplyLipstick
# 12943        v_PlayingFlute_g25_c05        PlayingFlute        PlayingFlute
# 12944             v_Haircut_g11_c04             Haircut             Haircut
# 12945         v_PommelHorse_g11_c01         PommelHorse         PommelHorse
# 12946       v_PlayingGuitar_g17_c04       PlayingGuitar       PlayingGuitar
# 12947      v_WalkingWithDog_g14_c01      WalkingWithDog            JumpRope
# 12948        v_PlayingSitar_g08_c07        PlayingSitar        PlayingSitar
# ...
# 13110            v_Kayaking_g09_c05            Kayaking            Kayaking
# 13111         v_CricketShot_g12_c05         CricketShot         CricketShot
# 13112        v_CleanAndJerk_g12_c04        CleanAndJerk        CleanAndJerk
# 13113           v_SkyDiving_g06_c03           SkyDiving           SkyDiving
# 13114        v_ParallelBars_g02_c03        ParallelBars        ParallelBars
# 13115          v_IceDancing_g13_c02          IceDancing          IceDancing
# 13116           v_PoleVault_g03_c03           PoleVault           PoleVault
# 13117         v_TennisSwing_g08_c06         TennisSwing         TennisSwing
# 13118             v_Rafting_g08_c05             Rafting             Rafting
# 13119      v_ApplyEyeMakeup_g04_c03      ApplyEyeMakeup      ApplyEyeMakeup
# 13120      v_MilitaryParade_g11_c02      MilitaryParade      MilitaryParade
# 13121           v_PoleVault_g18_c02           PoleVault           PoleVault
# 13122       v_PlayingGuitar_g12_c01       PlayingGuitar       PlayingGuitar
# 13123      v_BlowingCandles_g10_c01      BlowingCandles      BlowingCandles
# 13124       v_PlayingGuitar_g08_c06       PlayingGuitar       PlayingGuitar
# 13125   v_BoxingPunchingBag_g08_c06   BoxingPunchingBag   BoxingPunchingBag
# 13126          v_PlayingDaf_g05_c03          PlayingDaf          PlayingDaf
# 13127         v_TennisSwing_g15_c05         TennisSwing         TennisSwing
# 13128            v_Kayaking_g09_c02            Kayaking            Kayaking
# 13129   v_TrampolineJumping_g20_c04   TrampolineJumping   TrampolineJumping
# 13130   v_BoxingPunchingBag_g16_c05   BoxingPunchingBag   BoxingPunchingBag
# 13131       v_SumoWrestling_g24_c04       SumoWrestling       SumoWrestling
# 13132       v_BrushingTeeth_g19_c02       BrushingTeeth       BrushingTeeth
# 13133             v_Surfing_g20_c03             Surfing             Surfing
# 13134       v_SumoWrestling_g08_c06       SumoWrestling       SumoWrestling
# 13135        v_ShavingBeard_g16_c01        ShavingBeard        ShavingBeard
# 13136        v_BandMarching_g25_c02        BandMarching        BandMarching
# 13137             v_Shotput_g08_c02             Shotput             Shotput
# 13138    v_HandstandWalking_g12_c03    HandstandWalking    HandstandWalking
# 13139        v_FrisbeeCatch_g16_c05        FrisbeeCatch        FrisbeeCatch
# 13140              v_Mixing_g25_c01              Mixing           Hammering
# 13141   v_BoxingPunchingBag_g20_c02   BoxingPunchingBag   BoxingPunchingBag
# 13142         v_HammerThrow_g02_c05         HammerThrow         HammerThrow
# 13143        v_PizzaTossing_g04_c05        PizzaTossing        PizzaTossing
# 13144        v_BandMarching_g05_c04        BandMarching        BandMarching
# 13145              v_Typing_g14_c05              Typing              Typing
# 13146           v_SkyDiving_g02_c02           SkyDiving           SkyDiving
# 13147               v_Punch_g25_c07               Punch               Punch
# 13148        v_CleanAndJerk_g20_c04        CleanAndJerk        CleanAndJerk
# 13149         v_WallPushups_g11_c04         WallPushups         WallPushups
# 13150     v_FloorGymnastics_g16_c03     FloorGymnastics     FloorGymnastics
# 13151               v_Swing_g21_c03               Swing               Swing
# 13152         v_CliffDiving_g22_c02         CliffDiving         CliffDiving
# 13153    v_BodyWeightSquats_g10_c05    BodyWeightSquats    BodyWeightSquats
# 13154    v_HandstandWalking_g21_c04    HandstandWalking    HandstandWalking
# 13155        v_FrisbeeCatch_g09_c02        FrisbeeCatch        FrisbeeCatch
# 13156            v_Kayaking_g12_c01            Kayaking             Fencing
# 13157       v_JugglingBalls_g08_c01       JugglingBalls       JugglingBalls
# 13158      v_BoxingSpeedBag_g20_c04      BoxingSpeedBag      BoxingSpeedBag
# 13159        v_JavelinThrow_g05_c03        JavelinThrow        JavelinThrow
# 13160       v_BrushingTeeth_g07_c01       BrushingTeeth      ApplyEyeMakeup
# 13161             v_Surfing_g14_c04             Surfing             Surfing
# 13162     v_TableTennisShot_g24_c03     TableTennisShot     TableTennisShot
# 13163        v_PlayingSitar_g19_c03        PlayingSitar        PlayingSitar
# 13164        v_JavelinThrow_g01_c03        JavelinThrow        JavelinThrow
# 13165              v_Diving_g10_c02              Diving              Diving
# 13166         v_CliffDiving_g23_c05         CliffDiving         CliffDiving
# 13167          v_BenchPress_g21_c03          BenchPress    HandstandWalking
# 13168           v_Hammering_g11_c03           Hammering           Hammering
# 13169       v_BaseballPitch_g01_c05       BaseballPitch          Basketball
# 13170      v_WalkingWithDog_g14_c03      WalkingWithDog      WalkingWithDog
# 13171          v_FrontCrawl_g20_c04          FrontCrawl          FrontCrawl
# 13172         v_CliffDiving_g05_c02         CliffDiving         CliffDiving
# 13173         v_BlowDryHair_g19_c04         BlowDryHair         BlowDryHair
# 13174             v_Haircut_g08_c06             Haircut             Haircut
# 13175             v_Rafting_g03_c02             Rafting             Rafting
# 13176               v_Punch_g12_c05               Punch               Punch
# 13177   v_VolleyballSpiking_g24_c02   VolleyballSpiking   VolleyballSpiking
# 13178             v_Surfing_g07_c02             Surfing             Surfing
# 13179      v_SoccerJuggling_g01_c01      SoccerJuggling      SoccerJuggling
# 13180              v_Skiing_g04_c07              Skiing              Skiing
# 13181                v_YoYo_g03_c03                YoYo                YoYo
# 13182        v_ParallelBars_g16_c04        ParallelBars        ParallelBars
# 13183            v_Kayaking_g16_c03            Kayaking            Kayaking
# 13184      v_BasketballDunk_g05_c04      BasketballDunk      BasketballDunk
# 13185        v_PlayingCello_g16_c02        PlayingCello        PlayingCello
# 13186          v_BenchPress_g04_c05          BenchPress         HeadMassage
# 13187       v_SumoWrestling_g07_c04       SumoWrestling       SumoWrestling
# 13188         v_BalanceBeam_g17_c02         BalanceBeam         BalanceBeam
# 13189    v_HandstandWalking_g13_c03    HandstandWalking    HandstandWalking
# 13190         v_WallPushups_g16_c07         WallPushups         WallPushups
# 13191       v_BrushingTeeth_g05_c01       BrushingTeeth       BrushingTeeth
# 13192           v_SkyDiving_g18_c05           SkyDiving           SkyDiving
# 13193   v_TrampolineJumping_g12_c03   TrampolineJumping   TrampolineJumping
# 13194        v_BreastStroke_g06_c01        BreastStroke        BreastStroke
# 13195         v_HammerThrow_g03_c04         HammerThrow         HammerThrow
# 13196          v_Basketball_g23_c03          Basketball          Basketball
# 13197        v_BabyCrawling_g13_c05        BabyCrawling        BabyCrawling
# 13198            v_Kayaking_g10_c02            Kayaking          FrontCrawl
# 13199              v_Rowing_g10_c01              Rowing              Rowing
# 13200         v_JumpingJack_g05_c06         JumpingJack         JumpingJack
# 13201            v_HulaHoop_g02_c01            HulaHoop            HulaHoop
# 13202         v_HeadMassage_g14_c02         HeadMassage         HeadMassage
# 13203    v_BodyWeightSquats_g18_c04    BodyWeightSquats    BodyWeightSquats
# 13204         v_CricketShot_g06_c02         CricketShot         CricketShot
# 13205         v_PommelHorse_g02_c04         PommelHorse         PommelHorse
# 13206              v_Skiing_g05_c01              Skiing              Skiing
# 13207      v_BasketballDunk_g08_c05      BasketballDunk      BasketballDunk
# 13208       v_SumoWrestling_g17_c02       SumoWrestling       SumoWrestling
# 13209            v_HighJump_g16_c02            HighJump            HighJump
# 13210      v_WritingOnBoard_g05_c03      WritingOnBoard      WritingOnBoard
# 13211       v_JugglingBalls_g01_c01       JugglingBalls       JugglingBalls
# 13212           v_PoleVault_g23_c02           PoleVault             Fencing
# 13213          v_FrontCrawl_g05_c04          FrontCrawl          FrontCrawl
# 13214              v_Biking_g15_c03              Biking              Biking
# 13215            v_LongJump_g05_c02            LongJump            LongJump
# 13216              v_Skiing_g20_c07              Skiing             Rafting
# 13217           v_Nunchucks_g20_c02           Nunchucks           Nunchucks
# 13218       v_SkateBoarding_g23_c02       SkateBoarding       SkateBoarding
# 13219      v_CricketBowling_g18_c04      CricketBowling      CricketBowling
# 13220          v_BenchPress_g08_c06          BenchPress          BenchPress
# 13221             v_Archery_g05_c03             Archery             Archery
# 13222     v_TableTennisShot_g14_c02     TableTennisShot     TableTennisShot
# 13223             v_Bowling_g25_c05             Bowling             Bowling
# 13224          v_UnevenBars_g24_c03          UnevenBars          StillRings
# 13225         v_HeadMassage_g17_c06         HeadMassage         HeadMassage
# 13226        v_PlayingTabla_g23_c03        PlayingTabla        PlayingTabla
# 13227       v_SumoWrestling_g04_c01       SumoWrestling       SumoWrestling
# 13228             v_Archery_g12_c03             Archery             Archery
# 13229      v_MilitaryParade_g14_c05      MilitaryParade      MilitaryParade
# 13230           v_SkyDiving_g07_c02           SkyDiving          FrontCrawl
# 13231          v_PlayingDaf_g10_c03          PlayingDaf          PlayingDaf
# 13232                v_YoYo_g01_c02                YoYo                YoYo
# 13233       v_PlayingGuitar_g05_c01       PlayingGuitar       PlayingGuitar
# 13234              v_Lunges_g19_c01              Lunges              Lunges
# 13235             v_Haircut_g05_c03             Haircut      BlowingCandles
# 13236   v_VolleyballSpiking_g14_c04   VolleyballSpiking   VolleyballSpiking
# 13237         v_CliffDiving_g22_c06         CliffDiving         CliffDiving
# 13238         v_ThrowDiscus_g02_c03         ThrowDiscus             Shotput
# 13239           v_SkyDiving_g21_c01           SkyDiving           SkyDiving
# 13240        v_ShavingBeard_g13_c01        ShavingBeard      ApplyEyeMakeup
# 13241         v_ThrowDiscus_g01_c01         ThrowDiscus         ThrowDiscus
# 13242          v_Basketball_g06_c04          Basketball      BlowingCandles
# 13243      v_ApplyEyeMakeup_g25_c07      ApplyEyeMakeup      ApplyEyeMakeup
# 13244              v_Skiing_g18_c03              Skiing              Skiing
# 13245      v_BlowingCandles_g04_c02      BlowingCandles         HeadMassage
# 13246         v_HeadMassage_g23_c06         HeadMassage         HeadMassage
# 13247              v_TaiChi_g01_c02              TaiChi              TaiChi
# 13248          v_FrontCrawl_g04_c06          FrontCrawl          FrontCrawl
# 13249           v_Nunchucks_g05_c04           Nunchucks           Nunchucks
# 13250       v_SkateBoarding_g12_c02       SkateBoarding          FrontCrawl
# 13251        v_PlayingPiano_g12_c04        PlayingPiano        PlayingPiano
# 13252      v_WalkingWithDog_g25_c02      WalkingWithDog      WalkingWithDog
# 13253       v_PlayingGuitar_g10_c06       PlayingGuitar       PlayingGuitar
# 13254           v_Hammering_g19_c01           Hammering           Hammering
# 13255            v_JumpRope_g20_c05            JumpRope            JumpRope
# 13256         v_CricketShot_g21_c04         CricketShot         CricketShot
# 13257           v_Hammering_g03_c01           Hammering           Hammering
# 13258           v_Billiards_g14_c04           Billiards           Billiards
# 13259    v_CuttingInKitchen_g10_c04    CuttingInKitchen              Mixing
# 13260      v_ApplyEyeMakeup_g09_c06      ApplyEyeMakeup      ApplyEyeMakeup
# 13261        v_BandMarching_g02_c05        BandMarching        BandMarching
# 13262      v_BoxingSpeedBag_g20_c05      BoxingSpeedBag      BoxingSpeedBag
# 13263      v_MilitaryParade_g17_c02      MilitaryParade      MilitaryParade
# 13264             v_Bowling_g06_c01             Bowling             Bowling
# 13265     v_FloorGymnastics_g12_c01     FloorGymnastics     FloorGymnastics
# 13266              v_Typing_g02_c05              Typing              Typing
# 13267          v_PlayingDaf_g20_c01          PlayingDaf          PlayingDaf
# 13268    v_HandstandWalking_g01_c04    HandstandWalking    HandstandWalking
# 13269        v_BandMarching_g09_c02        BandMarching        BandMarching
# 13270      v_WalkingWithDog_g05_c04      WalkingWithDog      WalkingWithDog
# 13271          v_Basketball_g09_c03          Basketball          Basketball
# 13272         v_HorseRiding_g25_c04         HorseRiding         HorseRiding
# 13273         v_CliffDiving_g25_c04         CliffDiving         CliffDiving
# 13274          v_StillRings_g11_c01          StillRings          StillRings
# 13275    v_BodyWeightSquats_g05_c01    BodyWeightSquats          Basketball
# 13276              v_Rowing_g07_c03              Rowing              Rowing
# 13277             v_Surfing_g04_c01             Surfing             Surfing
# 13278             v_Fencing_g25_c04             Fencing             Fencing
# 13279             v_Surfing_g15_c03             Surfing             Surfing
# 13280              v_Rowing_g14_c05              Rowing              Rowing
# 13281           v_Hammering_g17_c01           Hammering           Hammering
# 13282           v_Billiards_g02_c07           Billiards           Billiards
# 13283              v_Skiing_g11_c04              Skiing              Skiing
# 13284      v_SoccerJuggling_g19_c06      SoccerJuggling      SoccerJuggling
# 13285           v_Nunchucks_g22_c03           Nunchucks           Nunchucks
# 13286         v_BalanceBeam_g15_c02         BalanceBeam         BalanceBeam
# 13287      v_MilitaryParade_g03_c01      MilitaryParade      MilitaryParade
# 13288  v_FieldHockeyPenalty_g23_c04  FieldHockeyPenalty  FieldHockeyPenalty
# 13289             v_Archery_g18_c02             Archery             Archery
# 13290             v_Rafting_g08_c01             Rafting             Rafting
# 13291         v_HeadMassage_g16_c04         HeadMassage         HeadMassage
# 13292         v_PlayingDhol_g05_c06         PlayingDhol         PlayingDhol
# 13293           v_Nunchucks_g16_c02           Nunchucks           GolfSwing
# 13294   v_VolleyballSpiking_g09_c06   VolleyballSpiking   VolleyballSpiking
# 13295   v_BoxingPunchingBag_g03_c03   BoxingPunchingBag   BoxingPunchingBag
# 13296         v_PlayingDhol_g25_c05         PlayingDhol         PlayingDhol
# 13297       v_SoccerPenalty_g06_c06       SoccerPenalty       SoccerPenalty
# 13298       v_BrushingTeeth_g03_c03       BrushingTeeth       BrushingTeeth
# 13299    v_HandstandPushups_g13_c01    HandstandPushups    HandstandPushups
# 13300           v_SkyDiving_g19_c02           SkyDiving           SkyDiving
# 13301          v_BenchPress_g12_c01          BenchPress          BenchPress
# 13302            v_Kayaking_g16_c05            Kayaking          FrontCrawl
# 13303           v_Nunchucks_g25_c04           Nunchucks           Nunchucks
# 13304    v_BodyWeightSquats_g01_c02    BodyWeightSquats    BodyWeightSquats
# 13305            v_HulaHoop_g03_c03            HulaHoop            HulaHoop
# 13306             v_Bowling_g16_c02             Bowling             Bowling
# 13307             v_Bowling_g09_c06             Bowling        BandMarching
# 13308        v_PlayingPiano_g15_c03        PlayingPiano        PlayingPiano
# 13309             v_Shotput_g20_c03             Shotput             Shotput
# 13310       v_PlayingGuitar_g23_c02       PlayingGuitar       PlayingGuitar
# 13311         v_BlowDryHair_g07_c01         BlowDryHair         BlowDryHair
# 13312          v_StillRings_g10_c03          StillRings          StillRings
# 13313   v_BoxingPunchingBag_g08_c05   BoxingPunchingBag   BoxingPunchingBag
# 13314            v_JumpRope_g15_c01            JumpRope            JumpRope
# 13315       v_PlayingGuitar_g20_c04       PlayingGuitar       PlayingGuitar
# 13316        v_JavelinThrow_g16_c05        JavelinThrow       SumoWrestling
# 13317        v_PlayingSitar_g23_c05        PlayingSitar        PlayingSitar
# 13318      v_BasketballDunk_g19_c03      BasketballDunk      BasketballDunk
# 13319            v_Drumming_g03_c04            Drumming            Drumming
#
# [13320 rows x 3 columns]

# %% [markdown]
# ### Videos with wrong predictions

# %%
a = df['filename'][df['y_pred']!=df['y']].tolist()
b = df['y'][df['y_pred']!=df['y']].tolist()
c = df['y_pred'][df['y_pred']!=df['y']].tolist()

df_mistakes = pd.DataFrame(data={'filename':a, 'y':b, 'y_pred':c})
df_mistakes.to_pickle('./wrong_predictions.pkl')

# %%
df_mistakes
# Out:
#                           filename                   y              y_pred
# 0           v_PlayingSitar_g09_c06        PlayingSitar   VolleyballSpiking
# 1           v_FrisbeeCatch_g17_c04        FrisbeeCatch            LongJump
# 2           v_PizzaTossing_g12_c03        PizzaTossing         HorseRiding
# 3     v_FieldHockeyPenalty_g13_c02  FieldHockeyPenalty         BlowDryHair
# 4                 v_Skiing_g17_c02              Skiing             Surfing
# 5          v_SkateBoarding_g24_c02       SkateBoarding        BabyCrawling
# 6               v_Knitting_g10_c01            Knitting         HorseRiding
# 7         v_CricketBowling_g19_c06      CricketBowling        MoppingFloor
# 8          v_BaseballPitch_g19_c01       BaseballPitch         ThrowDiscus
# 9                v_PushUps_g20_c03             PushUps              Lunges
# 10                v_Rowing_g15_c04              Rowing      MilitaryParade
# 11            v_StillRings_g10_c02          StillRings      BlowingCandles
# 12         v_BrushingTeeth_g12_c06       BrushingTeeth      ApplyEyeMakeup
# 13                v_Biking_g04_c04              Biking               Swing
# 14          v_RopeClimbing_g05_c05        RopeClimbing            LongJump
# 15          v_FrisbeeCatch_g08_c01        FrisbeeCatch              Lunges
# 16           v_PlayingDhol_g05_c01         PlayingDhol              Diving
# 17        v_CricketBowling_g09_c03      CricketBowling      BasketballDunk
# 18          v_FrisbeeCatch_g08_c03        FrisbeeCatch            Kayaking
# 19         v_JugglingBalls_g07_c02       JugglingBalls   BoxingPunchingBag
# 20                v_Biking_g17_c02              Biking           Hammering
# 21                 v_Swing_g19_c03               Swing        BandMarching
# 22            v_IceDancing_g04_c04          IceDancing                YoYo
# 23                v_TaiChi_g04_c03              TaiChi        BabyCrawling
# 24          v_BabyCrawling_g22_c02        BabyCrawling          PlayingDaf
# 25        v_SoccerJuggling_g22_c04      SoccerJuggling        MoppingFloor
# 26          v_ShavingBeard_g03_c04        ShavingBeard      ApplyEyeMakeup
# 27        v_BoxingSpeedBag_g10_c04      BoxingSpeedBag              Diving
# 28             v_Nunchucks_g19_c02           Nunchucks      WalkingWithDog
# 29               v_Haircut_g01_c01             Haircut        BabyCrawling
# 30         v_SkateBoarding_g12_c01       SkateBoarding         CliffDiving
# 31          v_ParallelBars_g07_c05        ParallelBars        PizzaTossing
# 32          v_PlayingTabla_g24_c04        PlayingTabla        PlayingCello
# 33                v_Biking_g06_c04              Biking      MilitaryParade
# 34           v_PommelHorse_g18_c04         PommelHorse        PlayingFlute
# 35            v_FrontCrawl_g17_c01          FrontCrawl             Shotput
# 36                  v_YoYo_g07_c01                YoYo        PlayingFlute
# 37               v_Archery_g25_c07             Archery   TrampolineJumping
# 38              v_HighJump_g14_c02            HighJump         HorseRiding
# 39         v_JugglingBalls_g07_c05       JugglingBalls      ApplyEyeMakeup
# 40    v_FieldHockeyPenalty_g25_c01  FieldHockeyPenalty          Basketball
# 41           v_TennisSwing_g14_c02         TennisSwing    HandstandWalking
# 42           v_JumpingJack_g21_c01         JumpingJack            JumpRope
# 43           v_HorseRiding_g04_c01         HorseRiding            Kayaking
# 44               v_Bowling_g04_c04             Bowling         CliffDiving
# 45         v_SumoWrestling_g05_c01       SumoWrestling               Punch
# 46         v_BaseballPitch_g01_c03       BaseballPitch         JumpingJack
# 47                v_Rowing_g04_c05              Rowing              Skijet
# 48           v_CricketShot_g04_c02         CricketShot      CricketBowling
# 49        v_BlowingCandles_g22_c04      BlowingCandles             Shotput
# 50           v_BalanceBeam_g19_c02         BalanceBeam        MoppingFloor
# 51               v_Rafting_g06_c02             Rafting               Swing
# 52         v_JugglingBalls_g07_c04       JugglingBalls      ApplyEyeMakeup
# 53              v_LongJump_g11_c01            LongJump          FrontCrawl
# 54        v_ApplyEyeMakeup_g13_c02      ApplyEyeMakeup         PlayingDhol
# 55              v_HighJump_g04_c01            HighJump        FrisbeeCatch
# 56       v_FloorGymnastics_g22_c03     FloorGymnastics            Knitting
# 57        v_ApplyEyeMakeup_g07_c03      ApplyEyeMakeup          Basketball
# 58         v_SkateBoarding_g10_c07       SkateBoarding         CricketShot
# 59             v_PoleVault_g06_c04           PoleVault              Skijet
# 60             v_PoleVault_g17_c06           PoleVault         HammerThrow
# 61           v_PlayingDhol_g11_c01         PlayingDhol      ApplyEyeMakeup
# 62      v_CuttingInKitchen_g12_c02    CuttingInKitchen        BabyCrawling
# 63                v_Lunges_g15_c02              Lunges        MoppingFloor
# 64                v_Skiing_g06_c01              Skiing                YoYo
# 65                v_Skijet_g23_c01              Skijet        FrisbeeCatch
# 66            v_StillRings_g11_c04          StillRings        MoppingFloor
# 67           v_CliffDiving_g22_c04         CliffDiving             Surfing
# 68        v_WritingOnBoard_g13_c02      WritingOnBoard        BabyCrawling
# 69            v_BenchPress_g03_c04          BenchPress            Drumming
# 70        v_BoxingSpeedBag_g15_c01      BoxingSpeedBag         BlowDryHair
# 71           v_PommelHorse_g13_c04         PommelHorse          StillRings
# 72             v_SalsaSpin_g02_c02           SalsaSpin              Lunges
# 73    v_RockClimbingIndoor_g16_c03  RockClimbingIndoor           Hammering
# 74           v_HorseRiding_g14_c04         HorseRiding              Lunges
# 75           v_PommelHorse_g05_c04         PommelHorse        BabyCrawling
# 76              v_HighJump_g22_c04            HighJump            JumpRope
# 77           v_BlowDryHair_g05_c01         BlowDryHair             Haircut
# 78             v_GolfSwing_g21_c03           GolfSwing      SoccerJuggling
# 79               v_Archery_g21_c03             Archery        PlayingSitar
# 80            v_PlayingDaf_g17_c03          PlayingDaf            Kayaking
# 81          v_PlayingSitar_g05_c02        PlayingSitar           Hammering
# 82        v_WritingOnBoard_g09_c05      WritingOnBoard       BrushingTeeth
# 83          v_BandMarching_g05_c03        BandMarching               Punch
# 84          v_RopeClimbing_g15_c04        RopeClimbing            Drumming
# 85            v_UnevenBars_g17_c02          UnevenBars      BlowingCandles
# 86           v_BalanceBeam_g23_c05         BalanceBeam              Mixing
# 87          v_BabyCrawling_g20_c03        BabyCrawling          FrontCrawl
# 88             v_PoleVault_g07_c03           PoleVault           SalsaSpin
# 89               v_Shotput_g25_c03             Shotput          FrontCrawl
# 90     v_TrampolineJumping_g22_c01   TrampolineJumping        MoppingFloor
# 91          v_BandMarching_g11_c01        BandMarching      BasketballDunk
# 92           v_CliffDiving_g01_c05         CliffDiving      WritingOnBoard
# 93               v_Shotput_g23_c01             Shotput     FloorGymnastics
# 94          v_PlayingFlute_g11_c01        PlayingFlute       PlayingViolin
# 95          v_PlayingFlute_g04_c06        PlayingFlute      BoxingSpeedBag
# 96           v_HorseRiding_g08_c02         HorseRiding            HighJump
# 97               v_Haircut_g16_c01             Haircut      WritingOnBoard
# 98     v_VolleyballSpiking_g17_c01   VolleyballSpiking         HorseRiding
# 99           v_HorseRiding_g14_c07         HorseRiding      MilitaryParade
# 100       v_WritingOnBoard_g24_c06      WritingOnBoard     FloorGymnastics
# 101               v_Rowing_g09_c06              Rowing              Diving
# 102                 v_YoYo_g16_c04                YoYo          BenchPress
# 103            v_PoleVault_g21_c04           PoleVault         HammerThrow
# 104         v_BandMarching_g17_c04        BandMarching         HeadMassage
# 105       v_WalkingWithDog_g25_c03      WalkingWithDog          FrontCrawl
# 106         v_ShavingBeard_g11_c03        ShavingBeard      ApplyEyeMakeup
# 107               v_TaiChi_g14_c03              TaiChi             Surfing
# 108              v_Bowling_g17_c02             Bowling        BandMarching
# 109               v_Biking_g16_c03              Biking      MilitaryParade
# 110     v_HandstandWalking_g05_c07    HandstandWalking      CricketBowling
# 111              v_Bowling_g22_c02             Bowling             Shotput
# 112            v_GolfSwing_g20_c03           GolfSwing      SoccerJuggling
# 113            v_SkyDiving_g18_c03           SkyDiving            Kayaking
# 114               v_Rowing_g02_c02              Rowing            LongJump
# 115             v_Drumming_g03_c03            Drumming        BandMarching
# 116         v_JavelinThrow_g12_c01        JavelinThrow            HighJump
# 117          v_TennisSwing_g03_c02         TennisSwing          Basketball
# 118           v_StillRings_g11_c02          StillRings   VolleyballSpiking
# 119      v_FloorGymnastics_g11_c04     FloorGymnastics            Kayaking
# 120                 v_YoYo_g15_c04                YoYo           SalsaSpin
# 121           v_BenchPress_g15_c03          BenchPress              Biking
# 122             v_HighJump_g07_c01            HighJump      WalkingWithDog
# 123        v_SoccerPenalty_g14_c05       SoccerPenalty              TaiChi
# 124              v_Archery_g01_c01             Archery           PoleVault
# 125              v_Bowling_g14_c05             Bowling      ApplyEyeMakeup
# 126              v_PushUps_g16_c02             PushUps      ApplyEyeMakeup
# 127             v_LongJump_g05_c01            LongJump        BandMarching
# 128               v_Biking_g20_c02              Biking         HeadMassage
# 129         v_BandMarching_g19_c03        BandMarching    HandstandWalking
# 130          v_HeadMassage_g15_c02         HeadMassage               Swing
# 131            v_HorseRace_g11_c03           HorseRace    HandstandWalking
# 132          v_BlowDryHair_g01_c01         BlowDryHair   BoxingPunchingBag
# 133       v_BlowingCandles_g04_c03      BlowingCandles         HeadMassage
# 134            v_SalsaSpin_g25_c02           SalsaSpin           GolfSwing
# 135    v_TrampolineJumping_g22_c02   TrampolineJumping        PlayingSitar
# 136                 v_YoYo_g13_c03                YoYo          BenchPress
# 137     v_CuttingInKitchen_g04_c05    CuttingInKitchen         HorseRiding
# 138         v_BandMarching_g10_c03        BandMarching      MilitaryParade
# 139            v_Hammering_g18_c06           Hammering        RopeClimbing
# 140          v_BlowDryHair_g07_c05         BlowDryHair             Bowling
# 141           v_BenchPress_g10_c01          BenchPress          StillRings
# 142            v_HorseRace_g12_c03           HorseRace      WalkingWithDog
# 143        v_SkateBoarding_g06_c02       SkateBoarding             Haircut
# 144              v_Rafting_g15_c02             Rafting              Diving
# 145          v_PlayingDhol_g19_c06         PlayingDhol      ApplyEyeMakeup
# 146         v_FrisbeeCatch_g01_c06        FrisbeeCatch              Rowing
# 147          v_BalanceBeam_g01_c04         BalanceBeam          StillRings
# 148     v_HandstandWalking_g14_c04    HandstandWalking      ApplyEyeMakeup
# 149      v_FloorGymnastics_g17_c02     FloorGymnastics            LongJump
# 150          v_HorseRiding_g12_c07         HorseRiding          FrontCrawl
# 151             v_HighJump_g15_c04            HighJump      SoccerJuggling
# 152     v_HandstandWalking_g04_c02    HandstandWalking      SoccerJuggling
# 153             v_Kayaking_g01_c03            Kayaking             Rafting
# 154         v_PizzaTossing_g19_c03        PizzaTossing        BandMarching
# 155             v_Knitting_g20_c04            Knitting               Swing
# 156          v_CliffDiving_g10_c06         CliffDiving        FrisbeeCatch
# 157               v_Mixing_g11_c02              Mixing  RockClimbingIndoor
# 158              v_Shotput_g22_c02             Shotput       PlayingViolin
# 159            v_PoleVault_g19_c02           PoleVault         HeadMassage
# 160               v_Lunges_g11_c06              Lunges            HulaHoop
# 161    v_VolleyballSpiking_g04_c02   VolleyballSpiking        PizzaTossing
# 162        v_BaseballPitch_g11_c02       BaseballPitch            Kayaking
# 163     v_CuttingInKitchen_g03_c03    CuttingInKitchen              Skiing
# 164               v_Lunges_g19_c06              Lunges               Swing
# 165       v_MilitaryParade_g14_c01      MilitaryParade        BandMarching
# 166          v_WallPushups_g10_c03         WallPushups      ApplyEyeMakeup
# 167        v_SoccerPenalty_g18_c01       SoccerPenalty          FrontCrawl
# 168          v_ThrowDiscus_g17_c05         ThrowDiscus         HammerThrow
# 169              v_Archery_g19_c01             Archery        ShavingBeard
# 170              v_Shotput_g14_c03             Shotput          Basketball
# 171       v_WritingOnBoard_g20_c03      WritingOnBoard           Hammering
# 172          v_HeadMassage_g23_c01         HeadMassage      BoxingSpeedBag
# 173          v_HammerThrow_g24_c01         HammerThrow           Hammering
# 174             v_HighJump_g22_c03            HighJump               Swing
# 175    v_VolleyballSpiking_g02_c04   VolleyballSpiking          Basketball
# 176             v_HighJump_g07_c05            HighJump          FrontCrawl
# 177         v_BandMarching_g22_c02        BandMarching    BodyWeightSquats
# 178   v_RockClimbingIndoor_g02_c02  RockClimbingIndoor            Knitting
# 179               v_Mixing_g02_c04              Mixing            Kayaking
# 180   v_RockClimbingIndoor_g20_c02  RockClimbingIndoor    HandstandPushups
# 181           v_Basketball_g25_c06          Basketball           Hammering
# 182         v_RopeClimbing_g04_c01        RopeClimbing        CleanAndJerk
# 183     v_HandstandPushups_g13_c03    HandstandPushups           Hammering
# 184         v_ParallelBars_g17_c04        ParallelBars        PizzaTossing
# 185          v_HeadMassage_g23_c03         HeadMassage      BlowingCandles
# 186        v_BrushingTeeth_g17_c01       BrushingTeeth              Biking
# 187        v_ApplyLipstick_g02_c01       ApplyLipstick      CricketBowling
# 188       v_CricketBowling_g02_c07      CricketBowling        FrisbeeCatch
# 189    v_TrampolineJumping_g13_c01   TrampolineJumping              Diving
# 190            v_Hammering_g07_c05           Hammering      MilitaryParade
# 191         v_PlayingSitar_g17_c02        PlayingSitar          Basketball
# 192            v_Hammering_g04_c02           Hammering         HeadMassage
# 193              v_Surfing_g11_c02             Surfing      BoxingSpeedBag
# 194          v_HeadMassage_g19_c02         HeadMassage            Knitting
# 195               v_Skiing_g10_c01              Skiing             Surfing
# 196       v_BlowingCandles_g18_c04      BlowingCandles        PlayingFlute
# 197           v_UnevenBars_g02_c02          UnevenBars          StillRings
# 198       v_CricketBowling_g19_c07      CricketBowling              TaiChi
# 199           v_UnevenBars_g18_c01          UnevenBars             Bowling
# 200     v_BodyWeightSquats_g20_c02    BodyWeightSquats         BlowDryHair
# 201            v_PoleVault_g09_c03           PoleVault        JavelinThrow
# 202              v_Archery_g08_c05             Archery         HorseRiding
# 203         v_RopeClimbing_g07_c03        RopeClimbing   VolleyballSpiking
# 204           v_PlayingDaf_g12_c03          PlayingDaf      ApplyEyeMakeup
# 205         v_PizzaTossing_g10_c04        PizzaTossing          UnevenBars
# 206           v_StillRings_g13_c02          StillRings      BlowingCandles
# 207              v_Bowling_g18_c04             Bowling      ApplyEyeMakeup
# 208                v_Punch_g07_c07               Punch             Fencing
# 209           v_Basketball_g18_c05          Basketball        BabyCrawling
# 210          v_PommelHorse_g15_c03         PommelHorse        CleanAndJerk
# 211             v_Drumming_g09_c04            Drumming        PlayingFlute
# 212         v_MoppingFloor_g22_c02        MoppingFloor       BrushingTeeth
# 213               v_Biking_g14_c01              Biking              Rowing
# 214         v_CleanAndJerk_g24_c02        CleanAndJerk             Fencing
# 215     v_HandstandWalking_g16_c04    HandstandWalking         PlayingDhol
# 216     v_CuttingInKitchen_g25_c05    CuttingInKitchen      ApplyEyeMakeup
# 217       v_BasketballDunk_g17_c07      BasketballDunk             Bowling
# 218          v_CliffDiving_g04_c01         CliffDiving      BlowingCandles
# 219     v_CuttingInKitchen_g19_c03    CuttingInKitchen        BabyCrawling
# 220         v_BandMarching_g24_c01        BandMarching    BodyWeightSquats
# 221          v_WallPushups_g10_c02         WallPushups              Skiing
# 222               v_Lunges_g16_c03              Lunges      WalkingWithDog
# 223     v_HandstandWalking_g17_c01    HandstandWalking      ApplyEyeMakeup
# 224              v_Rafting_g10_c03             Rafting            Kayaking
# 225          v_JumpingJack_g21_c04         JumpingJack          Basketball
# 226        v_ApplyLipstick_g17_c05       ApplyLipstick      ApplyEyeMakeup
# 227        v_BaseballPitch_g22_c03       BaseballPitch              Mixing
# 228       v_MilitaryParade_g10_c04      MilitaryParade            LongJump
# 229          v_PommelHorse_g21_c04         PommelHorse            Knitting
# 230                v_Swing_g12_c02               Swing           Hammering
# 231          v_ThrowDiscus_g14_c01         ThrowDiscus         HammerThrow
# 232               v_Rowing_g10_c05              Rowing              Diving
# 233             v_Knitting_g11_c02            Knitting            Kayaking
# 234              v_Bowling_g03_c01             Bowling          BenchPress
# 235      v_FloorGymnastics_g15_c02     FloorGymnastics  FieldHockeyPenalty
# 236           v_PlayingDaf_g03_c03          PlayingDaf         HeadMassage
# 237         v_BabyCrawling_g04_c04        BabyCrawling          PlayingDaf
# 238           v_IceDancing_g17_c04          IceDancing            Kayaking
# 239         v_CleanAndJerk_g17_c01        CleanAndJerk         WallPushups
# 240   v_RockClimbingIndoor_g21_c07  RockClimbingIndoor      BlowingCandles
# 241         v_BandMarching_g22_c04        BandMarching          StillRings
# 242           v_UnevenBars_g21_c01          UnevenBars      BlowingCandles
# 243          v_BlowDryHair_g13_c02         BlowDryHair        BabyCrawling
# 244          v_HorseRiding_g11_c02         HorseRiding      WalkingWithDog
# 245         v_PlayingFlute_g23_c03        PlayingFlute      ApplyEyeMakeup
# 246       v_BasketballDunk_g06_c01      BasketballDunk        BandMarching
# 247       v_WalkingWithDog_g13_c01      WalkingWithDog              Lunges
# 248               v_Mixing_g07_c03              Mixing            Kayaking
# 249             v_HulaHoop_g21_c04            HulaHoop       PlayingViolin
# 250     v_CuttingInKitchen_g01_c04    CuttingInKitchen          FrontCrawl
# 251      v_FloorGymnastics_g15_c01     FloorGymnastics            LongJump
# 252           v_FrontCrawl_g10_c02          FrontCrawl              Skijet
# 253              v_Shotput_g15_c02             Shotput        BandMarching
# 254       v_WalkingWithDog_g17_c02      WalkingWithDog        MoppingFloor
# 255              v_Haircut_g08_c02             Haircut  RockClimbingIndoor
# 256             v_Kayaking_g10_c01            Kayaking          FrontCrawl
# 257       v_BoxingSpeedBag_g22_c03      BoxingSpeedBag            Knitting
# 258                v_Swing_g03_c01               Swing              Lunges
# 259              v_PullUps_g05_c01             PullUps           GolfSwing
# 260               v_Biking_g12_c03              Biking              Skijet
# 261       v_WritingOnBoard_g13_c01      WritingOnBoard        BabyCrawling
# 262              v_Bowling_g22_c03             Bowling         HeadMassage
# 263         v_ParallelBars_g17_c03        ParallelBars              Diving
# 264         v_JavelinThrow_g07_c01        JavelinThrow              Diving
# 265               v_Skiing_g15_c01              Skiing             Rafting
# 266          v_CliffDiving_g19_c06         CliffDiving      WalkingWithDog
# 267       v_SoccerJuggling_g19_c01      SoccerJuggling         HorseRiding
# 268          v_WallPushups_g13_c03         WallPushups         BlowDryHair
# 269               v_Lunges_g14_c04              Lunges        BandMarching
# 270          v_HammerThrow_g09_c06         HammerThrow      BlowingCandles
# 271          v_CricketShot_g06_c06         CricketShot        BabyCrawling
# 272            v_SalsaSpin_g02_c05           SalsaSpin            HulaHoop
# 273           v_Basketball_g10_c02          Basketball             Fencing
# 274               v_Mixing_g09_c07              Mixing        PlayingPiano
# 275              v_Archery_g11_c07             Archery        PizzaTossing
# 276        v_SumoWrestling_g05_c03       SumoWrestling             Fencing
# 277        v_SoccerPenalty_g07_c04       SoccerPenalty            HighJump
# 278         v_FrisbeeCatch_g03_c04        FrisbeeCatch             Shotput
# 279     v_CuttingInKitchen_g15_c02    CuttingInKitchen              Skiing
# 280       v_CricketBowling_g19_c02      CricketBowling          Basketball
# 281          v_CricketShot_g03_c02         CricketShot              Biking
# 282               v_Skijet_g06_c01              Skijet      WalkingWithDog
# 283              v_PullUps_g05_c02             PullUps             Bowling
# 284                v_Punch_g10_c05               Punch        PlayingPiano
# 285          v_WallPushups_g15_c02         WallPushups           Nunchucks
# 286               v_Lunges_g15_c04              Lunges            HulaHoop
# 287    v_TrampolineJumping_g23_c02   TrampolineJumping          BenchPress
# 288         v_RopeClimbing_g20_c04        RopeClimbing        PlayingSitar
# 289            v_PoleVault_g14_c02           PoleVault            Kayaking
# 290       v_BasketballDunk_g03_c04      BasketballDunk               Punch
# 291    v_TrampolineJumping_g04_c02   TrampolineJumping               Swing
# 292    v_BoxingPunchingBag_g14_c04   BoxingPunchingBag        BabyCrawling
# 293              v_Bowling_g17_c06             Bowling        ParallelBars
# 294       v_SoccerJuggling_g09_c03      SoccerJuggling        MoppingFloor
# 295                v_Punch_g17_c07               Punch      BlowingCandles
# 296              v_Bowling_g22_c06             Bowling         BlowDryHair
# 297                 v_YoYo_g17_c06                YoYo         HorseRiding
# 298              v_Haircut_g24_c06             Haircut              Lunges
# 299     v_CuttingInKitchen_g07_c04    CuttingInKitchen      ApplyEyeMakeup
# 300     v_CuttingInKitchen_g12_c03    CuttingInKitchen        BabyCrawling
# 301       v_SoccerJuggling_g01_c03      SoccerJuggling        RopeClimbing
# 302       v_WritingOnBoard_g25_c02      WritingOnBoard            Kayaking
# 303            v_SkyDiving_g09_c02           SkyDiving              Skiing
# 304          v_HorseRiding_g18_c03         HorseRiding            HighJump
# 305             v_JumpRope_g10_c04            JumpRope      WalkingWithDog
# 306             v_LongJump_g09_c06            LongJump            HighJump
# 307     v_CuttingInKitchen_g11_c02    CuttingInKitchen      WalkingWithDog
# 308               v_Diving_g23_c01              Diving            LongJump
# 309         v_BandMarching_g08_c04        BandMarching      MilitaryParade
# 310   v_FieldHockeyPenalty_g05_c02  FieldHockeyPenalty     FloorGymnastics
# 311           v_PlayingDaf_g18_c04          PlayingDaf        PlayingSitar
# 312             v_Knitting_g24_c02            Knitting             Rafting
# 313               v_Mixing_g07_c02              Mixing              Skijet
# 314    v_BoxingPunchingBag_g20_c05   BoxingPunchingBag         PommelHorse
# 315               v_Mixing_g08_c04              Mixing        BabyCrawling
# 316               v_Skiing_g04_c05              Skiing             Surfing
# 317         v_PizzaTossing_g21_c03        PizzaTossing         HeadMassage
# 318          v_BlowDryHair_g03_c01         BlowDryHair            Knitting
# 319         v_BreastStroke_g03_c02        BreastStroke          FrontCrawl
# 320     v_HandstandWalking_g11_c03    HandstandWalking          Basketball
# 321            v_GolfSwing_g11_c04           GolfSwing           SalsaSpin
# 322              v_Rafting_g09_c04             Rafting          FrontCrawl
# 323    v_BoxingPunchingBag_g13_c02   BoxingPunchingBag      ApplyEyeMakeup
# 324          v_CliffDiving_g03_c03         CliffDiving        BandMarching
# 325       v_BoxingSpeedBag_g13_c05      BoxingSpeedBag        BabyCrawling
# 326           v_Basketball_g13_c03          Basketball      WalkingWithDog
# 327           v_StillRings_g04_c02          StillRings        PlayingCello
# 328              v_Bowling_g08_c07             Bowling        MoppingFloor
# 329             v_Kayaking_g15_c05            Kayaking        BabyCrawling
# 330   v_RockClimbingIndoor_g21_c01  RockClimbingIndoor      ApplyEyeMakeup
# 331     v_HandstandWalking_g16_c03    HandstandWalking            HulaHoop
# 332             v_Knitting_g17_c03            Knitting              Skijet
# 333             v_HighJump_g25_c02            HighJump              Skiing
# 334               v_Biking_g17_c04              Biking        PizzaTossing
# 335     v_HandstandWalking_g05_c06    HandstandWalking      CricketBowling
# 336       v_BlowingCandles_g20_c02      BlowingCandles        BandMarching
# 337             v_Knitting_g22_c02            Knitting          StillRings
# 338          v_HorseRiding_g06_c07         HorseRiding            Kayaking
# 339          v_HorseRiding_g19_c05         HorseRiding              Lunges
# 340          v_HeadMassage_g15_c07         HeadMassage               Swing
# 341         v_ShavingBeard_g08_c06        ShavingBeard       SumoWrestling
# 342          v_PommelHorse_g17_c01         PommelHorse       PlayingViolin
# 343               v_Skiing_g08_c05              Skiing              Skijet
# 344           v_IceDancing_g11_c02          IceDancing         CliffDiving
# 345          v_HorseRiding_g14_c06         HorseRiding      WalkingWithDog
# 346               v_Rowing_g14_c02              Rowing              Lunges
# 347              v_Bowling_g07_c06             Bowling             Shotput
# 348     v_CuttingInKitchen_g16_c01    CuttingInKitchen          FrontCrawl
# 349            v_SalsaSpin_g10_c05           SalsaSpin           Nunchucks
# 350       v_CricketBowling_g24_c01      CricketBowling              Diving
# 351              v_Rafting_g05_c02             Rafting      ApplyEyeMakeup
# 352              v_Shotput_g15_c04             Shotput             Fencing
# 353             v_LongJump_g09_c04            LongJump          FrontCrawl
# 354          v_HorseRiding_g15_c04         HorseRiding             Fencing
# 355       v_WalkingWithDog_g22_c03      WalkingWithDog              Biking
# 356        v_SumoWrestling_g22_c04       SumoWrestling              Diving
# 357            v_PoleVault_g06_c03           PoleVault              Rowing
# 358          v_CricketShot_g03_c03         CricketShot              Lunges
# 359           v_Basketball_g18_c04          Basketball         HorseRiding
# 360     v_BodyWeightSquats_g20_c01    BodyWeightSquats         BlowDryHair
# 361          v_PommelHorse_g17_c02         PommelHorse      BlowingCandles
# 362              v_Shotput_g13_c04             Shotput   VolleyballSpiking
# 363            v_Nunchucks_g16_c04           Nunchucks      BlowingCandles
# 364              v_Archery_g10_c01             Archery        BabyCrawling
# 365           v_Basketball_g22_c07          Basketball    HandstandWalking
# 366         v_PlayingPiano_g19_c04        PlayingPiano        CleanAndJerk
# 367               v_Rowing_g22_c01              Rowing      CricketBowling
# 368          v_CliffDiving_g18_c07         CliffDiving         BlowDryHair
# 369           v_IceDancing_g02_c02          IceDancing         HorseRiding
# 370           v_PlayingDaf_g09_c05          PlayingDaf           Nunchucks
# 371             v_Kayaking_g19_c04            Kayaking        BabyCrawling
# 372       v_BlowingCandles_g06_c06      BlowingCandles         HeadMassage
# 373       v_SoccerJuggling_g11_c05      SoccerJuggling            HighJump
# 374       v_WalkingWithDog_g19_c02      WalkingWithDog               Swing
# 375   v_RockClimbingIndoor_g04_c02  RockClimbingIndoor        MoppingFloor
# 376       v_BoxingSpeedBag_g14_c02      BoxingSpeedBag      ApplyEyeMakeup
# 377            v_PoleVault_g24_c04           PoleVault        BandMarching
# 378                v_Swing_g20_c03               Swing           Hammering
# 379          v_HorseRiding_g02_c03         HorseRiding              Biking
# 380       v_WritingOnBoard_g03_c04      WritingOnBoard         HeadMassage
# 381        v_BaseballPitch_g01_c06       BaseballPitch         JumpingJack
# 382            v_Hammering_g02_c04           Hammering      BoxingSpeedBag
# 383         v_BandMarching_g07_c01        BandMarching             Haircut
# 384             v_Knitting_g25_c05            Knitting        BabyCrawling
# 385       v_BlowingCandles_g06_c02      BlowingCandles         PlayingDhol
# 386              v_Bowling_g10_c02             Bowling        FrisbeeCatch
# 387        v_PlayingGuitar_g02_c04       PlayingGuitar       PlayingViolin
# 388              v_Rafting_g20_c02             Rafting              Biking
# 389               v_Diving_g09_c05              Diving     FloorGymnastics
# 390                v_Swing_g07_c06               Swing        BandMarching
# 391       v_ApplyEyeMakeup_g02_c04      ApplyEyeMakeup        PlayingFlute
# 392               v_Rowing_g14_c07              Rowing            HighJump
# 393                 v_YoYo_g12_c04                YoYo          UnevenBars
# 394             v_HulaHoop_g01_c05            HulaHoop               Swing
# 395           v_StillRings_g01_c02          StillRings     FloorGymnastics
# 396          v_PlayingDhol_g06_c03         PlayingDhol  RockClimbingIndoor
# 397        v_ApplyLipstick_g25_c02       ApplyLipstick      ApplyEyeMakeup
# 398              v_Bowling_g24_c02             Bowling      MilitaryParade
# 399      v_TableTennisShot_g08_c04     TableTennisShot             PushUps
# 400   v_FieldHockeyPenalty_g04_c05  FieldHockeyPenalty      MilitaryParade
# 401      v_FloorGymnastics_g01_c02     FloorGymnastics             Bowling
# 402          v_CliffDiving_g14_c04         CliffDiving         BalanceBeam
# 403         v_JavelinThrow_g13_c02        JavelinThrow      BasketballDunk
# 404          v_CliffDiving_g11_c05         CliffDiving         HorseRiding
# 405             v_Kayaking_g15_c07            Kayaking          Basketball
# 406          v_HammerThrow_g15_c04         HammerThrow            JumpRope
# 407               v_Diving_g16_c02              Diving             Shotput
# 408         v_PizzaTossing_g03_c01        PizzaTossing       ApplyLipstick
# 409          v_ThrowDiscus_g09_c01         ThrowDiscus          Basketball
# 410            v_SkyDiving_g05_c01           SkyDiving      CricketBowling
# 411       v_SoccerJuggling_g16_c04      SoccerJuggling               Swing
# 412         v_ParallelBars_g06_c07        ParallelBars        CleanAndJerk
# 413           v_BenchPress_g11_c02          BenchPress      BoxingSpeedBag
# 414             v_HighJump_g09_c05            HighJump              Biking
# 415         v_BabyCrawling_g13_c04        BabyCrawling        JavelinThrow
# 416           v_Basketball_g08_c03          Basketball               Swing
# 417         v_PizzaTossing_g19_c02        PizzaTossing         PommelHorse
# 418            v_GolfSwing_g17_c03           GolfSwing         ThrowDiscus
# 419            v_GolfSwing_g19_c01           GolfSwing         ThrowDiscus
# 420         v_FrisbeeCatch_g19_c04        FrisbeeCatch         BalanceBeam
# 421     v_CuttingInKitchen_g24_c02    CuttingInKitchen           SkyDiving
# 422              v_Bowling_g09_c02             Bowling        MoppingFloor
# 423             v_Drumming_g14_c01            Drumming        PizzaTossing
# 424           v_PlayingDaf_g17_c04          PlayingDaf              Mixing
# 425         v_FrisbeeCatch_g05_c04        FrisbeeCatch            Kayaking
# 426       v_BoxingSpeedBag_g01_c02      BoxingSpeedBag          PlayingDaf
# 427         v_PizzaTossing_g04_c07        PizzaTossing          Basketball
# 428          v_CricketShot_g03_c04         CricketShot         HorseRiding
# 429          v_HammerThrow_g07_c04         HammerThrow            LongJump
# 430                v_Swing_g12_c03               Swing              Skijet
# 431     v_CuttingInKitchen_g09_c02    CuttingInKitchen      ApplyEyeMakeup
# 432            v_SkyDiving_g21_c03           SkyDiving            LongJump
# 433     v_CuttingInKitchen_g19_c02    CuttingInKitchen      ApplyEyeMakeup
# 434             v_Kayaking_g18_c05            Kayaking        BabyCrawling
# 435            v_SkyDiving_g24_c04           SkyDiving             Rafting
# 436               v_Biking_g17_c01              Biking      BlowingCandles
# 437                v_Punch_g07_c05               Punch        BandMarching
# 438           v_StillRings_g11_c03          StillRings      BlowingCandles
# 439           v_PlayingDaf_g12_c01          PlayingDaf           Nunchucks
# 440               v_TaiChi_g20_c02              TaiChi          Basketball
# 441          v_PlayingDhol_g24_c03         PlayingDhol        PlayingSitar
# 442          v_ThrowDiscus_g11_c02         ThrowDiscus       BrushingTeeth
# 443            v_GolfSwing_g18_c06           GolfSwing        MoppingFloor
# 444         v_CleanAndJerk_g08_c02        CleanAndJerk        PizzaTossing
# 445           v_FrontCrawl_g24_c04          FrontCrawl              Skijet
# 446        v_PlayingViolin_g09_c03       PlayingViolin             Haircut
# 447        v_BrushingTeeth_g11_c03       BrushingTeeth         HammerThrow
# 448          v_PommelHorse_g22_c03         PommelHorse        BandMarching
# 449         v_BandMarching_g07_c04        BandMarching               Punch
# 450       v_SoccerJuggling_g12_c05      SoccerJuggling              Lunges
# 451       v_BoxingSpeedBag_g23_c01      BoxingSpeedBag       ApplyLipstick
# 452      v_TableTennisShot_g01_c04     TableTennisShot             Fencing
# 453           v_PlayingDaf_g04_c03          PlayingDaf          Basketball
# 454         v_FrisbeeCatch_g19_c02        FrisbeeCatch             Shotput
# 455                 v_YoYo_g03_c01                YoYo           Nunchucks
# 456             v_Kayaking_g06_c07            Kayaking      BasketballDunk
# 457       v_MilitaryParade_g24_c04      MilitaryParade           HorseRace
# 458     v_HandstandWalking_g04_c05    HandstandWalking        MoppingFloor
# 459             v_Kayaking_g19_c05            Kayaking        MoppingFloor
# 460           v_UnevenBars_g23_c02          UnevenBars      BlowingCandles
# 461             v_Drumming_g18_c01            Drumming      BlowingCandles
# 462          v_HeadMassage_g18_c03         HeadMassage               Swing
# 463              v_Surfing_g14_c03             Surfing          FrontCrawl
# 464            v_Hammering_g07_c03           Hammering        PizzaTossing
# 465       v_MilitaryParade_g08_c03      MilitaryParade        PizzaTossing
# 466               v_Diving_g06_c03              Diving  FieldHockeyPenalty
# 467         v_RopeClimbing_g05_c06        RopeClimbing             Surfing
# 468            v_GolfSwing_g09_c03           GolfSwing              TaiChi
# 469           v_IceDancing_g20_c06          IceDancing              Skiing
# 470       v_BlowingCandles_g04_c01      BlowingCandles        CleanAndJerk
# 471       v_MilitaryParade_g21_c03      MilitaryParade        BandMarching
# 472             v_HulaHoop_g15_c03            HulaHoop      BoxingSpeedBag
# 473              v_Rafting_g06_c04             Rafting               Swing
# 474               v_Diving_g09_c03              Diving     FloorGymnastics
# 475        v_SoccerPenalty_g07_c05       SoccerPenalty  FieldHockeyPenalty
# 476           v_FrontCrawl_g23_c06          FrontCrawl             Surfing
# 477        v_PlayingGuitar_g01_c02       PlayingGuitar        CleanAndJerk
# 478         v_PlayingPiano_g13_c03        PlayingPiano          UnevenBars
# 479       v_BlowingCandles_g11_c02      BlowingCandles             Fencing
# 480             v_Kayaking_g17_c01            Kayaking              Skiing
# 481              v_Haircut_g23_c07             Haircut         CliffDiving
# 482               v_Diving_g13_c03              Diving        PlayingFlute
# 483              v_Fencing_g02_c04             Fencing      BlowingCandles
# 484         v_PlayingPiano_g21_c01        PlayingPiano  RockClimbingIndoor
# 485   v_RockClimbingIndoor_g01_c02  RockClimbingIndoor         HammerThrow
# 486              v_PullUps_g11_c04             PullUps        MoppingFloor
# 487         v_PlayingCello_g14_c04        PlayingCello         PlayingDhol
# 488       v_MilitaryParade_g19_c03      MilitaryParade        BandMarching
# 489     v_BodyWeightSquats_g24_c02    BodyWeightSquats   BoxingPunchingBag
# 490         v_MoppingFloor_g17_c04        MoppingFloor             Rafting
# 491              v_Rafting_g06_c01             Rafting               Punch
# 492           v_UnevenBars_g16_c01          UnevenBars        PlayingFlute
# 493       v_WalkingWithDog_g03_c05      WalkingWithDog          FrontCrawl
# 494         v_RopeClimbing_g20_c01        RopeClimbing        ShavingBeard
# 495          v_HeadMassage_g25_c04         HeadMassage      CricketBowling
# 496               v_Skiing_g14_c01              Skiing            Kayaking
# 497         v_BandMarching_g04_c01        BandMarching             Fencing
# 498        v_ApplyLipstick_g01_c05       ApplyLipstick      ApplyEyeMakeup
# 499               v_Biking_g19_c04              Biking    HandstandWalking
# ...                            ...                 ...                 ...
# 1229           v_Hammering_g14_c07           Hammering        JavelinThrow
# 1230          v_BenchPress_g10_c02          BenchPress            Drumming
# 1231           v_SkyDiving_g25_c02           SkyDiving        BabyCrawling
# 1232        v_PlayingCello_g10_c03        PlayingCello             Haircut
# 1233              v_Lunges_g23_c05              Lunges               Swing
# 1234         v_HeadMassage_g15_c06         HeadMassage               Swing
# 1235    v_BodyWeightSquats_g04_c01    BodyWeightSquats            Knitting
# 1236          v_Basketball_g11_c03          Basketball         HorseRiding
# 1237         v_HeadMassage_g14_c01         HeadMassage         BlowDryHair
# 1238        v_RopeClimbing_g23_c01        RopeClimbing               Swing
# 1239            v_HighJump_g09_c04            HighJump               Swing
# 1240   v_VolleyballSpiking_g05_c02   VolleyballSpiking        BabyCrawling
# 1241         v_CliffDiving_g16_c04         CliffDiving      ApplyEyeMakeup
# 1242         v_CliffDiving_g25_c02         CliffDiving            Knitting
# 1243          v_IceDancing_g21_c03          IceDancing            Kayaking
# 1244         v_CricketShot_g01_c05         CricketShot      CricketBowling
# 1245        v_MoppingFloor_g03_c02        MoppingFloor            Kayaking
# 1246      v_MilitaryParade_g06_c01      MilitaryParade                YoYo
# 1247         v_PlayingDhol_g09_c04         PlayingDhol          Basketball
# 1248                v_YoYo_g05_c02                YoYo        PizzaTossing
# 1249           v_SalsaSpin_g01_c04           SalsaSpin              Lunges
# 1250         v_HammerThrow_g24_c03         HammerThrow          UnevenBars
# 1251    v_CuttingInKitchen_g16_c04    CuttingInKitchen            Kayaking
# 1252     v_FloorGymnastics_g24_c03     FloorGymnastics      BasketballDunk
# 1253             v_Shotput_g16_c05             Shotput              Lunges
# 1254  v_FieldHockeyPenalty_g03_c01  FieldHockeyPenalty              Diving
# 1255              v_Rowing_g20_c02              Rowing            LongJump
# 1256    v_CuttingInKitchen_g06_c01    CuttingInKitchen        BabyCrawling
# 1257             v_Haircut_g24_c01             Haircut   BoxingPunchingBag
# 1258               v_Swing_g09_c04               Swing          Basketball
# 1259  v_RockClimbingIndoor_g02_c03  RockClimbingIndoor        BabyCrawling
# 1260          v_PlayingDaf_g18_c06          PlayingDaf         HammerThrow
# 1261     v_TableTennisShot_g09_c02     TableTennisShot           Hammering
# 1262        v_MoppingFloor_g24_c02        MoppingFloor        BabyCrawling
# 1263      v_BlowingCandles_g10_c04      BlowingCandles           SalsaSpin
# 1264              v_Mixing_g19_c01              Mixing              Lunges
# 1265      v_BasketballDunk_g17_c01      BasketballDunk     FloorGymnastics
# 1266         v_HammerThrow_g16_c04         HammerThrow             Shotput
# 1267         v_ThrowDiscus_g11_c03         ThrowDiscus          Basketball
# 1268             v_PullUps_g04_c04             PullUps   TrampolineJumping
# 1269        v_PlayingCello_g08_c03        PlayingCello         ThrowDiscus
# 1270           v_GolfSwing_g08_c02           GolfSwing       BaseballPitch
# 1271            v_JumpRope_g05_c05            JumpRope           Nunchucks
# 1272           v_PoleVault_g10_c06           PoleVault            LongJump
# 1273           v_Hammering_g05_c03           Hammering         HorseRiding
# 1274           v_Nunchucks_g06_c01           Nunchucks           SalsaSpin
# 1275             v_Archery_g06_c01             Archery   BoxingPunchingBag
# 1276             v_PushUps_g07_c01             PushUps        MoppingFloor
# 1277  v_FieldHockeyPenalty_g08_c01  FieldHockeyPenalty          FrontCrawl
# 1278    v_BodyWeightSquats_g24_c04    BodyWeightSquats         PlayingDhol
# 1279  v_FieldHockeyPenalty_g19_c01  FieldHockeyPenalty             PushUps
# 1280           v_SalsaSpin_g01_c01           SalsaSpin              TaiChi
# 1281          v_StillRings_g25_c03          StillRings            HulaHoop
# 1282        v_MoppingFloor_g19_c01        MoppingFloor               Swing
# 1283        v_MoppingFloor_g21_c01        MoppingFloor          FrontCrawl
# 1284      v_MilitaryParade_g17_c04      MilitaryParade           HorseRace
# 1285      v_ApplyEyeMakeup_g13_c01      ApplyEyeMakeup          PlayingDaf
# 1286       v_SumoWrestling_g13_c01       SumoWrestling               Punch
# 1287               v_Swing_g13_c03               Swing         HeadMassage
# 1288      v_MilitaryParade_g01_c07      MilitaryParade    BodyWeightSquats
# 1289               v_Swing_g22_c03               Swing      BlowingCandles
# 1290         v_TennisSwing_g07_c03         TennisSwing           Hammering
# 1291               v_Punch_g06_c05               Punch      MilitaryParade
# 1292            v_HighJump_g07_c03            HighJump          FrontCrawl
# 1293              v_Lunges_g03_c01              Lunges               Swing
# 1294    v_CuttingInKitchen_g21_c01    CuttingInKitchen            LongJump
# 1295         v_BalanceBeam_g18_c03         BalanceBeam        ParallelBars
# 1296         v_HammerThrow_g08_c06         HammerThrow      BlowingCandles
# 1297         v_PommelHorse_g11_c04         PommelHorse      BlowingCandles
# 1298        v_PlayingCello_g05_c03        PlayingCello      BlowingCandles
# 1299       v_SkateBoarding_g14_c03       SkateBoarding          FrontCrawl
# 1300     v_FloorGymnastics_g03_c03     FloorGymnastics                YoYo
# 1301      v_BlowingCandles_g23_c01      BlowingCandles             Shotput
# 1302       v_SkateBoarding_g02_c06       SkateBoarding         BlowDryHair
# 1303            v_LongJump_g11_c02            LongJump          FrontCrawl
# 1304            v_HighJump_g23_c03            HighJump            LongJump
# 1305              v_Rowing_g19_c01              Rowing          FrontCrawl
# 1306       v_SoccerPenalty_g18_c05       SoccerPenalty          FrontCrawl
# 1307        v_ShavingBeard_g19_c01        ShavingBeard      ApplyEyeMakeup
# 1308               v_Punch_g04_c05               Punch      BasketballDunk
# 1309        v_PlayingFlute_g14_c03        PlayingFlute      BlowingCandles
# 1310              v_Skiing_g16_c05              Skiing             Surfing
# 1311           v_SkyDiving_g13_c01           SkyDiving      CricketBowling
# 1312  v_FieldHockeyPenalty_g16_c04  FieldHockeyPenalty      SoccerJuggling
# 1313           v_SkyDiving_g04_c01           SkyDiving             PushUps
# 1314              v_Typing_g04_c04              Typing         HammerThrow
# 1315      v_WalkingWithDog_g21_c01      WalkingWithDog        MoppingFloor
# 1316        v_PlayingTabla_g10_c01        PlayingTabla        CleanAndJerk
# 1317  v_RockClimbingIndoor_g11_c01  RockClimbingIndoor              Lunges
# 1318      v_WritingOnBoard_g21_c05      WritingOnBoard       SoccerPenalty
# 1319         v_HeadMassage_g03_c02         HeadMassage         BlowDryHair
# 1320        v_CleanAndJerk_g08_c03        CleanAndJerk             Fencing
# 1321        v_FrisbeeCatch_g01_c05        FrisbeeCatch              Rowing
# 1322             v_Haircut_g17_c01             Haircut      ApplyEyeMakeup
# 1323       v_BaseballPitch_g02_c02       BaseballPitch        BabyCrawling
# 1324           v_PoleVault_g19_c04           PoleVault              Diving
# 1325      v_BoxingSpeedBag_g10_c02      BoxingSpeedBag        BandMarching
# 1326              v_Mixing_g05_c07              Mixing            Knitting
# 1327             v_PullUps_g06_c03             PullUps        RopeClimbing
# 1328   v_TrampolineJumping_g05_c03   TrampolineJumping         PlayingDhol
# 1329      v_BlowingCandles_g02_c04      BlowingCandles        ParallelBars
# 1330       v_BrushingTeeth_g23_c02       BrushingTeeth       ApplyLipstick
# 1331        v_BabyCrawling_g19_c05        BabyCrawling    BodyWeightSquats
# 1332              v_Rowing_g21_c02              Rowing              Diving
# 1333           v_GolfSwing_g20_c05           GolfSwing      SoccerJuggling
# 1334            v_Kayaking_g11_c04            Kayaking              Biking
# 1335      v_BlowingCandles_g18_c01      BlowingCandles             Haircut
# 1336   v_BoxingPunchingBag_g19_c04   BoxingPunchingBag    HandstandWalking
# 1337             v_Bowling_g20_c04             Bowling              Diving
# 1338             v_PullUps_g04_c02             PullUps      SoccerJuggling
# 1339         v_ThrowDiscus_g08_c01         ThrowDiscus          FrontCrawl
# 1340           v_Hammering_g05_c04           Hammering               Swing
# 1341          v_UnevenBars_g09_c01          UnevenBars        BandMarching
# 1342   v_TrampolineJumping_g22_c06   TrampolineJumping             PushUps
# 1343             v_PullUps_g05_c04             PullUps          UnevenBars
# 1344       v_SumoWrestling_g06_c03       SumoWrestling      BasketballDunk
# 1345  v_FieldHockeyPenalty_g04_c01  FieldHockeyPenalty      BasketballDunk
# 1346      v_WalkingWithDog_g19_c04      WalkingWithDog    HandstandWalking
# 1347              v_TaiChi_g10_c04              TaiChi      CricketBowling
# 1348              v_Skijet_g13_c04              Skijet              Skiing
# 1349          v_StillRings_g02_c04          StillRings             Haircut
# 1350        v_PlayingFlute_g04_c01        PlayingFlute            HulaHoop
# 1351      v_CricketBowling_g12_c01      CricketBowling        FrisbeeCatch
# 1352        v_BandMarching_g19_c07        BandMarching               Swing
# 1353        v_RopeClimbing_g19_c03        RopeClimbing    HandstandPushups
# 1354          v_Basketball_g19_c05          Basketball     FloorGymnastics
# 1355      v_WritingOnBoard_g24_c04      WritingOnBoard              TaiChi
# 1356              v_Mixing_g13_c02              Mixing              Diving
# 1357              v_Biking_g10_c04              Biking         HorseRiding
# 1358         v_HeadMassage_g21_c01         HeadMassage      ApplyEyeMakeup
# 1359             v_Bowling_g06_c04             Bowling     FloorGymnastics
# 1360        v_PizzaTossing_g24_c02        PizzaTossing            HulaHoop
# 1361        v_BabyCrawling_g02_c05        BabyCrawling              TaiChi
# 1362              v_TaiChi_g08_c02              TaiChi          Basketball
# 1363           v_SkyDiving_g13_c04           SkyDiving      CricketBowling
# 1364       v_BrushingTeeth_g12_c02       BrushingTeeth         HeadMassage
# 1365           v_SkyDiving_g05_c02           SkyDiving             Rafting
# 1366      v_CricketBowling_g17_c01      CricketBowling        FrisbeeCatch
# ...
# 1516              v_Lunges_g05_c01              Lunges        BabyCrawling
# 1517             v_Rafting_g05_c01             Rafting            Kayaking
# 1518         v_JumpingJack_g17_c02         JumpingJack      BlowingCandles
# 1519        v_ParallelBars_g11_c01        ParallelBars      BlowingCandles
# 1520              v_Mixing_g07_c05              Mixing              Biking
# 1521            v_HulaHoop_g03_c04            HulaHoop      CricketBowling
# 1522        v_RopeClimbing_g12_c01        RopeClimbing        PizzaTossing
# 1523         v_CliffDiving_g09_c01         CliffDiving             Bowling
# 1524          v_IceDancing_g14_c05          IceDancing         HorseRiding
# 1525            v_Drumming_g18_c04            Drumming      BlowingCandles
# 1526       v_SoccerPenalty_g19_c02       SoccerPenalty              TaiChi
# 1527       v_JugglingBalls_g20_c03       JugglingBalls  RockClimbingIndoor
# 1528          v_UnevenBars_g10_c03          UnevenBars          StillRings
# 1529               v_Swing_g06_c03               Swing           Hammering
# 1530            v_JumpRope_g10_c01            JumpRope              Diving
# 1531      v_WalkingWithDog_g22_c04      WalkingWithDog              Biking
# 1532              v_Skijet_g16_c01              Skijet              Rowing
# 1533      v_CricketBowling_g24_c03      CricketBowling          Basketball
# 1534          v_BenchPress_g20_c07          BenchPress         BlowDryHair
# 1535         v_BlowDryHair_g20_c01         BlowDryHair      ApplyEyeMakeup
# 1536       v_BrushingTeeth_g24_c07       BrushingTeeth        PlayingSitar
# 1537            v_Drumming_g04_c05            Drumming       PlayingViolin
# 1538            v_HulaHoop_g22_c05            HulaHoop        BandMarching
# 1539      v_MilitaryParade_g19_c05      MilitaryParade            HighJump
# 1540           v_SkyDiving_g16_c02           SkyDiving      CricketBowling
# 1541         v_CricketShot_g12_c04         CricketShot         HeadMassage
# 1542               v_Swing_g04_c04               Swing        BandMarching
# 1543      v_MilitaryParade_g11_c03      MilitaryParade             Shotput
# 1544         v_HeadMassage_g08_c01         HeadMassage         CliffDiving
# 1545          v_PlayingDaf_g12_c05          PlayingDaf      BoxingSpeedBag
# 1546        v_ParallelBars_g22_c02        ParallelBars        PlayingCello
# 1547              v_Lunges_g17_c04              Lunges         HeadMassage
# 1548       v_SumoWrestling_g09_c02       SumoWrestling             Bowling
# 1549       v_JugglingBalls_g17_c01       JugglingBalls        PizzaTossing
# 1550       v_PlayingViolin_g14_c01       PlayingViolin           SkyDiving
# 1551        v_BandMarching_g09_c05        BandMarching           GolfSwing
# 1552      v_BlowingCandles_g07_c01      BlowingCandles    HandstandWalking
# 1553              v_Lunges_g02_c03              Lunges   TrampolineJumping
# 1554           v_SalsaSpin_g10_c06           SalsaSpin    HandstandWalking
# 1555         v_CricketShot_g03_c05         CricketShot      WalkingWithDog
# 1556              v_Lunges_g12_c02              Lunges              Biking
# 1557        v_ParallelBars_g20_c01        ParallelBars          UnevenBars
# 1558              v_Biking_g13_c03              Biking        FrisbeeCatch
# 1559         v_HammerThrow_g25_c04         HammerThrow              Diving
# 1560         v_PlayingDhol_g01_c02         PlayingDhol            HulaHoop
# 1561              v_TaiChi_g17_c03              TaiChi      CricketBowling
# 1562      v_WalkingWithDog_g24_c05      WalkingWithDog       SkateBoarding
# 1563       v_PlayingGuitar_g16_c06       PlayingGuitar          StillRings
# 1564      v_WalkingWithDog_g11_c02      WalkingWithDog              Lunges
# 1565      v_CricketBowling_g21_c02      CricketBowling        MoppingFloor
# 1566        v_PizzaTossing_g19_c01        PizzaTossing         PlayingDhol
# 1567         v_TennisSwing_g20_c05         TennisSwing          Basketball
# 1568        v_RopeClimbing_g19_c07        RopeClimbing        BandMarching
# 1569         v_HammerThrow_g05_c04         HammerThrow             Shotput
# 1570         v_BlowDryHair_g13_c03         BlowDryHair          PlayingDaf
# 1571         v_BalanceBeam_g24_c04         BalanceBeam        PlayingPiano
# 1572          v_PlayingDaf_g06_c01          PlayingDaf        BabyCrawling
# 1573  v_RockClimbingIndoor_g03_c02  RockClimbingIndoor           Hammering
# 1574    v_HandstandPushups_g17_c04    HandstandPushups        MoppingFloor
# 1575        v_PlayingSitar_g05_c03        PlayingSitar           Hammering
# 1576            v_HighJump_g06_c01            HighJump         HeadMassage
# 1577              v_Biking_g13_c01              Biking              Lunges
# 1578      v_WritingOnBoard_g05_c02      WritingOnBoard  RockClimbingIndoor
# 1579         v_PommelHorse_g19_c01         PommelHorse            HulaHoop
# 1580        v_PlayingTabla_g04_c06        PlayingTabla        PlayingFlute
# 1581             v_Bowling_g11_c06             Bowling        ParallelBars
# 1582       v_BaseballPitch_g14_c02       BaseballPitch   VolleyballSpiking
# 1583       v_SoccerPenalty_g09_c01       SoccerPenalty             Shotput
# 1584              v_Skijet_g17_c03              Skijet         HorseRiding
# 1585      v_SoccerJuggling_g08_c02      SoccerJuggling         HorseRiding
# 1586        v_JavelinThrow_g06_c03        JavelinThrow         CliffDiving
# 1587      v_MilitaryParade_g03_c02      MilitaryParade          BenchPress
# 1588          v_BenchPress_g20_c06          BenchPress         HammerThrow
# 1589              v_Skijet_g23_c04              Skijet          FrontCrawl
# 1590               v_Swing_g06_c04               Swing        CleanAndJerk
# 1591         v_TennisSwing_g08_c02         TennisSwing              Rowing
# 1592     v_TableTennisShot_g20_c06     TableTennisShot           Nunchucks
# 1593        v_PlayingSitar_g11_c02        PlayingSitar         PlayingDhol
# 1594           v_SkyDiving_g15_c03           SkyDiving            Knitting
# 1595           v_Hammering_g01_c04           Hammering  RockClimbingIndoor
# 1596                v_YoYo_g03_c06                YoYo  RockClimbingIndoor
# 1597      v_BlowingCandles_g16_c03      BlowingCandles         HeadMassage
# 1598      v_SoccerJuggling_g07_c06      SoccerJuggling      CricketBowling
# 1599      v_BlowingCandles_g06_c07      BlowingCandles             Archery
# 1600              v_Mixing_g24_c01              Mixing       PlayingViolin
# 1601        v_RopeClimbing_g20_c03        RopeClimbing        MoppingFloor
# 1602    v_CuttingInKitchen_g14_c02    CuttingInKitchen            Kayaking
# 1603              v_Skijet_g12_c01              Skijet             Surfing
# 1604          v_BenchPress_g11_c03          BenchPress        PlayingSitar
# 1605            v_HighJump_g06_c02            HighJump           PoleVault
# 1606            v_LongJump_g13_c05            LongJump          Basketball
# 1607        v_ParallelBars_g07_c06        ParallelBars         PlayingDhol
# 1608     v_TableTennisShot_g21_c03     TableTennisShot   VolleyballSpiking
# 1609           v_PoleVault_g10_c07           PoleVault          FrontCrawl
# 1610        v_PizzaTossing_g15_c01        PizzaTossing            LongJump
# 1611        v_PlayingFlute_g22_c05        PlayingFlute       JugglingBalls
# 1612         v_ThrowDiscus_g18_c06         ThrowDiscus           Hammering
# 1613   v_BoxingPunchingBag_g04_c02   BoxingPunchingBag         HeadMassage
# 1614             v_PushUps_g16_c01             PushUps         BlowDryHair
# 1615  v_RockClimbingIndoor_g21_c05  RockClimbingIndoor      BlowingCandles
# 1616             v_Shotput_g04_c02             Shotput           Hammering
# 1617       v_PlayingGuitar_g17_c01       PlayingGuitar      ApplyEyeMakeup
# 1618        v_MoppingFloor_g06_c03        MoppingFloor               Swing
# 1619           v_SkyDiving_g23_c02           SkyDiving              Skiing
# 1620           v_SalsaSpin_g14_c06           SalsaSpin      BoxingSpeedBag
# 1621         v_HorseRiding_g10_c02         HorseRiding           GolfSwing
# 1622        v_BandMarching_g05_c06        BandMarching        CleanAndJerk
# 1623       v_SkateBoarding_g10_c05       SkateBoarding         HorseRiding
# 1624       v_PlayingGuitar_g03_c01       PlayingGuitar       ApplyLipstick
# 1625          v_Basketball_g02_c04          Basketball              Skijet
# 1626                v_YoYo_g20_c03                YoYo       PlayingViolin
# 1627         v_HorseRiding_g15_c01         HorseRiding            Kayaking
# 1628           v_Hammering_g12_c01           Hammering         HeadMassage
# 1629           v_HorseRace_g13_c01           HorseRace               Punch
# 1630              v_Skijet_g14_c01              Skijet          Basketball
# 1631              v_Lunges_g05_c04              Lunges               Swing
# 1632          v_StillRings_g18_c01          StillRings        PlayingSitar
# 1633        v_PizzaTossing_g09_c03        PizzaTossing      BlowingCandles
# 1634             v_Haircut_g18_c02             Haircut          PlayingDaf
# 1635               v_Punch_g06_c06               Punch         HammerThrow
# 1636        v_ParallelBars_g23_c02        ParallelBars      BlowingCandles
# 1637             v_Rafting_g16_c07             Rafting            Kayaking
# 1638        v_CleanAndJerk_g10_c02        CleanAndJerk           Hammering
# 1639        v_BandMarching_g01_c06        BandMarching             Fencing
# 1640               v_Punch_g04_c01               Punch      BasketballDunk
# 1641             v_PushUps_g14_c04             PushUps        BabyCrawling
# 1642       v_SumoWrestling_g11_c03       SumoWrestling             PushUps
# 1643             v_PullUps_g06_c04             PullUps          UnevenBars
# 1644               v_Swing_g07_c04               Swing      WalkingWithDog
# 1645            v_Kayaking_g11_c07            Kayaking        BabyCrawling
# 1646            v_JumpRope_g01_c04            JumpRope   VolleyballSpiking
# 1647           v_SalsaSpin_g25_c04           SalsaSpin          BenchPress
# 1648              v_TaiChi_g12_c02              TaiChi         ThrowDiscus
# 1649        v_PlayingSitar_g12_c02        PlayingSitar      BlowingCandles
# 1650          v_StillRings_g25_c02          StillRings         PommelHorse
# 1651      v_WritingOnBoard_g10_c01      WritingOnBoard         WallPushups
# 1652              v_Biking_g10_c05              Biking      WalkingWithDog
# 1653             v_Bowling_g04_c02             Bowling                YoYo
# 1654         v_CricketShot_g01_c07         CricketShot      CricketBowling
# 1655    v_HandstandWalking_g13_c02    HandstandWalking        BandMarching
# 1656        v_PlayingTabla_g13_c01        PlayingTabla        CleanAndJerk
# 1657          v_IceDancing_g14_c03          IceDancing      WalkingWithDog
# 1658       v_SumoWrestling_g10_c01       SumoWrestling     FloorGymnastics
# 1659            v_Knitting_g03_c05            Knitting      ApplyEyeMakeup
# 1660            v_Kayaking_g14_c02            Kayaking          FrontCrawl
# 1661       v_SkateBoarding_g02_c01       SkateBoarding            HighJump
# 1662     v_TableTennisShot_g12_c03     TableTennisShot         BalanceBeam
# 1663        v_JavelinThrow_g13_c03        JavelinThrow              Diving
# 1664               v_Swing_g01_c02               Swing          Basketball
# 1665  v_RockClimbingIndoor_g05_c06  RockClimbingIndoor          Basketball
# 1666          v_IceDancing_g08_c01          IceDancing       SumoWrestling
# 1667           v_Hammering_g07_c01           Hammering              Diving
# 1668      v_WalkingWithDog_g13_c03      WalkingWithDog              Skiing
# 1669            v_Drumming_g22_c03            Drumming          IceDancing
# 1670              v_Biking_g09_c03              Biking              Lunges
# 1671             v_PullUps_g23_c03             PullUps              Diving
# 1672          v_Basketball_g20_c04          Basketball         HorseRiding
# 1673            v_Knitting_g08_c03            Knitting        PlayingTabla
# 1674        v_RopeClimbing_g17_c01        RopeClimbing         HeadMassage
# 1675      v_WalkingWithDog_g12_c01      WalkingWithDog        BabyCrawling
# 1676     v_FloorGymnastics_g07_c03     FloorGymnastics      BasketballDunk
# 1677   v_TrampolineJumping_g07_c01   TrampolineJumping         HorseRiding
# 1678       v_SkateBoarding_g06_c01       SkateBoarding             Rafting
# 1679      v_CricketBowling_g12_c02      CricketBowling        FrisbeeCatch
# 1680        v_BandMarching_g11_c04        BandMarching               Swing
# 1681        v_PlayingFlute_g24_c05        PlayingFlute         PlayingDhol
# 1682      v_WalkingWithDog_g14_c01      WalkingWithDog            JumpRope
# 1683       v_PlayingViolin_g11_c03       PlayingViolin      ApplyEyeMakeup
# 1684         v_ThrowDiscus_g02_c07         ThrowDiscus              Diving
# 1685       v_PlayingGuitar_g03_c06       PlayingGuitar       ApplyLipstick
# 1686      v_WalkingWithDog_g21_c03      WalkingWithDog              Skijet
# 1687         v_CricketShot_g01_c01         CricketShot      CricketBowling
# 1688      v_CricketBowling_g19_c05      CricketBowling        MoppingFloor
# 1689            v_HulaHoop_g09_c05            HulaHoop  RockClimbingIndoor
# 1690        v_BabyCrawling_g06_c01        BabyCrawling             Haircut
# 1691     v_TableTennisShot_g20_c04     TableTennisShot              Lunges
# 1692              v_Lunges_g14_c01              Lunges               Swing
# 1693        v_PlayingCello_g12_c01        PlayingCello      MilitaryParade
# 1694            v_HighJump_g07_c06            HighJump          FrontCrawl
# 1695      v_SoccerJuggling_g07_c01      SoccerJuggling        BabyCrawling
# 1696           v_Hammering_g15_c01           Hammering       SumoWrestling
# 1697        v_MoppingFloor_g02_c06        MoppingFloor         HammerThrow
# 1698           v_HorseRace_g19_c01           HorseRace           PoleVault
# 1699              v_Lunges_g11_c02              Lunges        BabyCrawling
# 1700        v_FrisbeeCatch_g22_c01        FrisbeeCatch              Mixing
# 1701           v_GolfSwing_g20_c07           GolfSwing          Basketball
# 1702         v_BlowDryHair_g10_c05         BlowDryHair             Fencing
# 1703            v_HulaHoop_g16_c05            HulaHoop        CleanAndJerk
# 1704              v_Diving_g01_c04              Diving      WalkingWithDog
# 1705         v_CliffDiving_g04_c03         CliffDiving        CleanAndJerk
# 1706              v_Mixing_g25_c01              Mixing           Hammering
# 1707            v_Kayaking_g12_c01            Kayaking             Fencing
# 1708       v_BrushingTeeth_g07_c01       BrushingTeeth      ApplyEyeMakeup
# 1709          v_BenchPress_g21_c03          BenchPress    HandstandWalking
# 1710       v_BaseballPitch_g01_c05       BaseballPitch          Basketball
# 1711          v_BenchPress_g04_c05          BenchPress         HeadMassage
# 1712            v_Kayaking_g10_c02            Kayaking          FrontCrawl
# 1713           v_PoleVault_g23_c02           PoleVault             Fencing
# 1714              v_Skiing_g20_c07              Skiing             Rafting
# 1715          v_UnevenBars_g24_c03          UnevenBars          StillRings
# 1716           v_SkyDiving_g07_c02           SkyDiving          FrontCrawl
# 1717             v_Haircut_g05_c03             Haircut      BlowingCandles
# 1718         v_ThrowDiscus_g02_c03         ThrowDiscus             Shotput
# 1719        v_ShavingBeard_g13_c01        ShavingBeard      ApplyEyeMakeup
# 1720          v_Basketball_g06_c04          Basketball      BlowingCandles
# 1721      v_BlowingCandles_g04_c02      BlowingCandles         HeadMassage
# 1722       v_SkateBoarding_g12_c02       SkateBoarding          FrontCrawl
# 1723    v_CuttingInKitchen_g10_c04    CuttingInKitchen              Mixing
# 1724    v_BodyWeightSquats_g05_c01    BodyWeightSquats          Basketball
# 1725           v_Nunchucks_g16_c02           Nunchucks           GolfSwing
# 1726            v_Kayaking_g16_c05            Kayaking          FrontCrawl
# 1727             v_Bowling_g09_c06             Bowling        BandMarching
# 1728        v_JavelinThrow_g16_c05        JavelinThrow       SumoWrestling
#
# [1729 rows x 3 columns]

# %% [markdown]
# ### Videos with correct predictions

# %%
# find video filenames
correct_predict = ~df['filename'].isin(df_mistakes['filename'])

df_correct = df[correct_predict]
# df_correct.to_pickle('./correct_predictions.pkl')

# %%
df_correct
# Out:
#                            filename                   y              y_pred
# 1            v_PlayingPiano_g17_c02        PlayingPiano        PlayingPiano
# 2                v_LongJump_g03_c03            LongJump            LongJump
# 3                  v_TaiChi_g16_c02              TaiChi              TaiChi
# 4            v_ParallelBars_g01_c04        ParallelBars        ParallelBars
# 5            v_PlayingCello_g06_c05        PlayingCello        PlayingCello
# 6            v_PizzaTossing_g17_c03        PizzaTossing        PizzaTossing
# 7            v_MoppingFloor_g23_c04        MoppingFloor        MoppingFloor
# 8              v_BenchPress_g25_c06          BenchPress          BenchPress
# 9               v_GolfSwing_g12_c01           GolfSwing           GolfSwing
# 10               v_HighJump_g02_c03            HighJump            HighJump
# 11                 v_Typing_g06_c01              Typing              Typing
# 12         v_WritingOnBoard_g01_c02      WritingOnBoard      WritingOnBoard
# 13              v_Hammering_g17_c05           Hammering           Hammering
# 14                 v_Biking_g05_c07              Biking              Biking
# 15             v_PlayingDaf_g25_c05          PlayingDaf          PlayingDaf
# 16          v_BaseballPitch_g23_c05       BaseballPitch       BaseballPitch
# 18           v_BabyCrawling_g03_c02        BabyCrawling        BabyCrawling
# 19           v_ShavingBeard_g24_c03        ShavingBeard        ShavingBeard
# 20                  v_Punch_g14_c07               Punch               Punch
# 21        v_FloorGymnastics_g15_c03     FloorGymnastics     FloorGymnastics
# 22                 v_Skiing_g22_c03              Skiing              Skiing
# 23           v_PlayingPiano_g14_c02        PlayingPiano        PlayingPiano
# 24           v_PlayingFlute_g05_c02        PlayingFlute        PlayingFlute
# 25             v_IceDancing_g08_c03          IceDancing          IceDancing
# 26               v_JumpRope_g09_c05            JumpRope            JumpRope
# 27                v_PullUps_g07_c01             PullUps             PullUps
# 28                v_Bowling_g01_c07             Bowling             Bowling
# 29           v_FrisbeeCatch_g17_c03        FrisbeeCatch        FrisbeeCatch
# 30              v_GolfSwing_g04_c01           GolfSwing           GolfSwing
# 31             v_UnevenBars_g18_c03          UnevenBars          UnevenBars
# 32              v_HorseRace_g21_c02           HorseRace           HorseRace
# 33          v_BaseballPitch_g09_c02       BaseballPitch       BaseballPitch
# 34                 v_Typing_g08_c02              Typing              Typing
# 37             v_StillRings_g23_c02          StillRings          StillRings
# 38         v_CricketBowling_g12_c04      CricketBowling      CricketBowling
# 39              v_GolfSwing_g04_c04           GolfSwing           GolfSwing
# 40                v_Fencing_g17_c02             Fencing             Fencing
# 41            v_CricketShot_g18_c05         CricketShot         CricketShot
# 42             v_FrontCrawl_g06_c05          FrontCrawl          FrontCrawl
# 44         v_MilitaryParade_g13_c02      MilitaryParade      MilitaryParade
# 47             v_StillRings_g17_c01          StillRings          StillRings
# 48           v_BabyCrawling_g01_c01        BabyCrawling        BabyCrawling
# 49          v_SkateBoarding_g13_c04       SkateBoarding       SkateBoarding
# 50         v_WalkingWithDog_g02_c05      WalkingWithDog      WalkingWithDog
# 51               v_Kayaking_g05_c04            Kayaking            Kayaking
# 52                v_Surfing_g24_c01             Surfing             Surfing
# 53            v_CricketShot_g11_c07         CricketShot         CricketShot
# 54                  v_Swing_g17_c02               Swing               Swing
# 55                v_Shotput_g19_c01             Shotput             Shotput
# 56                v_PushUps_g05_c04             PushUps             PushUps
# 57           v_BabyCrawling_g09_c03        BabyCrawling        BabyCrawling
# 58                v_Shotput_g10_c03             Shotput             Shotput
# 59          v_ApplyLipstick_g06_c03       ApplyLipstick       ApplyLipstick
# 60             v_IceDancing_g14_c04          IceDancing          IceDancing
# 62                 v_Skiing_g24_c06              Skiing              Skiing
# 64           v_JavelinThrow_g05_c05        JavelinThrow        JavelinThrow
# 65                v_PushUps_g15_c02             PushUps             PushUps
# 66          v_BaseballPitch_g18_c04       BaseballPitch       BaseballPitch
# 67           v_FrisbeeCatch_g10_c05        FrisbeeCatch        FrisbeeCatch
# 69                v_Shotput_g09_c05             Shotput             Shotput
# 70            v_WallPushups_g20_c06         WallPushups         WallPushups
# 71                v_Surfing_g24_c03             Surfing             Surfing
# 72           v_PlayingSitar_g06_c06        PlayingSitar        PlayingSitar
# 74             v_IceDancing_g02_c01          IceDancing          IceDancing
# 75                v_Bowling_g11_c02             Bowling             Bowling
# 76             v_StillRings_g01_c05          StillRings          StillRings
# 77                 v_Skiing_g02_c01              Skiing              Skiing
# 78                 v_Typing_g03_c06              Typing              Typing
# 80          v_BrushingTeeth_g20_c04       BrushingTeeth       BrushingTeeth
# 81                v_PullUps_g11_c02             PullUps             PullUps
# 82               v_JumpRope_g13_c05            JumpRope            JumpRope
# 84           v_JavelinThrow_g18_c01        JavelinThrow        JavelinThrow
# 85      v_TrampolineJumping_g09_c04   TrampolineJumping   TrampolineJumping
# 86         v_MilitaryParade_g01_c06      MilitaryParade      MilitaryParade
# 87                 v_TaiChi_g01_c01              TaiChi              TaiChi
# 89           v_MoppingFloor_g15_c01        MoppingFloor        MoppingFloor
# 90            v_BalanceBeam_g17_c04         BalanceBeam         BalanceBeam
# 91           v_PlayingFlute_g15_c01        PlayingFlute        PlayingFlute
# 92              v_Nunchucks_g04_c01           Nunchucks           Nunchucks
# 93                v_Shotput_g18_c01             Shotput             Shotput
# 94         v_CricketBowling_g02_c01      CricketBowling      CricketBowling
# 97                 v_Diving_g04_c05              Diving              Diving
# 98          v_BaseballPitch_g05_c03       BaseballPitch       BaseballPitch
# 99          v_PlayingViolin_g17_c02       PlayingViolin       PlayingViolin
# 100          v_ParallelBars_g11_c06        ParallelBars        ParallelBars
# 101              v_Drumming_g12_c01            Drumming            Drumming
# 102      v_BodyWeightSquats_g15_c01    BodyWeightSquats    BodyWeightSquats
# 103             v_HorseRace_g24_c05           HorseRace           HorseRace
# 104            v_PlayingDaf_g05_c01          PlayingDaf          PlayingDaf
# 105        v_CricketBowling_g08_c03      CricketBowling      CricketBowling
# 106                v_Skiing_g12_c02              Skiing              Skiing
# 107          v_PlayingTabla_g04_c05        PlayingTabla        PlayingTabla
# 108         v_BaseballPitch_g15_c02       BaseballPitch       BaseballPitch
# 109            v_Basketball_g04_c02          Basketball          Basketball
# 110               v_Shotput_g10_c04             Shotput             Shotput
# 112                v_Typing_g18_c02              Typing              Typing
# 114             v_Billiards_g12_c01           Billiards           Billiards
# 115             v_HorseRace_g08_c04           HorseRace           HorseRace
# 116     v_VolleyballSpiking_g07_c01   VolleyballSpiking   VolleyballSpiking
# 117           v_CricketShot_g12_c03         CricketShot         CricketShot
# 118             v_SalsaSpin_g24_c03           SalsaSpin           SalsaSpin
# 119          v_PlayingTabla_g01_c04        PlayingTabla        PlayingTabla
# 120      v_HandstandWalking_g03_c02    HandstandWalking    HandstandWalking
# 121                v_Skiing_g25_c05              Skiing              Skiing
# 122             v_GolfSwing_g05_c02           GolfSwing           GolfSwing
# 123                  v_YoYo_g16_c03                YoYo                YoYo
# 124            v_UnevenBars_g12_c03          UnevenBars          UnevenBars
# 125             v_Billiards_g15_c02           Billiards           Billiards
# 126        v_WalkingWithDog_g23_c02      WalkingWithDog      WalkingWithDog
# 127                 v_Swing_g20_c01               Swing               Swing
# 128              v_JumpRope_g19_c04            JumpRope            JumpRope
# 129     v_TrampolineJumping_g11_c04   TrampolineJumping   TrampolineJumping
# 130               v_Archery_g13_c05             Archery             Archery
# 131               v_PullUps_g19_c03             PullUps             PullUps
# 132              v_JumpRope_g03_c01            JumpRope            JumpRope
# 133           v_BlowDryHair_g18_c05         BlowDryHair         BlowDryHair
# 135              v_Drumming_g24_c06            Drumming            Drumming
# 136        v_WalkingWithDog_g23_c01      WalkingWithDog      WalkingWithDog
# 137          v_JavelinThrow_g07_c05        JavelinThrow        JavelinThrow
# 138           v_BlowDryHair_g10_c02         BlowDryHair         BlowDryHair
# 139          v_BabyCrawling_g21_c01        BabyCrawling        BabyCrawling
# 140     v_VolleyballSpiking_g16_c02   VolleyballSpiking   VolleyballSpiking
# 141              v_Kayaking_g09_c04            Kayaking            Kayaking
# 142         v_BaseballPitch_g24_c01       BaseballPitch       BaseballPitch
# 143        v_WritingOnBoard_g15_c03      WritingOnBoard      WritingOnBoard
# 144           v_BlowDryHair_g11_c07         BlowDryHair         BlowDryHair
# 145               v_Haircut_g08_c04             Haircut             Haircut
# 146          v_JavelinThrow_g24_c03        JavelinThrow        JavelinThrow
# 147         v_BrushingTeeth_g19_c05       BrushingTeeth       BrushingTeeth
# 148              v_JumpRope_g21_c04            JumpRope            JumpRope
# 150             v_Nunchucks_g16_c01           Nunchucks           Nunchucks
# 151          v_ShavingBeard_g18_c01        ShavingBeard        ShavingBeard
# 152              v_HulaHoop_g15_c05            HulaHoop            HulaHoop
# 153           v_CricketShot_g21_c01         CricketShot         CricketShot
# 154          v_PlayingCello_g12_c02        PlayingCello        PlayingCello
# 155      v_HandstandPushups_g20_c01    HandstandPushups    HandstandPushups
# 156              v_JumpRope_g04_c05            JumpRope            JumpRope
# 158          v_RopeClimbing_g25_c03        RopeClimbing        RopeClimbing
# 159         v_PlayingGuitar_g21_c01       PlayingGuitar       PlayingGuitar
# 160              v_Kayaking_g07_c01            Kayaking            Kayaking
# 161                v_Skijet_g17_c02              Skijet              Skijet
# 162        v_BoxingSpeedBag_g04_c06      BoxingSpeedBag      BoxingSpeedBag
# 163           v_WallPushups_g07_c05         WallPushups         WallPushups
# 164           v_PlayingDhol_g12_c05         PlayingDhol         PlayingDhol
# 165             v_Hammering_g09_c07           Hammering           Hammering
# 166           v_HorseRiding_g02_c02         HorseRiding         HorseRiding
# 167               v_PullUps_g22_c04             PullUps             PullUps
# 170                  v_YoYo_g09_c05                YoYo                YoYo
# 171              v_JumpRope_g21_c06            JumpRope            JumpRope
# 172    v_FieldHockeyPenalty_g09_c05  FieldHockeyPenalty  FieldHockeyPenalty
# 173             v_Billiards_g03_c05           Billiards           Billiards
# 174     v_BoxingPunchingBag_g23_c07   BoxingPunchingBag   BoxingPunchingBag
# 175         v_BrushingTeeth_g24_c04       BrushingTeeth       BrushingTeeth
# 176                v_Biking_g03_c03              Biking              Biking
# 178           v_CricketShot_g04_c01         CricketShot         CricketShot
# 179               v_Haircut_g15_c02             Haircut             Haircut
# 182           v_HammerThrow_g22_c04         HammerThrow         HammerThrow
# 183          v_BreastStroke_g05_c02        BreastStroke        BreastStroke
# 184     v_BoxingPunchingBag_g16_c03   BoxingPunchingBag   BoxingPunchingBag
# 185     v_BoxingPunchingBag_g14_c02   BoxingPunchingBag   BoxingPunchingBag
# 186           v_HorseRiding_g07_c02         HorseRiding         HorseRiding
# 187             v_SkyDiving_g23_c04           SkyDiving           SkyDiving
# 189             v_Hammering_g21_c03           Hammering           Hammering
# 190    v_FieldHockeyPenalty_g03_c02  FieldHockeyPenalty  FieldHockeyPenalty
# 191          v_FrisbeeCatch_g03_c03        FrisbeeCatch        FrisbeeCatch
# 192          v_PizzaTossing_g15_c03        PizzaTossing        PizzaTossing
# 193          v_PizzaTossing_g06_c01        PizzaTossing        PizzaTossing
# 194          v_MoppingFloor_g06_c04        MoppingFloor        MoppingFloor
# 195            v_StillRings_g09_c03          StillRings          StillRings
# 196          v_BandMarching_g07_c03        BandMarching        BandMarching
# 197           v_HammerThrow_g06_c05         HammerThrow         HammerThrow
# 198           v_CliffDiving_g24_c04         CliffDiving         CliffDiving
# 199            v_Basketball_g21_c04          Basketball          Basketball
# 200                v_Typing_g24_c01              Typing              Typing
# 201        v_CricketBowling_g03_c01      CricketBowling      CricketBowling
# 202           v_JumpingJack_g06_c02         JumpingJack         JumpingJack
# 203           v_TennisSwing_g25_c01         TennisSwing         TennisSwing
# 204          v_PizzaTossing_g11_c03        PizzaTossing        PizzaTossing
# 205          v_PlayingCello_g20_c01        PlayingCello        PlayingCello
# 206           v_CricketShot_g21_c06         CricketShot         CricketShot
# 207         v_BaseballPitch_g10_c03       BaseballPitch       BaseballPitch
# 208      v_CuttingInKitchen_g06_c04    CuttingInKitchen    CuttingInKitchen
# 209              v_Drumming_g05_c02            Drumming            Drumming
# 211          v_ParallelBars_g08_c02        ParallelBars        ParallelBars
# 212           v_BlowDryHair_g09_c01         BlowDryHair         BlowDryHair
# 213                v_Typing_g03_c01              Typing              Typing
# 215                v_Skiing_g01_c03              Skiing              Skiing
# 218         v_SoccerPenalty_g11_c03       SoccerPenalty       SoccerPenalty
# 219        v_MilitaryParade_g22_c01      MilitaryParade      MilitaryParade
# 220               v_Haircut_g15_c04             Haircut             Haircut
# 222                  v_YoYo_g04_c04                YoYo                YoYo
# 223                v_Diving_g07_c02              Diving              Diving
# 224                v_Diving_g15_c02              Diving              Diving
# 225              v_LongJump_g11_c05            LongJump            LongJump
# 226          v_BreastStroke_g10_c02        BreastStroke        BreastStroke
# 227      v_HandstandPushups_g15_c04    HandstandPushups    HandstandPushups
# 228            v_Basketball_g10_c05          Basketball          Basketball
# 229            v_UnevenBars_g09_c02          UnevenBars          UnevenBars
# 230               v_Surfing_g08_c07             Surfing             Surfing
# 231            v_StillRings_g05_c04          StillRings          StillRings
# 232            v_UnevenBars_g15_c06          UnevenBars          UnevenBars
# 233            v_PlayingDaf_g05_c04          PlayingDaf          PlayingDaf
# 234          v_BandMarching_g14_c02        BandMarching        BandMarching
# 235           v_PlayingDhol_g24_c01         PlayingDhol         PlayingDhol
# 236          v_PlayingSitar_g08_c02        PlayingSitar        PlayingSitar
# 237             v_HorseRace_g01_c01           HorseRace           HorseRace
# 238             v_Nunchucks_g21_c05           Nunchucks           Nunchucks
# 239                 v_Punch_g18_c05               Punch               Punch
# 240                 v_Swing_g15_c02               Swing               Swing
# 241        v_BlowingCandles_g08_c03      BlowingCandles      BlowingCandles
# 242           v_PommelHorse_g22_c02         PommelHorse         PommelHorse
# 243          v_PizzaTossing_g04_c01        PizzaTossing        PizzaTossing
# 244                 v_Punch_g01_c05               Punch               Punch
# 246          v_PlayingFlute_g20_c02        PlayingFlute        PlayingFlute
# 248         v_SoccerPenalty_g16_c01       SoccerPenalty       SoccerPenalty
# 249         v_PlayingGuitar_g04_c01       PlayingGuitar       PlayingGuitar
# 250       v_TableTennisShot_g19_c01     TableTennisShot     TableTennisShot
# 252                v_Diving_g15_c05              Diving              Diving
# 253               v_Bowling_g23_c04             Bowling             Bowling
# 254               v_Surfing_g16_c02             Surfing             Surfing
# 255              v_HighJump_g11_c06            HighJump            HighJump
# 256          v_BandMarching_g18_c02        BandMarching        BandMarching
# 257           v_HeadMassage_g10_c03         HeadMassage         HeadMassage
# 258                v_Typing_g06_c02              Typing              Typing
# 260           v_HammerThrow_g01_c03         HammerThrow         HammerThrow
# 261    v_RockClimbingIndoor_g20_c03  RockClimbingIndoor  RockClimbingIndoor
# 262               v_Rafting_g16_c01             Rafting             Rafting
# 264              v_Knitting_g14_c03            Knitting            Knitting
# 266        v_BasketballDunk_g21_c02      BasketballDunk      BasketballDunk
# 267             v_SalsaSpin_g03_c03           SalsaSpin           SalsaSpin
# 268             v_GolfSwing_g22_c03           GolfSwing           GolfSwing
# 269          v_CleanAndJerk_g24_c01        CleanAndJerk        CleanAndJerk
# 270          v_PizzaTossing_g04_c03        PizzaTossing        PizzaTossing
# 271          v_FrisbeeCatch_g02_c01        FrisbeeCatch        FrisbeeCatch
# 272          v_PlayingTabla_g19_c01        PlayingTabla        PlayingTabla
# 273                v_Mixing_g04_c01              Mixing              Mixing
# 274           v_WallPushups_g25_c01         WallPushups         WallPushups
# 276             v_SkyDiving_g02_c03           SkyDiving           SkyDiving
# 277           v_PlayingDhol_g23_c07         PlayingDhol         PlayingDhol
# 278          v_PlayingCello_g05_c05        PlayingCello        PlayingCello
# 279            v_FrontCrawl_g14_c01          FrontCrawl          FrontCrawl
# 280       v_FloorGymnastics_g07_c04     FloorGymnastics     FloorGymnastics
# 281            v_BenchPress_g05_c07          BenchPress          BenchPress
# 282             v_SalsaSpin_g07_c01           SalsaSpin           SalsaSpin
# 283           v_HorseRiding_g23_c04         HorseRiding         HorseRiding
# 284           v_CricketShot_g05_c04         CricketShot         CricketShot
# 285                v_Mixing_g15_c02              Mixing              Mixing
# 286               v_Archery_g07_c06             Archery             Archery
# 287               v_Surfing_g07_c01             Surfing             Surfing
# 288         v_PlayingGuitar_g21_c03       PlayingGuitar       PlayingGuitar
# 289                v_Biking_g16_c05              Biking              Biking
# 292          v_PlayingPiano_g08_c01        PlayingPiano        PlayingPiano
# 294          v_BandMarching_g20_c06        BandMarching        BandMarching
# 296           v_BlowDryHair_g21_c06         BlowDryHair         BlowDryHair
# 297          v_PizzaTossing_g19_c04        PizzaTossing        PizzaTossing
# 298          v_BandMarching_g20_c04        BandMarching        BandMarching
# 299       v_TableTennisShot_g16_c03     TableTennisShot     TableTennisShot
# 300         v_SkateBoarding_g20_c02       SkateBoarding       SkateBoarding
# 301             v_HorseRace_g21_c05           HorseRace           HorseRace
# 302        v_WritingOnBoard_g11_c06      WritingOnBoard      WritingOnBoard
# 305                v_Skijet_g21_c04              Skijet              Skijet
# 306             v_SalsaSpin_g17_c01           SalsaSpin           SalsaSpin
# 307                v_Typing_g14_c03              Typing              Typing
# 308          v_JavelinThrow_g11_c02        JavelinThrow        JavelinThrow
# 309        v_BoxingSpeedBag_g05_c05      BoxingSpeedBag      BoxingSpeedBag
# 310                v_Mixing_g10_c04              Mixing              Mixing
# 311         v_SoccerPenalty_g10_c05       SoccerPenalty       SoccerPenalty
# 312          v_BreastStroke_g09_c04        BreastStroke        BreastStroke
# 313                v_Skijet_g25_c02              Skijet              Skijet
# 314         v_BaseballPitch_g08_c05       BaseballPitch       BaseballPitch
# 316         v_PlayingGuitar_g05_c05       PlayingGuitar       PlayingGuitar
# 317              v_Kayaking_g24_c03            Kayaking            Kayaking
# 319                v_Biking_g16_c04              Biking              Biking
# 320                 v_Swing_g02_c02               Swing               Swing
# 321           v_HammerThrow_g23_c06         HammerThrow         HammerThrow
# 322           v_WallPushups_g03_c05         WallPushups         WallPushups
# 323         v_JugglingBalls_g16_c04       JugglingBalls       JugglingBalls
# 324           v_TennisSwing_g20_c01         TennisSwing         TennisSwing
# 325                v_Skiing_g12_c01              Skiing              Skiing
# 326    v_FieldHockeyPenalty_g06_c02  FieldHockeyPenalty  FieldHockeyPenalty
# 328              v_Drumming_g13_c04            Drumming            Drumming
# 329         v_SkateBoarding_g10_c06       SkateBoarding       SkateBoarding
# 330        v_BasketballDunk_g11_c03      BasketballDunk      BasketballDunk
# 332    v_FieldHockeyPenalty_g14_c06  FieldHockeyPenalty  FieldHockeyPenalty
# 333           v_HammerThrow_g14_c05         HammerThrow         HammerThrow
# 334                v_Diving_g10_c04              Diving              Diving
# 336                 v_Punch_g05_c04               Punch               Punch
# 337          v_BandMarching_g24_c02        BandMarching        BandMarching
# 338         v_SkateBoarding_g18_c04       SkateBoarding       SkateBoarding
# 339          v_CleanAndJerk_g19_c04        CleanAndJerk        CleanAndJerk
# 340    v_RockClimbingIndoor_g12_c02  RockClimbingIndoor  RockClimbingIndoor
# 341            v_FrontCrawl_g11_c07          FrontCrawl          FrontCrawl
# 342         v_ApplyLipstick_g16_c01       ApplyLipstick       ApplyLipstick
# 343          v_PlayingFlute_g23_c01        PlayingFlute        PlayingFlute
# 344           v_HammerThrow_g05_c03         HammerThrow         HammerThrow
# 345                v_Mixing_g10_c01              Mixing              Mixing
# 347         v_BrushingTeeth_g07_c02       BrushingTeeth       BrushingTeeth
# 348             v_Billiards_g15_c07           Billiards           Billiards
# 349              v_HighJump_g16_c05            HighJump            HighJump
# 350     v_BoxingPunchingBag_g20_c04   BoxingPunchingBag   BoxingPunchingBag
# 351     v_BoxingPunchingBag_g04_c03   BoxingPunchingBag   BoxingPunchingBag
# 352          v_PizzaTossing_g06_c05        PizzaTossing        PizzaTossing
# 353                v_Typing_g17_c01              Typing              Typing
# 354                v_Rowing_g01_c01              Rowing              Rowing
# 355          v_PlayingSitar_g04_c06        PlayingSitar        PlayingSitar
# 356         v_SoccerPenalty_g23_c05       SoccerPenalty       SoccerPenalty
# 358             v_PoleVault_g20_c04           PoleVault           PoleVault
# 359                v_Mixing_g02_c02              Mixing              Mixing
# 361          v_PlayingSitar_g17_c01        PlayingSitar        PlayingSitar
# 362               v_Shotput_g08_c04             Shotput             Shotput
# 363           v_BalanceBeam_g07_c02         BalanceBeam         BalanceBeam
# 364           v_HeadMassage_g19_c05         HeadMassage         HeadMassage
# 365                v_Mixing_g23_c04              Mixing              Mixing
# 366               v_Rafting_g24_c01             Rafting             Rafting
# 367          v_PlayingCello_g06_c01        PlayingCello        PlayingCello
# 368         v_SumoWrestling_g25_c03       SumoWrestling       SumoWrestling
# 369           v_HorseRiding_g13_c04         HorseRiding         HorseRiding
# 370          v_PlayingTabla_g22_c03        PlayingTabla        PlayingTabla
# 371          v_BandMarching_g01_c05        BandMarching        BandMarching
# 372           v_PlayingDhol_g15_c01         PlayingDhol         PlayingDhol
# 373          v_PlayingTabla_g12_c04        PlayingTabla        PlayingTabla
# 374                 v_Punch_g16_c04               Punch               Punch
# 375          v_JavelinThrow_g14_c06        JavelinThrow        JavelinThrow
# 376            v_BenchPress_g13_c07          BenchPress          BenchPress
# 377         v_PlayingGuitar_g14_c01       PlayingGuitar       PlayingGuitar
# 378       v_TableTennisShot_g18_c04     TableTennisShot     TableTennisShot
# 380             v_Billiards_g24_c03           Billiards           Billiards
# 381                v_Skijet_g12_c04              Skijet              Skijet
# 382                v_Lunges_g10_c05              Lunges              Lunges
# 383          v_RopeClimbing_g09_c03        RopeClimbing        RopeClimbing
# 384          v_ParallelBars_g09_c01        ParallelBars        ParallelBars
# 386             v_GolfSwing_g03_c03           GolfSwing           GolfSwing
# 387          v_PizzaTossing_g25_c01        PizzaTossing        PizzaTossing
# 388        v_CricketBowling_g24_c04      CricketBowling      CricketBowling
# 389               v_Fencing_g24_c02             Fencing             Fencing
# 390              v_Knitting_g05_c04            Knitting            Knitting
# 391             v_Billiards_g04_c07           Billiards           Billiards
# 392            v_UnevenBars_g03_c03          UnevenBars          UnevenBars
# 393        v_ApplyEyeMakeup_g24_c04      ApplyEyeMakeup      ApplyEyeMakeup
# 394          v_PlayingFlute_g10_c04        PlayingFlute        PlayingFlute
# 395         v_ApplyLipstick_g06_c05       ApplyLipstick       ApplyLipstick
# 397          v_PlayingPiano_g06_c01        PlayingPiano        PlayingPiano
# 398           v_JumpingJack_g13_c06         JumpingJack         JumpingJack
# 400                v_Skiing_g02_c04              Skiing              Skiing
# 401          v_PlayingSitar_g23_c07        PlayingSitar        PlayingSitar
# 402            v_IceDancing_g13_c04          IceDancing          IceDancing
# 403        v_BoxingSpeedBag_g17_c04      BoxingSpeedBag      BoxingSpeedBag
# 404               v_Bowling_g13_c02             Bowling             Bowling
# 405        v_ApplyEyeMakeup_g10_c05      ApplyEyeMakeup      ApplyEyeMakeup
# 406        v_MilitaryParade_g07_c02      MilitaryParade      MilitaryParade
# 410        v_CricketBowling_g04_c05      CricketBowling      CricketBowling
# 411               v_Bowling_g20_c06             Bowling             Bowling
# 412    v_RockClimbingIndoor_g05_c05  RockClimbingIndoor  RockClimbingIndoor
# 413              v_HighJump_g24_c03            HighJump            HighJump
# 414         v_SoccerPenalty_g09_c05       SoccerPenalty       SoccerPenalty
# 416            v_StillRings_g01_c01          StillRings          StillRings
# 417            v_BenchPress_g01_c01          BenchPress          BenchPress
# 418                 v_Punch_g19_c06               Punch               Punch
# 419                v_Rowing_g03_c07              Rowing              Rowing
# 421         v_SoccerPenalty_g22_c05       SoccerPenalty       SoccerPenalty
# 422                v_Lunges_g08_c04              Lunges              Lunges
# 423           v_JumpingJack_g12_c02         JumpingJack         JumpingJack
# 424             v_Hammering_g24_c05           Hammering           Hammering
# 425           v_ThrowDiscus_g07_c02         ThrowDiscus         ThrowDiscus
# 427              v_Drumming_g11_c07            Drumming            Drumming
# 428           v_HeadMassage_g15_c03         HeadMassage         HeadMassage
# 429         v_PlayingViolin_g06_c01       PlayingViolin       PlayingViolin
# 431        v_SoccerJuggling_g05_c03      SoccerJuggling      SoccerJuggling
# 432               v_PushUps_g04_c03             PushUps             PushUps
# 433        v_SoccerJuggling_g14_c03      SoccerJuggling      SoccerJuggling
# 435              v_Drumming_g17_c03            Drumming            Drumming
# 436           v_BalanceBeam_g18_c02         BalanceBeam         BalanceBeam
# 437             v_GolfSwing_g04_c02           GolfSwing           GolfSwing
# 438           v_BalanceBeam_g06_c03         BalanceBeam         BalanceBeam
# 440         v_JugglingBalls_g10_c02       JugglingBalls       JugglingBalls
# 441          v_PlayingCello_g23_c06        PlayingCello        PlayingCello
# 442          v_JavelinThrow_g10_c04        JavelinThrow        JavelinThrow
# 443         v_PlayingViolin_g23_c04       PlayingViolin       PlayingViolin
# 444         v_JugglingBalls_g03_c07       JugglingBalls       JugglingBalls
# 445                v_Mixing_g24_c02              Mixing              Mixing
# 446                v_Typing_g08_c05              Typing              Typing
# 448        v_WalkingWithDog_g02_c04      WalkingWithDog      WalkingWithDog
# 449                 v_Punch_g10_c06               Punch               Punch
# 451            v_Basketball_g23_c01          Basketball          Basketball
# 452                v_Skijet_g25_c01              Skijet              Skijet
# 453        v_ApplyEyeMakeup_g23_c05      ApplyEyeMakeup      ApplyEyeMakeup
# 454           v_JumpingJack_g12_c01         JumpingJack         JumpingJack
# 455      v_HandstandPushups_g11_c06    HandstandPushups    HandstandPushups
# 456      v_BodyWeightSquats_g14_c04    BodyWeightSquats    BodyWeightSquats
# 458                v_Skiing_g13_c02              Skiing              Skiing
# 459        v_SoccerJuggling_g11_c06      SoccerJuggling      SoccerJuggling
# 460               v_Rafting_g11_c01             Rafting             Rafting
# 462               v_Rafting_g22_c04             Rafting             Rafting
# 463          v_PizzaTossing_g22_c01        PizzaTossing        PizzaTossing
# 464                v_Skiing_g18_c01              Skiing              Skiing
# 465            v_BenchPress_g17_c03          BenchPress          BenchPress
# 466     v_BoxingPunchingBag_g07_c03   BoxingPunchingBag   BoxingPunchingBag
# 467         v_ApplyLipstick_g14_c04       ApplyLipstick       ApplyLipstick
# 469               v_Surfing_g08_c06             Surfing             Surfing
# 470           v_ThrowDiscus_g01_c03         ThrowDiscus         ThrowDiscus
# 471              v_JumpRope_g09_c02            JumpRope            JumpRope
# 474       v_FloorGymnastics_g16_c02     FloorGymnastics     FloorGymnastics
# 475         v_SumoWrestling_g05_c02       SumoWrestling       SumoWrestling
# 477      v_BodyWeightSquats_g16_c01    BodyWeightSquats    BodyWeightSquats
# 478              v_HulaHoop_g09_c01            HulaHoop            HulaHoop
# 479           v_BalanceBeam_g13_c03         BalanceBeam         BalanceBeam
# 480             v_HorseRace_g24_c02           HorseRace           HorseRace
# 481                v_Biking_g20_c04              Biking              Biking
# 482        v_BoxingSpeedBag_g11_c06      BoxingSpeedBag      BoxingSpeedBag
# 483         v_SkateBoarding_g25_c02       SkateBoarding       SkateBoarding
# 484      v_CuttingInKitchen_g05_c01    CuttingInKitchen    CuttingInKitchen
# 485         v_PlayingGuitar_g20_c03       PlayingGuitar       PlayingGuitar
# 486            v_BenchPress_g13_c06          BenchPress          BenchPress
# 488                v_Typing_g07_c01              Typing              Typing
# 489     v_TrampolineJumping_g03_c02   TrampolineJumping   TrampolineJumping
# 490        v_WritingOnBoard_g20_c06      WritingOnBoard      WritingOnBoard
# 491               v_PushUps_g21_c02             PushUps             PushUps
# 492         v_SkateBoarding_g12_c06       SkateBoarding       SkateBoarding
# 494           v_TennisSwing_g22_c04         TennisSwing         TennisSwing
# 495           v_PlayingDhol_g01_c06         PlayingDhol         PlayingDhol
# 496       v_TableTennisShot_g23_c02     TableTennisShot     TableTennisShot
# 497               v_PushUps_g10_c03             PushUps             PushUps
# 498               v_Fencing_g06_c04             Fencing             Fencing
# 501          v_PlayingCello_g13_c04        PlayingCello        PlayingCello
# 502           v_TennisSwing_g24_c04         TennisSwing         TennisSwing
# 503               v_Haircut_g07_c05             Haircut             Haircut
# 504    v_RockClimbingIndoor_g07_c04  RockClimbingIndoor  RockClimbingIndoor
# 505           v_CliffDiving_g17_c04         CliffDiving         CliffDiving
# 506          v_PlayingPiano_g15_c02        PlayingPiano        PlayingPiano
# 507          v_MoppingFloor_g20_c02        MoppingFloor        MoppingFloor
# 508          v_RopeClimbing_g23_c04        RopeClimbing        RopeClimbing
# 509          v_PlayingFlute_g09_c02        PlayingFlute        PlayingFlute
# 511            v_IceDancing_g03_c05          IceDancing          IceDancing
# 512        v_BoxingSpeedBag_g11_c05      BoxingSpeedBag      BoxingSpeedBag
# 513                v_Skijet_g18_c02              Skijet              Skijet
# 514           v_TennisSwing_g02_c06         TennisSwing         TennisSwing
# 515         v_ApplyLipstick_g22_c01       ApplyLipstick       ApplyLipstick
# 516          v_PlayingSitar_g22_c01        PlayingSitar        PlayingSitar
# 517            v_UnevenBars_g16_c05          UnevenBars          UnevenBars
# 518             v_HorseRace_g07_c05           HorseRace           HorseRace
# 519             v_HorseRace_g20_c03           HorseRace           HorseRace
# 520          v_CleanAndJerk_g16_c01        CleanAndJerk        CleanAndJerk
# 521        v_WalkingWithDog_g01_c04      WalkingWithDog      WalkingWithDog
# 522               v_Bowling_g09_c04             Bowling             Bowling
# 523      v_CuttingInKitchen_g04_c01    CuttingInKitchen    CuttingInKitchen
# 524       v_TableTennisShot_g06_c01     TableTennisShot     TableTennisShot
# 525              v_JumpRope_g24_c03            JumpRope            JumpRope
# 526           v_HeadMassage_g18_c04         HeadMassage         HeadMassage
# 527          v_PlayingSitar_g05_c07        PlayingSitar        PlayingSitar
# 528               v_Haircut_g12_c02             Haircut             Haircut
# 529          v_PlayingPiano_g16_c05        PlayingPiano        PlayingPiano
# 530                v_Mixing_g13_c01              Mixing              Mixing
# 531        v_BasketballDunk_g19_c01      BasketballDunk      BasketballDunk
# 532             v_Nunchucks_g03_c03           Nunchucks           Nunchucks
# 533           v_JumpingJack_g06_c07         JumpingJack         JumpingJack
# 534            v_Basketball_g19_c01          Basketball          Basketball
# 536              v_Drumming_g10_c05            Drumming            Drumming
# 537            v_Basketball_g16_c06          Basketball          Basketball
# 538             v_Billiards_g16_c01           Billiards           Billiards
# 539         v_SoccerPenalty_g02_c01       SoccerPenalty       SoccerPenalty
# 540           v_WallPushups_g04_c02         WallPushups         WallPushups
# 541              v_JumpRope_g21_c01            JumpRope            JumpRope
# 544              v_Knitting_g03_c04            Knitting            Knitting
# 545          v_MoppingFloor_g17_c05        MoppingFloor        MoppingFloor
# 546           v_ThrowDiscus_g21_c04         ThrowDiscus         ThrowDiscus
# 547           v_TennisSwing_g04_c04         TennisSwing         TennisSwing
# 548         v_JugglingBalls_g06_c01       JugglingBalls       JugglingBalls
# 549               v_Rafting_g16_c04             Rafting             Rafting
# 550              v_HighJump_g25_c01            HighJump            HighJump
# 551         v_JugglingBalls_g14_c01       JugglingBalls       JugglingBalls
# 552                v_TaiChi_g03_c01              TaiChi              TaiChi
# 553      v_HandstandPushups_g05_c03    HandstandPushups    HandstandPushups
# 555          v_MoppingFloor_g21_c03        MoppingFloor        MoppingFloor
# 556         v_BaseballPitch_g16_c04       BaseballPitch       BaseballPitch
# 557              v_HighJump_g03_c01            HighJump            HighJump
# 558          v_FrisbeeCatch_g05_c01        FrisbeeCatch        FrisbeeCatch
# 559          v_BandMarching_g22_c01        BandMarching        BandMarching
# 560       v_TableTennisShot_g20_c05     TableTennisShot     TableTennisShot
# 561           v_JumpingJack_g01_c05         JumpingJack         JumpingJack
# 562            v_StillRings_g20_c04          StillRings          StillRings
# 564           v_CricketShot_g25_c03         CricketShot         CricketShot
# 566    v_FieldHockeyPenalty_g25_c02  FieldHockeyPenalty  FieldHockeyPenalty
# 567              v_LongJump_g04_c05            LongJump            LongJump
# 568      v_CuttingInKitchen_g05_c06    CuttingInKitchen    CuttingInKitchen
# 569               v_Rafting_g13_c02             Rafting             Rafting
# 570         v_PlayingGuitar_g13_c01       PlayingGuitar       PlayingGuitar
# 571          v_BabyCrawling_g02_c01        BabyCrawling        BabyCrawling
# 572        v_CricketBowling_g15_c01      CricketBowling      CricketBowling
# 574                 v_Punch_g10_c02               Punch               Punch
# 575               v_PushUps_g25_c04             PushUps             PushUps
# 579           v_CricketShot_g12_c07         CricketShot         CricketShot
# 580               v_Bowling_g24_c05             Bowling             Bowling
# 581              v_JumpRope_g23_c04            JumpRope            JumpRope
# 583               v_Archery_g09_c07             Archery             Archery
# 584                v_Typing_g22_c04              Typing              Typing
# 585     v_BoxingPunchingBag_g15_c07   BoxingPunchingBag   BoxingPunchingBag
# 586          v_FrisbeeCatch_g14_c02        FrisbeeCatch        FrisbeeCatch
# 587        v_ApplyEyeMakeup_g09_c01      ApplyEyeMakeup      ApplyEyeMakeup
# 588          v_PizzaTossing_g02_c03        PizzaTossing        PizzaTossing
# 589           v_BlowDryHair_g13_c04         BlowDryHair         BlowDryHair
# ...                             ...                 ...                 ...
# 12752            v_Kayaking_g17_c04            Kayaking            Kayaking
# 12753        v_FrisbeeCatch_g12_c04        FrisbeeCatch        FrisbeeCatch
# 12754                v_YoYo_g13_c01                YoYo                YoYo
# 12755              v_Typing_g08_c01              Typing              Typing
# 12756    v_CuttingInKitchen_g08_c01    CuttingInKitchen    CuttingInKitchen
# 12757         v_BlowDryHair_g07_c03         BlowDryHair         BlowDryHair
# 12758    v_CuttingInKitchen_g21_c03    CuttingInKitchen    CuttingInKitchen
# 12759            v_Knitting_g14_c05            Knitting            Knitting
# 12760        v_PizzaTossing_g02_c04        PizzaTossing        PizzaTossing
# 12761        v_JavelinThrow_g21_c01        JavelinThrow        JavelinThrow
# 12762           v_PoleVault_g25_c03           PoleVault           PoleVault
# 12763         v_HorseRiding_g19_c03         HorseRiding         HorseRiding
# 12764         v_CricketShot_g23_c03         CricketShot         CricketShot
# 12765            v_Drumming_g15_c02            Drumming            Drumming
# 12766        v_ShavingBeard_g05_c04        ShavingBeard        ShavingBeard
# 12767              v_Skijet_g25_c04              Skijet              Skijet
# 12769             v_PushUps_g13_c03             PushUps             PushUps
# 12770        v_PizzaTossing_g25_c03        PizzaTossing        PizzaTossing
# 12772       v_SumoWrestling_g13_c04       SumoWrestling       SumoWrestling
# 12773             v_PushUps_g16_c04             PushUps             PushUps
# 12774        v_PlayingSitar_g21_c04        PlayingSitar        PlayingSitar
# 12775       v_JugglingBalls_g15_c03       JugglingBalls       JugglingBalls
# 12776        v_PlayingFlute_g11_c05        PlayingFlute        PlayingFlute
# 12777         v_BlowDryHair_g25_c04         BlowDryHair         BlowDryHair
# 12778      v_CricketBowling_g15_c02      CricketBowling      CricketBowling
# 12780             v_Rafting_g25_c02             Rafting             Rafting
# 12781              v_Skijet_g13_c02              Skijet              Skijet
# 12782          v_UnevenBars_g21_c02          UnevenBars          UnevenBars
# 12783    v_HandstandPushups_g10_c01    HandstandPushups    HandstandPushups
# 12784         v_HammerThrow_g13_c06         HammerThrow         HammerThrow
# 12785              v_Diving_g01_c05              Diving              Diving
# 12786    v_HandstandPushups_g16_c02    HandstandPushups    HandstandPushups
# 12788        v_ShavingBeard_g07_c06        ShavingBeard        ShavingBeard
# 12789         v_CricketShot_g13_c02         CricketShot         CricketShot
# 12790           v_GolfSwing_g10_c01           GolfSwing           GolfSwing
# 12792          v_BenchPress_g07_c07          BenchPress          BenchPress
# 12793        v_FrisbeeCatch_g05_c05        FrisbeeCatch        FrisbeeCatch
# 12794             v_Shotput_g11_c07             Shotput             Shotput
# 12795              v_Diving_g09_c07              Diving              Diving
# 12796            v_Drumming_g12_c03            Drumming            Drumming
# 12797            v_JumpRope_g08_c05            JumpRope            JumpRope
# 12798            v_JumpRope_g04_c03            JumpRope            JumpRope
# 12799       v_PlayingGuitar_g16_c04       PlayingGuitar       PlayingGuitar
# 12800          v_PlayingDaf_g19_c05          PlayingDaf          PlayingDaf
# 12802              v_Lunges_g21_c02              Lunges              Lunges
# 12803              v_Skiing_g13_c03              Skiing              Skiing
# 12804        v_PlayingSitar_g17_c05        PlayingSitar        PlayingSitar
# 12805        v_ShavingBeard_g17_c06        ShavingBeard        ShavingBeard
# 12806            v_JumpRope_g11_c03            JumpRope            JumpRope
# 12807            v_Drumming_g17_c05            Drumming            Drumming
# 12808      v_WalkingWithDog_g16_c01      WalkingWithDog      WalkingWithDog
# 12810              v_Rowing_g05_c02              Rowing              Rowing
# 12811         v_HammerThrow_g25_c01         HammerThrow         HammerThrow
# 12813        v_BandMarching_g23_c06        BandMarching        BandMarching
# 12814         v_BalanceBeam_g12_c04         BalanceBeam         BalanceBeam
# 12815      v_BlowingCandles_g12_c03      BlowingCandles      BlowingCandles
# 12817            v_LongJump_g04_c06            LongJump            LongJump
# 12818                v_YoYo_g08_c04                YoYo                YoYo
# 12819        v_BabyCrawling_g07_c06        BabyCrawling        BabyCrawling
# 12821              v_Diving_g06_c07              Diving              Diving
# 12822         v_PommelHorse_g02_c03         PommelHorse         PommelHorse
# 12823    v_BodyWeightSquats_g24_c03    BodyWeightSquats    BodyWeightSquats
# 12824        v_ShavingBeard_g20_c02        ShavingBeard        ShavingBeard
# 12825           v_SkyDiving_g04_c04           SkyDiving           SkyDiving
# 12826           v_HorseRace_g15_c01           HorseRace           HorseRace
# 12827         v_HammerThrow_g08_c01         HammerThrow         HammerThrow
# 12828         v_WallPushups_g06_c07         WallPushups         WallPushups
# 12830              v_TaiChi_g22_c04              TaiChi              TaiChi
# 12831             v_Archery_g07_c01             Archery             Archery
# 12832           v_Billiards_g25_c03           Billiards           Billiards
# 12833         v_BalanceBeam_g11_c03         BalanceBeam         BalanceBeam
# 12834      v_BoxingSpeedBag_g09_c01      BoxingSpeedBag      BoxingSpeedBag
# 12835          v_IceDancing_g19_c07          IceDancing          IceDancing
# 12836             v_PushUps_g21_c04             PushUps             PushUps
# 12837        v_BreastStroke_g14_c01        BreastStroke        BreastStroke
# 12838          v_IceDancing_g11_c01          IceDancing          IceDancing
# 12839       v_ApplyLipstick_g24_c01       ApplyLipstick       ApplyLipstick
# 12840             v_PullUps_g12_c01             PullUps             PullUps
# 12841             v_Surfing_g15_c02             Surfing             Surfing
# 12842            v_Knitting_g15_c05            Knitting            Knitting
# 12843         v_HeadMassage_g25_c05         HeadMassage         HeadMassage
# 12844             v_Archery_g10_c05             Archery             Archery
# 12845         v_TennisSwing_g06_c06         TennisSwing         TennisSwing
# 12846               v_Swing_g24_c04               Swing               Swing
# 12847       v_PlayingGuitar_g13_c06       PlayingGuitar       PlayingGuitar
# 12848        v_FrisbeeCatch_g09_c05        FrisbeeCatch        FrisbeeCatch
# 12849       v_SkateBoarding_g07_c02       SkateBoarding       SkateBoarding
# 12850           v_PoleVault_g08_c04           PoleVault           PoleVault
# 12851           v_SalsaSpin_g22_c01           SalsaSpin           SalsaSpin
# 12852            v_LongJump_g18_c03            LongJump            LongJump
# 12853         v_ThrowDiscus_g09_c05         ThrowDiscus         ThrowDiscus
# 12854         v_PommelHorse_g23_c03         PommelHorse         PommelHorse
# 12855        v_RopeClimbing_g14_c01        RopeClimbing        RopeClimbing
# 12856   v_VolleyballSpiking_g08_c04   VolleyballSpiking   VolleyballSpiking
# 12857             v_Surfing_g15_c04             Surfing             Surfing
# 12858            v_Knitting_g04_c01            Knitting            Knitting
# 12860          v_Basketball_g25_c07          Basketball          Basketball
# 12861         v_CliffDiving_g15_c03         CliffDiving         CliffDiving
# 12862          v_PlayingDaf_g10_c07          PlayingDaf          PlayingDaf
# 12863              v_Lunges_g23_c01              Lunges              Lunges
# 12864           v_Nunchucks_g10_c04           Nunchucks           Nunchucks
# 12865  v_FieldHockeyPenalty_g11_c04  FieldHockeyPenalty  FieldHockeyPenalty
# 12866      v_BoxingSpeedBag_g09_c03      BoxingSpeedBag      BoxingSpeedBag
# 12868        v_FrisbeeCatch_g25_c03        FrisbeeCatch        FrisbeeCatch
# 12870         v_HorseRiding_g25_c05         HorseRiding         HorseRiding
# 12871             v_Shotput_g03_c03             Shotput             Shotput
# 12872    v_HandstandPushups_g18_c05    HandstandPushups    HandstandPushups
# 12873        v_CleanAndJerk_g19_c02        CleanAndJerk        CleanAndJerk
# 12874             v_PullUps_g25_c04             PullUps             PullUps
# 12875          v_FrontCrawl_g07_c05          FrontCrawl          FrontCrawl
# 12876        v_MoppingFloor_g01_c02        MoppingFloor        MoppingFloor
# 12877       v_BaseballPitch_g04_c05       BaseballPitch       BaseballPitch
# 12878           v_HorseRace_g18_c03           HorseRace           HorseRace
# 12879        v_JavelinThrow_g04_c02        JavelinThrow        JavelinThrow
# 12880              v_TaiChi_g08_c01              TaiChi              TaiChi
# 12881            v_Kayaking_g19_c03            Kayaking            Kayaking
# 12882           v_SalsaSpin_g05_c06           SalsaSpin           SalsaSpin
# 12883     v_TableTennisShot_g15_c03     TableTennisShot     TableTennisShot
# 12884         v_HorseRiding_g06_c02         HorseRiding         HorseRiding
# 12885          v_FrontCrawl_g20_c06          FrontCrawl          FrontCrawl
# 12886    v_CuttingInKitchen_g17_c01    CuttingInKitchen    CuttingInKitchen
# 12887           v_PoleVault_g22_c01           PoleVault           PoleVault
# 12888        v_PlayingCello_g25_c02        PlayingCello        PlayingCello
# 12889   v_VolleyballSpiking_g19_c04   VolleyballSpiking   VolleyballSpiking
# 12891           v_SalsaSpin_g11_c06           SalsaSpin           SalsaSpin
# 12892         v_PlayingDhol_g25_c03         PlayingDhol         PlayingDhol
# 12893       v_JugglingBalls_g03_c03       JugglingBalls       JugglingBalls
# 12894              v_Skijet_g01_c01              Skijet              Skijet
# 12895         v_HammerThrow_g19_c04         HammerThrow         HammerThrow
# ...
# 13084        v_ParallelBars_g02_c02        ParallelBars        ParallelBars
# 13085                v_YoYo_g17_c03                YoYo                YoYo
# 13086              v_Mixing_g01_c03              Mixing              Mixing
# 13087       v_PlayingGuitar_g20_c02       PlayingGuitar       PlayingGuitar
# 13088           v_SkyDiving_g23_c01           SkyDiving           SkyDiving
# 13089              v_Typing_g02_c06              Typing              Typing
# 13090            v_Drumming_g12_c02            Drumming            Drumming
# 13091         v_HeadMassage_g11_c06         HeadMassage         HeadMassage
# 13092              v_Mixing_g01_c05              Mixing              Mixing
# 13093         v_PlayingDhol_g04_c06         PlayingDhol         PlayingDhol
# 13095              v_TaiChi_g21_c01              TaiChi              TaiChi
# 13097          v_PlayingDaf_g06_c03          PlayingDaf          PlayingDaf
# 13099           v_SalsaSpin_g08_c05           SalsaSpin           SalsaSpin
# 13100         v_CricketShot_g22_c02         CricketShot         CricketShot
# 13101            v_LongJump_g15_c03            LongJump            LongJump
# 13102       v_ApplyLipstick_g14_c01       ApplyLipstick       ApplyLipstick
# 13103      v_MilitaryParade_g06_c04      MilitaryParade      MilitaryParade
# 13104            v_Kayaking_g19_c02            Kayaking            Kayaking
# 13105      v_SoccerJuggling_g18_c03      SoccerJuggling      SoccerJuggling
# 13106          v_IceDancing_g09_c01          IceDancing          IceDancing
# 13107              v_Diving_g08_c02              Diving              Diving
# 13108         v_JumpingJack_g10_c01         JumpingJack         JumpingJack
# 13109      v_WalkingWithDog_g23_c04      WalkingWithDog      WalkingWithDog
# 13110            v_Kayaking_g09_c05            Kayaking            Kayaking
# 13111         v_CricketShot_g12_c05         CricketShot         CricketShot
# 13112        v_CleanAndJerk_g12_c04        CleanAndJerk        CleanAndJerk
# 13113           v_SkyDiving_g06_c03           SkyDiving           SkyDiving
# 13114        v_ParallelBars_g02_c03        ParallelBars        ParallelBars
# 13115          v_IceDancing_g13_c02          IceDancing          IceDancing
# 13116           v_PoleVault_g03_c03           PoleVault           PoleVault
# 13117         v_TennisSwing_g08_c06         TennisSwing         TennisSwing
# 13118             v_Rafting_g08_c05             Rafting             Rafting
# 13119      v_ApplyEyeMakeup_g04_c03      ApplyEyeMakeup      ApplyEyeMakeup
# 13120      v_MilitaryParade_g11_c02      MilitaryParade      MilitaryParade
# 13121           v_PoleVault_g18_c02           PoleVault           PoleVault
# 13122       v_PlayingGuitar_g12_c01       PlayingGuitar       PlayingGuitar
# 13123      v_BlowingCandles_g10_c01      BlowingCandles      BlowingCandles
# 13124       v_PlayingGuitar_g08_c06       PlayingGuitar       PlayingGuitar
# 13125   v_BoxingPunchingBag_g08_c06   BoxingPunchingBag   BoxingPunchingBag
# 13126          v_PlayingDaf_g05_c03          PlayingDaf          PlayingDaf
# 13127         v_TennisSwing_g15_c05         TennisSwing         TennisSwing
# 13128            v_Kayaking_g09_c02            Kayaking            Kayaking
# 13129   v_TrampolineJumping_g20_c04   TrampolineJumping   TrampolineJumping
# 13130   v_BoxingPunchingBag_g16_c05   BoxingPunchingBag   BoxingPunchingBag
# 13131       v_SumoWrestling_g24_c04       SumoWrestling       SumoWrestling
# 13132       v_BrushingTeeth_g19_c02       BrushingTeeth       BrushingTeeth
# 13133             v_Surfing_g20_c03             Surfing             Surfing
# 13134       v_SumoWrestling_g08_c06       SumoWrestling       SumoWrestling
# 13135        v_ShavingBeard_g16_c01        ShavingBeard        ShavingBeard
# 13136        v_BandMarching_g25_c02        BandMarching        BandMarching
# 13137             v_Shotput_g08_c02             Shotput             Shotput
# 13138    v_HandstandWalking_g12_c03    HandstandWalking    HandstandWalking
# 13139        v_FrisbeeCatch_g16_c05        FrisbeeCatch        FrisbeeCatch
# 13141   v_BoxingPunchingBag_g20_c02   BoxingPunchingBag   BoxingPunchingBag
# 13142         v_HammerThrow_g02_c05         HammerThrow         HammerThrow
# 13143        v_PizzaTossing_g04_c05        PizzaTossing        PizzaTossing
# 13144        v_BandMarching_g05_c04        BandMarching        BandMarching
# 13145              v_Typing_g14_c05              Typing              Typing
# 13146           v_SkyDiving_g02_c02           SkyDiving           SkyDiving
# 13147               v_Punch_g25_c07               Punch               Punch
# 13148        v_CleanAndJerk_g20_c04        CleanAndJerk        CleanAndJerk
# 13149         v_WallPushups_g11_c04         WallPushups         WallPushups
# 13150     v_FloorGymnastics_g16_c03     FloorGymnastics     FloorGymnastics
# 13151               v_Swing_g21_c03               Swing               Swing
# 13152         v_CliffDiving_g22_c02         CliffDiving         CliffDiving
# 13153    v_BodyWeightSquats_g10_c05    BodyWeightSquats    BodyWeightSquats
# 13154    v_HandstandWalking_g21_c04    HandstandWalking    HandstandWalking
# 13155        v_FrisbeeCatch_g09_c02        FrisbeeCatch        FrisbeeCatch
# 13157       v_JugglingBalls_g08_c01       JugglingBalls       JugglingBalls
# 13158      v_BoxingSpeedBag_g20_c04      BoxingSpeedBag      BoxingSpeedBag
# 13159        v_JavelinThrow_g05_c03        JavelinThrow        JavelinThrow
# 13161             v_Surfing_g14_c04             Surfing             Surfing
# 13162     v_TableTennisShot_g24_c03     TableTennisShot     TableTennisShot
# 13163        v_PlayingSitar_g19_c03        PlayingSitar        PlayingSitar
# 13164        v_JavelinThrow_g01_c03        JavelinThrow        JavelinThrow
# 13165              v_Diving_g10_c02              Diving              Diving
# 13166         v_CliffDiving_g23_c05         CliffDiving         CliffDiving
# 13168           v_Hammering_g11_c03           Hammering           Hammering
# 13170      v_WalkingWithDog_g14_c03      WalkingWithDog      WalkingWithDog
# 13171          v_FrontCrawl_g20_c04          FrontCrawl          FrontCrawl
# 13172         v_CliffDiving_g05_c02         CliffDiving         CliffDiving
# 13173         v_BlowDryHair_g19_c04         BlowDryHair         BlowDryHair
# 13174             v_Haircut_g08_c06             Haircut             Haircut
# 13175             v_Rafting_g03_c02             Rafting             Rafting
# 13176               v_Punch_g12_c05               Punch               Punch
# 13177   v_VolleyballSpiking_g24_c02   VolleyballSpiking   VolleyballSpiking
# 13178             v_Surfing_g07_c02             Surfing             Surfing
# 13179      v_SoccerJuggling_g01_c01      SoccerJuggling      SoccerJuggling
# 13180              v_Skiing_g04_c07              Skiing              Skiing
# 13181                v_YoYo_g03_c03                YoYo                YoYo
# 13182        v_ParallelBars_g16_c04        ParallelBars        ParallelBars
# 13183            v_Kayaking_g16_c03            Kayaking            Kayaking
# 13184      v_BasketballDunk_g05_c04      BasketballDunk      BasketballDunk
# 13185        v_PlayingCello_g16_c02        PlayingCello        PlayingCello
# 13187       v_SumoWrestling_g07_c04       SumoWrestling       SumoWrestling
# 13188         v_BalanceBeam_g17_c02         BalanceBeam         BalanceBeam
# 13189    v_HandstandWalking_g13_c03    HandstandWalking    HandstandWalking
# 13190         v_WallPushups_g16_c07         WallPushups         WallPushups
# 13191       v_BrushingTeeth_g05_c01       BrushingTeeth       BrushingTeeth
# 13192           v_SkyDiving_g18_c05           SkyDiving           SkyDiving
# 13193   v_TrampolineJumping_g12_c03   TrampolineJumping   TrampolineJumping
# 13194        v_BreastStroke_g06_c01        BreastStroke        BreastStroke
# 13195         v_HammerThrow_g03_c04         HammerThrow         HammerThrow
# 13196          v_Basketball_g23_c03          Basketball          Basketball
# 13197        v_BabyCrawling_g13_c05        BabyCrawling        BabyCrawling
# 13199              v_Rowing_g10_c01              Rowing              Rowing
# 13200         v_JumpingJack_g05_c06         JumpingJack         JumpingJack
# 13201            v_HulaHoop_g02_c01            HulaHoop            HulaHoop
# 13202         v_HeadMassage_g14_c02         HeadMassage         HeadMassage
# 13203    v_BodyWeightSquats_g18_c04    BodyWeightSquats    BodyWeightSquats
# 13204         v_CricketShot_g06_c02         CricketShot         CricketShot
# 13205         v_PommelHorse_g02_c04         PommelHorse         PommelHorse
# 13206              v_Skiing_g05_c01              Skiing              Skiing
# 13207      v_BasketballDunk_g08_c05      BasketballDunk      BasketballDunk
# 13208       v_SumoWrestling_g17_c02       SumoWrestling       SumoWrestling
# 13209            v_HighJump_g16_c02            HighJump            HighJump
# 13210      v_WritingOnBoard_g05_c03      WritingOnBoard      WritingOnBoard
# 13211       v_JugglingBalls_g01_c01       JugglingBalls       JugglingBalls
# 13213          v_FrontCrawl_g05_c04          FrontCrawl          FrontCrawl
# 13214              v_Biking_g15_c03              Biking              Biking
# 13215            v_LongJump_g05_c02            LongJump            LongJump
# 13217           v_Nunchucks_g20_c02           Nunchucks           Nunchucks
# 13218       v_SkateBoarding_g23_c02       SkateBoarding       SkateBoarding
# 13219      v_CricketBowling_g18_c04      CricketBowling      CricketBowling
# 13220          v_BenchPress_g08_c06          BenchPress          BenchPress
# 13221             v_Archery_g05_c03             Archery             Archery
# 13222     v_TableTennisShot_g14_c02     TableTennisShot     TableTennisShot
# 13223             v_Bowling_g25_c05             Bowling             Bowling
# 13225         v_HeadMassage_g17_c06         HeadMassage         HeadMassage
# 13226        v_PlayingTabla_g23_c03        PlayingTabla        PlayingTabla
# 13227       v_SumoWrestling_g04_c01       SumoWrestling       SumoWrestling
# 13228             v_Archery_g12_c03             Archery             Archery
# 13229      v_MilitaryParade_g14_c05      MilitaryParade      MilitaryParade
# 13231          v_PlayingDaf_g10_c03          PlayingDaf          PlayingDaf
# 13232                v_YoYo_g01_c02                YoYo                YoYo
# 13233       v_PlayingGuitar_g05_c01       PlayingGuitar       PlayingGuitar
# 13234              v_Lunges_g19_c01              Lunges              Lunges
# 13236   v_VolleyballSpiking_g14_c04   VolleyballSpiking   VolleyballSpiking
# 13237         v_CliffDiving_g22_c06         CliffDiving         CliffDiving
# 13239           v_SkyDiving_g21_c01           SkyDiving           SkyDiving
# 13241         v_ThrowDiscus_g01_c01         ThrowDiscus         ThrowDiscus
# 13243      v_ApplyEyeMakeup_g25_c07      ApplyEyeMakeup      ApplyEyeMakeup
# 13244              v_Skiing_g18_c03              Skiing              Skiing
# 13246         v_HeadMassage_g23_c06         HeadMassage         HeadMassage
# 13247              v_TaiChi_g01_c02              TaiChi              TaiChi
# 13248          v_FrontCrawl_g04_c06          FrontCrawl          FrontCrawl
# 13249           v_Nunchucks_g05_c04           Nunchucks           Nunchucks
# 13251        v_PlayingPiano_g12_c04        PlayingPiano        PlayingPiano
# 13252      v_WalkingWithDog_g25_c02      WalkingWithDog      WalkingWithDog
# 13253       v_PlayingGuitar_g10_c06       PlayingGuitar       PlayingGuitar
# 13254           v_Hammering_g19_c01           Hammering           Hammering
# 13255            v_JumpRope_g20_c05            JumpRope            JumpRope
# 13256         v_CricketShot_g21_c04         CricketShot         CricketShot
# 13257           v_Hammering_g03_c01           Hammering           Hammering
# 13258           v_Billiards_g14_c04           Billiards           Billiards
# 13260      v_ApplyEyeMakeup_g09_c06      ApplyEyeMakeup      ApplyEyeMakeup
# 13261        v_BandMarching_g02_c05        BandMarching        BandMarching
# 13262      v_BoxingSpeedBag_g20_c05      BoxingSpeedBag      BoxingSpeedBag
# 13263      v_MilitaryParade_g17_c02      MilitaryParade      MilitaryParade
# 13264             v_Bowling_g06_c01             Bowling             Bowling
# 13265     v_FloorGymnastics_g12_c01     FloorGymnastics     FloorGymnastics
# 13266              v_Typing_g02_c05              Typing              Typing
# 13267          v_PlayingDaf_g20_c01          PlayingDaf          PlayingDaf
# 13268    v_HandstandWalking_g01_c04    HandstandWalking    HandstandWalking
# 13269        v_BandMarching_g09_c02        BandMarching        BandMarching
# 13270      v_WalkingWithDog_g05_c04      WalkingWithDog      WalkingWithDog
# 13271          v_Basketball_g09_c03          Basketball          Basketball
# 13272         v_HorseRiding_g25_c04         HorseRiding         HorseRiding
# 13273         v_CliffDiving_g25_c04         CliffDiving         CliffDiving
# 13274          v_StillRings_g11_c01          StillRings          StillRings
# 13276              v_Rowing_g07_c03              Rowing              Rowing
# 13277             v_Surfing_g04_c01             Surfing             Surfing
# 13278             v_Fencing_g25_c04             Fencing             Fencing
# 13279             v_Surfing_g15_c03             Surfing             Surfing
# 13280              v_Rowing_g14_c05              Rowing              Rowing
# 13281           v_Hammering_g17_c01           Hammering           Hammering
# 13282           v_Billiards_g02_c07           Billiards           Billiards
# 13283              v_Skiing_g11_c04              Skiing              Skiing
# 13284      v_SoccerJuggling_g19_c06      SoccerJuggling      SoccerJuggling
# 13285           v_Nunchucks_g22_c03           Nunchucks           Nunchucks
# 13286         v_BalanceBeam_g15_c02         BalanceBeam         BalanceBeam
# 13287      v_MilitaryParade_g03_c01      MilitaryParade      MilitaryParade
# 13288  v_FieldHockeyPenalty_g23_c04  FieldHockeyPenalty  FieldHockeyPenalty
# 13289             v_Archery_g18_c02             Archery             Archery
# 13290             v_Rafting_g08_c01             Rafting             Rafting
# 13291         v_HeadMassage_g16_c04         HeadMassage         HeadMassage
# 13292         v_PlayingDhol_g05_c06         PlayingDhol         PlayingDhol
# 13294   v_VolleyballSpiking_g09_c06   VolleyballSpiking   VolleyballSpiking
# 13295   v_BoxingPunchingBag_g03_c03   BoxingPunchingBag   BoxingPunchingBag
# 13296         v_PlayingDhol_g25_c05         PlayingDhol         PlayingDhol
# 13297       v_SoccerPenalty_g06_c06       SoccerPenalty       SoccerPenalty
# 13298       v_BrushingTeeth_g03_c03       BrushingTeeth       BrushingTeeth
# 13299    v_HandstandPushups_g13_c01    HandstandPushups    HandstandPushups
# 13300           v_SkyDiving_g19_c02           SkyDiving           SkyDiving
# 13301          v_BenchPress_g12_c01          BenchPress          BenchPress
# 13303           v_Nunchucks_g25_c04           Nunchucks           Nunchucks
# 13304    v_BodyWeightSquats_g01_c02    BodyWeightSquats    BodyWeightSquats
# 13305            v_HulaHoop_g03_c03            HulaHoop            HulaHoop
# 13306             v_Bowling_g16_c02             Bowling             Bowling
# 13308        v_PlayingPiano_g15_c03        PlayingPiano        PlayingPiano
# 13309             v_Shotput_g20_c03             Shotput             Shotput
# 13310       v_PlayingGuitar_g23_c02       PlayingGuitar       PlayingGuitar
# 13311         v_BlowDryHair_g07_c01         BlowDryHair         BlowDryHair
# 13312          v_StillRings_g10_c03          StillRings          StillRings
# 13313   v_BoxingPunchingBag_g08_c05   BoxingPunchingBag   BoxingPunchingBag
# 13314            v_JumpRope_g15_c01            JumpRope            JumpRope
# 13315       v_PlayingGuitar_g20_c04       PlayingGuitar       PlayingGuitar
# 13317        v_PlayingSitar_g23_c05        PlayingSitar        PlayingSitar
# 13318      v_BasketballDunk_g19_c03      BasketballDunk      BasketballDunk
# 13319            v_Drumming_g03_c04            Drumming            Drumming
#
# [11591 rows x 3 columns]

# %%
N = len(df)
N_correct = len(df_correct)
N_mistake = len(df_mistakes)

print('total videos: {}'.format(N))
print('Accuracy: {:.2f}%'.format(N_correct/N * 100))
# Out:
# total videos: 13320
# Accuracy: 87.02%
