# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 1000)

# %%
df = pd.read_pickle('./UCF101_videos_prediction.pkl')

# %%
df
# Out:
#                            filename                   y              y_pred
# 0            v_PlayingSitar_g09_c06        PlayingSitar        PlayingSitar
# 1            v_PlayingPiano_g17_c02        PlayingPiano        PlayingPiano
# 2                v_LongJump_g03_c03            LongJump            LongJump
# 3                  v_TaiChi_g16_c02              TaiChi              TaiChi
# 4            v_ParallelBars_g01_c04        ParallelBars        ParallelBars
# 5            v_PlayingCello_g06_c05        PlayingCello        PlayingCello
# 6            v_PizzaTossing_g17_c03        PizzaTossing        PizzaTossing
# 7            v_MoppingFloor_g23_c04        MoppingFloor        MoppingFloor
# 8              v_BenchPress_g25_c06          BenchPress          BenchPress
# 9               v_GolfSwing_g12_c01           GolfSwing           GolfSwing
# 10               v_HighJump_g02_c03            HighJump            HighJump
# 11                 v_Typing_g06_c01              Typing              Typing
# 12         v_WritingOnBoard_g01_c02      WritingOnBoard      WritingOnBoard
# 13              v_Hammering_g17_c05           Hammering           Hammering
# 14                 v_Biking_g05_c07              Biking              Biking
# 15             v_PlayingDaf_g25_c05          PlayingDaf          PlayingDaf
# 16          v_BaseballPitch_g23_c05       BaseballPitch       BaseballPitch
# 17           v_FrisbeeCatch_g17_c04        FrisbeeCatch        FrisbeeCatch
# 18           v_BabyCrawling_g03_c02        BabyCrawling        BabyCrawling
# 19           v_ShavingBeard_g24_c03        ShavingBeard        ShavingBeard
# 20                  v_Punch_g14_c07               Punch               Punch
# 21        v_FloorGymnastics_g15_c03     FloorGymnastics     FloorGymnastics
# 22                 v_Skiing_g22_c03              Skiing              Skiing
# 23           v_PlayingPiano_g14_c02        PlayingPiano        PlayingPiano
# 24           v_PlayingFlute_g05_c02        PlayingFlute        PlayingFlute
# 25             v_IceDancing_g08_c03          IceDancing          IceDancing
# 26               v_JumpRope_g09_c05            JumpRope            JumpRope
# 27                v_PullUps_g07_c01             PullUps             PullUps
# 28                v_Bowling_g01_c07             Bowling             Bowling
# 29           v_FrisbeeCatch_g17_c03        FrisbeeCatch        FrisbeeCatch
# 30              v_GolfSwing_g04_c01           GolfSwing           GolfSwing
# 31             v_UnevenBars_g18_c03          UnevenBars          UnevenBars
# 32              v_HorseRace_g21_c02           HorseRace           HorseRace
# 33          v_BaseballPitch_g09_c02       BaseballPitch       BaseballPitch
# 34                 v_Typing_g08_c02              Typing              Typing
# 35           v_PizzaTossing_g12_c03        PizzaTossing        PizzaTossing
# 36     v_FieldHockeyPenalty_g13_c02  FieldHockeyPenalty  FieldHockeyPenalty
# 37             v_StillRings_g23_c02          StillRings          StillRings
# 38         v_CricketBowling_g12_c04      CricketBowling      CricketBowling
# 39              v_GolfSwing_g04_c04           GolfSwing           GolfSwing
# 40                v_Fencing_g17_c02             Fencing             Fencing
# 41            v_CricketShot_g18_c05         CricketShot         CricketShot
# 42             v_FrontCrawl_g06_c05          FrontCrawl          FrontCrawl
# 43                 v_Skiing_g17_c02              Skiing              Skiing
# 44         v_MilitaryParade_g13_c02      MilitaryParade      MilitaryParade
# 45          v_SkateBoarding_g24_c02       SkateBoarding         CricketShot
# 46               v_Knitting_g10_c01            Knitting            Knitting
# 47             v_StillRings_g17_c01          StillRings          StillRings
# 48           v_BabyCrawling_g01_c01        BabyCrawling        BabyCrawling
# 49          v_SkateBoarding_g13_c04       SkateBoarding       SkateBoarding
# 50         v_WalkingWithDog_g02_c05      WalkingWithDog       SkateBoarding
# 51               v_Kayaking_g05_c04            Kayaking            Kayaking
# 52                v_Surfing_g24_c01             Surfing             Surfing
# 53            v_CricketShot_g11_c07         CricketShot         CricketShot
# 54                  v_Swing_g17_c02               Swing               Swing
# 55                v_Shotput_g19_c01             Shotput             Shotput
# 56                v_PushUps_g05_c04             PushUps             PushUps
# 57           v_BabyCrawling_g09_c03        BabyCrawling        BabyCrawling
# 58                v_Shotput_g10_c03             Shotput             Shotput
# 59          v_ApplyLipstick_g06_c03       ApplyLipstick       ApplyLipstick
# 60             v_IceDancing_g14_c04          IceDancing          IceDancing
# 61         v_CricketBowling_g19_c06      CricketBowling           SalsaSpin
# 62                 v_Skiing_g24_c06              Skiing              Skiing
# 63          v_BaseballPitch_g19_c01       BaseballPitch       BaseballPitch
# 64           v_JavelinThrow_g05_c05        JavelinThrow        JavelinThrow
# 65                v_PushUps_g15_c02             PushUps             PushUps
# 66          v_BaseballPitch_g18_c04       BaseballPitch       BaseballPitch
# 67           v_FrisbeeCatch_g10_c05        FrisbeeCatch        FrisbeeCatch
# 68                v_PushUps_g20_c03             PushUps             PushUps
# 69                v_Shotput_g09_c05             Shotput             Shotput
# 70            v_WallPushups_g20_c06         WallPushups         WallPushups
# 71                v_Surfing_g24_c03             Surfing             Surfing
# 72           v_PlayingSitar_g06_c06        PlayingSitar        PlayingSitar
# 73                 v_Rowing_g15_c04              Rowing              Rowing
# 74             v_IceDancing_g02_c01          IceDancing          IceDancing
# 75                v_Bowling_g11_c02             Bowling             Bowling
# 76             v_StillRings_g01_c05          StillRings          StillRings
# 77                 v_Skiing_g02_c01              Skiing              Skiing
# 78                 v_Typing_g03_c06              Typing              Typing
# 79             v_StillRings_g10_c02          StillRings          StillRings
# 80          v_BrushingTeeth_g20_c04       BrushingTeeth       BrushingTeeth
# 81                v_PullUps_g11_c02             PullUps             PullUps
# 82               v_JumpRope_g13_c05            JumpRope            JumpRope
# 83          v_BrushingTeeth_g12_c06       BrushingTeeth       BrushingTeeth
# 84           v_JavelinThrow_g18_c01        JavelinThrow        JavelinThrow
# 85      v_TrampolineJumping_g09_c04   TrampolineJumping   TrampolineJumping
# 86         v_MilitaryParade_g01_c06      MilitaryParade      MilitaryParade
# 87                 v_TaiChi_g01_c01              TaiChi              TaiChi
# 88                 v_Biking_g04_c04              Biking               Swing
# 89           v_MoppingFloor_g15_c01        MoppingFloor        MoppingFloor
# 90            v_BalanceBeam_g17_c04         BalanceBeam         BalanceBeam
# 91           v_PlayingFlute_g15_c01        PlayingFlute        PlayingFlute
# 92              v_Nunchucks_g04_c01           Nunchucks           Nunchucks
# 93                v_Shotput_g18_c01             Shotput             Shotput
# 94         v_CricketBowling_g02_c01      CricketBowling      CricketBowling
# 95           v_RopeClimbing_g05_c05        RopeClimbing             PullUps
# 96           v_FrisbeeCatch_g08_c01        FrisbeeCatch        FrisbeeCatch
# 97                 v_Diving_g04_c05              Diving              Diving
# 98          v_BaseballPitch_g05_c03       BaseballPitch       BaseballPitch
# 99          v_PlayingViolin_g17_c02       PlayingViolin       PlayingViolin
# 100          v_ParallelBars_g11_c06        ParallelBars        ParallelBars
# 101              v_Drumming_g12_c01            Drumming            Drumming
# 102      v_BodyWeightSquats_g15_c01    BodyWeightSquats             Shotput
# 103             v_HorseRace_g24_c05           HorseRace           HorseRace
# 104            v_PlayingDaf_g05_c01          PlayingDaf          PlayingDaf
# 105        v_CricketBowling_g08_c03      CricketBowling      CricketBowling
# 106                v_Skiing_g12_c02              Skiing              Skiing
# 107          v_PlayingTabla_g04_c05        PlayingTabla        PlayingTabla
# 108         v_BaseballPitch_g15_c02       BaseballPitch       BaseballPitch
# 109            v_Basketball_g04_c02          Basketball          Basketball
# 110               v_Shotput_g10_c04             Shotput             Shotput
# 111           v_PlayingDhol_g05_c01         PlayingDhol         PlayingDhol
# 112                v_Typing_g18_c02              Typing              Typing
# 113        v_CricketBowling_g09_c03      CricketBowling      CricketBowling
# 114             v_Billiards_g12_c01           Billiards           Billiards
# 115             v_HorseRace_g08_c04           HorseRace           HorseRace
# 116     v_VolleyballSpiking_g07_c01   VolleyballSpiking   VolleyballSpiking
# 117           v_CricketShot_g12_c03         CricketShot         CricketShot
# 118             v_SalsaSpin_g24_c03           SalsaSpin           SalsaSpin
# 119          v_PlayingTabla_g01_c04        PlayingTabla        PlayingTabla
# 120      v_HandstandWalking_g03_c02    HandstandWalking    HandstandWalking
# 121                v_Skiing_g25_c05              Skiing              Skiing
# 122             v_GolfSwing_g05_c02           GolfSwing           GolfSwing
# 123                  v_YoYo_g16_c03                YoYo                YoYo
# 124            v_UnevenBars_g12_c03          UnevenBars          UnevenBars
# 125             v_Billiards_g15_c02           Billiards           Billiards
# 126        v_WalkingWithDog_g23_c02      WalkingWithDog      WalkingWithDog
# 127                 v_Swing_g20_c01               Swing               Swing
# 128              v_JumpRope_g19_c04            JumpRope            JumpRope
# 129     v_TrampolineJumping_g11_c04   TrampolineJumping   TrampolineJumping
# 130               v_Archery_g13_c05             Archery             Archery
# 131               v_PullUps_g19_c03             PullUps             PullUps
# 132              v_JumpRope_g03_c01            JumpRope            JumpRope
# 133           v_BlowDryHair_g18_c05         BlowDryHair         BlowDryHair
# 134          v_FrisbeeCatch_g08_c03        FrisbeeCatch        FrisbeeCatch
# 135              v_Drumming_g24_c06            Drumming            Drumming
# 136        v_WalkingWithDog_g23_c01      WalkingWithDog      WalkingWithDog
# 137          v_JavelinThrow_g07_c05        JavelinThrow        JavelinThrow
# 138           v_BlowDryHair_g10_c02         BlowDryHair         BlowDryHair
# 139          v_BabyCrawling_g21_c01        BabyCrawling        BabyCrawling
# 140     v_VolleyballSpiking_g16_c02   VolleyballSpiking   VolleyballSpiking
# 141              v_Kayaking_g09_c04            Kayaking            Kayaking
# 142         v_BaseballPitch_g24_c01       BaseballPitch       BaseballPitch
# 143        v_WritingOnBoard_g15_c03      WritingOnBoard      WritingOnBoard
# 144           v_BlowDryHair_g11_c07         BlowDryHair         BlowDryHair
# 145               v_Haircut_g08_c04             Haircut             Haircut
# 146          v_JavelinThrow_g24_c03        JavelinThrow        JavelinThrow
# 147         v_BrushingTeeth_g19_c05       BrushingTeeth       BrushingTeeth
# 148              v_JumpRope_g21_c04            JumpRope            JumpRope
# 149         v_JugglingBalls_g07_c02       JugglingBalls       JugglingBalls
# 150             v_Nunchucks_g16_c01           Nunchucks           Nunchucks
# 151          v_ShavingBeard_g18_c01        ShavingBeard        ShavingBeard
# 152              v_HulaHoop_g15_c05            HulaHoop            HulaHoop
# 153           v_CricketShot_g21_c01         CricketShot         CricketShot
# 154          v_PlayingCello_g12_c02        PlayingCello        PlayingCello
# 155      v_HandstandPushups_g20_c01    HandstandPushups    HandstandPushups
# 156              v_JumpRope_g04_c05            JumpRope            JumpRope
# 157                v_Biking_g17_c02              Biking              Biking
# 158          v_RopeClimbing_g25_c03        RopeClimbing        RopeClimbing
# 159         v_PlayingGuitar_g21_c01       PlayingGuitar       PlayingGuitar
# 160              v_Kayaking_g07_c01            Kayaking            Kayaking
# 161                v_Skijet_g17_c02              Skijet              Skijet
# 162        v_BoxingSpeedBag_g04_c06      BoxingSpeedBag      BoxingSpeedBag
# 163           v_WallPushups_g07_c05         WallPushups         WallPushups
# 164           v_PlayingDhol_g12_c05         PlayingDhol         PlayingDhol
# 165             v_Hammering_g09_c07           Hammering           Hammering
# 166           v_HorseRiding_g02_c02         HorseRiding         HorseRiding
# 167               v_PullUps_g22_c04             PullUps             PullUps
# 168                 v_Swing_g19_c03               Swing               Swing
# 169            v_IceDancing_g04_c04          IceDancing          IceDancing
# 170                  v_YoYo_g09_c05                YoYo                YoYo
# 171              v_JumpRope_g21_c06            JumpRope            JumpRope
# 172    v_FieldHockeyPenalty_g09_c05  FieldHockeyPenalty  FieldHockeyPenalty
# 173             v_Billiards_g03_c05           Billiards           Billiards
# 174     v_BoxingPunchingBag_g23_c07   BoxingPunchingBag   BoxingPunchingBag
# 175         v_BrushingTeeth_g24_c04       BrushingTeeth       BrushingTeeth
# 176                v_Biking_g03_c03              Biking              Biking
# 177                v_TaiChi_g04_c03              TaiChi              TaiChi
# 178           v_CricketShot_g04_c01         CricketShot         CricketShot
# 179               v_Haircut_g15_c02             Haircut             Haircut
# 180          v_BabyCrawling_g22_c02        BabyCrawling        BabyCrawling
# 181        v_SoccerJuggling_g22_c04      SoccerJuggling        RopeClimbing
# 182           v_HammerThrow_g22_c04         HammerThrow         HammerThrow
# 183          v_BreastStroke_g05_c02        BreastStroke        BreastStroke
# 184     v_BoxingPunchingBag_g16_c03   BoxingPunchingBag   BoxingPunchingBag
# 185     v_BoxingPunchingBag_g14_c02   BoxingPunchingBag   BoxingPunchingBag
# 186           v_HorseRiding_g07_c02         HorseRiding         HorseRiding
# 187             v_SkyDiving_g23_c04           SkyDiving           SkyDiving
# 188          v_ShavingBeard_g03_c04        ShavingBeard        ShavingBeard
# 189             v_Hammering_g21_c03           Hammering           Hammering
# 190    v_FieldHockeyPenalty_g03_c02  FieldHockeyPenalty  FieldHockeyPenalty
# 191          v_FrisbeeCatch_g03_c03        FrisbeeCatch        FrisbeeCatch
# 192          v_PizzaTossing_g15_c03        PizzaTossing        PizzaTossing
# 193          v_PizzaTossing_g06_c01        PizzaTossing        PizzaTossing
# 194          v_MoppingFloor_g06_c04        MoppingFloor        MoppingFloor
# 195            v_StillRings_g09_c03          StillRings          StillRings
# 196          v_BandMarching_g07_c03        BandMarching        BandMarching
# 197           v_HammerThrow_g06_c05         HammerThrow         HammerThrow
# 198           v_CliffDiving_g24_c04         CliffDiving         CliffDiving
# 199            v_Basketball_g21_c04          Basketball          Basketball
# 200                v_Typing_g24_c01              Typing              Typing
# 201        v_CricketBowling_g03_c01      CricketBowling      CricketBowling
# 202           v_JumpingJack_g06_c02         JumpingJack         JumpingJack
# 203           v_TennisSwing_g25_c01         TennisSwing         TennisSwing
# 204          v_PizzaTossing_g11_c03        PizzaTossing        PizzaTossing
# 205          v_PlayingCello_g20_c01        PlayingCello        PlayingCello
# 206           v_CricketShot_g21_c06         CricketShot         CricketShot
# 207         v_BaseballPitch_g10_c03       BaseballPitch       BaseballPitch
# 208      v_CuttingInKitchen_g06_c04    CuttingInKitchen    CuttingInKitchen
# 209              v_Drumming_g05_c02            Drumming            Drumming
# 210        v_BoxingSpeedBag_g10_c04      BoxingSpeedBag      BoxingSpeedBag
# 211          v_ParallelBars_g08_c02        ParallelBars        ParallelBars
# 212           v_BlowDryHair_g09_c01         BlowDryHair         BlowDryHair
# 213                v_Typing_g03_c01              Typing              Typing
# 214             v_Nunchucks_g19_c02           Nunchucks           Nunchucks
# 215                v_Skiing_g01_c03              Skiing              Skiing
# 216               v_Haircut_g01_c01             Haircut             Haircut
# 217         v_SkateBoarding_g12_c01       SkateBoarding           PoleVault
# 218         v_SoccerPenalty_g11_c03       SoccerPenalty  FieldHockeyPenalty
# 219        v_MilitaryParade_g22_c01      MilitaryParade      MilitaryParade
# 220               v_Haircut_g15_c04             Haircut             Haircut
# 221          v_ParallelBars_g07_c05        ParallelBars        ParallelBars
# 222                  v_YoYo_g04_c04                YoYo                YoYo
# 223                v_Diving_g07_c02              Diving              Diving
# 224                v_Diving_g15_c02              Diving              Diving
# 225              v_LongJump_g11_c05            LongJump            LongJump
# 226          v_BreastStroke_g10_c02        BreastStroke        BreastStroke
# 227      v_HandstandPushups_g15_c04    HandstandPushups    HandstandPushups
# 228            v_Basketball_g10_c05          Basketball          Basketball
# 229            v_UnevenBars_g09_c02          UnevenBars          UnevenBars
# 230               v_Surfing_g08_c07             Surfing             Surfing
# 231            v_StillRings_g05_c04          StillRings          StillRings
# 232            v_UnevenBars_g15_c06          UnevenBars          UnevenBars
# 233            v_PlayingDaf_g05_c04          PlayingDaf          PlayingDaf
# 234          v_BandMarching_g14_c02        BandMarching        BandMarching
# 235           v_PlayingDhol_g24_c01         PlayingDhol         PlayingDhol
# 236          v_PlayingSitar_g08_c02        PlayingSitar        PlayingSitar
# 237             v_HorseRace_g01_c01           HorseRace           HorseRace
# 238             v_Nunchucks_g21_c05           Nunchucks           Nunchucks
# 239                 v_Punch_g18_c05               Punch               Punch
# 240                 v_Swing_g15_c02               Swing               Swing
# 241        v_BlowingCandles_g08_c03      BlowingCandles      BlowingCandles
# 242           v_PommelHorse_g22_c02         PommelHorse         PommelHorse
# 243          v_PizzaTossing_g04_c01        PizzaTossing        PizzaTossing
# 244                 v_Punch_g01_c05               Punch               Punch
# 245          v_PlayingTabla_g24_c04        PlayingTabla        PlayingTabla
# 246          v_PlayingFlute_g20_c02        PlayingFlute        PlayingFlute
# 247                v_Biking_g06_c04              Biking   TrampolineJumping
# 248         v_SoccerPenalty_g16_c01       SoccerPenalty       SoccerPenalty
# 249         v_PlayingGuitar_g04_c01       PlayingGuitar       PlayingGuitar
# 250       v_TableTennisShot_g19_c01     TableTennisShot     TableTennisShot
# 251           v_PommelHorse_g18_c04         PommelHorse         PommelHorse
# 252                v_Diving_g15_c05              Diving              Diving
# 253               v_Bowling_g23_c04             Bowling             Bowling
# 254               v_Surfing_g16_c02             Surfing             Surfing
# 255              v_HighJump_g11_c06            HighJump            HighJump
# 256          v_BandMarching_g18_c02        BandMarching        BandMarching
# 257           v_HeadMassage_g10_c03         HeadMassage         HeadMassage
# 258                v_Typing_g06_c02              Typing              Typing
# 259            v_FrontCrawl_g17_c01          FrontCrawl              Diving
# 260           v_HammerThrow_g01_c03         HammerThrow         HammerThrow
# 261    v_RockClimbingIndoor_g20_c03  RockClimbingIndoor  RockClimbingIndoor
# 262               v_Rafting_g16_c01             Rafting             Rafting
# 263                  v_YoYo_g07_c01                YoYo                YoYo
# 264              v_Knitting_g14_c03            Knitting            Knitting
# 265               v_Archery_g25_c07             Archery             Archery
# 266        v_BasketballDunk_g21_c02      BasketballDunk         PommelHorse
# 267             v_SalsaSpin_g03_c03           SalsaSpin           SalsaSpin
# 268             v_GolfSwing_g22_c03           GolfSwing           GolfSwing
# 269          v_CleanAndJerk_g24_c01        CleanAndJerk         PommelHorse
# 270          v_PizzaTossing_g04_c03        PizzaTossing        PizzaTossing
# 271          v_FrisbeeCatch_g02_c01        FrisbeeCatch        FrisbeeCatch
# 272          v_PlayingTabla_g19_c01        PlayingTabla        PlayingTabla
# 273                v_Mixing_g04_c01              Mixing              Mixing
# 274           v_WallPushups_g25_c01         WallPushups         WallPushups
# 275              v_HighJump_g14_c02            HighJump        JavelinThrow
# 276             v_SkyDiving_g02_c03           SkyDiving           SkyDiving
# 277           v_PlayingDhol_g23_c07         PlayingDhol         PlayingDhol
# 278          v_PlayingCello_g05_c05        PlayingCello        PlayingCello
# 279            v_FrontCrawl_g14_c01          FrontCrawl          FrontCrawl
# 280       v_FloorGymnastics_g07_c04     FloorGymnastics     FloorGymnastics
# 281            v_BenchPress_g05_c07          BenchPress          BenchPress
# 282             v_SalsaSpin_g07_c01           SalsaSpin           SalsaSpin
# 283           v_HorseRiding_g23_c04         HorseRiding         HorseRiding
# 284           v_CricketShot_g05_c04         CricketShot         CricketShot
# 285                v_Mixing_g15_c02              Mixing              Mixing
# 286               v_Archery_g07_c06             Archery             Rafting
# 287               v_Surfing_g07_c01             Surfing             Surfing
# 288         v_PlayingGuitar_g21_c03       PlayingGuitar       PlayingGuitar
# 289                v_Biking_g16_c05              Biking              Biking
# 290         v_JugglingBalls_g07_c05       JugglingBalls       JugglingBalls
# 291    v_FieldHockeyPenalty_g25_c01  FieldHockeyPenalty            HighJump
# 292          v_PlayingPiano_g08_c01        PlayingPiano        PlayingPiano
# 293           v_TennisSwing_g14_c02         TennisSwing         TennisSwing
# 294          v_BandMarching_g20_c06        BandMarching        BandMarching
# 295           v_JumpingJack_g21_c01         JumpingJack         JumpingJack
# 296           v_BlowDryHair_g21_c06         BlowDryHair         BlowDryHair
# 297          v_PizzaTossing_g19_c04        PizzaTossing        PizzaTossing
# 298          v_BandMarching_g20_c04        BandMarching        BandMarching
# 299       v_TableTennisShot_g16_c03     TableTennisShot     TableTennisShot
# 300         v_SkateBoarding_g20_c02       SkateBoarding       SkateBoarding
# 301             v_HorseRace_g21_c05           HorseRace           HorseRace
# 302        v_WritingOnBoard_g11_c06      WritingOnBoard      WritingOnBoard
# 303           v_HorseRiding_g04_c01         HorseRiding           HorseRace
# 304               v_Bowling_g04_c04             Bowling             Bowling
# 305                v_Skijet_g21_c04              Skijet              Skijet
# 306             v_SalsaSpin_g17_c01           SalsaSpin           SalsaSpin
# 307                v_Typing_g14_c03              Typing              Typing
# 308          v_JavelinThrow_g11_c02        JavelinThrow        JavelinThrow
# 309        v_BoxingSpeedBag_g05_c05      BoxingSpeedBag      BoxingSpeedBag
# 310                v_Mixing_g10_c04              Mixing              Mixing
# 311         v_SoccerPenalty_g10_c05       SoccerPenalty       SoccerPenalty
# 312          v_BreastStroke_g09_c04        BreastStroke          FrontCrawl
# 313                v_Skijet_g25_c02              Skijet              Skijet
# 314         v_BaseballPitch_g08_c05       BaseballPitch       BaseballPitch
# 315         v_SumoWrestling_g05_c01       SumoWrestling        ParallelBars
# 316         v_PlayingGuitar_g05_c05       PlayingGuitar        PlayingSitar
# 317              v_Kayaking_g24_c03            Kayaking            Kayaking
# 318         v_BaseballPitch_g01_c03       BaseballPitch           Nunchucks
# 319                v_Biking_g16_c04              Biking              Biking
# 320                 v_Swing_g02_c02               Swing               Swing
# 321           v_HammerThrow_g23_c06         HammerThrow         HammerThrow
# 322           v_WallPushups_g03_c05         WallPushups         WallPushups
# 323         v_JugglingBalls_g16_c04       JugglingBalls       JugglingBalls
# 324           v_TennisSwing_g20_c01         TennisSwing         TennisSwing
# 325                v_Skiing_g12_c01              Skiing              Skiing
# 326    v_FieldHockeyPenalty_g06_c02  FieldHockeyPenalty  FieldHockeyPenalty
# 327                v_Rowing_g04_c05              Rowing              Rowing
# 328              v_Drumming_g13_c04            Drumming            Drumming
# 329         v_SkateBoarding_g10_c06       SkateBoarding       SkateBoarding
# 330        v_BasketballDunk_g11_c03      BasketballDunk      BasketballDunk
# 331           v_CricketShot_g04_c02         CricketShot         CricketShot
# 332    v_FieldHockeyPenalty_g14_c06  FieldHockeyPenalty  FieldHockeyPenalty
# 333           v_HammerThrow_g14_c05         HammerThrow          StillRings
# 334                v_Diving_g10_c04              Diving              Diving
# 335        v_BlowingCandles_g22_c04      BlowingCandles      BlowingCandles
# 336                 v_Punch_g05_c04               Punch               Punch
# 337          v_BandMarching_g24_c02        BandMarching        BandMarching
# 338         v_SkateBoarding_g18_c04       SkateBoarding       SkateBoarding
# 339          v_CleanAndJerk_g19_c04        CleanAndJerk        CleanAndJerk
# 340    v_RockClimbingIndoor_g12_c02  RockClimbingIndoor  RockClimbingIndoor
# 341            v_FrontCrawl_g11_c07          FrontCrawl          FrontCrawl
# 342         v_ApplyLipstick_g16_c01       ApplyLipstick       ApplyLipstick
# 343          v_PlayingFlute_g23_c01        PlayingFlute        PlayingFlute
# 344           v_HammerThrow_g05_c03         HammerThrow         HammerThrow
# 345                v_Mixing_g10_c01              Mixing              Mixing
# 346           v_BalanceBeam_g19_c02         BalanceBeam          UnevenBars
# 347         v_BrushingTeeth_g07_c02       BrushingTeeth       BrushingTeeth
# 348             v_Billiards_g15_c07           Billiards           Billiards
# 349              v_HighJump_g16_c05            HighJump            HighJump
# 350     v_BoxingPunchingBag_g20_c04   BoxingPunchingBag   BoxingPunchingBag
# 351     v_BoxingPunchingBag_g04_c03   BoxingPunchingBag   BoxingPunchingBag
# 352          v_PizzaTossing_g06_c05        PizzaTossing        PizzaTossing
# 353                v_Typing_g17_c01              Typing              Typing
# 354                v_Rowing_g01_c01              Rowing              Rowing
# 355          v_PlayingSitar_g04_c06        PlayingSitar        PlayingSitar
# 356         v_SoccerPenalty_g23_c05       SoccerPenalty       SoccerPenalty
# 357               v_Rafting_g06_c02             Rafting             Rafting
# 358             v_PoleVault_g20_c04           PoleVault           PoleVault
# 359                v_Mixing_g02_c02              Mixing              Mixing
# 360         v_JugglingBalls_g07_c04       JugglingBalls       JugglingBalls
# 361          v_PlayingSitar_g17_c01        PlayingSitar        PlayingSitar
# 362               v_Shotput_g08_c04             Shotput             Shotput
# 363           v_BalanceBeam_g07_c02         BalanceBeam         BalanceBeam
# 364           v_HeadMassage_g19_c05         HeadMassage         HeadMassage
# 365                v_Mixing_g23_c04              Mixing              Mixing
# 366               v_Rafting_g24_c01             Rafting             Rafting
# 367          v_PlayingCello_g06_c01        PlayingCello        PlayingCello
# 368         v_SumoWrestling_g25_c03       SumoWrestling       SumoWrestling
# 369           v_HorseRiding_g13_c04         HorseRiding         HorseRiding
# 370          v_PlayingTabla_g22_c03        PlayingTabla        PlayingTabla
# 371          v_BandMarching_g01_c05        BandMarching        BandMarching
# 372           v_PlayingDhol_g15_c01         PlayingDhol         PlayingDhol
# 373          v_PlayingTabla_g12_c04        PlayingTabla        PlayingTabla
# 374                 v_Punch_g16_c04               Punch               Punch
# 375          v_JavelinThrow_g14_c06        JavelinThrow        JavelinThrow
# 376            v_BenchPress_g13_c07          BenchPress          BenchPress
# 377         v_PlayingGuitar_g14_c01       PlayingGuitar       PlayingGuitar
# 378       v_TableTennisShot_g18_c04     TableTennisShot     TableTennisShot
# 379              v_LongJump_g11_c01            LongJump            LongJump
# 380             v_Billiards_g24_c03           Billiards           Billiards
# 381                v_Skijet_g12_c04              Skijet              Skijet
# 382                v_Lunges_g10_c05              Lunges              Lunges
# 383          v_RopeClimbing_g09_c03        RopeClimbing        RopeClimbing
# 384          v_ParallelBars_g09_c01        ParallelBars        ParallelBars
# 385        v_ApplyEyeMakeup_g13_c02      ApplyEyeMakeup      ApplyEyeMakeup
# 386             v_GolfSwing_g03_c03           GolfSwing           GolfSwing
# 387          v_PizzaTossing_g25_c01        PizzaTossing        PizzaTossing
# 388        v_CricketBowling_g24_c04      CricketBowling      CricketBowling
# 389               v_Fencing_g24_c02             Fencing             Fencing
# 390              v_Knitting_g05_c04            Knitting            Knitting
# 391             v_Billiards_g04_c07           Billiards           Billiards
# 392            v_UnevenBars_g03_c03          UnevenBars          UnevenBars
# 393        v_ApplyEyeMakeup_g24_c04      ApplyEyeMakeup      ApplyEyeMakeup
# 394          v_PlayingFlute_g10_c04        PlayingFlute        PlayingFlute
# 395         v_ApplyLipstick_g06_c05       ApplyLipstick       ApplyLipstick
# 396              v_HighJump_g04_c01            HighJump            LongJump
# 397          v_PlayingPiano_g06_c01        PlayingPiano        PlayingPiano
# 398           v_JumpingJack_g13_c06         JumpingJack         JumpingJack
# 399       v_FloorGymnastics_g22_c03     FloorGymnastics     TableTennisShot
# 400                v_Skiing_g02_c04              Skiing              Skiing
# 401          v_PlayingSitar_g23_c07        PlayingSitar        PlayingSitar
# 402            v_IceDancing_g13_c04          IceDancing          IceDancing
# 403        v_BoxingSpeedBag_g17_c04      BoxingSpeedBag      BoxingSpeedBag
# 404               v_Bowling_g13_c02             Bowling             Bowling
# 405        v_ApplyEyeMakeup_g10_c05      ApplyEyeMakeup      ApplyEyeMakeup
# 406        v_MilitaryParade_g07_c02      MilitaryParade      MilitaryParade
# 407        v_ApplyEyeMakeup_g07_c03      ApplyEyeMakeup      ApplyEyeMakeup
# 408         v_SkateBoarding_g10_c07       SkateBoarding             Archery
# 409             v_PoleVault_g06_c04           PoleVault           PoleVault
# 410        v_CricketBowling_g04_c05      CricketBowling      CricketBowling
# 411               v_Bowling_g20_c06             Bowling             Bowling
# 412    v_RockClimbingIndoor_g05_c05  RockClimbingIndoor  RockClimbingIndoor
# 413              v_HighJump_g24_c03            HighJump            HighJump
# 414         v_SoccerPenalty_g09_c05       SoccerPenalty       SoccerPenalty
# 415             v_PoleVault_g17_c06           PoleVault           PoleVault
# 416            v_StillRings_g01_c01          StillRings          StillRings
# 417            v_BenchPress_g01_c01          BenchPress          BenchPress
# 418                 v_Punch_g19_c06               Punch               Punch
# 419                v_Rowing_g03_c07              Rowing              Rowing
# 420           v_PlayingDhol_g11_c01         PlayingDhol         PlayingDhol
# 421         v_SoccerPenalty_g22_c05       SoccerPenalty       SoccerPenalty
# 422                v_Lunges_g08_c04              Lunges              Lunges
# 423           v_JumpingJack_g12_c02         JumpingJack         JumpingJack
# 424             v_Hammering_g24_c05           Hammering           Hammering
# 425           v_ThrowDiscus_g07_c02         ThrowDiscus         ThrowDiscus
# 426      v_CuttingInKitchen_g12_c02    CuttingInKitchen    CuttingInKitchen
# 427              v_Drumming_g11_c07            Drumming            Drumming
# 428           v_HeadMassage_g15_c03         HeadMassage         HeadMassage
# 429         v_PlayingViolin_g06_c01       PlayingViolin       PlayingViolin
# 430                v_Lunges_g15_c02              Lunges          BenchPress
# 431        v_SoccerJuggling_g05_c03      SoccerJuggling      SoccerJuggling
# 432               v_PushUps_g04_c03             PushUps             PushUps
# 433        v_SoccerJuggling_g14_c03      SoccerJuggling      SoccerJuggling
# 434                v_Skiing_g06_c01              Skiing              Skiing
# 435              v_Drumming_g17_c03            Drumming            Drumming
# 436           v_BalanceBeam_g18_c02         BalanceBeam         BalanceBeam
# 437             v_GolfSwing_g04_c02           GolfSwing           GolfSwing
# 438           v_BalanceBeam_g06_c03         BalanceBeam         BalanceBeam
# 439                v_Skijet_g23_c01              Skijet              Skijet
# 440         v_JugglingBalls_g10_c02       JugglingBalls       JugglingBalls
# 441          v_PlayingCello_g23_c06        PlayingCello        PlayingCello
# 442          v_JavelinThrow_g10_c04        JavelinThrow        JavelinThrow
# 443         v_PlayingViolin_g23_c04       PlayingViolin       PlayingViolin
# 444         v_JugglingBalls_g03_c07       JugglingBalls       JugglingBalls
# 445                v_Mixing_g24_c02              Mixing              Mixing
# 446                v_Typing_g08_c05              Typing              Typing
# 447            v_StillRings_g11_c04          StillRings        RopeClimbing
# 448        v_WalkingWithDog_g02_c04      WalkingWithDog      WalkingWithDog
# 449                 v_Punch_g10_c06               Punch               Punch
# 450           v_CliffDiving_g22_c04         CliffDiving         CliffDiving
# 451            v_Basketball_g23_c01          Basketball          Basketball
# 452                v_Skijet_g25_c01              Skijet              Skijet
# 453        v_ApplyEyeMakeup_g23_c05      ApplyEyeMakeup      ApplyEyeMakeup
# 454           v_JumpingJack_g12_c01         JumpingJack         JumpingJack
# 455      v_HandstandPushups_g11_c06    HandstandPushups    HandstandPushups
# 456      v_BodyWeightSquats_g14_c04    BodyWeightSquats    BodyWeightSquats
# 457        v_WritingOnBoard_g13_c02      WritingOnBoard      WritingOnBoard
# 458                v_Skiing_g13_c02              Skiing         CliffDiving
# 459        v_SoccerJuggling_g11_c06      SoccerJuggling      SoccerJuggling
# 460               v_Rafting_g11_c01             Rafting             Rafting
# 461            v_BenchPress_g03_c04          BenchPress          BenchPress
# 462               v_Rafting_g22_c04             Rafting             Rafting
# 463          v_PizzaTossing_g22_c01        PizzaTossing        PizzaTossing
# 464                v_Skiing_g18_c01              Skiing              Skiing
# 465            v_BenchPress_g17_c03          BenchPress          BenchPress
# 466     v_BoxingPunchingBag_g07_c03   BoxingPunchingBag   BoxingPunchingBag
# 467         v_ApplyLipstick_g14_c04       ApplyLipstick       ApplyLipstick
# 468        v_BoxingSpeedBag_g15_c01      BoxingSpeedBag      BoxingSpeedBag
# 469               v_Surfing_g08_c06             Surfing             Surfing
# 470           v_ThrowDiscus_g01_c03         ThrowDiscus         ThrowDiscus
# 471              v_JumpRope_g09_c02            JumpRope        CleanAndJerk
# 472           v_PommelHorse_g13_c04         PommelHorse         PommelHorse
# 473             v_SalsaSpin_g02_c02           SalsaSpin           Nunchucks
# 474       v_FloorGymnastics_g16_c02     FloorGymnastics     FloorGymnastics
# 475         v_SumoWrestling_g05_c02       SumoWrestling       SumoWrestling
# 476    v_RockClimbingIndoor_g16_c03  RockClimbingIndoor  RockClimbingIndoor
# 477      v_BodyWeightSquats_g16_c01    BodyWeightSquats    BodyWeightSquats
# 478              v_HulaHoop_g09_c01            HulaHoop            HulaHoop
# 479           v_BalanceBeam_g13_c03         BalanceBeam         BalanceBeam
# 480             v_HorseRace_g24_c02           HorseRace           HorseRace
# 481                v_Biking_g20_c04              Biking              Biking
# 482        v_BoxingSpeedBag_g11_c06      BoxingSpeedBag      BoxingSpeedBag
# 483         v_SkateBoarding_g25_c02       SkateBoarding             Archery
# 484      v_CuttingInKitchen_g05_c01    CuttingInKitchen    CuttingInKitchen
# 485         v_PlayingGuitar_g20_c03       PlayingGuitar       PlayingGuitar
# 486            v_BenchPress_g13_c06          BenchPress          BenchPress
# 487           v_HorseRiding_g14_c04         HorseRiding         HorseRiding
# 488                v_Typing_g07_c01              Typing              Typing
# 489     v_TrampolineJumping_g03_c02   TrampolineJumping   TrampolineJumping
# 490        v_WritingOnBoard_g20_c06      WritingOnBoard      WritingOnBoard
# 491               v_PushUps_g21_c02             PushUps             PushUps
# 492         v_SkateBoarding_g12_c06       SkateBoarding       SkateBoarding
# 493           v_PommelHorse_g05_c04         PommelHorse         PommelHorse
# 494           v_TennisSwing_g22_c04         TennisSwing         TennisSwing
# 495           v_PlayingDhol_g01_c06         PlayingDhol         PlayingDhol
# 496       v_TableTennisShot_g23_c02     TableTennisShot     TableTennisShot
# 497               v_PushUps_g10_c03             PushUps             PushUps
# 498               v_Fencing_g06_c04             Fencing             Fencing
# 499              v_HighJump_g22_c04            HighJump             Bowling
# ...                             ...                 ...                 ...
# 12820              v_Biking_g09_c03              Biking              Biking
# 12821              v_Diving_g06_c07              Diving              Diving
# 12822         v_PommelHorse_g02_c03         PommelHorse         PommelHorse
# 12823    v_BodyWeightSquats_g24_c03    BodyWeightSquats    BodyWeightSquats
# 12824        v_ShavingBeard_g20_c02        ShavingBeard        ShavingBeard
# 12825           v_SkyDiving_g04_c04           SkyDiving           SkyDiving
# 12826           v_HorseRace_g15_c01           HorseRace           HorseRace
# 12827         v_HammerThrow_g08_c01         HammerThrow         HammerThrow
# 12828         v_WallPushups_g06_c07         WallPushups         WallPushups
# 12829             v_PullUps_g23_c03             PullUps             PullUps
# 12830              v_TaiChi_g22_c04              TaiChi              TaiChi
# 12831             v_Archery_g07_c01             Archery             Archery
# 12832           v_Billiards_g25_c03           Billiards           Billiards
# 12833         v_BalanceBeam_g11_c03         BalanceBeam         BalanceBeam
# 12834      v_BoxingSpeedBag_g09_c01      BoxingSpeedBag      BoxingSpeedBag
# 12835          v_IceDancing_g19_c07          IceDancing          IceDancing
# 12836             v_PushUps_g21_c04             PushUps             PushUps
# 12837        v_BreastStroke_g14_c01        BreastStroke        BreastStroke
# 12838          v_IceDancing_g11_c01          IceDancing          IceDancing
# 12839       v_ApplyLipstick_g24_c01       ApplyLipstick       ApplyLipstick
# 12840             v_PullUps_g12_c01             PullUps             PullUps
# 12841             v_Surfing_g15_c02             Surfing             Surfing
# 12842            v_Knitting_g15_c05            Knitting            Knitting
# 12843         v_HeadMassage_g25_c05         HeadMassage         HeadMassage
# 12844             v_Archery_g10_c05             Archery             Archery
# 12845         v_TennisSwing_g06_c06         TennisSwing         TennisSwing
# 12846               v_Swing_g24_c04               Swing               Swing
# 12847       v_PlayingGuitar_g13_c06       PlayingGuitar       PlayingGuitar
# 12848        v_FrisbeeCatch_g09_c05        FrisbeeCatch        FrisbeeCatch
# 12849       v_SkateBoarding_g07_c02       SkateBoarding       SkateBoarding
# 12850           v_PoleVault_g08_c04           PoleVault           PoleVault
# 12851           v_SalsaSpin_g22_c01           SalsaSpin           SalsaSpin
# 12852            v_LongJump_g18_c03            LongJump            LongJump
# 12853         v_ThrowDiscus_g09_c05         ThrowDiscus         PommelHorse
# 12854         v_PommelHorse_g23_c03         PommelHorse         PommelHorse
# 12855        v_RopeClimbing_g14_c01        RopeClimbing        RopeClimbing
# 12856   v_VolleyballSpiking_g08_c04   VolleyballSpiking   VolleyballSpiking
# 12857             v_Surfing_g15_c04             Surfing             Surfing
# 12858            v_Knitting_g04_c01            Knitting            Knitting
# 12859          v_Basketball_g20_c04          Basketball          Basketball
# 12860          v_Basketball_g25_c07          Basketball          Basketball
# 12861         v_CliffDiving_g15_c03         CliffDiving         CliffDiving
# 12862          v_PlayingDaf_g10_c07          PlayingDaf          PlayingDaf
# 12863              v_Lunges_g23_c01              Lunges              Lunges
# 12864           v_Nunchucks_g10_c04           Nunchucks           Nunchucks
# 12865  v_FieldHockeyPenalty_g11_c04  FieldHockeyPenalty  FieldHockeyPenalty
# 12866      v_BoxingSpeedBag_g09_c03      BoxingSpeedBag      BoxingSpeedBag
# 12867            v_Knitting_g08_c03            Knitting            Knitting
# 12868        v_FrisbeeCatch_g25_c03        FrisbeeCatch        FrisbeeCatch
# 12869        v_RopeClimbing_g17_c01        RopeClimbing        RopeClimbing
# 12870         v_HorseRiding_g25_c05         HorseRiding         HorseRiding
# 12871             v_Shotput_g03_c03             Shotput             Shotput
# 12872    v_HandstandPushups_g18_c05    HandstandPushups    HandstandPushups
# 12873        v_CleanAndJerk_g19_c02        CleanAndJerk        CleanAndJerk
# 12874             v_PullUps_g25_c04             PullUps             PullUps
# 12875          v_FrontCrawl_g07_c05          FrontCrawl          FrontCrawl
# 12876        v_MoppingFloor_g01_c02        MoppingFloor        MoppingFloor
# 12877       v_BaseballPitch_g04_c05       BaseballPitch               Swing
# 12878           v_HorseRace_g18_c03           HorseRace           HorseRace
# 12879        v_JavelinThrow_g04_c02        JavelinThrow        JavelinThrow
# 12880              v_TaiChi_g08_c01              TaiChi              TaiChi
# 12881            v_Kayaking_g19_c03            Kayaking            Kayaking
# 12882           v_SalsaSpin_g05_c06           SalsaSpin           SalsaSpin
# 12883     v_TableTennisShot_g15_c03     TableTennisShot     TableTennisShot
# 12884         v_HorseRiding_g06_c02         HorseRiding         HorseRiding
# 12885          v_FrontCrawl_g20_c06          FrontCrawl          FrontCrawl
# 12886    v_CuttingInKitchen_g17_c01    CuttingInKitchen    CuttingInKitchen
# 12887           v_PoleVault_g22_c01           PoleVault           PoleVault
# 12888        v_PlayingCello_g25_c02        PlayingCello        PlayingCello
# 12889   v_VolleyballSpiking_g19_c04   VolleyballSpiking   VolleyballSpiking
# 12890      v_WalkingWithDog_g12_c01      WalkingWithDog      WalkingWithDog
# 12891           v_SalsaSpin_g11_c06           SalsaSpin           SalsaSpin
# 12892         v_PlayingDhol_g25_c03         PlayingDhol         PlayingDhol
# 12893       v_JugglingBalls_g03_c03       JugglingBalls       JugglingBalls
# 12894              v_Skijet_g01_c01              Skijet              Skijet
# 12895         v_HammerThrow_g19_c04         HammerThrow         HammerThrow
# 12896         v_CliffDiving_g20_c01         CliffDiving         CliffDiving
# 12897         v_CricketShot_g05_c06         CricketShot         CricketShot
# 12898          v_UnevenBars_g25_c01          UnevenBars          UnevenBars
# 12899     v_FloorGymnastics_g07_c03     FloorGymnastics     FloorGymnastics
# 12900   v_TrampolineJumping_g07_c01   TrampolineJumping   TrampolineJumping
# 12901   v_VolleyballSpiking_g10_c01   VolleyballSpiking   VolleyballSpiking
# 12902          v_StillRings_g09_c01          StillRings          StillRings
# 12903   v_TrampolineJumping_g23_c04   TrampolineJumping   TrampolineJumping
# 12904             v_PullUps_g23_c02             PullUps             PullUps
# 12905        v_PlayingPiano_g03_c03        PlayingPiano        PlayingPiano
# 12906          v_BenchPress_g15_c02          BenchPress          BenchPress
# 12907        v_RopeClimbing_g01_c03        RopeClimbing        RopeClimbing
# 12908             v_Fencing_g15_c04             Fencing             Fencing
# 12909        v_CleanAndJerk_g06_c03        CleanAndJerk            JumpRope
# 12910         v_ThrowDiscus_g07_c05         ThrowDiscus         PommelHorse
# 12911      v_BasketballDunk_g17_c06      BasketballDunk      BasketballDunk
# 12912         v_PlayingDhol_g01_c04         PlayingDhol         PlayingDhol
# 12913          v_PlayingDaf_g19_c01          PlayingDaf          PlayingDaf
# 12914         v_CliffDiving_g06_c06         CliffDiving         CliffDiving
# 12915             v_Shotput_g10_c05             Shotput             Shotput
# 12916       v_SkateBoarding_g06_c01       SkateBoarding       SkateBoarding
# 12917         v_PlayingDhol_g12_c01         PlayingDhol         PlayingDhol
# 12918          v_Basketball_g16_c05          Basketball          Basketball
# 12919      v_MilitaryParade_g02_c03      MilitaryParade      MilitaryParade
# 12920  v_RockClimbingIndoor_g03_c07  RockClimbingIndoor  RockClimbingIndoor
# 12921      v_CricketBowling_g12_c02      CricketBowling      CricketBowling
# 12922                v_YoYo_g13_c04                YoYo                YoYo
# 12923             v_Surfing_g17_c06             Surfing             Surfing
# 12924   v_TrampolineJumping_g23_c03   TrampolineJumping   TrampolineJumping
# 12925        v_FrisbeeCatch_g04_c04        FrisbeeCatch        FrisbeeCatch
# 12926       v_JugglingBalls_g12_c05       JugglingBalls       JugglingBalls
# 12927          v_BenchPress_g09_c07          BenchPress          BenchPress
# 12928        v_BandMarching_g11_c04        BandMarching    HandstandWalking
# 12929          v_PlayingDaf_g07_c02          PlayingDaf          PlayingDaf
# 12930            v_JumpRope_g18_c07            JumpRope            JumpRope
# 12931      v_SoccerJuggling_g25_c01      SoccerJuggling      SoccerJuggling
# 12932      v_BoxingSpeedBag_g17_c06      BoxingSpeedBag      BoxingSpeedBag
# 12933         v_PlayingDhol_g17_c03         PlayingDhol         PlayingDhol
# 12934           v_HorseRace_g14_c02           HorseRace           HorseRace
# 12935        v_BandMarching_g08_c02        BandMarching        BandMarching
# 12936       v_ApplyLipstick_g16_c05       ApplyLipstick       ApplyLipstick
# 12937           v_SkyDiving_g19_c01           SkyDiving         CliffDiving
# 12938        v_PlayingFlute_g24_c05        PlayingFlute        PlayingFlute
# 12939         v_BalanceBeam_g16_c02         BalanceBeam         BalanceBeam
# 12940              v_TaiChi_g13_c02              TaiChi           GolfSwing
# 12941         v_PommelHorse_g04_c03         PommelHorse         PommelHorse
# 12942       v_ApplyLipstick_g05_c05       ApplyLipstick       ApplyLipstick
# 12943        v_PlayingFlute_g25_c05        PlayingFlute        PlayingFlute
# 12944             v_Haircut_g11_c04             Haircut             Haircut
# 12945         v_PommelHorse_g11_c01         PommelHorse         PommelHorse
# 12946       v_PlayingGuitar_g17_c04       PlayingGuitar       PlayingGuitar
# 12947      v_WalkingWithDog_g14_c01      WalkingWithDog             Archery
# 12948        v_PlayingSitar_g08_c07        PlayingSitar        PlayingSitar
# ...
# 13110            v_Kayaking_g09_c05            Kayaking            Kayaking
# 13111         v_CricketShot_g12_c05         CricketShot         CricketShot
# 13112        v_CleanAndJerk_g12_c04        CleanAndJerk        CleanAndJerk
# 13113           v_SkyDiving_g06_c03           SkyDiving           SkyDiving
# 13114        v_ParallelBars_g02_c03        ParallelBars        ParallelBars
# 13115          v_IceDancing_g13_c02          IceDancing          IceDancing
# 13116           v_PoleVault_g03_c03           PoleVault           PoleVault
# 13117         v_TennisSwing_g08_c06         TennisSwing         TennisSwing
# 13118             v_Rafting_g08_c05             Rafting             Rafting
# 13119      v_ApplyEyeMakeup_g04_c03      ApplyEyeMakeup      ApplyEyeMakeup
# 13120      v_MilitaryParade_g11_c02      MilitaryParade      MilitaryParade
# 13121           v_PoleVault_g18_c02           PoleVault           PoleVault
# 13122       v_PlayingGuitar_g12_c01       PlayingGuitar       PlayingGuitar
# 13123      v_BlowingCandles_g10_c01      BlowingCandles      BlowingCandles
# 13124       v_PlayingGuitar_g08_c06       PlayingGuitar       PlayingGuitar
# 13125   v_BoxingPunchingBag_g08_c06   BoxingPunchingBag   BoxingPunchingBag
# 13126          v_PlayingDaf_g05_c03          PlayingDaf          PlayingDaf
# 13127         v_TennisSwing_g15_c05         TennisSwing         TennisSwing
# 13128            v_Kayaking_g09_c02            Kayaking            Kayaking
# 13129   v_TrampolineJumping_g20_c04   TrampolineJumping   TrampolineJumping
# 13130   v_BoxingPunchingBag_g16_c05   BoxingPunchingBag   BoxingPunchingBag
# 13131       v_SumoWrestling_g24_c04       SumoWrestling       SumoWrestling
# 13132       v_BrushingTeeth_g19_c02       BrushingTeeth       BrushingTeeth
# 13133             v_Surfing_g20_c03             Surfing             Surfing
# 13134       v_SumoWrestling_g08_c06       SumoWrestling       SumoWrestling
# 13135        v_ShavingBeard_g16_c01        ShavingBeard        ShavingBeard
# 13136        v_BandMarching_g25_c02        BandMarching        BandMarching
# 13137             v_Shotput_g08_c02             Shotput             Shotput
# 13138    v_HandstandWalking_g12_c03    HandstandWalking    HandstandWalking
# 13139        v_FrisbeeCatch_g16_c05        FrisbeeCatch        FrisbeeCatch
# 13140              v_Mixing_g25_c01              Mixing              Mixing
# 13141   v_BoxingPunchingBag_g20_c02   BoxingPunchingBag   BoxingPunchingBag
# 13142         v_HammerThrow_g02_c05         HammerThrow         HammerThrow
# 13143        v_PizzaTossing_g04_c05        PizzaTossing        PizzaTossing
# 13144        v_BandMarching_g05_c04        BandMarching        BandMarching
# 13145              v_Typing_g14_c05              Typing              Typing
# 13146           v_SkyDiving_g02_c02           SkyDiving           SkyDiving
# 13147               v_Punch_g25_c07               Punch               Punch
# 13148        v_CleanAndJerk_g20_c04        CleanAndJerk        CleanAndJerk
# 13149         v_WallPushups_g11_c04         WallPushups         WallPushups
# 13150     v_FloorGymnastics_g16_c03     FloorGymnastics     FloorGymnastics
# 13151               v_Swing_g21_c03               Swing               Swing
# 13152         v_CliffDiving_g22_c02         CliffDiving         CliffDiving
# 13153    v_BodyWeightSquats_g10_c05    BodyWeightSquats    BodyWeightSquats
# 13154    v_HandstandWalking_g21_c04    HandstandWalking    HandstandWalking
# 13155        v_FrisbeeCatch_g09_c02        FrisbeeCatch        FrisbeeCatch
# 13156            v_Kayaking_g12_c01            Kayaking             Rafting
# 13157       v_JugglingBalls_g08_c01       JugglingBalls       JugglingBalls
# 13158      v_BoxingSpeedBag_g20_c04      BoxingSpeedBag      BoxingSpeedBag
# 13159        v_JavelinThrow_g05_c03        JavelinThrow        JavelinThrow
# 13160       v_BrushingTeeth_g07_c01       BrushingTeeth       ApplyLipstick
# 13161             v_Surfing_g14_c04             Surfing             Surfing
# 13162     v_TableTennisShot_g24_c03     TableTennisShot     TableTennisShot
# 13163        v_PlayingSitar_g19_c03        PlayingSitar        PlayingSitar
# 13164        v_JavelinThrow_g01_c03        JavelinThrow        JavelinThrow
# 13165              v_Diving_g10_c02              Diving              Diving
# 13166         v_CliffDiving_g23_c05         CliffDiving         CliffDiving
# 13167          v_BenchPress_g21_c03          BenchPress          BenchPress
# 13168           v_Hammering_g11_c03           Hammering    HandstandWalking
# 13169       v_BaseballPitch_g01_c05       BaseballPitch         JumpingJack
# 13170      v_WalkingWithDog_g14_c03      WalkingWithDog      WalkingWithDog
# 13171          v_FrontCrawl_g20_c04          FrontCrawl          FrontCrawl
# 13172         v_CliffDiving_g05_c02         CliffDiving         CliffDiving
# 13173         v_BlowDryHair_g19_c04         BlowDryHair         BlowDryHair
# 13174             v_Haircut_g08_c06             Haircut             Haircut
# 13175             v_Rafting_g03_c02             Rafting             Rafting
# 13176               v_Punch_g12_c05               Punch               Punch
# 13177   v_VolleyballSpiking_g24_c02   VolleyballSpiking   VolleyballSpiking
# 13178             v_Surfing_g07_c02             Surfing             Surfing
# 13179      v_SoccerJuggling_g01_c01      SoccerJuggling      SoccerJuggling
# 13180              v_Skiing_g04_c07              Skiing              Skiing
# 13181                v_YoYo_g03_c03                YoYo                YoYo
# 13182        v_ParallelBars_g16_c04        ParallelBars        ParallelBars
# 13183            v_Kayaking_g16_c03            Kayaking            Kayaking
# 13184      v_BasketballDunk_g05_c04      BasketballDunk      BasketballDunk
# 13185        v_PlayingCello_g16_c02        PlayingCello        PlayingCello
# 13186          v_BenchPress_g04_c05          BenchPress          BenchPress
# 13187       v_SumoWrestling_g07_c04       SumoWrestling       SumoWrestling
# 13188         v_BalanceBeam_g17_c02         BalanceBeam         BalanceBeam
# 13189    v_HandstandWalking_g13_c03    HandstandWalking    HandstandWalking
# 13190         v_WallPushups_g16_c07         WallPushups         WallPushups
# 13191       v_BrushingTeeth_g05_c01       BrushingTeeth       BrushingTeeth
# 13192           v_SkyDiving_g18_c05           SkyDiving           SkyDiving
# 13193   v_TrampolineJumping_g12_c03   TrampolineJumping   TrampolineJumping
# 13194        v_BreastStroke_g06_c01        BreastStroke         CliffDiving
# 13195         v_HammerThrow_g03_c04         HammerThrow         HammerThrow
# 13196          v_Basketball_g23_c03          Basketball          Basketball
# 13197        v_BabyCrawling_g13_c05        BabyCrawling        BabyCrawling
# 13198            v_Kayaking_g10_c02            Kayaking         CliffDiving
# 13199              v_Rowing_g10_c01              Rowing              Rowing
# 13200         v_JumpingJack_g05_c06         JumpingJack         JumpingJack
# 13201            v_HulaHoop_g02_c01            HulaHoop            HulaHoop
# 13202         v_HeadMassage_g14_c02         HeadMassage         HeadMassage
# 13203    v_BodyWeightSquats_g18_c04    BodyWeightSquats    BodyWeightSquats
# 13204         v_CricketShot_g06_c02         CricketShot         CricketShot
# 13205         v_PommelHorse_g02_c04         PommelHorse         PommelHorse
# 13206              v_Skiing_g05_c01              Skiing         CliffDiving
# 13207      v_BasketballDunk_g08_c05      BasketballDunk      BasketballDunk
# 13208       v_SumoWrestling_g17_c02       SumoWrestling       SumoWrestling
# 13209            v_HighJump_g16_c02            HighJump            HighJump
# 13210      v_WritingOnBoard_g05_c03      WritingOnBoard      WritingOnBoard
# 13211       v_JugglingBalls_g01_c01       JugglingBalls       JugglingBalls
# 13212           v_PoleVault_g23_c02           PoleVault           PoleVault
# 13213          v_FrontCrawl_g05_c04          FrontCrawl          FrontCrawl
# 13214              v_Biking_g15_c03              Biking              Biking
# 13215            v_LongJump_g05_c02            LongJump            LongJump
# 13216              v_Skiing_g20_c07              Skiing              Skiing
# 13217           v_Nunchucks_g20_c02           Nunchucks           Nunchucks
# 13218       v_SkateBoarding_g23_c02       SkateBoarding       SkateBoarding
# 13219      v_CricketBowling_g18_c04      CricketBowling      CricketBowling
# 13220          v_BenchPress_g08_c06          BenchPress          BenchPress
# 13221             v_Archery_g05_c03             Archery             Archery
# 13222     v_TableTennisShot_g14_c02     TableTennisShot     TableTennisShot
# 13223             v_Bowling_g25_c05             Bowling             Bowling
# 13224          v_UnevenBars_g24_c03          UnevenBars          UnevenBars
# 13225         v_HeadMassage_g17_c06         HeadMassage               Punch
# 13226        v_PlayingTabla_g23_c03        PlayingTabla        PlayingTabla
# 13227       v_SumoWrestling_g04_c01       SumoWrestling             Shotput
# 13228             v_Archery_g12_c03             Archery             Archery
# 13229      v_MilitaryParade_g14_c05      MilitaryParade      MilitaryParade
# 13230           v_SkyDiving_g07_c02           SkyDiving           SkyDiving
# 13231          v_PlayingDaf_g10_c03          PlayingDaf          PlayingDaf
# 13232                v_YoYo_g01_c02                YoYo                YoYo
# 13233       v_PlayingGuitar_g05_c01       PlayingGuitar       PlayingGuitar
# 13234              v_Lunges_g19_c01              Lunges              Lunges
# 13235             v_Haircut_g05_c03             Haircut        ShavingBeard
# 13236   v_VolleyballSpiking_g14_c04   VolleyballSpiking   VolleyballSpiking
# 13237         v_CliffDiving_g22_c06         CliffDiving         CliffDiving
# 13238         v_ThrowDiscus_g02_c03         ThrowDiscus         ThrowDiscus
# 13239           v_SkyDiving_g21_c01           SkyDiving           SkyDiving
# 13240        v_ShavingBeard_g13_c01        ShavingBeard        ShavingBeard
# 13241         v_ThrowDiscus_g01_c01         ThrowDiscus         ThrowDiscus
# 13242          v_Basketball_g06_c04          Basketball        JavelinThrow
# 13243      v_ApplyEyeMakeup_g25_c07      ApplyEyeMakeup      ApplyEyeMakeup
# 13244              v_Skiing_g18_c03              Skiing              Skiing
# 13245      v_BlowingCandles_g04_c02      BlowingCandles      BlowingCandles
# 13246         v_HeadMassage_g23_c06         HeadMassage         HeadMassage
# 13247              v_TaiChi_g01_c02              TaiChi              TaiChi
# 13248          v_FrontCrawl_g04_c06          FrontCrawl          FrontCrawl
# 13249           v_Nunchucks_g05_c04           Nunchucks           Nunchucks
# 13250       v_SkateBoarding_g12_c02       SkateBoarding       SkateBoarding
# 13251        v_PlayingPiano_g12_c04        PlayingPiano        PlayingPiano
# 13252      v_WalkingWithDog_g25_c02      WalkingWithDog      WalkingWithDog
# 13253       v_PlayingGuitar_g10_c06       PlayingGuitar       PlayingGuitar
# 13254           v_Hammering_g19_c01           Hammering           Hammering
# 13255            v_JumpRope_g20_c05            JumpRope            JumpRope
# 13256         v_CricketShot_g21_c04         CricketShot         CricketShot
# 13257           v_Hammering_g03_c01           Hammering           Hammering
# 13258           v_Billiards_g14_c04           Billiards           Billiards
# 13259    v_CuttingInKitchen_g10_c04    CuttingInKitchen           Hammering
# 13260      v_ApplyEyeMakeup_g09_c06      ApplyEyeMakeup      ApplyEyeMakeup
# 13261        v_BandMarching_g02_c05        BandMarching        BandMarching
# 13262      v_BoxingSpeedBag_g20_c05      BoxingSpeedBag      BoxingSpeedBag
# 13263      v_MilitaryParade_g17_c02      MilitaryParade      MilitaryParade
# 13264             v_Bowling_g06_c01             Bowling             Bowling
# 13265     v_FloorGymnastics_g12_c01     FloorGymnastics     FloorGymnastics
# 13266              v_Typing_g02_c05              Typing              Typing
# 13267          v_PlayingDaf_g20_c01          PlayingDaf          PlayingDaf
# 13268    v_HandstandWalking_g01_c04    HandstandWalking    HandstandWalking
# 13269        v_BandMarching_g09_c02        BandMarching      MilitaryParade
# 13270      v_WalkingWithDog_g05_c04      WalkingWithDog      WalkingWithDog
# 13271          v_Basketball_g09_c03          Basketball          Basketball
# 13272         v_HorseRiding_g25_c04         HorseRiding         HorseRiding
# 13273         v_CliffDiving_g25_c04         CliffDiving         CliffDiving
# 13274          v_StillRings_g11_c01          StillRings          StillRings
# 13275    v_BodyWeightSquats_g05_c01    BodyWeightSquats    BodyWeightSquats
# 13276              v_Rowing_g07_c03              Rowing              Rowing
# 13277             v_Surfing_g04_c01             Surfing             Surfing
# 13278             v_Fencing_g25_c04             Fencing             Fencing
# 13279             v_Surfing_g15_c03             Surfing             Surfing
# 13280              v_Rowing_g14_c05              Rowing              Rowing
# 13281           v_Hammering_g17_c01           Hammering           Hammering
# 13282           v_Billiards_g02_c07           Billiards           Billiards
# 13283              v_Skiing_g11_c04              Skiing              Skiing
# 13284      v_SoccerJuggling_g19_c06      SoccerJuggling      SoccerJuggling
# 13285           v_Nunchucks_g22_c03           Nunchucks           Nunchucks
# 13286         v_BalanceBeam_g15_c02         BalanceBeam         BalanceBeam
# 13287      v_MilitaryParade_g03_c01      MilitaryParade      MilitaryParade
# 13288  v_FieldHockeyPenalty_g23_c04  FieldHockeyPenalty  FieldHockeyPenalty
# 13289             v_Archery_g18_c02             Archery             Archery
# 13290             v_Rafting_g08_c01             Rafting             Rafting
# 13291         v_HeadMassage_g16_c04         HeadMassage         HeadMassage
# 13292         v_PlayingDhol_g05_c06         PlayingDhol         PlayingDhol
# 13293           v_Nunchucks_g16_c02           Nunchucks           SalsaSpin
# 13294   v_VolleyballSpiking_g09_c06   VolleyballSpiking   VolleyballSpiking
# 13295   v_BoxingPunchingBag_g03_c03   BoxingPunchingBag   BoxingPunchingBag
# 13296         v_PlayingDhol_g25_c05         PlayingDhol         PlayingDhol
# 13297       v_SoccerPenalty_g06_c06       SoccerPenalty       SoccerPenalty
# 13298       v_BrushingTeeth_g03_c03       BrushingTeeth       BrushingTeeth
# 13299    v_HandstandPushups_g13_c01    HandstandPushups    HandstandPushups
# 13300           v_SkyDiving_g19_c02           SkyDiving           SkyDiving
# 13301          v_BenchPress_g12_c01          BenchPress          BenchPress
# 13302            v_Kayaking_g16_c05            Kayaking            Kayaking
# 13303           v_Nunchucks_g25_c04           Nunchucks           Nunchucks
# 13304    v_BodyWeightSquats_g01_c02    BodyWeightSquats    BodyWeightSquats
# 13305            v_HulaHoop_g03_c03            HulaHoop            HulaHoop
# 13306             v_Bowling_g16_c02             Bowling             Bowling
# 13307             v_Bowling_g09_c06             Bowling             Bowling
# 13308        v_PlayingPiano_g15_c03        PlayingPiano        PlayingPiano
# 13309             v_Shotput_g20_c03             Shotput             Shotput
# 13310       v_PlayingGuitar_g23_c02       PlayingGuitar       PlayingGuitar
# 13311         v_BlowDryHair_g07_c01         BlowDryHair         BlowDryHair
# 13312          v_StillRings_g10_c03          StillRings          StillRings
# 13313   v_BoxingPunchingBag_g08_c05   BoxingPunchingBag   BoxingPunchingBag
# 13314            v_JumpRope_g15_c01            JumpRope            JumpRope
# 13315       v_PlayingGuitar_g20_c04       PlayingGuitar       PlayingGuitar
# 13316        v_JavelinThrow_g16_c05        JavelinThrow  FieldHockeyPenalty
# 13317        v_PlayingSitar_g23_c05        PlayingSitar        PlayingSitar
# 13318      v_BasketballDunk_g19_c03      BasketballDunk      BasketballDunk
# 13319            v_Drumming_g03_c04            Drumming            Drumming
#
# [13320 rows x 3 columns]

# %% [markdown]
# ### Videos with wrong predictions

# %%
a = df['filename'][df['y_pred']!=df['y']].tolist()
b = df['y'][df['y_pred']!=df['y']].tolist()
c = df['y_pred'][df['y_pred']!=df['y']].tolist()

df_mistakes = pd.DataFrame(data={'filename':a, 'y':b, 'y_pred':c})
df_mistakes.to_pickle('./wrong_predictions.pkl')

# %%
df_mistakes
# Out:
#                          filename                   y              y_pred
# 0         v_SkateBoarding_g24_c02       SkateBoarding         CricketShot
# 1        v_WalkingWithDog_g02_c05      WalkingWithDog       SkateBoarding
# 2        v_CricketBowling_g19_c06      CricketBowling           SalsaSpin
# 3                v_Biking_g04_c04              Biking               Swing
# 4          v_RopeClimbing_g05_c05        RopeClimbing             PullUps
# 5      v_BodyWeightSquats_g15_c01    BodyWeightSquats             Shotput
# 6        v_SoccerJuggling_g22_c04      SoccerJuggling        RopeClimbing
# 7         v_SkateBoarding_g12_c01       SkateBoarding           PoleVault
# 8         v_SoccerPenalty_g11_c03       SoccerPenalty  FieldHockeyPenalty
# 9                v_Biking_g06_c04              Biking   TrampolineJumping
# 10           v_FrontCrawl_g17_c01          FrontCrawl              Diving
# 11       v_BasketballDunk_g21_c02      BasketballDunk         PommelHorse
# 12         v_CleanAndJerk_g24_c01        CleanAndJerk         PommelHorse
# 13             v_HighJump_g14_c02            HighJump        JavelinThrow
# 14              v_Archery_g07_c06             Archery             Rafting
# 15   v_FieldHockeyPenalty_g25_c01  FieldHockeyPenalty            HighJump
# 16          v_HorseRiding_g04_c01         HorseRiding           HorseRace
# 17         v_BreastStroke_g09_c04        BreastStroke          FrontCrawl
# 18        v_SumoWrestling_g05_c01       SumoWrestling        ParallelBars
# 19        v_PlayingGuitar_g05_c05       PlayingGuitar        PlayingSitar
# 20        v_BaseballPitch_g01_c03       BaseballPitch           Nunchucks
# 21          v_HammerThrow_g14_c05         HammerThrow          StillRings
# 22          v_BalanceBeam_g19_c02         BalanceBeam          UnevenBars
# 23             v_HighJump_g04_c01            HighJump            LongJump
# 24      v_FloorGymnastics_g22_c03     FloorGymnastics     TableTennisShot
# 25        v_SkateBoarding_g10_c07       SkateBoarding             Archery
# 26               v_Lunges_g15_c02              Lunges          BenchPress
# 27           v_StillRings_g11_c04          StillRings        RopeClimbing
# 28               v_Skiing_g13_c02              Skiing         CliffDiving
# 29             v_JumpRope_g09_c02            JumpRope        CleanAndJerk
# 30            v_SalsaSpin_g02_c02           SalsaSpin           Nunchucks
# 31        v_SkateBoarding_g25_c02       SkateBoarding             Archery
# 32             v_HighJump_g22_c04            HighJump             Bowling
# 33              v_Haircut_g07_c05             Haircut         BlowDryHair
# 34            v_GolfSwing_g21_c03           GolfSwing         HorseRiding
# 35          v_ThrowDiscus_g21_c04         ThrowDiscus         PommelHorse
# 36         v_FrisbeeCatch_g05_c01        FrisbeeCatch         ThrowDiscus
# 37           v_StillRings_g20_c04          StillRings        RopeClimbing
# 38         v_RopeClimbing_g15_c04        RopeClimbing             PullUps
# 39           v_UnevenBars_g17_c02          UnevenBars        ParallelBars
# 40         v_BabyCrawling_g20_c03        BabyCrawling             Archery
# 41            v_GolfSwing_g24_c04           GolfSwing               Swing
# 42         v_JavelinThrow_g20_c01        JavelinThrow            HighJump
# 43              v_Haircut_g16_c01             Haircut      WritingOnBoard
# 44    v_VolleyballSpiking_g17_c01   VolleyballSpiking      MilitaryParade
# 45               v_Lunges_g07_c03              Lunges          Basketball
# 46                 v_YoYo_g16_c04                YoYo           Nunchucks
# 47         v_BandMarching_g17_c04        BandMarching      BlowingCandles
# 48         v_ShavingBeard_g11_c03        ShavingBeard       BrushingTeeth
# 49         v_PlayingCello_g24_c06        PlayingCello        PlayingTabla
# 50     v_HandstandWalking_g05_c07    HandstandWalking        RopeClimbing
# 51         v_BandMarching_g19_c06        BandMarching      MilitaryParade
# 52            v_GolfSwing_g20_c03           GolfSwing      SoccerJuggling
# 53               v_Rowing_g02_c02              Rowing          FrontCrawl
# 54         v_PizzaTossing_g07_c04        PizzaTossing            Drumming
# 55         v_JavelinThrow_g12_c01        JavelinThrow            HighJump
# 56              v_Haircut_g04_c04             Haircut      BoxingSpeedBag
# 57          v_ThrowDiscus_g10_c01         ThrowDiscus         HammerThrow
# 58              v_Fencing_g10_c02             Fencing          StillRings
# 59       v_CricketBowling_g22_c05      CricketBowling           HorseRace
# 60        v_JugglingBalls_g18_c01       JugglingBalls       BrushingTeeth
# 61              v_PushUps_g16_c02             PushUps        RopeClimbing
# 62         v_PlayingTabla_g15_c02        PlayingTabla            HulaHoop
# 63          v_CliffDiving_g12_c05         CliffDiving      MilitaryParade
# 64          v_ThrowDiscus_g12_c01         ThrowDiscus      SoccerJuggling
# 65        v_BaseballPitch_g04_c01       BaseballPitch               Swing
# 66           v_Basketball_g09_c04          Basketball              TaiChi
# 67      v_FloorGymnastics_g17_c02     FloorGymnastics  FieldHockeyPenalty
# 68          v_HorseRiding_g12_c07         HorseRiding      WalkingWithDog
# 69         v_RopeClimbing_g22_c02        RopeClimbing    HandstandWalking
# 70     v_HandstandWalking_g04_c02    HandstandWalking           GolfSwing
# 71             v_Kayaking_g01_c03            Kayaking             Rafting
# 72         v_PizzaTossing_g19_c03        PizzaTossing           SalsaSpin
# 73        v_PlayingViolin_g06_c04       PlayingViolin        RopeClimbing
# 74               v_Lunges_g11_c06              Lunges         HammerThrow
# 75    v_VolleyballSpiking_g04_c02   VolleyballSpiking      BlowingCandles
# 76               v_Lunges_g19_c06              Lunges          BenchPress
# 77          v_ThrowDiscus_g17_c05         ThrowDiscus        JavelinThrow
# 78              v_Shotput_g14_c03             Shotput         TennisSwing
# 79       v_ApplyEyeMakeup_g22_c01      ApplyEyeMakeup        RopeClimbing
# 80          v_HammerThrow_g13_c07         HammerThrow         ThrowDiscus
# 81             v_HighJump_g22_c03            HighJump           Nunchucks
# 82    v_VolleyballSpiking_g02_c04   VolleyballSpiking         PommelHorse
# 83          v_BalanceBeam_g07_c04         BalanceBeam          UnevenBars
# 84             v_HighJump_g07_c05            HighJump        JavelinThrow
# 85         v_BreastStroke_g11_c04        BreastStroke          FrontCrawl
# 86         v_RopeClimbing_g04_c01        RopeClimbing             PullUps
# 87         v_ParallelBars_g17_c04        ParallelBars              Diving
# 88            v_GolfSwing_g24_c07           GolfSwing      SoccerJuggling
# 89       v_ApplyEyeMakeup_g14_c05      ApplyEyeMakeup      BoxingSpeedBag
# 90          v_BlowDryHair_g08_c02         BlowDryHair       BrushingTeeth
# 91               v_Skiing_g19_c06              Skiing            HighJump
# 92              v_Surfing_g16_c07             Surfing              Skijet
# 93          v_HeadMassage_g19_c02         HeadMassage             Shotput
# 94       v_SoccerJuggling_g20_c03      SoccerJuggling         TennisSwing
# 95           v_UnevenBars_g18_c01          UnevenBars          StillRings
# 96     v_BodyWeightSquats_g20_c02    BodyWeightSquats             Archery
# 97         v_FrisbeeCatch_g22_c06        FrisbeeCatch      WalkingWithDog
# 98        v_PlayingViolin_g17_c03       PlayingViolin        PlayingFlute
# 99         v_PizzaTossing_g10_c04        PizzaTossing   VolleyballSpiking
# 100         v_TennisSwing_g16_c06         TennisSwing         ThrowDiscus
# 101          v_Basketball_g18_c05          Basketball        CleanAndJerk
# 102             v_Haircut_g07_c06             Haircut      BoxingSpeedBag
# 103            v_LongJump_g07_c04            LongJump             Shotput
# 104        v_CleanAndJerk_g24_c02        CleanAndJerk          BenchPress
# 105        v_BreastStroke_g01_c02        BreastStroke          FrontCrawl
# 106    v_HandstandWalking_g16_c04    HandstandWalking    BodyWeightSquats
# 107         v_CliffDiving_g04_c01         CliffDiving            Kayaking
# 108        v_BandMarching_g24_c01        BandMarching           PoleVault
# 109         v_WallPushups_g10_c02         WallPushups             PullUps
# 110    v_HandstandWalking_g17_c01    HandstandWalking        BabyCrawling
# 111      v_BasketballDunk_g14_c05      BasketballDunk         PommelHorse
# 112         v_JumpingJack_g21_c04         JumpingJack           GolfSwing
# 113         v_PommelHorse_g21_c04         PommelHorse        RopeClimbing
# 114               v_Swing_g12_c02               Swing      WalkingWithDog
# 115         v_ThrowDiscus_g14_c01         ThrowDiscus          StillRings
# 116              v_Rowing_g10_c05              Rowing             Rafting
# 117  v_RockClimbingIndoor_g21_c07  RockClimbingIndoor        RopeClimbing
# 118        v_BandMarching_g22_c04        BandMarching        ParallelBars
# 119      v_BasketballDunk_g06_c01      BasketballDunk           PoleVault
# 120              v_Mixing_g07_c03              Mixing           Hammering
# 121     v_TableTennisShot_g14_c04     TableTennisShot             PullUps
# 122             v_Haircut_g08_c02             Haircut           Hammering
# 123            v_Kayaking_g10_c01            Kayaking         CliffDiving
# 124        v_ParallelBars_g17_c03        ParallelBars          StillRings
# 125              v_Skiing_g15_c01              Skiing       SkateBoarding
# 126              v_Lunges_g14_c04              Lunges      BlowingCandles
# 127         v_HammerThrow_g09_c06         HammerThrow         ThrowDiscus
# 128          v_Basketball_g10_c02          Basketball     TableTennisShot
# 129          v_BenchPress_g23_c02          BenchPress              Lunges
# 130       v_SumoWrestling_g05_c03       SumoWrestling         PommelHorse
# 131    v_CuttingInKitchen_g15_c02    CuttingInKitchen          PlayingDaf
# 132        v_PlayingFlute_g08_c02        PlayingFlute      MilitaryParade
# 133      v_BasketballDunk_g21_c01      BasketballDunk    HandstandPushups
# 134           v_Hammering_g11_c02           Hammering        ParallelBars
# 135       v_BaseballPitch_g22_c06       BaseballPitch            HighJump
# 136               v_Punch_g10_c05               Punch           Nunchucks
# 137              v_Lunges_g15_c04              Lunges           SalsaSpin
# 138       v_PlayingViolin_g16_c04       PlayingViolin         PommelHorse
# 139      v_SoccerJuggling_g09_c03      SoccerJuggling          Basketball
# 140      v_SoccerJuggling_g01_c03      SoccerJuggling             PullUps
# 141   v_VolleyballSpiking_g09_c02   VolleyballSpiking           PoleVault
# 142              v_Rowing_g23_c02              Rowing              Diving
# 143              v_Diving_g23_c01              Diving          FrontCrawl
# 144           v_GolfSwing_g21_c02           GolfSwing      WalkingWithDog
# 145        v_FrisbeeCatch_g18_c03        FrisbeeCatch         HorseRiding
# 146   v_BoxingPunchingBag_g20_c05   BoxingPunchingBag          BenchPress
# 147           v_HorseRace_g09_c04           HorseRace      MilitaryParade
# 148        v_BreastStroke_g06_c04        BreastStroke          FrontCrawl
# 149        v_PizzaTossing_g21_c03        PizzaTossing     TableTennisShot
# 150      v_WalkingWithDog_g19_c01      WalkingWithDog      SoccerJuggling
# 151        v_PizzaTossing_g03_c02        PizzaTossing    HandstandPushups
# 152         v_BlowDryHair_g03_c01         BlowDryHair        ShavingBeard
# 153           v_Hammering_g13_c06           Hammering             Archery
# 154    v_CuttingInKitchen_g08_c02    CuttingInKitchen          PlayingDaf
# 155       v_SkateBoarding_g01_c04       SkateBoarding           PoleVault
# 156          v_Basketball_g13_c03          Basketball        RopeClimbing
# 157          v_StillRings_g04_c02          StillRings        ParallelBars
# 158        v_PizzaTossing_g12_c02        PizzaTossing         JumpingJack
# 159    v_HandstandWalking_g16_c03    HandstandWalking      BoxingSpeedBag
# 160       v_SumoWrestling_g19_c02       SumoWrestling             Shotput
# 161    v_HandstandWalking_g05_c06    HandstandWalking        ParallelBars
# 162         v_HorseRiding_g04_c07         HorseRiding      WalkingWithDog
# 163      v_CricketBowling_g22_c01      CricketBowling   VolleyballSpiking
# 164         v_HorseRiding_g19_c05         HorseRiding      WalkingWithDog
# 165              v_Skiing_g03_c04              Skiing       SkateBoarding
# 166                v_YoYo_g02_c01                YoYo            HulaHoop
# 167              v_Rowing_g14_c02              Rowing          FrontCrawl
# 168            v_HighJump_g13_c03            HighJump           PoleVault
# 169      v_CricketBowling_g24_c01      CricketBowling        FrisbeeCatch
# 170            v_LongJump_g09_c04            LongJump            HighJump
# 171        v_PlayingFlute_g02_c04        PlayingFlute        PlayingCello
# 172         v_HorseRiding_g15_c04         HorseRiding      WalkingWithDog
# 173        v_FrisbeeCatch_g22_c03        FrisbeeCatch              Lunges
# 174      v_WalkingWithDog_g22_c03      WalkingWithDog              Skiing
# 175       v_SumoWrestling_g22_c04       SumoWrestling             Shotput
# 176        v_ShavingBeard_g20_c07        ShavingBeard         HeadMassage
# 177   v_TrampolineJumping_g24_c01   TrampolineJumping         CliffDiving
# 178        v_BreastStroke_g10_c04        BreastStroke         CliffDiving
# 179         v_BalanceBeam_g07_c01         BalanceBeam          UnevenBars
# 180          v_Basketball_g18_c04          Basketball        CleanAndJerk
# 181    v_BodyWeightSquats_g20_c01    BodyWeightSquats           GolfSwing
# 182        v_JavelinThrow_g20_c03        JavelinThrow           PoleVault
# 183         v_PommelHorse_g17_c02         PommelHorse   BoxingPunchingBag
# 184             v_Shotput_g13_c04             Shotput            HighJump
# 185              v_Rowing_g22_c01              Rowing             Surfing
# 186          v_PlayingDaf_g09_c05          PlayingDaf      WritingOnBoard
# 187      v_WalkingWithDog_g10_c03      WalkingWithDog              Biking
# 188       v_SkateBoarding_g19_c02       SkateBoarding              Mixing
# 189      v_SoccerJuggling_g11_c05      SoccerJuggling          Basketball
# 190              v_Lunges_g07_c01              Lunges       SkateBoarding
# 191    v_HandstandWalking_g06_c02    HandstandWalking             PullUps
# 192    v_HandstandWalking_g17_c02    HandstandWalking              Mixing
# 193      v_BoxingSpeedBag_g14_c02      BoxingSpeedBag        MoppingFloor
# 194        v_JavelinThrow_g03_c03        JavelinThrow     FloorGymnastics
# 195        v_ParallelBars_g04_c06        ParallelBars              Diving
# 196       v_BaseballPitch_g01_c06       BaseballPitch           GolfSwing
# 197              v_TaiChi_g19_c02              TaiChi             PushUps
# 198        v_BandMarching_g07_c01        BandMarching            Drumming
# 199        v_BabyCrawling_g07_c03        BabyCrawling       BrushingTeeth
# 200              v_Mixing_g06_c03              Mixing      BlowingCandles
# 201    v_CuttingInKitchen_g19_c01    CuttingInKitchen           Hammering
# 202      v_ApplyEyeMakeup_g02_c04      ApplyEyeMakeup         BlowDryHair
# 203            v_HulaHoop_g01_c05            HulaHoop        BandMarching
# 204        v_ShavingBeard_g17_c05        ShavingBeard         HeadMassage
# 205          v_UnevenBars_g01_c01          UnevenBars         BalanceBeam
# 206      v_ApplyEyeMakeup_g10_c02      ApplyEyeMakeup       BrushingTeeth
# 207  v_FieldHockeyPenalty_g04_c05  FieldHockeyPenalty         HammerThrow
# 208      v_WritingOnBoard_g10_c07      WritingOnBoard             PullUps
# 209        v_JavelinThrow_g13_c02        JavelinThrow            HighJump
# 210        v_PizzaTossing_g03_c01        PizzaTossing         JumpingJack
# 211         v_ThrowDiscus_g09_c01         ThrowDiscus         HammerThrow
# 212            v_HighJump_g09_c05            HighJump     FloorGymnastics
# 213        v_PizzaTossing_g19_c02        PizzaTossing           SalsaSpin
# 214           v_GolfSwing_g17_c03           GolfSwing           Nunchucks
# 215             v_Rafting_g21_c01             Rafting            Kayaking
# 216        v_FrisbeeCatch_g05_c04        FrisbeeCatch         HammerThrow
# 217       v_BrushingTeeth_g21_c04       BrushingTeeth       ApplyLipstick
# 218      v_BoxingSpeedBag_g01_c02      BoxingSpeedBag         WallPushups
# 219        v_PizzaTossing_g18_c04        PizzaTossing        ParallelBars
# 220         v_CricketShot_g03_c04         CricketShot           GolfSwing
# 221         v_HammerThrow_g07_c04         HammerThrow      MilitaryParade
# 222        v_JavelinThrow_g24_c06        JavelinThrow           PoleVault
# 223          v_StillRings_g16_c03          StillRings           PoleVault
# 224        v_ShavingBeard_g11_c04        ShavingBeard       BrushingTeeth
# 225           v_GolfSwing_g18_c06           GolfSwing           Nunchucks
# 226        v_CleanAndJerk_g08_c02        CleanAndJerk              Lunges
# 227          v_FrontCrawl_g24_c04          FrontCrawl            Kayaking
# 228              v_Rowing_g19_c04              Rowing              Diving
# 229         v_BalanceBeam_g18_c04         BalanceBeam        ParallelBars
# 230      v_SoccerJuggling_g12_c05      SoccerJuggling              Rowing
# 231        v_FrisbeeCatch_g19_c02        FrisbeeCatch           PoleVault
# 232                v_YoYo_g03_c01                YoYo            HulaHoop
# 233      v_MilitaryParade_g24_c04      MilitaryParade         HorseRiding
# 234    v_HandstandWalking_g04_c05    HandstandWalking         JumpingJack
# 235        v_JavelinThrow_g16_c02        JavelinThrow           PoleVault
# 236              v_TaiChi_g21_c04              TaiChi           GolfSwing
# 237      v_MilitaryParade_g08_c03      MilitaryParade        BandMarching
# 238        v_RopeClimbing_g05_c06        RopeClimbing        ParallelBars
# 239           v_GolfSwing_g09_c03           GolfSwing             Shotput
# 240            v_HulaHoop_g15_c03            HulaHoop            Drumming
# 241              v_Diving_g09_c03              Diving            Kayaking
# 242        v_JavelinThrow_g25_c03        JavelinThrow            HighJump
# 243            v_Kayaking_g17_c01            Kayaking             Rafting
# 244         v_TennisSwing_g02_c01         TennisSwing           PoleVault
# 245    v_BodyWeightSquats_g24_c02    BodyWeightSquats            JumpRope
# 246             v_Rafting_g06_c01             Rafting            Kayaking
# 247         v_BalanceBeam_g20_c02         BalanceBeam     FloorGymnastics
# 248      v_ApplyEyeMakeup_g10_c01      ApplyEyeMakeup       ApplyLipstick
# 249       v_BrushingTeeth_g22_c04       BrushingTeeth       ApplyLipstick
# 250   v_VolleyballSpiking_g16_c01   VolleyballSpiking        BandMarching
# 251   v_VolleyballSpiking_g13_c05   VolleyballSpiking           PoleVault
# 252       v_SkateBoarding_g14_c02       SkateBoarding  RockClimbingIndoor
# 253            v_LongJump_g06_c02            LongJump       SkateBoarding
# 254        v_BandMarching_g03_c01        BandMarching             Shotput
# 255         v_HorseRiding_g01_c07         HorseRiding      MilitaryParade
# 256         v_ThrowDiscus_g13_c03         ThrowDiscus          StillRings
# 257              v_Lunges_g25_c03              Lunges      WalkingWithDog
# 258  v_RockClimbingIndoor_g07_c07  RockClimbingIndoor        MoppingFloor
# 259              v_TaiChi_g08_c04              TaiChi         JumpingJack
# 260      v_BasketballDunk_g25_c04      BasketballDunk          StillRings
# 261            v_HighJump_g12_c02            HighJump           PoleVault
# 262        v_PlayingTabla_g21_c02        PlayingTabla             Archery
# 263        v_CleanAndJerk_g04_c03        CleanAndJerk             PullUps
# 264        v_BreastStroke_g03_c01        BreastStroke              Diving
# 265              v_Diving_g25_c02              Diving         CliffDiving
# 266        v_PizzaTossing_g18_c01        PizzaTossing            Drumming
# 267      v_WalkingWithDog_g04_c01      WalkingWithDog   TrampolineJumping
# 268         v_WallPushups_g24_c03         WallPushups   BoxingPunchingBag
# 269             v_Shotput_g15_c07             Shotput     FloorGymnastics
# 270        v_BreastStroke_g11_c03        BreastStroke          FrontCrawl
# 271            v_Kayaking_g07_c02            Kayaking             Rafting
# 272        v_PizzaTossing_g21_c04        PizzaTossing                YoYo
# 273         v_PommelHorse_g21_c02         PommelHorse        RopeClimbing
# 274            v_Kayaking_g11_c06            Kayaking             Rafting
# 275              v_Lunges_g15_c01              Lunges         JumpingJack
# 276              v_Skijet_g08_c03              Skijet            Kayaking
# 277            v_HighJump_g18_c01            HighJump   TrampolineJumping
# 278             v_Shotput_g24_c01             Shotput      CricketBowling
# 279            v_HighJump_g13_c05            HighJump           PoleVault
# 280        v_FrisbeeCatch_g25_c01        FrisbeeCatch        BandMarching
# 281              v_TaiChi_g25_c01              TaiChi         JumpingJack
# 282         v_ThrowDiscus_g09_c04         ThrowDiscus              Lunges
# 283         v_HorseRiding_g22_c01         HorseRiding           HorseRace
# 284        v_MoppingFloor_g11_c03        MoppingFloor             Archery
# 285   v_VolleyballSpiking_g25_c01   VolleyballSpiking            HighJump
# 286              v_Diving_g24_c03              Diving   VolleyballSpiking
# 287     v_TableTennisShot_g18_c02     TableTennisShot            JumpRope
# 288        v_PlayingSitar_g01_c04        PlayingSitar        RopeClimbing
# 289        v_BreastStroke_g19_c02        BreastStroke          FrontCrawl
# 290        v_JavelinThrow_g16_c01        JavelinThrow           PoleVault
# 291          v_Basketball_g12_c03          Basketball   VolleyballSpiking
# 292        v_BreastStroke_g13_c01        BreastStroke          FrontCrawl
# 293      v_CricketBowling_g04_c04      CricketBowling   VolleyballSpiking
# 294         v_HammerThrow_g01_c02         HammerThrow      MilitaryParade
# 295        v_BreastStroke_g20_c04        BreastStroke          FrontCrawl
# 296        v_ParallelBars_g21_c04        ParallelBars          StillRings
# 297          v_Basketball_g05_c02          Basketball           PoleVault
# 298       v_SumoWrestling_g22_c01       SumoWrestling        ParallelBars
# 299           v_PoleVault_g04_c01           PoleVault             Archery
# 300             v_Haircut_g18_c05             Haircut         BlowDryHair
# 301              v_TaiChi_g07_c03              TaiChi         HammerThrow
# 302      v_SoccerJuggling_g04_c05      SoccerJuggling    BodyWeightSquats
# 303        v_PlayingFlute_g17_c06        PlayingFlute        PlayingTabla
# 304             v_Shotput_g17_c04             Shotput    BodyWeightSquats
# 305       v_BaseballPitch_g25_c05       BaseballPitch        FrisbeeCatch
# 306            v_HulaHoop_g01_c02            HulaHoop         BalanceBeam
# 307         v_ThrowDiscus_g07_c06         ThrowDiscus         PommelHorse
# 308             v_Haircut_g19_c03             Haircut         WallPushups
# 309        v_PizzaTossing_g21_c01        PizzaTossing            HulaHoop
# 310        v_FrisbeeCatch_g07_c06        FrisbeeCatch  FieldHockeyPenalty
# 311          v_Basketball_g02_c05          Basketball        JavelinThrow
# 312              v_Lunges_g25_c01              Lunges         JumpingJack
# 313             v_Surfing_g16_c01             Surfing              Skijet
# 314              v_Lunges_g03_c03              Lunges         HammerThrow
# 315              v_Lunges_g07_c04              Lunges          Basketball
# 316        v_RopeClimbing_g25_c05        RopeClimbing             PullUps
# 317           v_Nunchucks_g24_c01           Nunchucks             Archery
# 318           v_GolfSwing_g17_c02           GolfSwing         HorseRiding
# 319            v_JumpRope_g01_c02            JumpRope        PizzaTossing
# 320    v_HandstandPushups_g04_c04    HandstandPushups   BoxingPunchingBag
# 321    v_HandstandWalking_g08_c01    HandstandWalking            HighJump
# 322      v_BlowingCandles_g12_c01      BlowingCandles       JugglingBalls
# 323          v_UnevenBars_g18_c02          UnevenBars         BalanceBeam
# 324         v_BalanceBeam_g24_c01         BalanceBeam            HighJump
# 325       v_BrushingTeeth_g06_c04       BrushingTeeth            Knitting
# 326           v_HorseRace_g11_c05           HorseRace              Skiing
# 327        v_PlayingFlute_g05_c01        PlayingFlute       PlayingViolin
# 328         v_HammerThrow_g13_c02         HammerThrow      BasketballDunk
# 329      v_BlowingCandles_g12_c02      BlowingCandles            Drumming
# 330       v_BrushingTeeth_g10_c02       BrushingTeeth        ShavingBeard
# 331          v_FrontCrawl_g07_c07          FrontCrawl          PlayingDaf
# 332         v_ThrowDiscus_g03_c01         ThrowDiscus         HammerThrow
# 333        v_RopeClimbing_g05_c07        RopeClimbing          StillRings
# 334         v_HorseRiding_g01_c06         HorseRiding        BandMarching
# 335           v_Nunchucks_g24_c05           Nunchucks         JumpingJack
# 336             v_Surfing_g05_c02             Surfing              Skijet
# 337        v_ParallelBars_g05_c02        ParallelBars        RopeClimbing
# 338      v_SoccerJuggling_g12_c04      SoccerJuggling        JavelinThrow
# 339            v_Kayaking_g09_c01            Kayaking             Rafting
# 340          v_IceDancing_g11_c03          IceDancing            HighJump
# 341        v_JavelinThrow_g16_c04        JavelinThrow           PoleVault
# 342      v_CricketBowling_g05_c03      CricketBowling        ParallelBars
# 343         v_HeadMassage_g15_c01         HeadMassage       JugglingBalls
# 344        v_FrisbeeCatch_g13_c01        FrisbeeCatch    HandstandWalking
# 345       v_SkateBoarding_g04_c05       SkateBoarding      WalkingWithDog
# 346      v_BasketballDunk_g15_c05      BasketballDunk            HighJump
# 347    v_HandstandWalking_g19_c01    HandstandWalking        RopeClimbing
# 348         v_BalanceBeam_g25_c01         BalanceBeam           PoleVault
# 349         v_BalanceBeam_g12_c02         BalanceBeam          UnevenBars
# 350         v_CliffDiving_g05_c01         CliffDiving       SkateBoarding
# 351        v_PlayingFlute_g08_c07        PlayingFlute      MilitaryParade
# 352      v_BlowingCandles_g11_c01      BlowingCandles          FrontCrawl
# 353       v_SumoWrestling_g22_c02       SumoWrestling         BalanceBeam
# 354           v_Nunchucks_g14_c04           Nunchucks   BoxingPunchingBag
# 355            v_HulaHoop_g18_c04            HulaHoop               Punch
# 356            v_HulaHoop_g05_c03            HulaHoop       SkateBoarding
# 357              v_Typing_g24_c02              Typing      ApplyEyeMakeup
# 358              v_Lunges_g25_c04              Lunges            HulaHoop
# 359       v_SkateBoarding_g16_c02       SkateBoarding              Biking
# 360             v_Bowling_g19_c04             Bowling         HammerThrow
# 361        v_BreastStroke_g02_c01        BreastStroke          FrontCrawl
# 362           v_SalsaSpin_g12_c02           SalsaSpin            HulaHoop
# 363        v_MoppingFloor_g07_c05        MoppingFloor        RopeClimbing
# 364       v_BaseballPitch_g04_c04       BaseballPitch               Swing
# 365             v_Rafting_g17_c02             Rafting              Rowing
# 366        v_BandMarching_g17_c03        BandMarching            Drumming
# 367       v_PlayingViolin_g16_c03       PlayingViolin         PlayingDhol
# 368                v_YoYo_g06_c01                YoYo        PlayingTabla
# 369        v_JavelinThrow_g23_c04        JavelinThrow           PoleVault
# 370        v_ShavingBeard_g12_c06        ShavingBeard      ApplyEyeMakeup
# 371   v_VolleyballSpiking_g22_c03   VolleyballSpiking     TableTennisShot
# 372              v_Biking_g04_c02              Biking       SkateBoarding
# 373          v_UnevenBars_g03_c01          UnevenBars              Diving
# 374       v_BrushingTeeth_g23_c01       BrushingTeeth       ApplyLipstick
# 375         v_ThrowDiscus_g18_c01         ThrowDiscus       BaseballPitch
# 376         v_HammerThrow_g21_c01         HammerThrow        RopeClimbing
# 377            v_Kayaking_g13_c01            Kayaking             Rafting
# 378     v_TableTennisShot_g25_c07     TableTennisShot            JumpRope
# 379        v_BreastStroke_g17_c02        BreastStroke          FrontCrawl
# 380        v_PlayingFlute_g02_c01        PlayingFlute         PlayingDhol
# 381         v_ThrowDiscus_g21_c05         ThrowDiscus      WalkingWithDog
# 382         v_PommelHorse_g19_c05         PommelHorse        PizzaTossing
# 383              v_Skijet_g16_c04              Skijet             Surfing
# 384      v_SoccerJuggling_g03_c02      SoccerJuggling         TennisSwing
# 385          v_Basketball_g02_c01          Basketball        JavelinThrow
# 386    v_HandstandPushups_g21_c02    HandstandPushups        RopeClimbing
# 387      v_WalkingWithDog_g08_c01      WalkingWithDog             Archery
# 388        v_JavelinThrow_g23_c05        JavelinThrow           PoleVault
# 389         v_CliffDiving_g04_c04         CliffDiving  RockClimbingIndoor
# 390        v_RopeClimbing_g21_c03        RopeClimbing           Hammering
# 391       v_BaseballPitch_g22_c05       BaseballPitch            HighJump
# 392             v_Haircut_g18_c03             Haircut         BlowDryHair
# 393        v_CleanAndJerk_g21_c04        CleanAndJerk        JavelinThrow
# 394        v_BabyCrawling_g17_c01        BabyCrawling        MoppingFloor
# 395              v_Skijet_g16_c02              Skijet             Surfing
# 396      v_BoxingSpeedBag_g18_c02      BoxingSpeedBag             PullUps
# 397              v_Skijet_g16_c03              Skijet             Surfing
# 398              v_Biking_g08_c04              Biking           PoleVault
# 399       v_SumoWrestling_g21_c01       SumoWrestling             Shotput
# 400  v_FieldHockeyPenalty_g03_c04  FieldHockeyPenalty      WalkingWithDog
# 401       v_BaseballPitch_g04_c02       BaseballPitch               Swing
# 402         v_ThrowDiscus_g07_c01         ThrowDiscus         PommelHorse
# 403     v_FloorGymnastics_g23_c01     FloorGymnastics         CliffDiving
# 404     v_FloorGymnastics_g25_c05     FloorGymnastics         TennisSwing
# 405          v_FrontCrawl_g06_c03          FrontCrawl        BreastStroke
# 406        v_JavelinThrow_g04_c01        JavelinThrow              Skiing
# 407        v_MoppingFloor_g13_c01        MoppingFloor  RockClimbingIndoor
# 408         v_CliffDiving_g23_c04         CliffDiving             Bowling
# 409    v_HandstandWalking_g19_c04    HandstandWalking        RopeClimbing
# 410       v_SumoWrestling_g04_c03       SumoWrestling             Shotput
# 411        v_BabyCrawling_g05_c02        BabyCrawling             PushUps
# 412         v_BalanceBeam_g04_c01         BalanceBeam          UnevenBars
# 413        v_PlayingPiano_g02_c03        PlayingPiano        PlayingCello
# 414       v_BrushingTeeth_g23_c03       BrushingTeeth       ApplyLipstick
# 415        v_MoppingFloor_g16_c03        MoppingFloor        RopeClimbing
# 416            v_HulaHoop_g16_c03            HulaHoop        PizzaTossing
# 417      v_SoccerJuggling_g11_c02      SoccerJuggling       JugglingBalls
# 418            v_HulaHoop_g08_c05            HulaHoop                YoYo
# 419         v_CricketShot_g07_c01         CricketShot       BaseballPitch
# 420        v_ShavingBeard_g20_c06        ShavingBeard             Haircut
# 421        v_PizzaTossing_g09_c04        PizzaTossing      BoxingSpeedBag
# 422  v_RockClimbingIndoor_g24_c05  RockClimbingIndoor         CliffDiving
# 423         v_ThrowDiscus_g24_c01         ThrowDiscus         HammerThrow
# 424                v_YoYo_g06_c04                YoYo            HulaHoop
# 425         v_HorseRiding_g04_c06         HorseRiding      WalkingWithDog
# 426         v_TennisSwing_g04_c07         TennisSwing         ThrowDiscus
# 427              v_TaiChi_g09_c04              TaiChi      WritingOnBoard
# 428             v_Shotput_g22_c01             Shotput         HammerThrow
# 429              v_Mixing_g04_c07              Mixing      BlowingCandles
# 430           v_GolfSwing_g25_c03           GolfSwing   BoxingPunchingBag
# 431        v_CleanAndJerk_g08_c01        CleanAndJerk           SalsaSpin
# 432               v_Swing_g17_c01               Swing           PoleVault
# 433          v_FrontCrawl_g06_c02          FrontCrawl         CliffDiving
# 434           v_Hammering_g18_c03           Hammering    HandstandPushups
# 435              v_Lunges_g20_c01              Lunges   BoxingPunchingBag
# 436       v_SumoWrestling_g20_c04       SumoWrestling         BalanceBeam
# 437            v_HulaHoop_g16_c01            HulaHoop           SalsaSpin
# 438              v_Typing_g19_c01              Typing        PlayingPiano
# 439             v_Haircut_g15_c03             Haircut              Mixing
# 440            v_LongJump_g06_c03            LongJump        BabyCrawling
# 441    v_CuttingInKitchen_g13_c02    CuttingInKitchen              Mixing
# 442            v_LongJump_g09_c01            LongJump           PoleVault
# 443      v_CricketBowling_g07_c03      CricketBowling         TennisSwing
# 444         v_PlayingDhol_g02_c05         PlayingDhol   BoxingPunchingBag
# 445              v_Lunges_g13_c01              Lunges        RopeClimbing
# 446      v_SoccerJuggling_g03_c04      SoccerJuggling         TennisSwing
# 447          v_Basketball_g13_c04          Basketball        RopeClimbing
# 448        v_BreastStroke_g04_c03        BreastStroke         CliffDiving
# 449           v_GolfSwing_g17_c01           GolfSwing         HorseRiding
# 450       v_SkateBoarding_g18_c05       SkateBoarding            HighJump
# 451            v_JumpRope_g05_c03            JumpRope            HulaHoop
# 452     v_FloorGymnastics_g17_c05     FloorGymnastics            LongJump
# 453             v_PushUps_g16_c03             PushUps         PommelHorse
# 454   v_VolleyballSpiking_g04_c07   VolleyballSpiking      BlowingCandles
# 455              v_Typing_g24_c04              Typing      ApplyEyeMakeup
# 456      v_SoccerJuggling_g03_c01      SoccerJuggling         TennisSwing
# 457         v_CricketShot_g07_c02         CricketShot      WalkingWithDog
# 458           v_SkyDiving_g07_c04           SkyDiving            Kayaking
# 459      v_WalkingWithDog_g07_c04      WalkingWithDog            HulaHoop
# 460        v_PizzaTossing_g18_c02        PizzaTossing        ParallelBars
# 461             v_Surfing_g25_c03             Surfing              Skijet
# 462            v_HighJump_g22_c02            HighJump           Nunchucks
# 463    v_BodyWeightSquats_g20_c05    BodyWeightSquats        MoppingFloor
# 464             v_Shotput_g09_c07             Shotput        PizzaTossing
# 465   v_VolleyballSpiking_g20_c01   VolleyballSpiking              Diving
# 466        v_ParallelBars_g10_c04        ParallelBars         PommelHorse
# 467      v_BoxingSpeedBag_g15_c02      BoxingSpeedBag         WallPushups
# 468       v_PlayingViolin_g05_c01       PlayingViolin        PlayingTabla
# 469         v_CliffDiving_g17_c03         CliffDiving             Rafting
# 470               v_Punch_g15_c06               Punch         PommelHorse
# 471    v_BodyWeightSquats_g02_c01    BodyWeightSquats             PullUps
# 472              v_Skijet_g09_c04              Skijet            Kayaking
# 473           v_HorseRace_g22_c04           HorseRace         HorseRiding
# 474            v_JumpRope_g10_c02            JumpRope           Nunchucks
# 475      v_ApplyEyeMakeup_g23_c01      ApplyEyeMakeup        PlayingFlute
# 476       v_BrushingTeeth_g25_c05       BrushingTeeth       ApplyLipstick
# 477        v_BabyCrawling_g22_c01        BabyCrawling           Hammering
# 478  v_FieldHockeyPenalty_g17_c04  FieldHockeyPenalty         TennisSwing
# 479              v_Lunges_g11_c01              Lunges        MoppingFloor
# 480       v_BrushingTeeth_g23_c04       BrushingTeeth       ApplyLipstick
# 481      v_BasketballDunk_g22_c04      BasketballDunk      MilitaryParade
# 482            v_LongJump_g06_c01            LongJump             Shotput
# 483        v_BabyCrawling_g13_c01        BabyCrawling        RopeClimbing
# 484        v_PlayingPiano_g18_c03        PlayingPiano      MilitaryParade
# 485         v_BlowDryHair_g16_c01         BlowDryHair        ShavingBeard
# 486     v_FloorGymnastics_g12_c04     FloorGymnastics           PoleVault
# 487    v_HandstandWalking_g19_c03    HandstandWalking        MoppingFloor
# 488              v_Mixing_g07_c04              Mixing    CuttingInKitchen
# 489              v_Skiing_g13_c05              Skiing         CliffDiving
# 490           v_SalsaSpin_g12_c06           SalsaSpin            HulaHoop
# 491              v_Typing_g04_c01              Typing        ShavingBeard
# 492          v_Basketball_g18_c02          Basketball        ParallelBars
# 493        v_RopeClimbing_g02_c05        RopeClimbing         HammerThrow
# 494        v_PizzaTossing_g13_c04        PizzaTossing   VolleyballSpiking
# 495    v_CuttingInKitchen_g05_c05    CuttingInKitchen              Mixing
# 496            v_HighJump_g04_c02            HighJump             PullUps
# 497      v_BlowingCandles_g12_c05      BlowingCandles        PizzaTossing
# 498    v_HandstandWalking_g15_c01    HandstandWalking          Basketball
# 499      v_SoccerJuggling_g02_c04      SoccerJuggling        MoppingFloor
# 500        v_PizzaTossing_g19_c05        PizzaTossing           Nunchucks
# 501              v_Skijet_g08_c02              Skijet            Kayaking
# 502         v_BlowDryHair_g02_c04         BlowDryHair        ShavingBeard
# 503       v_BaseballPitch_g01_c04       BaseballPitch             Shotput
# 504        v_BabyCrawling_g23_c02        BabyCrawling             Bowling
# 505   v_VolleyballSpiking_g25_c02   VolleyballSpiking          StillRings
# 506        v_JavelinThrow_g12_c04        JavelinThrow         TennisSwing
# 507        v_BandMarching_g16_c02        BandMarching            Drumming
# 508       v_SumoWrestling_g23_c03       SumoWrestling         PommelHorse
# 509        v_BandMarching_g16_c01        BandMarching            Drumming
# 510            v_HighJump_g13_c01            HighJump           PoleVault
# 511             v_Surfing_g19_c03             Surfing              Skijet
# 512        v_BandMarching_g02_c06        BandMarching            Drumming
# 513             v_Haircut_g17_c03             Haircut            Knitting
# 514              v_Rowing_g24_c02              Rowing              Diving
# 515        v_JavelinThrow_g09_c01        JavelinThrow            HighJump
# 516        v_PlayingFlute_g19_c02        PlayingFlute       PlayingViolin
# 517          v_FrontCrawl_g23_c07          FrontCrawl             Surfing
# 518        v_BabyCrawling_g16_c01        BabyCrawling        MoppingFloor
# 519         v_BalanceBeam_g14_c02         BalanceBeam          UnevenBars
# 520           v_GolfSwing_g17_c06           GolfSwing         HammerThrow
# 521             v_Haircut_g04_c05             Haircut      BoxingSpeedBag
# 522           v_SkyDiving_g15_c05           SkyDiving       SkateBoarding
# 523        v_PlayingPiano_g02_c04        PlayingPiano        PizzaTossing
# 524         v_ThrowDiscus_g22_c04         ThrowDiscus            HighJump
# 525        v_BandMarching_g07_c02        BandMarching      MilitaryParade
# 526            v_HulaHoop_g23_c05            HulaHoop         PlayingDhol
# 527         v_TennisSwing_g04_c06         TennisSwing         ThrowDiscus
# 528         v_HammerThrow_g13_c04         HammerThrow      BasketballDunk
# 529          v_StillRings_g12_c02          StillRings  RockClimbingIndoor
# 530        v_JavelinThrow_g25_c01        JavelinThrow            HighJump
# 531       v_BrushingTeeth_g01_c02       BrushingTeeth       ApplyLipstick
# 532             v_Shotput_g10_c01             Shotput            HighJump
# 533         v_ThrowDiscus_g13_c02         ThrowDiscus      WritingOnBoard
# 534       v_BaseballPitch_g04_c03       BaseballPitch               Swing
# 535        v_PlayingTabla_g05_c02        PlayingTabla            Drumming
# 536        v_PlayingTabla_g07_c01        PlayingTabla            Drumming
# 537  v_FieldHockeyPenalty_g04_c07  FieldHockeyPenalty         HammerThrow
# 538         v_HeadMassage_g05_c06         HeadMassage             Archery
# 539            v_HulaHoop_g15_c04            HulaHoop         JumpingJack
# 540      v_BoxingSpeedBag_g18_c04      BoxingSpeedBag             PullUps
# 541              v_Rowing_g17_c03              Rowing               Punch
# 542              v_Skiing_g22_c01              Skiing           SkyDiving
# 543   v_VolleyballSpiking_g23_c04   VolleyballSpiking          Basketball
# 544         v_HorseRiding_g01_c05         HorseRiding      MilitaryParade
# 545         v_BlowDryHair_g25_c01         BlowDryHair   BoxingPunchingBag
# 546       v_BrushingTeeth_g01_c01       BrushingTeeth       ApplyLipstick
# 547             v_Shotput_g04_c05             Shotput    HandstandWalking
# 548            v_LongJump_g04_c02            LongJump            HighJump
# 549        v_ShavingBeard_g12_c03        ShavingBeard             Haircut
# 550             v_PullUps_g05_c03             PullUps        RopeClimbing
# 551              v_Lunges_g05_c03              Lunges         ThrowDiscus
# 552            v_Drumming_g16_c07            Drumming         PommelHorse
# 553  v_RockClimbingIndoor_g05_c02  RockClimbingIndoor       SkateBoarding
# 554         v_HammerThrow_g07_c05         HammerThrow      MilitaryParade
# 555           v_Hammering_g06_c01           Hammering             PushUps
# 556        v_JavelinThrow_g17_c04        JavelinThrow            HighJump
# 557         v_HammerThrow_g16_c02         HammerThrow        RopeClimbing
# 558       v_JugglingBalls_g15_c02       JugglingBalls          PlayingDaf
# 559              v_Skiing_g13_c07              Skiing       SkateBoarding
# 560        v_PlayingSitar_g11_c03        PlayingSitar        RopeClimbing
# 561        v_BabyCrawling_g23_c03        BabyCrawling             Bowling
# 562              v_Rowing_g24_c03              Rowing             Rafting
# 563         v_HeadMassage_g20_c05         HeadMassage             Haircut
# 564     v_TableTennisShot_g05_c03     TableTennisShot        CleanAndJerk
# 565             v_Haircut_g24_c03             Haircut        ShavingBeard
# 566            v_HulaHoop_g25_c04            HulaHoop         ThrowDiscus
# 567        v_FrisbeeCatch_g15_c01        FrisbeeCatch         HorseRiding
# 568            v_HulaHoop_g08_c04            HulaHoop    BodyWeightSquats
# 569  v_FieldHockeyPenalty_g25_c03  FieldHockeyPenalty           PoleVault
# 570        v_PlayingFlute_g02_c07        PlayingFlute        PlayingCello
# 571          v_Basketball_g02_c03          Basketball            HighJump
# 572              v_Biking_g13_c05              Biking             Archery
# 573        v_CleanAndJerk_g06_c04        CleanAndJerk            JumpRope
# 574         v_ThrowDiscus_g18_c03         ThrowDiscus       BaseballPitch
# 575              v_Typing_g20_c07              Typing        PlayingCello
# 576              v_Mixing_g08_c05              Mixing    CuttingInKitchen
# 577       v_SkateBoarding_g12_c04       SkateBoarding   TrampolineJumping
# 578              v_Lunges_g21_c01              Lunges    BodyWeightSquats
# 579              v_Lunges_g21_c04              Lunges             PushUps
# 580             v_Shotput_g21_c01             Shotput        ParallelBars
# 581         v_WallPushups_g10_c04         WallPushups        RopeClimbing
# 582        v_PlayingFlute_g02_c03        PlayingFlute         PlayingDhol
# 583          v_Basketball_g12_c02          Basketball         ThrowDiscus
# 584      v_BasketballDunk_g22_c02      BasketballDunk   VolleyballSpiking
# 585           v_PoleVault_g11_c02           PoleVault   VolleyballSpiking
# 586         v_BlowDryHair_g16_c03         BlowDryHair        ShavingBeard
# 587             v_Haircut_g25_c03             Haircut        ShavingBeard
# 588        v_BandMarching_g06_c04        BandMarching        RopeClimbing
# 589           v_HorseRace_g06_c01           HorseRace         HorseRiding
# 590        v_PlayingTabla_g24_c01        PlayingTabla         PlayingDhol
# 591    v_CuttingInKitchen_g13_c04    CuttingInKitchen              Mixing
# 592        v_PlayingCello_g03_c04        PlayingCello        PlayingTabla
# 593        v_PizzaTossing_g20_c02        PizzaTossing           Nunchucks
# 594       v_SoccerPenalty_g13_c04       SoccerPenalty           PoleVault
# 595           v_HorseRace_g16_c02           HorseRace  RockClimbingIndoor
# 596              v_Rowing_g19_c03              Rowing              Diving
# 597              v_Skijet_g14_c04              Skijet            Kayaking
# 598        v_RopeClimbing_g12_c02        RopeClimbing         PommelHorse
# 599        v_JavelinThrow_g24_c02        JavelinThrow           PoleVault
# 600      v_SoccerJuggling_g22_c03      SoccerJuggling             PullUps
# 601  v_RockClimbingIndoor_g05_c01  RockClimbingIndoor       SkateBoarding
# 602             v_Shotput_g16_c07             Shotput           GolfSwing
# 603    v_HandstandWalking_g10_c02    HandstandWalking            JumpRope
# 604            v_Drumming_g08_c04            Drumming          UnevenBars
# 605    v_HandstandWalking_g01_c01    HandstandWalking    HandstandPushups
# 606         v_BalanceBeam_g05_c03         BalanceBeam        ParallelBars
# 607         v_CliffDiving_g05_c05         CliffDiving        RopeClimbing
# 608           v_HorseRace_g16_c04           HorseRace            HighJump
# 609            v_HighJump_g13_c04            HighJump           PoleVault
# 610      v_BlowingCandles_g24_c02      BlowingCandles       BrushingTeeth
# 611    v_BodyWeightSquats_g04_c03    BodyWeightSquats            JumpRope
# 612       v_ApplyLipstick_g15_c02       ApplyLipstick      ApplyEyeMakeup
# 613       v_BaseballPitch_g19_c05       BaseballPitch          IceDancing
# 614        v_BreastStroke_g22_c01        BreastStroke          FrontCrawl
# 615         v_BalanceBeam_g22_c01         BalanceBeam          UnevenBars
# 616       v_BaseballPitch_g18_c07       BaseballPitch            LongJump
# 617    v_BodyWeightSquats_g04_c01    BodyWeightSquats            JumpRope
# 618         v_TennisSwing_g02_c07         TennisSwing   TrampolineJumping
# 619         v_HeadMassage_g14_c01         HeadMassage             Archery
# 620           v_GolfSwing_g21_c01           GolfSwing      WalkingWithDog
# 621            v_HighJump_g09_c04            HighJump           PoleVault
# 622             v_Haircut_g07_c04             Haircut        PizzaTossing
# 623          v_Basketball_g15_c06          Basketball   VolleyballSpiking
# 624          v_IceDancing_g21_c03          IceDancing         ThrowDiscus
# 625             v_Shotput_g04_c03             Shotput  FieldHockeyPenalty
# 626     v_FloorGymnastics_g15_c06     FloorGymnastics            HighJump
# 627                v_YoYo_g05_c02                YoYo        MoppingFloor
# 628         v_HammerThrow_g24_c03         HammerThrow      MilitaryParade
# 629             v_Shotput_g16_c05             Shotput            HulaHoop
# 630    v_CuttingInKitchen_g06_c01    CuttingInKitchen         CliffDiving
# 631  v_FieldHockeyPenalty_g24_c01  FieldHockeyPenalty             Surfing
# 632        v_BreastStroke_g17_c04        BreastStroke              Rowing
# 633             v_Shotput_g25_c02             Shotput         HammerThrow
# 634        v_JavelinThrow_g09_c03        JavelinThrow            HighJump
# 635    v_CuttingInKitchen_g05_c02    CuttingInKitchen             PushUps
# 636         v_ThrowDiscus_g11_c03         ThrowDiscus           PoleVault
# 637  v_FieldHockeyPenalty_g18_c04  FieldHockeyPenalty      BasketballDunk
# 638    v_BodyWeightSquats_g15_c04    BodyWeightSquats        CleanAndJerk
# 639           v_Hammering_g05_c03           Hammering             Archery
# 640           v_Nunchucks_g06_c01           Nunchucks           SalsaSpin
# 641  v_FieldHockeyPenalty_g19_c01  FieldHockeyPenalty         HammerThrow
# 642        v_BreastStroke_g11_c02        BreastStroke         CliffDiving
# 643            v_LongJump_g07_c03            LongJump     FloorGymnastics
# 644        v_JavelinThrow_g23_c03        JavelinThrow           PoleVault
# 645      v_MilitaryParade_g01_c07      MilitaryParade        BandMarching
# 646        v_PlayingTabla_g20_c03        PlayingTabla         PlayingDhol
# ...
# 660           v_GolfSwing_g24_c01           GolfSwing               Swing
# 661         v_ThrowDiscus_g21_c03         ThrowDiscus         HammerThrow
# 662              v_Mixing_g05_c07              Mixing      BlowingCandles
# 663       v_BrushingTeeth_g23_c02       BrushingTeeth       ApplyLipstick
# 664        v_BabyCrawling_g19_c05        BabyCrawling        MoppingFloor
# 665       v_SumoWrestling_g22_c03       SumoWrestling             Fencing
# 666     v_TableTennisShot_g14_c05     TableTennisShot            JumpRope
# 667       v_PlayingViolin_g05_c03       PlayingViolin        PlayingCello
# 668             v_PullUps_g04_c02             PullUps               Swing
# 669         v_ThrowDiscus_g08_c01         ThrowDiscus           PoleVault
# 670           v_Hammering_g05_c04           Hammering             Archery
# 671             v_PullUps_g05_c04             PullUps        RopeClimbing
# 672    v_BodyWeightSquats_g09_c05    BodyWeightSquats      BasketballDunk
# 673           v_SalsaSpin_g21_c01           SalsaSpin         HorseRiding
# 674         v_BlowDryHair_g03_c02         BlowDryHair        ShavingBeard
# 675  v_FieldHockeyPenalty_g04_c01  FieldHockeyPenalty       BaseballPitch
# 676              v_TaiChi_g10_c04              TaiChi          IceDancing
# 677        v_PlayingTabla_g24_c03        PlayingTabla         PlayingDhol
# 678        v_BandMarching_g15_c06        BandMarching            LongJump
# 679        v_BandMarching_g10_c04        BandMarching            LongJump
# 680        v_RopeClimbing_g19_c03        RopeClimbing        MoppingFloor
# 681               v_Punch_g15_c05               Punch          BenchPress
# 682        v_ShavingBeard_g22_c05        ShavingBeard         HeadMassage
# 683  v_FieldHockeyPenalty_g12_c06  FieldHockeyPenalty           PoleVault
# 684        v_RopeClimbing_g10_c04        RopeClimbing             Archery
# 685             v_Bowling_g06_c04             Bowling     FloorGymnastics
# 686              v_TaiChi_g08_c02              TaiChi           Nunchucks
# 687       v_BaseballPitch_g15_c03       BaseballPitch             Shotput
# 688       v_SumoWrestling_g19_c04       SumoWrestling     TableTennisShot
# 689        v_MoppingFloor_g21_c04        MoppingFloor         HammerThrow
# 690        v_PlayingTabla_g08_c03        PlayingTabla            Drumming
# 691       v_BrushingTeeth_g04_c03       BrushingTeeth        ShavingBeard
# 692        v_CleanAndJerk_g13_c02        CleanAndJerk               Punch
# 693              v_Diving_g25_c03              Diving         BalanceBeam
# 694        v_BandMarching_g06_c01        BandMarching      BasketballDunk
# 695        v_JavelinThrow_g25_c02        JavelinThrow            HighJump
# 696              v_Skijet_g02_c02              Skijet            Kayaking
# 697              v_Lunges_g18_c03              Lunges           SalsaSpin
# 698    v_HandstandWalking_g24_c06    HandstandWalking             PullUps
# 699         v_ThrowDiscus_g22_c03         ThrowDiscus       BaseballPitch
# 700         v_ThrowDiscus_g07_c07         ThrowDiscus         PommelHorse
# 701           v_SkyDiving_g07_c05           SkyDiving              Skiing
# 702     v_TableTennisShot_g05_c01     TableTennisShot        CleanAndJerk
# 703        v_BreastStroke_g20_c03        BreastStroke          FrontCrawl
# 704        v_FrisbeeCatch_g22_c05        FrisbeeCatch           GolfSwing
# 705        v_BabyCrawling_g25_c01        BabyCrawling    HandstandWalking
# 706        v_RopeClimbing_g10_c02        RopeClimbing               Swing
# 707         v_PlayingDhol_g25_c07         PlayingDhol        MoppingFloor
# 708        v_BabyCrawling_g05_c05        BabyCrawling             PushUps
# 709              v_Skiing_g19_c04              Skiing        RopeClimbing
# 710         v_HammerThrow_g16_c03         HammerThrow        RopeClimbing
# 711              v_Rowing_g12_c04              Rowing              Diving
# 712       v_JugglingBalls_g05_c03       JugglingBalls          PlayingDaf
# 713               v_Punch_g22_c02               Punch         PommelHorse
# 714   v_VolleyballSpiking_g07_c03   VolleyballSpiking         PommelHorse
# 715        v_BabyCrawling_g13_c06        BabyCrawling    HandstandWalking
# 716      v_CricketBowling_g14_c05      CricketBowling         CricketShot
# 717        v_JavelinThrow_g07_c02        JavelinThrow          Basketball
# 718       v_BaseballPitch_g20_c04       BaseballPitch        JavelinThrow
# 719        v_PlayingSitar_g04_c01        PlayingSitar        RopeClimbing
# 720        v_JavelinThrow_g13_c01        JavelinThrow           PoleVault
# 721            v_HighJump_g06_c03            HighJump               Punch
# 722   v_BoxingPunchingBag_g10_c04   BoxingPunchingBag      BlowingCandles
# 723          v_BenchPress_g10_c04          BenchPress              Lunges
# 724        v_BabyCrawling_g25_c02        BabyCrawling    HandstandPushups
# 725              v_Rowing_g19_c05              Rowing            Kayaking
# 726               v_Punch_g01_c03               Punch         HorseRiding
# 727        v_BreastStroke_g17_c01        BreastStroke         CliffDiving
# 728             v_Surfing_g12_c06             Surfing              Skijet
# 729         v_ThrowDiscus_g17_c03         ThrowDiscus         HammerThrow
# 730        v_BandMarching_g23_c03        BandMarching      MilitaryParade
# 731        v_JavelinThrow_g08_c02        JavelinThrow            HighJump
# 732             v_Archery_g05_c01             Archery        MoppingFloor
# 733        v_ShavingBeard_g08_c01        ShavingBeard         HeadMassage
# 734        v_PlayingTabla_g17_c02        PlayingTabla            Drumming
# 735              v_Lunges_g07_c02              Lunges          Basketball
# 736              v_Lunges_g25_c02              Lunges         CliffDiving
# 737           v_PoleVault_g22_c03           PoleVault        RopeClimbing
# 738               v_Swing_g04_c02               Swing            HulaHoop
# 739             v_Shotput_g13_c01             Shotput       SumoWrestling
# 740         v_HeadMassage_g01_c01         HeadMassage       JugglingBalls
# 741        v_ShavingBeard_g25_c01        ShavingBeard    HandstandPushups
# 742             v_Rafting_g13_c03             Rafting            Kayaking
# 743       v_PlayingViolin_g16_c01       PlayingViolin         PommelHorse
# 744     v_FloorGymnastics_g03_c01     FloorGymnastics          UnevenBars
# 745        v_PlayingFlute_g17_c04        PlayingFlute          PlayingDaf
# 746           v_Hammering_g05_c01           Hammering             Archery
# 747              v_Rowing_g17_c02              Rowing              Skiing
# 748             v_Shotput_g15_c06             Shotput     FloorGymnastics
# 749              v_Lunges_g19_c07              Lunges          BenchPress
# 750           v_SalsaSpin_g03_c02           SalsaSpin         PommelHorse
# 751  v_RockClimbingIndoor_g07_c06  RockClimbingIndoor        MoppingFloor
# 752      v_ApplyEyeMakeup_g10_c03      ApplyEyeMakeup       ApplyLipstick
# 753      v_CricketBowling_g02_c02      CricketBowling         CliffDiving
# 754      v_ApplyEyeMakeup_g24_c03      ApplyEyeMakeup       ApplyLipstick
# 755        v_BreastStroke_g09_c02        BreastStroke          FrontCrawl
# 756        v_CleanAndJerk_g21_c03        CleanAndJerk         PlayingDhol
# 757   v_VolleyballSpiking_g21_c01   VolleyballSpiking        ParallelBars
# 758   v_VolleyballSpiking_g09_c05   VolleyballSpiking      SoccerJuggling
# 759             v_Haircut_g24_c05             Haircut      BoxingSpeedBag
# 760        v_BabyCrawling_g20_c04        BabyCrawling       SkateBoarding
# 761                v_YoYo_g07_c02                YoYo       JugglingBalls
# 762        v_RopeClimbing_g07_c04        RopeClimbing              Diving
# 763         v_ThrowDiscus_g22_c02         ThrowDiscus            HighJump
# 764              v_TaiChi_g24_c01              TaiChi         HammerThrow
# 765        v_ShavingBeard_g13_c05        ShavingBeard       BrushingTeeth
# 766              v_Lunges_g05_c01              Lunges         JumpingJack
# 767      v_SoccerJuggling_g15_c01      SoccerJuggling            HulaHoop
# 768             v_Haircut_g11_c05             Haircut        ShavingBeard
# 769        v_BreastStroke_g02_c04        BreastStroke          FrontCrawl
# 770        v_RopeClimbing_g12_c01        RopeClimbing           PoleVault
# 771       v_BaseballPitch_g22_c07       BaseballPitch            HighJump
# 772         v_HeadMassage_g06_c02         HeadMassage             Archery
# 773       v_PlayingViolin_g10_c02       PlayingViolin        PlayingCello
# 774            v_JumpRope_g10_c01            JumpRope           Nunchucks
# 775      v_WalkingWithDog_g22_c04      WalkingWithDog              Skiing
# 776              v_Skijet_g16_c01              Skijet             Surfing
# 777      v_CricketBowling_g24_c03      CricketBowling           Nunchucks
# 778               v_Punch_g09_c01               Punch     FloorGymnastics
# 779       v_SkateBoarding_g20_c03       SkateBoarding   TrampolineJumping
# 780        v_JavelinThrow_g03_c02        JavelinThrow     FloorGymnastics
# 781         v_ThrowDiscus_g12_c03         ThrowDiscus    BodyWeightSquats
# 782        v_ParallelBars_g22_c02        ParallelBars         HammerThrow
# 783       v_PlayingGuitar_g22_c03       PlayingGuitar       PlayingViolin
# 784      v_SoccerJuggling_g03_c03      SoccerJuggling         TennisSwing
# 785              v_TaiChi_g17_c03              TaiChi      WritingOnBoard
# 786      v_WalkingWithDog_g24_c05      WalkingWithDog           GolfSwing
# 787              v_Lunges_g21_c05              Lunges             PushUps
# 788     v_TableTennisShot_g14_c03     TableTennisShot             PullUps
# 789         v_BlowDryHair_g13_c03         BlowDryHair            Knitting
# 790         v_BalanceBeam_g24_c04         BalanceBeam        ParallelBars
# 791          v_Basketball_g02_c06          Basketball      CricketBowling
# 792        v_JavelinThrow_g03_c04        JavelinThrow           PoleVault
# 793         v_CliffDiving_g14_c02         CliffDiving         HammerThrow
# 794         v_PommelHorse_g19_c01         PommelHorse           Nunchucks
# 795             v_Bowling_g11_c06             Bowling         PommelHorse
# 796       v_BaseballPitch_g14_c02       BaseballPitch             Archery
# 797     v_TableTennisShot_g03_c04     TableTennisShot             PullUps
# 798      v_SoccerJuggling_g08_c02      SoccerJuggling            HulaHoop
# 799         v_ThrowDiscus_g24_c04         ThrowDiscus         HammerThrow
# 800      v_WritingOnBoard_g01_c06      WritingOnBoard  RockClimbingIndoor
# 801        v_BandMarching_g19_c02        BandMarching      MilitaryParade
# 802           v_SkyDiving_g15_c03           SkyDiving           Hammering
# 803           v_Hammering_g01_c04           Hammering  RockClimbingIndoor
# 804          v_Basketball_g12_c01          Basketball            HighJump
# 805      v_CricketBowling_g25_c04      CricketBowling         CricketShot
# 806            v_HulaHoop_g16_c06            HulaHoop        PizzaTossing
# 807       v_SumoWrestling_g21_c02       SumoWrestling             Shotput
# 808        v_PizzaTossing_g15_c01        PizzaTossing           Hammering
# 809         v_ThrowDiscus_g21_c07         ThrowDiscus       SkateBoarding
# 810      v_BasketballDunk_g11_c04      BasketballDunk     FloorGymnastics
# 811       v_PlayingGuitar_g17_c01       PlayingGuitar      BoxingSpeedBag
# 812       v_PlayingViolin_g15_c01       PlayingViolin        PlayingTabla
# 813        v_BreastStroke_g14_c02        BreastStroke          FrontCrawl
# 814       v_PlayingGuitar_g03_c01       PlayingGuitar        PlayingSitar
# 815          v_Basketball_g02_c04          Basketball            JumpRope
# 816                v_YoYo_g20_c03                YoYo               Punch
# 817        v_MoppingFloor_g04_c04        MoppingFloor         JumpingJack
# 818              v_Skijet_g14_c01              Skijet            Kayaking
# 819              v_Lunges_g05_c04              Lunges            HulaHoop
# 820       v_SumoWrestling_g21_c04       SumoWrestling   VolleyballSpiking
# 821      v_WalkingWithDog_g02_c02      WalkingWithDog       SkateBoarding
# 822             v_Haircut_g18_c02             Haircut      ApplyEyeMakeup
# 823           v_Hammering_g11_c01           Hammering    HandstandWalking
# 824       v_SumoWrestling_g11_c03       SumoWrestling         PommelHorse
# 825             v_PullUps_g06_c04             PullUps                YoYo
# 826            v_JumpRope_g01_c04            JumpRope           SalsaSpin
# 827           v_GolfSwing_g16_c03           GolfSwing      SoccerJuggling
# 828              v_Rowing_g05_c03              Rowing              Skiing
# 829                v_YoYo_g06_c03                YoYo            HulaHoop
# 830            v_Knitting_g01_c03            Knitting  RockClimbingIndoor
# 831              v_Rowing_g17_c05              Rowing  FieldHockeyPenalty
# 832        v_CleanAndJerk_g20_c03        CleanAndJerk          BenchPress
# 833       v_SkateBoarding_g02_c01       SkateBoarding           PoleVault
# 834             v_PushUps_g16_c04             PushUps   TrampolineJumping
# 835        v_JavelinThrow_g13_c03        JavelinThrow           PoleVault
# 836           v_Hammering_g07_c01           Hammering             Archery
# 837              v_Rowing_g05_c02              Rowing      MilitaryParade
# 838         v_HammerThrow_g25_c01         HammerThrow         ThrowDiscus
# 839      v_WalkingWithDog_g13_c03      WalkingWithDog       SkateBoarding
# 840      v_BlowingCandles_g12_c03      BlowingCandles        PizzaTossing
# 841         v_ThrowDiscus_g09_c05         ThrowDiscus         PommelHorse
# 842       v_BaseballPitch_g04_c05       BaseballPitch               Swing
# 843        v_CleanAndJerk_g06_c03        CleanAndJerk            JumpRope
# 844         v_ThrowDiscus_g07_c05         ThrowDiscus         PommelHorse
# 845        v_BandMarching_g11_c04        BandMarching    HandstandWalking
# 846           v_SkyDiving_g19_c01           SkyDiving         CliffDiving
# 847              v_TaiChi_g13_c02              TaiChi           GolfSwing
# 848      v_WalkingWithDog_g14_c01      WalkingWithDog             Archery
# 849              v_TaiChi_g04_c04              TaiChi      SoccerJuggling
# 850            v_HulaHoop_g03_c05            HulaHoop               Swing
# 851        v_PlayingCello_g12_c01        PlayingCello            Drumming
# 852         v_WallPushups_g19_c03         WallPushups    BodyWeightSquats
# 853             v_Fencing_g18_c04             Fencing      BasketballDunk
# 854           v_Hammering_g15_c01           Hammering        ShavingBeard
# 855        v_MoppingFloor_g02_c06        MoppingFloor           SalsaSpin
# 856        v_BreastStroke_g01_c03        BreastStroke          FrontCrawl
# 857        v_FrisbeeCatch_g22_c01        FrisbeeCatch              Lunges
# 858       v_PlayingViolin_g08_c04       PlayingViolin         HeadMassage
# 859           v_SkyDiving_g23_c01           SkyDiving              Skiing
# 860            v_HulaHoop_g16_c05            HulaHoop         PommelHorse
# 861            v_Kayaking_g12_c01            Kayaking             Rafting
# 862       v_BrushingTeeth_g07_c01       BrushingTeeth       ApplyLipstick
# 863           v_Hammering_g11_c03           Hammering    HandstandWalking
# 864       v_BaseballPitch_g01_c05       BaseballPitch         JumpingJack
# 865        v_BreastStroke_g06_c01        BreastStroke         CliffDiving
# 866            v_Kayaking_g10_c02            Kayaking         CliffDiving
# 867              v_Skiing_g05_c01              Skiing         CliffDiving
# 868         v_HeadMassage_g17_c06         HeadMassage               Punch
# 869       v_SumoWrestling_g04_c01       SumoWrestling             Shotput
# 870             v_Haircut_g05_c03             Haircut        ShavingBeard
# 871          v_Basketball_g06_c04          Basketball        JavelinThrow
# 872    v_CuttingInKitchen_g10_c04    CuttingInKitchen           Hammering
# 873        v_BandMarching_g09_c02        BandMarching      MilitaryParade
# 874           v_Nunchucks_g16_c02           Nunchucks           SalsaSpin
# 875        v_JavelinThrow_g16_c05        JavelinThrow  FieldHockeyPenalty

# %% [markdown]
# ### Videos with correct predictions

# %%
# find video filenames
correct_predict = ~df['filename'].isin(df_mistakes['filename'])

df_correct = df[correct_predict]
# df_correct.to_pickle('./correct_predictions.pkl')

# %%
df_correct
# Out:
#                            filename                   y              y_pred
# 0            v_PlayingSitar_g09_c06        PlayingSitar        PlayingSitar
# 1            v_PlayingPiano_g17_c02        PlayingPiano        PlayingPiano
# 2                v_LongJump_g03_c03            LongJump            LongJump
# 3                  v_TaiChi_g16_c02              TaiChi              TaiChi
# 4            v_ParallelBars_g01_c04        ParallelBars        ParallelBars
# 5            v_PlayingCello_g06_c05        PlayingCello        PlayingCello
# 6            v_PizzaTossing_g17_c03        PizzaTossing        PizzaTossing
# 7            v_MoppingFloor_g23_c04        MoppingFloor        MoppingFloor
# 8              v_BenchPress_g25_c06          BenchPress          BenchPress
# 9               v_GolfSwing_g12_c01           GolfSwing           GolfSwing
# 10               v_HighJump_g02_c03            HighJump            HighJump
# 11                 v_Typing_g06_c01              Typing              Typing
# 12         v_WritingOnBoard_g01_c02      WritingOnBoard      WritingOnBoard
# 13              v_Hammering_g17_c05           Hammering           Hammering
# 14                 v_Biking_g05_c07              Biking              Biking
# 15             v_PlayingDaf_g25_c05          PlayingDaf          PlayingDaf
# 16          v_BaseballPitch_g23_c05       BaseballPitch       BaseballPitch
# 17           v_FrisbeeCatch_g17_c04        FrisbeeCatch        FrisbeeCatch
# 18           v_BabyCrawling_g03_c02        BabyCrawling        BabyCrawling
# 19           v_ShavingBeard_g24_c03        ShavingBeard        ShavingBeard
# 20                  v_Punch_g14_c07               Punch               Punch
# 21        v_FloorGymnastics_g15_c03     FloorGymnastics     FloorGymnastics
# 22                 v_Skiing_g22_c03              Skiing              Skiing
# 23           v_PlayingPiano_g14_c02        PlayingPiano        PlayingPiano
# 24           v_PlayingFlute_g05_c02        PlayingFlute        PlayingFlute
# 25             v_IceDancing_g08_c03          IceDancing          IceDancing
# 26               v_JumpRope_g09_c05            JumpRope            JumpRope
# 27                v_PullUps_g07_c01             PullUps             PullUps
# 28                v_Bowling_g01_c07             Bowling             Bowling
# 29           v_FrisbeeCatch_g17_c03        FrisbeeCatch        FrisbeeCatch
# 30              v_GolfSwing_g04_c01           GolfSwing           GolfSwing
# 31             v_UnevenBars_g18_c03          UnevenBars          UnevenBars
# 32              v_HorseRace_g21_c02           HorseRace           HorseRace
# 33          v_BaseballPitch_g09_c02       BaseballPitch       BaseballPitch
# 34                 v_Typing_g08_c02              Typing              Typing
# 35           v_PizzaTossing_g12_c03        PizzaTossing        PizzaTossing
# 36     v_FieldHockeyPenalty_g13_c02  FieldHockeyPenalty  FieldHockeyPenalty
# 37             v_StillRings_g23_c02          StillRings          StillRings
# 38         v_CricketBowling_g12_c04      CricketBowling      CricketBowling
# 39              v_GolfSwing_g04_c04           GolfSwing           GolfSwing
# 40                v_Fencing_g17_c02             Fencing             Fencing
# 41            v_CricketShot_g18_c05         CricketShot         CricketShot
# 42             v_FrontCrawl_g06_c05          FrontCrawl          FrontCrawl
# 43                 v_Skiing_g17_c02              Skiing              Skiing
# 44         v_MilitaryParade_g13_c02      MilitaryParade      MilitaryParade
# 46               v_Knitting_g10_c01            Knitting            Knitting
# 47             v_StillRings_g17_c01          StillRings          StillRings
# 48           v_BabyCrawling_g01_c01        BabyCrawling        BabyCrawling
# 49          v_SkateBoarding_g13_c04       SkateBoarding       SkateBoarding
# 51               v_Kayaking_g05_c04            Kayaking            Kayaking
# 52                v_Surfing_g24_c01             Surfing             Surfing
# 53            v_CricketShot_g11_c07         CricketShot         CricketShot
# 54                  v_Swing_g17_c02               Swing               Swing
# 55                v_Shotput_g19_c01             Shotput             Shotput
# 56                v_PushUps_g05_c04             PushUps             PushUps
# 57           v_BabyCrawling_g09_c03        BabyCrawling        BabyCrawling
# 58                v_Shotput_g10_c03             Shotput             Shotput
# 59          v_ApplyLipstick_g06_c03       ApplyLipstick       ApplyLipstick
# 60             v_IceDancing_g14_c04          IceDancing          IceDancing
# 62                 v_Skiing_g24_c06              Skiing              Skiing
# 63          v_BaseballPitch_g19_c01       BaseballPitch       BaseballPitch
# 64           v_JavelinThrow_g05_c05        JavelinThrow        JavelinThrow
# 65                v_PushUps_g15_c02             PushUps             PushUps
# 66          v_BaseballPitch_g18_c04       BaseballPitch       BaseballPitch
# 67           v_FrisbeeCatch_g10_c05        FrisbeeCatch        FrisbeeCatch
# 68                v_PushUps_g20_c03             PushUps             PushUps
# 69                v_Shotput_g09_c05             Shotput             Shotput
# 70            v_WallPushups_g20_c06         WallPushups         WallPushups
# 71                v_Surfing_g24_c03             Surfing             Surfing
# 72           v_PlayingSitar_g06_c06        PlayingSitar        PlayingSitar
# 73                 v_Rowing_g15_c04              Rowing              Rowing
# 74             v_IceDancing_g02_c01          IceDancing          IceDancing
# 75                v_Bowling_g11_c02             Bowling             Bowling
# 76             v_StillRings_g01_c05          StillRings          StillRings
# 77                 v_Skiing_g02_c01              Skiing              Skiing
# 78                 v_Typing_g03_c06              Typing              Typing
# 79             v_StillRings_g10_c02          StillRings          StillRings
# 80          v_BrushingTeeth_g20_c04       BrushingTeeth       BrushingTeeth
# 81                v_PullUps_g11_c02             PullUps             PullUps
# 82               v_JumpRope_g13_c05            JumpRope            JumpRope
# 83          v_BrushingTeeth_g12_c06       BrushingTeeth       BrushingTeeth
# 84           v_JavelinThrow_g18_c01        JavelinThrow        JavelinThrow
# 85      v_TrampolineJumping_g09_c04   TrampolineJumping   TrampolineJumping
# 86         v_MilitaryParade_g01_c06      MilitaryParade      MilitaryParade
# 87                 v_TaiChi_g01_c01              TaiChi              TaiChi
# 89           v_MoppingFloor_g15_c01        MoppingFloor        MoppingFloor
# 90            v_BalanceBeam_g17_c04         BalanceBeam         BalanceBeam
# 91           v_PlayingFlute_g15_c01        PlayingFlute        PlayingFlute
# 92              v_Nunchucks_g04_c01           Nunchucks           Nunchucks
# 93                v_Shotput_g18_c01             Shotput             Shotput
# 94         v_CricketBowling_g02_c01      CricketBowling      CricketBowling
# 96           v_FrisbeeCatch_g08_c01        FrisbeeCatch        FrisbeeCatch
# 97                 v_Diving_g04_c05              Diving              Diving
# 98          v_BaseballPitch_g05_c03       BaseballPitch       BaseballPitch
# 99          v_PlayingViolin_g17_c02       PlayingViolin       PlayingViolin
# 100          v_ParallelBars_g11_c06        ParallelBars        ParallelBars
# 101              v_Drumming_g12_c01            Drumming            Drumming
# 103             v_HorseRace_g24_c05           HorseRace           HorseRace
# 104            v_PlayingDaf_g05_c01          PlayingDaf          PlayingDaf
# 105        v_CricketBowling_g08_c03      CricketBowling      CricketBowling
# 106                v_Skiing_g12_c02              Skiing              Skiing
# 107          v_PlayingTabla_g04_c05        PlayingTabla        PlayingTabla
# 108         v_BaseballPitch_g15_c02       BaseballPitch       BaseballPitch
# 109            v_Basketball_g04_c02          Basketball          Basketball
# 110               v_Shotput_g10_c04             Shotput             Shotput
# 111           v_PlayingDhol_g05_c01         PlayingDhol         PlayingDhol
# 112                v_Typing_g18_c02              Typing              Typing
# 113        v_CricketBowling_g09_c03      CricketBowling      CricketBowling
# 114             v_Billiards_g12_c01           Billiards           Billiards
# 115             v_HorseRace_g08_c04           HorseRace           HorseRace
# 116     v_VolleyballSpiking_g07_c01   VolleyballSpiking   VolleyballSpiking
# 117           v_CricketShot_g12_c03         CricketShot         CricketShot
# 118             v_SalsaSpin_g24_c03           SalsaSpin           SalsaSpin
# 119          v_PlayingTabla_g01_c04        PlayingTabla        PlayingTabla
# 120      v_HandstandWalking_g03_c02    HandstandWalking    HandstandWalking
# 121                v_Skiing_g25_c05              Skiing              Skiing
# 122             v_GolfSwing_g05_c02           GolfSwing           GolfSwing
# 123                  v_YoYo_g16_c03                YoYo                YoYo
# 124            v_UnevenBars_g12_c03          UnevenBars          UnevenBars
# 125             v_Billiards_g15_c02           Billiards           Billiards
# 126        v_WalkingWithDog_g23_c02      WalkingWithDog      WalkingWithDog
# 127                 v_Swing_g20_c01               Swing               Swing
# 128              v_JumpRope_g19_c04            JumpRope            JumpRope
# 129     v_TrampolineJumping_g11_c04   TrampolineJumping   TrampolineJumping
# 130               v_Archery_g13_c05             Archery             Archery
# 131               v_PullUps_g19_c03             PullUps             PullUps
# 132              v_JumpRope_g03_c01            JumpRope            JumpRope
# 133           v_BlowDryHair_g18_c05         BlowDryHair         BlowDryHair
# 134          v_FrisbeeCatch_g08_c03        FrisbeeCatch        FrisbeeCatch
# 135              v_Drumming_g24_c06            Drumming            Drumming
# 136        v_WalkingWithDog_g23_c01      WalkingWithDog      WalkingWithDog
# 137          v_JavelinThrow_g07_c05        JavelinThrow        JavelinThrow
# 138           v_BlowDryHair_g10_c02         BlowDryHair         BlowDryHair
# 139          v_BabyCrawling_g21_c01        BabyCrawling        BabyCrawling
# 140     v_VolleyballSpiking_g16_c02   VolleyballSpiking   VolleyballSpiking
# 141              v_Kayaking_g09_c04            Kayaking            Kayaking
# 142         v_BaseballPitch_g24_c01       BaseballPitch       BaseballPitch
# 143        v_WritingOnBoard_g15_c03      WritingOnBoard      WritingOnBoard
# 144           v_BlowDryHair_g11_c07         BlowDryHair         BlowDryHair
# 145               v_Haircut_g08_c04             Haircut             Haircut
# 146          v_JavelinThrow_g24_c03        JavelinThrow        JavelinThrow
# 147         v_BrushingTeeth_g19_c05       BrushingTeeth       BrushingTeeth
# 148              v_JumpRope_g21_c04            JumpRope            JumpRope
# 149         v_JugglingBalls_g07_c02       JugglingBalls       JugglingBalls
# 150             v_Nunchucks_g16_c01           Nunchucks           Nunchucks
# 151          v_ShavingBeard_g18_c01        ShavingBeard        ShavingBeard
# 152              v_HulaHoop_g15_c05            HulaHoop            HulaHoop
# 153           v_CricketShot_g21_c01         CricketShot         CricketShot
# 154          v_PlayingCello_g12_c02        PlayingCello        PlayingCello
# 155      v_HandstandPushups_g20_c01    HandstandPushups    HandstandPushups
# 156              v_JumpRope_g04_c05            JumpRope            JumpRope
# 157                v_Biking_g17_c02              Biking              Biking
# 158          v_RopeClimbing_g25_c03        RopeClimbing        RopeClimbing
# 159         v_PlayingGuitar_g21_c01       PlayingGuitar       PlayingGuitar
# 160              v_Kayaking_g07_c01            Kayaking            Kayaking
# 161                v_Skijet_g17_c02              Skijet              Skijet
# 162        v_BoxingSpeedBag_g04_c06      BoxingSpeedBag      BoxingSpeedBag
# 163           v_WallPushups_g07_c05         WallPushups         WallPushups
# 164           v_PlayingDhol_g12_c05         PlayingDhol         PlayingDhol
# 165             v_Hammering_g09_c07           Hammering           Hammering
# 166           v_HorseRiding_g02_c02         HorseRiding         HorseRiding
# 167               v_PullUps_g22_c04             PullUps             PullUps
# 168                 v_Swing_g19_c03               Swing               Swing
# 169            v_IceDancing_g04_c04          IceDancing          IceDancing
# 170                  v_YoYo_g09_c05                YoYo                YoYo
# 171              v_JumpRope_g21_c06            JumpRope            JumpRope
# 172    v_FieldHockeyPenalty_g09_c05  FieldHockeyPenalty  FieldHockeyPenalty
# 173             v_Billiards_g03_c05           Billiards           Billiards
# 174     v_BoxingPunchingBag_g23_c07   BoxingPunchingBag   BoxingPunchingBag
# 175         v_BrushingTeeth_g24_c04       BrushingTeeth       BrushingTeeth
# 176                v_Biking_g03_c03              Biking              Biking
# 177                v_TaiChi_g04_c03              TaiChi              TaiChi
# 178           v_CricketShot_g04_c01         CricketShot         CricketShot
# 179               v_Haircut_g15_c02             Haircut             Haircut
# 180          v_BabyCrawling_g22_c02        BabyCrawling        BabyCrawling
# 182           v_HammerThrow_g22_c04         HammerThrow         HammerThrow
# 183          v_BreastStroke_g05_c02        BreastStroke        BreastStroke
# 184     v_BoxingPunchingBag_g16_c03   BoxingPunchingBag   BoxingPunchingBag
# 185     v_BoxingPunchingBag_g14_c02   BoxingPunchingBag   BoxingPunchingBag
# 186           v_HorseRiding_g07_c02         HorseRiding         HorseRiding
# 187             v_SkyDiving_g23_c04           SkyDiving           SkyDiving
# 188          v_ShavingBeard_g03_c04        ShavingBeard        ShavingBeard
# 189             v_Hammering_g21_c03           Hammering           Hammering
# 190    v_FieldHockeyPenalty_g03_c02  FieldHockeyPenalty  FieldHockeyPenalty
# 191          v_FrisbeeCatch_g03_c03        FrisbeeCatch        FrisbeeCatch
# 192          v_PizzaTossing_g15_c03        PizzaTossing        PizzaTossing
# 193          v_PizzaTossing_g06_c01        PizzaTossing        PizzaTossing
# 194          v_MoppingFloor_g06_c04        MoppingFloor        MoppingFloor
# 195            v_StillRings_g09_c03          StillRings          StillRings
# 196          v_BandMarching_g07_c03        BandMarching        BandMarching
# 197           v_HammerThrow_g06_c05         HammerThrow         HammerThrow
# 198           v_CliffDiving_g24_c04         CliffDiving         CliffDiving
# 199            v_Basketball_g21_c04          Basketball          Basketball
# 200                v_Typing_g24_c01              Typing              Typing
# 201        v_CricketBowling_g03_c01      CricketBowling      CricketBowling
# 202           v_JumpingJack_g06_c02         JumpingJack         JumpingJack
# 203           v_TennisSwing_g25_c01         TennisSwing         TennisSwing
# 204          v_PizzaTossing_g11_c03        PizzaTossing        PizzaTossing
# 205          v_PlayingCello_g20_c01        PlayingCello        PlayingCello
# 206           v_CricketShot_g21_c06         CricketShot         CricketShot
# 207         v_BaseballPitch_g10_c03       BaseballPitch       BaseballPitch
# 208      v_CuttingInKitchen_g06_c04    CuttingInKitchen    CuttingInKitchen
# 209              v_Drumming_g05_c02            Drumming            Drumming
# 210        v_BoxingSpeedBag_g10_c04      BoxingSpeedBag      BoxingSpeedBag
# 211          v_ParallelBars_g08_c02        ParallelBars        ParallelBars
# 212           v_BlowDryHair_g09_c01         BlowDryHair         BlowDryHair
# 213                v_Typing_g03_c01              Typing              Typing
# 214             v_Nunchucks_g19_c02           Nunchucks           Nunchucks
# 215                v_Skiing_g01_c03              Skiing              Skiing
# 216               v_Haircut_g01_c01             Haircut             Haircut
# 219        v_MilitaryParade_g22_c01      MilitaryParade      MilitaryParade
# 220               v_Haircut_g15_c04             Haircut             Haircut
# 221          v_ParallelBars_g07_c05        ParallelBars        ParallelBars
# 222                  v_YoYo_g04_c04                YoYo                YoYo
# 223                v_Diving_g07_c02              Diving              Diving
# 224                v_Diving_g15_c02              Diving              Diving
# 225              v_LongJump_g11_c05            LongJump            LongJump
# 226          v_BreastStroke_g10_c02        BreastStroke        BreastStroke
# 227      v_HandstandPushups_g15_c04    HandstandPushups    HandstandPushups
# 228            v_Basketball_g10_c05          Basketball          Basketball
# 229            v_UnevenBars_g09_c02          UnevenBars          UnevenBars
# 230               v_Surfing_g08_c07             Surfing             Surfing
# 231            v_StillRings_g05_c04          StillRings          StillRings
# 232            v_UnevenBars_g15_c06          UnevenBars          UnevenBars
# 233            v_PlayingDaf_g05_c04          PlayingDaf          PlayingDaf
# 234          v_BandMarching_g14_c02        BandMarching        BandMarching
# 235           v_PlayingDhol_g24_c01         PlayingDhol         PlayingDhol
# 236          v_PlayingSitar_g08_c02        PlayingSitar        PlayingSitar
# 237             v_HorseRace_g01_c01           HorseRace           HorseRace
# 238             v_Nunchucks_g21_c05           Nunchucks           Nunchucks
# 239                 v_Punch_g18_c05               Punch               Punch
# 240                 v_Swing_g15_c02               Swing               Swing
# 241        v_BlowingCandles_g08_c03      BlowingCandles      BlowingCandles
# 242           v_PommelHorse_g22_c02         PommelHorse         PommelHorse
# 243          v_PizzaTossing_g04_c01        PizzaTossing        PizzaTossing
# 244                 v_Punch_g01_c05               Punch               Punch
# 245          v_PlayingTabla_g24_c04        PlayingTabla        PlayingTabla
# 246          v_PlayingFlute_g20_c02        PlayingFlute        PlayingFlute
# 248         v_SoccerPenalty_g16_c01       SoccerPenalty       SoccerPenalty
# 249         v_PlayingGuitar_g04_c01       PlayingGuitar       PlayingGuitar
# 250       v_TableTennisShot_g19_c01     TableTennisShot     TableTennisShot
# 251           v_PommelHorse_g18_c04         PommelHorse         PommelHorse
# 252                v_Diving_g15_c05              Diving              Diving
# 253               v_Bowling_g23_c04             Bowling             Bowling
# 254               v_Surfing_g16_c02             Surfing             Surfing
# 255              v_HighJump_g11_c06            HighJump            HighJump
# 256          v_BandMarching_g18_c02        BandMarching        BandMarching
# 257           v_HeadMassage_g10_c03         HeadMassage         HeadMassage
# 258                v_Typing_g06_c02              Typing              Typing
# 260           v_HammerThrow_g01_c03         HammerThrow         HammerThrow
# 261    v_RockClimbingIndoor_g20_c03  RockClimbingIndoor  RockClimbingIndoor
# 262               v_Rafting_g16_c01             Rafting             Rafting
# 263                  v_YoYo_g07_c01                YoYo                YoYo
# 264              v_Knitting_g14_c03            Knitting            Knitting
# 265               v_Archery_g25_c07             Archery             Archery
# 267             v_SalsaSpin_g03_c03           SalsaSpin           SalsaSpin
# 268             v_GolfSwing_g22_c03           GolfSwing           GolfSwing
# 270          v_PizzaTossing_g04_c03        PizzaTossing        PizzaTossing
# 271          v_FrisbeeCatch_g02_c01        FrisbeeCatch        FrisbeeCatch
# 272          v_PlayingTabla_g19_c01        PlayingTabla        PlayingTabla
# 273                v_Mixing_g04_c01              Mixing              Mixing
# 274           v_WallPushups_g25_c01         WallPushups         WallPushups
# 276             v_SkyDiving_g02_c03           SkyDiving           SkyDiving
# 277           v_PlayingDhol_g23_c07         PlayingDhol         PlayingDhol
# 278          v_PlayingCello_g05_c05        PlayingCello        PlayingCello
# 279            v_FrontCrawl_g14_c01          FrontCrawl          FrontCrawl
# 280       v_FloorGymnastics_g07_c04     FloorGymnastics     FloorGymnastics
# 281            v_BenchPress_g05_c07          BenchPress          BenchPress
# 282             v_SalsaSpin_g07_c01           SalsaSpin           SalsaSpin
# 283           v_HorseRiding_g23_c04         HorseRiding         HorseRiding
# 284           v_CricketShot_g05_c04         CricketShot         CricketShot
# 285                v_Mixing_g15_c02              Mixing              Mixing
# 287               v_Surfing_g07_c01             Surfing             Surfing
# 288         v_PlayingGuitar_g21_c03       PlayingGuitar       PlayingGuitar
# 289                v_Biking_g16_c05              Biking              Biking
# 290         v_JugglingBalls_g07_c05       JugglingBalls       JugglingBalls
# 292          v_PlayingPiano_g08_c01        PlayingPiano        PlayingPiano
# 293           v_TennisSwing_g14_c02         TennisSwing         TennisSwing
# 294          v_BandMarching_g20_c06        BandMarching        BandMarching
# 295           v_JumpingJack_g21_c01         JumpingJack         JumpingJack
# 296           v_BlowDryHair_g21_c06         BlowDryHair         BlowDryHair
# 297          v_PizzaTossing_g19_c04        PizzaTossing        PizzaTossing
# 298          v_BandMarching_g20_c04        BandMarching        BandMarching
# 299       v_TableTennisShot_g16_c03     TableTennisShot     TableTennisShot
# 300         v_SkateBoarding_g20_c02       SkateBoarding       SkateBoarding
# 301             v_HorseRace_g21_c05           HorseRace           HorseRace
# 302        v_WritingOnBoard_g11_c06      WritingOnBoard      WritingOnBoard
# 304               v_Bowling_g04_c04             Bowling             Bowling
# 305                v_Skijet_g21_c04              Skijet              Skijet
# 306             v_SalsaSpin_g17_c01           SalsaSpin           SalsaSpin
# 307                v_Typing_g14_c03              Typing              Typing
# 308          v_JavelinThrow_g11_c02        JavelinThrow        JavelinThrow
# 309        v_BoxingSpeedBag_g05_c05      BoxingSpeedBag      BoxingSpeedBag
# 310                v_Mixing_g10_c04              Mixing              Mixing
# 311         v_SoccerPenalty_g10_c05       SoccerPenalty       SoccerPenalty
# 313                v_Skijet_g25_c02              Skijet              Skijet
# 314         v_BaseballPitch_g08_c05       BaseballPitch       BaseballPitch
# 317              v_Kayaking_g24_c03            Kayaking            Kayaking
# 319                v_Biking_g16_c04              Biking              Biking
# 320                 v_Swing_g02_c02               Swing               Swing
# 321           v_HammerThrow_g23_c06         HammerThrow         HammerThrow
# 322           v_WallPushups_g03_c05         WallPushups         WallPushups
# 323         v_JugglingBalls_g16_c04       JugglingBalls       JugglingBalls
# 324           v_TennisSwing_g20_c01         TennisSwing         TennisSwing
# 325                v_Skiing_g12_c01              Skiing              Skiing
# 326    v_FieldHockeyPenalty_g06_c02  FieldHockeyPenalty  FieldHockeyPenalty
# 327                v_Rowing_g04_c05              Rowing              Rowing
# 328              v_Drumming_g13_c04            Drumming            Drumming
# 329         v_SkateBoarding_g10_c06       SkateBoarding       SkateBoarding
# 330        v_BasketballDunk_g11_c03      BasketballDunk      BasketballDunk
# 331           v_CricketShot_g04_c02         CricketShot         CricketShot
# 332    v_FieldHockeyPenalty_g14_c06  FieldHockeyPenalty  FieldHockeyPenalty
# 334                v_Diving_g10_c04              Diving              Diving
# 335        v_BlowingCandles_g22_c04      BlowingCandles      BlowingCandles
# 336                 v_Punch_g05_c04               Punch               Punch
# 337          v_BandMarching_g24_c02        BandMarching        BandMarching
# 338         v_SkateBoarding_g18_c04       SkateBoarding       SkateBoarding
# 339          v_CleanAndJerk_g19_c04        CleanAndJerk        CleanAndJerk
# 340    v_RockClimbingIndoor_g12_c02  RockClimbingIndoor  RockClimbingIndoor
# 341            v_FrontCrawl_g11_c07          FrontCrawl          FrontCrawl
# 342         v_ApplyLipstick_g16_c01       ApplyLipstick       ApplyLipstick
# 343          v_PlayingFlute_g23_c01        PlayingFlute        PlayingFlute
# 344           v_HammerThrow_g05_c03         HammerThrow         HammerThrow
# 345                v_Mixing_g10_c01              Mixing              Mixing
# 347         v_BrushingTeeth_g07_c02       BrushingTeeth       BrushingTeeth
# 348             v_Billiards_g15_c07           Billiards           Billiards
# 349              v_HighJump_g16_c05            HighJump            HighJump
# 350     v_BoxingPunchingBag_g20_c04   BoxingPunchingBag   BoxingPunchingBag
# 351     v_BoxingPunchingBag_g04_c03   BoxingPunchingBag   BoxingPunchingBag
# 352          v_PizzaTossing_g06_c05        PizzaTossing        PizzaTossing
# 353                v_Typing_g17_c01              Typing              Typing
# 354                v_Rowing_g01_c01              Rowing              Rowing
# 355          v_PlayingSitar_g04_c06        PlayingSitar        PlayingSitar
# 356         v_SoccerPenalty_g23_c05       SoccerPenalty       SoccerPenalty
# 357               v_Rafting_g06_c02             Rafting             Rafting
# 358             v_PoleVault_g20_c04           PoleVault           PoleVault
# 359                v_Mixing_g02_c02              Mixing              Mixing
# 360         v_JugglingBalls_g07_c04       JugglingBalls       JugglingBalls
# 361          v_PlayingSitar_g17_c01        PlayingSitar        PlayingSitar
# 362               v_Shotput_g08_c04             Shotput             Shotput
# 363           v_BalanceBeam_g07_c02         BalanceBeam         BalanceBeam
# 364           v_HeadMassage_g19_c05         HeadMassage         HeadMassage
# 365                v_Mixing_g23_c04              Mixing              Mixing
# 366               v_Rafting_g24_c01             Rafting             Rafting
# 367          v_PlayingCello_g06_c01        PlayingCello        PlayingCello
# 368         v_SumoWrestling_g25_c03       SumoWrestling       SumoWrestling
# 369           v_HorseRiding_g13_c04         HorseRiding         HorseRiding
# 370          v_PlayingTabla_g22_c03        PlayingTabla        PlayingTabla
# 371          v_BandMarching_g01_c05        BandMarching        BandMarching
# 372           v_PlayingDhol_g15_c01         PlayingDhol         PlayingDhol
# 373          v_PlayingTabla_g12_c04        PlayingTabla        PlayingTabla
# 374                 v_Punch_g16_c04               Punch               Punch
# 375          v_JavelinThrow_g14_c06        JavelinThrow        JavelinThrow
# 376            v_BenchPress_g13_c07          BenchPress          BenchPress
# 377         v_PlayingGuitar_g14_c01       PlayingGuitar       PlayingGuitar
# 378       v_TableTennisShot_g18_c04     TableTennisShot     TableTennisShot
# 379              v_LongJump_g11_c01            LongJump            LongJump
# 380             v_Billiards_g24_c03           Billiards           Billiards
# 381                v_Skijet_g12_c04              Skijet              Skijet
# 382                v_Lunges_g10_c05              Lunges              Lunges
# 383          v_RopeClimbing_g09_c03        RopeClimbing        RopeClimbing
# 384          v_ParallelBars_g09_c01        ParallelBars        ParallelBars
# 385        v_ApplyEyeMakeup_g13_c02      ApplyEyeMakeup      ApplyEyeMakeup
# 386             v_GolfSwing_g03_c03           GolfSwing           GolfSwing
# 387          v_PizzaTossing_g25_c01        PizzaTossing        PizzaTossing
# 388        v_CricketBowling_g24_c04      CricketBowling      CricketBowling
# 389               v_Fencing_g24_c02             Fencing             Fencing
# 390              v_Knitting_g05_c04            Knitting            Knitting
# 391             v_Billiards_g04_c07           Billiards           Billiards
# 392            v_UnevenBars_g03_c03          UnevenBars          UnevenBars
# 393        v_ApplyEyeMakeup_g24_c04      ApplyEyeMakeup      ApplyEyeMakeup
# 394          v_PlayingFlute_g10_c04        PlayingFlute        PlayingFlute
# 395         v_ApplyLipstick_g06_c05       ApplyLipstick       ApplyLipstick
# 397          v_PlayingPiano_g06_c01        PlayingPiano        PlayingPiano
# 398           v_JumpingJack_g13_c06         JumpingJack         JumpingJack
# 400                v_Skiing_g02_c04              Skiing              Skiing
# 401          v_PlayingSitar_g23_c07        PlayingSitar        PlayingSitar
# 402            v_IceDancing_g13_c04          IceDancing          IceDancing
# 403        v_BoxingSpeedBag_g17_c04      BoxingSpeedBag      BoxingSpeedBag
# 404               v_Bowling_g13_c02             Bowling             Bowling
# 405        v_ApplyEyeMakeup_g10_c05      ApplyEyeMakeup      ApplyEyeMakeup
# 406        v_MilitaryParade_g07_c02      MilitaryParade      MilitaryParade
# 407        v_ApplyEyeMakeup_g07_c03      ApplyEyeMakeup      ApplyEyeMakeup
# 409             v_PoleVault_g06_c04           PoleVault           PoleVault
# 410        v_CricketBowling_g04_c05      CricketBowling      CricketBowling
# 411               v_Bowling_g20_c06             Bowling             Bowling
# 412    v_RockClimbingIndoor_g05_c05  RockClimbingIndoor  RockClimbingIndoor
# 413              v_HighJump_g24_c03            HighJump            HighJump
# 414         v_SoccerPenalty_g09_c05       SoccerPenalty       SoccerPenalty
# 415             v_PoleVault_g17_c06           PoleVault           PoleVault
# 416            v_StillRings_g01_c01          StillRings          StillRings
# 417            v_BenchPress_g01_c01          BenchPress          BenchPress
# 418                 v_Punch_g19_c06               Punch               Punch
# 419                v_Rowing_g03_c07              Rowing              Rowing
# 420           v_PlayingDhol_g11_c01         PlayingDhol         PlayingDhol
# 421         v_SoccerPenalty_g22_c05       SoccerPenalty       SoccerPenalty
# 422                v_Lunges_g08_c04              Lunges              Lunges
# 423           v_JumpingJack_g12_c02         JumpingJack         JumpingJack
# 424             v_Hammering_g24_c05           Hammering           Hammering
# 425           v_ThrowDiscus_g07_c02         ThrowDiscus         ThrowDiscus
# 426      v_CuttingInKitchen_g12_c02    CuttingInKitchen    CuttingInKitchen
# 427              v_Drumming_g11_c07            Drumming            Drumming
# 428           v_HeadMassage_g15_c03         HeadMassage         HeadMassage
# 429         v_PlayingViolin_g06_c01       PlayingViolin       PlayingViolin
# 431        v_SoccerJuggling_g05_c03      SoccerJuggling      SoccerJuggling
# 432               v_PushUps_g04_c03             PushUps             PushUps
# 433        v_SoccerJuggling_g14_c03      SoccerJuggling      SoccerJuggling
# 434                v_Skiing_g06_c01              Skiing              Skiing
# 435              v_Drumming_g17_c03            Drumming            Drumming
# 436           v_BalanceBeam_g18_c02         BalanceBeam         BalanceBeam
# 437             v_GolfSwing_g04_c02           GolfSwing           GolfSwing
# 438           v_BalanceBeam_g06_c03         BalanceBeam         BalanceBeam
# 439                v_Skijet_g23_c01              Skijet              Skijet
# 440         v_JugglingBalls_g10_c02       JugglingBalls       JugglingBalls
# 441          v_PlayingCello_g23_c06        PlayingCello        PlayingCello
# 442          v_JavelinThrow_g10_c04        JavelinThrow        JavelinThrow
# 443         v_PlayingViolin_g23_c04       PlayingViolin       PlayingViolin
# 444         v_JugglingBalls_g03_c07       JugglingBalls       JugglingBalls
# 445                v_Mixing_g24_c02              Mixing              Mixing
# 446                v_Typing_g08_c05              Typing              Typing
# 448        v_WalkingWithDog_g02_c04      WalkingWithDog      WalkingWithDog
# 449                 v_Punch_g10_c06               Punch               Punch
# 450           v_CliffDiving_g22_c04         CliffDiving         CliffDiving
# 451            v_Basketball_g23_c01          Basketball          Basketball
# 452                v_Skijet_g25_c01              Skijet              Skijet
# 453        v_ApplyEyeMakeup_g23_c05      ApplyEyeMakeup      ApplyEyeMakeup
# 454           v_JumpingJack_g12_c01         JumpingJack         JumpingJack
# 455      v_HandstandPushups_g11_c06    HandstandPushups    HandstandPushups
# 456      v_BodyWeightSquats_g14_c04    BodyWeightSquats    BodyWeightSquats
# 457        v_WritingOnBoard_g13_c02      WritingOnBoard      WritingOnBoard
# 459        v_SoccerJuggling_g11_c06      SoccerJuggling      SoccerJuggling
# 460               v_Rafting_g11_c01             Rafting             Rafting
# 461            v_BenchPress_g03_c04          BenchPress          BenchPress
# 462               v_Rafting_g22_c04             Rafting             Rafting
# 463          v_PizzaTossing_g22_c01        PizzaTossing        PizzaTossing
# 464                v_Skiing_g18_c01              Skiing              Skiing
# 465            v_BenchPress_g17_c03          BenchPress          BenchPress
# 466     v_BoxingPunchingBag_g07_c03   BoxingPunchingBag   BoxingPunchingBag
# 467         v_ApplyLipstick_g14_c04       ApplyLipstick       ApplyLipstick
# 468        v_BoxingSpeedBag_g15_c01      BoxingSpeedBag      BoxingSpeedBag
# 469               v_Surfing_g08_c06             Surfing             Surfing
# 470           v_ThrowDiscus_g01_c03         ThrowDiscus         ThrowDiscus
# 472           v_PommelHorse_g13_c04         PommelHorse         PommelHorse
# 474       v_FloorGymnastics_g16_c02     FloorGymnastics     FloorGymnastics
# 475         v_SumoWrestling_g05_c02       SumoWrestling       SumoWrestling
# 476    v_RockClimbingIndoor_g16_c03  RockClimbingIndoor  RockClimbingIndoor
# 477      v_BodyWeightSquats_g16_c01    BodyWeightSquats    BodyWeightSquats
# 478              v_HulaHoop_g09_c01            HulaHoop            HulaHoop
# 479           v_BalanceBeam_g13_c03         BalanceBeam         BalanceBeam
# 480             v_HorseRace_g24_c02           HorseRace           HorseRace
# 481                v_Biking_g20_c04              Biking              Biking
# 482        v_BoxingSpeedBag_g11_c06      BoxingSpeedBag      BoxingSpeedBag
# 484      v_CuttingInKitchen_g05_c01    CuttingInKitchen    CuttingInKitchen
# 485         v_PlayingGuitar_g20_c03       PlayingGuitar       PlayingGuitar
# 486            v_BenchPress_g13_c06          BenchPress          BenchPress
# 487           v_HorseRiding_g14_c04         HorseRiding         HorseRiding
# 488                v_Typing_g07_c01              Typing              Typing
# 489     v_TrampolineJumping_g03_c02   TrampolineJumping   TrampolineJumping
# 490        v_WritingOnBoard_g20_c06      WritingOnBoard      WritingOnBoard
# 491               v_PushUps_g21_c02             PushUps             PushUps
# 492         v_SkateBoarding_g12_c06       SkateBoarding       SkateBoarding
# 493           v_PommelHorse_g05_c04         PommelHorse         PommelHorse
# 494           v_TennisSwing_g22_c04         TennisSwing         TennisSwing
# 495           v_PlayingDhol_g01_c06         PlayingDhol         PlayingDhol
# 496       v_TableTennisShot_g23_c02     TableTennisShot     TableTennisShot
# 497               v_PushUps_g10_c03             PushUps             PushUps
# 498               v_Fencing_g06_c04             Fencing             Fencing
# 500           v_BlowDryHair_g05_c01         BlowDryHair         BlowDryHair
# 501          v_PlayingCello_g13_c04        PlayingCello        PlayingCello
# 502           v_TennisSwing_g24_c04         TennisSwing         TennisSwing
# 504    v_RockClimbingIndoor_g07_c04  RockClimbingIndoor  RockClimbingIndoor
# 505           v_CliffDiving_g17_c04         CliffDiving         CliffDiving
# 506          v_PlayingPiano_g15_c02        PlayingPiano        PlayingPiano
# 507          v_MoppingFloor_g20_c02        MoppingFloor        MoppingFloor
# 508          v_RopeClimbing_g23_c04        RopeClimbing        RopeClimbing
# 509          v_PlayingFlute_g09_c02        PlayingFlute        PlayingFlute
# 511            v_IceDancing_g03_c05          IceDancing          IceDancing
# 512        v_BoxingSpeedBag_g11_c05      BoxingSpeedBag      BoxingSpeedBag
# 513                v_Skijet_g18_c02              Skijet              Skijet
# 514           v_TennisSwing_g02_c06         TennisSwing         TennisSwing
# 515         v_ApplyLipstick_g22_c01       ApplyLipstick       ApplyLipstick
# 516          v_PlayingSitar_g22_c01        PlayingSitar        PlayingSitar
# 517            v_UnevenBars_g16_c05          UnevenBars          UnevenBars
# 518             v_HorseRace_g07_c05           HorseRace           HorseRace
# 519             v_HorseRace_g20_c03           HorseRace           HorseRace
# 520          v_CleanAndJerk_g16_c01        CleanAndJerk        CleanAndJerk
# 521        v_WalkingWithDog_g01_c04      WalkingWithDog      WalkingWithDog
# 522               v_Bowling_g09_c04             Bowling             Bowling
# 523      v_CuttingInKitchen_g04_c01    CuttingInKitchen    CuttingInKitchen
# 524       v_TableTennisShot_g06_c01     TableTennisShot     TableTennisShot
# 525              v_JumpRope_g24_c03            JumpRope            JumpRope
# 526           v_HeadMassage_g18_c04         HeadMassage         HeadMassage
# 527          v_PlayingSitar_g05_c07        PlayingSitar        PlayingSitar
# 528               v_Haircut_g12_c02             Haircut             Haircut
# 529          v_PlayingPiano_g16_c05        PlayingPiano        PlayingPiano
# 530                v_Mixing_g13_c01              Mixing              Mixing
# 531        v_BasketballDunk_g19_c01      BasketballDunk      BasketballDunk
# 532             v_Nunchucks_g03_c03           Nunchucks           Nunchucks
# 533           v_JumpingJack_g06_c07         JumpingJack         JumpingJack
# 534            v_Basketball_g19_c01          Basketball          Basketball
# ...                             ...                 ...                 ...
# 12780             v_Rafting_g25_c02             Rafting             Rafting
# 12781              v_Skijet_g13_c02              Skijet              Skijet
# 12782          v_UnevenBars_g21_c02          UnevenBars          UnevenBars
# 12783    v_HandstandPushups_g10_c01    HandstandPushups    HandstandPushups
# 12784         v_HammerThrow_g13_c06         HammerThrow         HammerThrow
# 12785              v_Diving_g01_c05              Diving              Diving
# 12786    v_HandstandPushups_g16_c02    HandstandPushups    HandstandPushups
# 12787               v_Swing_g01_c02               Swing               Swing
# 12788        v_ShavingBeard_g07_c06        ShavingBeard        ShavingBeard
# 12789         v_CricketShot_g13_c02         CricketShot         CricketShot
# 12790           v_GolfSwing_g10_c01           GolfSwing           GolfSwing
# 12791  v_RockClimbingIndoor_g05_c06  RockClimbingIndoor  RockClimbingIndoor
# 12792          v_BenchPress_g07_c07          BenchPress          BenchPress
# 12793        v_FrisbeeCatch_g05_c05        FrisbeeCatch        FrisbeeCatch
# 12794             v_Shotput_g11_c07             Shotput             Shotput
# 12795              v_Diving_g09_c07              Diving              Diving
# 12796            v_Drumming_g12_c03            Drumming            Drumming
# 12797            v_JumpRope_g08_c05            JumpRope            JumpRope
# 12798            v_JumpRope_g04_c03            JumpRope            JumpRope
# 12799       v_PlayingGuitar_g16_c04       PlayingGuitar       PlayingGuitar
# 12800          v_PlayingDaf_g19_c05          PlayingDaf          PlayingDaf
# 12801          v_IceDancing_g08_c01          IceDancing          IceDancing
# 12802              v_Lunges_g21_c02              Lunges              Lunges
# 12803              v_Skiing_g13_c03              Skiing              Skiing
# 12804        v_PlayingSitar_g17_c05        PlayingSitar        PlayingSitar
# 12805        v_ShavingBeard_g17_c06        ShavingBeard        ShavingBeard
# 12806            v_JumpRope_g11_c03            JumpRope            JumpRope
# 12807            v_Drumming_g17_c05            Drumming            Drumming
# 12808      v_WalkingWithDog_g16_c01      WalkingWithDog      WalkingWithDog
# 12813        v_BandMarching_g23_c06        BandMarching        BandMarching
# 12814         v_BalanceBeam_g12_c04         BalanceBeam         BalanceBeam
# 12816            v_Drumming_g22_c03            Drumming            Drumming
# 12817            v_LongJump_g04_c06            LongJump            LongJump
# 12818                v_YoYo_g08_c04                YoYo                YoYo
# 12819        v_BabyCrawling_g07_c06        BabyCrawling        BabyCrawling
# 12820              v_Biking_g09_c03              Biking              Biking
# 12821              v_Diving_g06_c07              Diving              Diving
# 12822         v_PommelHorse_g02_c03         PommelHorse         PommelHorse
# 12823    v_BodyWeightSquats_g24_c03    BodyWeightSquats    BodyWeightSquats
# 12824        v_ShavingBeard_g20_c02        ShavingBeard        ShavingBeard
# 12825           v_SkyDiving_g04_c04           SkyDiving           SkyDiving
# 12826           v_HorseRace_g15_c01           HorseRace           HorseRace
# 12827         v_HammerThrow_g08_c01         HammerThrow         HammerThrow
# 12828         v_WallPushups_g06_c07         WallPushups         WallPushups
# 12829             v_PullUps_g23_c03             PullUps             PullUps
# 12830              v_TaiChi_g22_c04              TaiChi              TaiChi
# 12831             v_Archery_g07_c01             Archery             Archery
# 12832           v_Billiards_g25_c03           Billiards           Billiards
# 12833         v_BalanceBeam_g11_c03         BalanceBeam         BalanceBeam
# 12834      v_BoxingSpeedBag_g09_c01      BoxingSpeedBag      BoxingSpeedBag
# 12835          v_IceDancing_g19_c07          IceDancing          IceDancing
# 12836             v_PushUps_g21_c04             PushUps             PushUps
# 12837        v_BreastStroke_g14_c01        BreastStroke        BreastStroke
# 12838          v_IceDancing_g11_c01          IceDancing          IceDancing
# 12839       v_ApplyLipstick_g24_c01       ApplyLipstick       ApplyLipstick
# 12840             v_PullUps_g12_c01             PullUps             PullUps
# 12841             v_Surfing_g15_c02             Surfing             Surfing
# 12842            v_Knitting_g15_c05            Knitting            Knitting
# 12843         v_HeadMassage_g25_c05         HeadMassage         HeadMassage
# 12844             v_Archery_g10_c05             Archery             Archery
# 12845         v_TennisSwing_g06_c06         TennisSwing         TennisSwing
# 12846               v_Swing_g24_c04               Swing               Swing
# 12847       v_PlayingGuitar_g13_c06       PlayingGuitar       PlayingGuitar
# 12848        v_FrisbeeCatch_g09_c05        FrisbeeCatch        FrisbeeCatch
# 12849       v_SkateBoarding_g07_c02       SkateBoarding       SkateBoarding
# 12850           v_PoleVault_g08_c04           PoleVault           PoleVault
# 12851           v_SalsaSpin_g22_c01           SalsaSpin           SalsaSpin
# 12852            v_LongJump_g18_c03            LongJump            LongJump
# 12854         v_PommelHorse_g23_c03         PommelHorse         PommelHorse
# 12855        v_RopeClimbing_g14_c01        RopeClimbing        RopeClimbing
# 12856   v_VolleyballSpiking_g08_c04   VolleyballSpiking   VolleyballSpiking
# 12857             v_Surfing_g15_c04             Surfing             Surfing
# 12858            v_Knitting_g04_c01            Knitting            Knitting
# 12859          v_Basketball_g20_c04          Basketball          Basketball
# 12860          v_Basketball_g25_c07          Basketball          Basketball
# 12861         v_CliffDiving_g15_c03         CliffDiving         CliffDiving
# 12862          v_PlayingDaf_g10_c07          PlayingDaf          PlayingDaf
# 12863              v_Lunges_g23_c01              Lunges              Lunges
# 12864           v_Nunchucks_g10_c04           Nunchucks           Nunchucks
# 12865  v_FieldHockeyPenalty_g11_c04  FieldHockeyPenalty  FieldHockeyPenalty
# 12866      v_BoxingSpeedBag_g09_c03      BoxingSpeedBag      BoxingSpeedBag
# 12867            v_Knitting_g08_c03            Knitting            Knitting
# 12868        v_FrisbeeCatch_g25_c03        FrisbeeCatch        FrisbeeCatch
# 12869        v_RopeClimbing_g17_c01        RopeClimbing        RopeClimbing
# 12870         v_HorseRiding_g25_c05         HorseRiding         HorseRiding
# 12871             v_Shotput_g03_c03             Shotput             Shotput
# 12872    v_HandstandPushups_g18_c05    HandstandPushups    HandstandPushups
# 12873        v_CleanAndJerk_g19_c02        CleanAndJerk        CleanAndJerk
# 12874             v_PullUps_g25_c04             PullUps             PullUps
# 12875          v_FrontCrawl_g07_c05          FrontCrawl          FrontCrawl
# 12876        v_MoppingFloor_g01_c02        MoppingFloor        MoppingFloor
# 12878           v_HorseRace_g18_c03           HorseRace           HorseRace
# 12879        v_JavelinThrow_g04_c02        JavelinThrow        JavelinThrow
# 12880              v_TaiChi_g08_c01              TaiChi              TaiChi
# 12881            v_Kayaking_g19_c03            Kayaking            Kayaking
# 12882           v_SalsaSpin_g05_c06           SalsaSpin           SalsaSpin
# 12883     v_TableTennisShot_g15_c03     TableTennisShot     TableTennisShot
# 12884         v_HorseRiding_g06_c02         HorseRiding         HorseRiding
# 12885          v_FrontCrawl_g20_c06          FrontCrawl          FrontCrawl
# 12886    v_CuttingInKitchen_g17_c01    CuttingInKitchen    CuttingInKitchen
# 12887           v_PoleVault_g22_c01           PoleVault           PoleVault
# 12888        v_PlayingCello_g25_c02        PlayingCello        PlayingCello
# 12889   v_VolleyballSpiking_g19_c04   VolleyballSpiking   VolleyballSpiking
# 12890      v_WalkingWithDog_g12_c01      WalkingWithDog      WalkingWithDog
# 12891           v_SalsaSpin_g11_c06           SalsaSpin           SalsaSpin
# 12892         v_PlayingDhol_g25_c03         PlayingDhol         PlayingDhol
# 12893       v_JugglingBalls_g03_c03       JugglingBalls       JugglingBalls
# 12894              v_Skijet_g01_c01              Skijet              Skijet
# 12895         v_HammerThrow_g19_c04         HammerThrow         HammerThrow
# 12896         v_CliffDiving_g20_c01         CliffDiving         CliffDiving
# 12897         v_CricketShot_g05_c06         CricketShot         CricketShot
# 12898          v_UnevenBars_g25_c01          UnevenBars          UnevenBars
# 12899     v_FloorGymnastics_g07_c03     FloorGymnastics     FloorGymnastics
# 12900   v_TrampolineJumping_g07_c01   TrampolineJumping   TrampolineJumping
# 12901   v_VolleyballSpiking_g10_c01   VolleyballSpiking   VolleyballSpiking
# 12902          v_StillRings_g09_c01          StillRings          StillRings
# 12903   v_TrampolineJumping_g23_c04   TrampolineJumping   TrampolineJumping
# 12904             v_PullUps_g23_c02             PullUps             PullUps
# 12905        v_PlayingPiano_g03_c03        PlayingPiano        PlayingPiano
# 12906          v_BenchPress_g15_c02          BenchPress          BenchPress
# 12907        v_RopeClimbing_g01_c03        RopeClimbing        RopeClimbing
# 12908             v_Fencing_g15_c04             Fencing             Fencing
# 12911      v_BasketballDunk_g17_c06      BasketballDunk      BasketballDunk
# 12912         v_PlayingDhol_g01_c04         PlayingDhol         PlayingDhol
# 12913          v_PlayingDaf_g19_c01          PlayingDaf          PlayingDaf
# 12914         v_CliffDiving_g06_c06         CliffDiving         CliffDiving
# 12915             v_Shotput_g10_c05             Shotput             Shotput
# 12916       v_SkateBoarding_g06_c01       SkateBoarding       SkateBoarding
# 12917         v_PlayingDhol_g12_c01         PlayingDhol         PlayingDhol
# ...
# 13095              v_TaiChi_g21_c01              TaiChi              TaiChi
# 13096              v_Diving_g01_c04              Diving              Diving
# 13097          v_PlayingDaf_g06_c03          PlayingDaf          PlayingDaf
# 13098         v_CliffDiving_g04_c03         CliffDiving         CliffDiving
# 13099           v_SalsaSpin_g08_c05           SalsaSpin           SalsaSpin
# 13100         v_CricketShot_g22_c02         CricketShot         CricketShot
# 13101            v_LongJump_g15_c03            LongJump            LongJump
# 13102       v_ApplyLipstick_g14_c01       ApplyLipstick       ApplyLipstick
# 13103      v_MilitaryParade_g06_c04      MilitaryParade      MilitaryParade
# 13104            v_Kayaking_g19_c02            Kayaking            Kayaking
# 13105      v_SoccerJuggling_g18_c03      SoccerJuggling      SoccerJuggling
# 13106          v_IceDancing_g09_c01          IceDancing          IceDancing
# 13107              v_Diving_g08_c02              Diving              Diving
# 13108         v_JumpingJack_g10_c01         JumpingJack         JumpingJack
# 13109      v_WalkingWithDog_g23_c04      WalkingWithDog      WalkingWithDog
# 13110            v_Kayaking_g09_c05            Kayaking            Kayaking
# 13111         v_CricketShot_g12_c05         CricketShot         CricketShot
# 13112        v_CleanAndJerk_g12_c04        CleanAndJerk        CleanAndJerk
# 13113           v_SkyDiving_g06_c03           SkyDiving           SkyDiving
# 13114        v_ParallelBars_g02_c03        ParallelBars        ParallelBars
# 13115          v_IceDancing_g13_c02          IceDancing          IceDancing
# 13116           v_PoleVault_g03_c03           PoleVault           PoleVault
# 13117         v_TennisSwing_g08_c06         TennisSwing         TennisSwing
# 13118             v_Rafting_g08_c05             Rafting             Rafting
# 13119      v_ApplyEyeMakeup_g04_c03      ApplyEyeMakeup      ApplyEyeMakeup
# 13120      v_MilitaryParade_g11_c02      MilitaryParade      MilitaryParade
# 13121           v_PoleVault_g18_c02           PoleVault           PoleVault
# 13122       v_PlayingGuitar_g12_c01       PlayingGuitar       PlayingGuitar
# 13123      v_BlowingCandles_g10_c01      BlowingCandles      BlowingCandles
# 13124       v_PlayingGuitar_g08_c06       PlayingGuitar       PlayingGuitar
# 13125   v_BoxingPunchingBag_g08_c06   BoxingPunchingBag   BoxingPunchingBag
# 13126          v_PlayingDaf_g05_c03          PlayingDaf          PlayingDaf
# 13127         v_TennisSwing_g15_c05         TennisSwing         TennisSwing
# 13128            v_Kayaking_g09_c02            Kayaking            Kayaking
# 13129   v_TrampolineJumping_g20_c04   TrampolineJumping   TrampolineJumping
# 13130   v_BoxingPunchingBag_g16_c05   BoxingPunchingBag   BoxingPunchingBag
# 13131       v_SumoWrestling_g24_c04       SumoWrestling       SumoWrestling
# 13132       v_BrushingTeeth_g19_c02       BrushingTeeth       BrushingTeeth
# 13133             v_Surfing_g20_c03             Surfing             Surfing
# 13134       v_SumoWrestling_g08_c06       SumoWrestling       SumoWrestling
# 13135        v_ShavingBeard_g16_c01        ShavingBeard        ShavingBeard
# 13136        v_BandMarching_g25_c02        BandMarching        BandMarching
# 13137             v_Shotput_g08_c02             Shotput             Shotput
# 13138    v_HandstandWalking_g12_c03    HandstandWalking    HandstandWalking
# 13139        v_FrisbeeCatch_g16_c05        FrisbeeCatch        FrisbeeCatch
# 13140              v_Mixing_g25_c01              Mixing              Mixing
# 13141   v_BoxingPunchingBag_g20_c02   BoxingPunchingBag   BoxingPunchingBag
# 13142         v_HammerThrow_g02_c05         HammerThrow         HammerThrow
# 13143        v_PizzaTossing_g04_c05        PizzaTossing        PizzaTossing
# 13144        v_BandMarching_g05_c04        BandMarching        BandMarching
# 13145              v_Typing_g14_c05              Typing              Typing
# 13146           v_SkyDiving_g02_c02           SkyDiving           SkyDiving
# 13147               v_Punch_g25_c07               Punch               Punch
# 13148        v_CleanAndJerk_g20_c04        CleanAndJerk        CleanAndJerk
# 13149         v_WallPushups_g11_c04         WallPushups         WallPushups
# 13150     v_FloorGymnastics_g16_c03     FloorGymnastics     FloorGymnastics
# 13151               v_Swing_g21_c03               Swing               Swing
# 13152         v_CliffDiving_g22_c02         CliffDiving         CliffDiving
# 13153    v_BodyWeightSquats_g10_c05    BodyWeightSquats    BodyWeightSquats
# 13154    v_HandstandWalking_g21_c04    HandstandWalking    HandstandWalking
# 13155        v_FrisbeeCatch_g09_c02        FrisbeeCatch        FrisbeeCatch
# 13157       v_JugglingBalls_g08_c01       JugglingBalls       JugglingBalls
# 13158      v_BoxingSpeedBag_g20_c04      BoxingSpeedBag      BoxingSpeedBag
# 13159        v_JavelinThrow_g05_c03        JavelinThrow        JavelinThrow
# 13161             v_Surfing_g14_c04             Surfing             Surfing
# 13162     v_TableTennisShot_g24_c03     TableTennisShot     TableTennisShot
# 13163        v_PlayingSitar_g19_c03        PlayingSitar        PlayingSitar
# 13164        v_JavelinThrow_g01_c03        JavelinThrow        JavelinThrow
# 13165              v_Diving_g10_c02              Diving              Diving
# 13166         v_CliffDiving_g23_c05         CliffDiving         CliffDiving
# 13167          v_BenchPress_g21_c03          BenchPress          BenchPress
# 13170      v_WalkingWithDog_g14_c03      WalkingWithDog      WalkingWithDog
# 13171          v_FrontCrawl_g20_c04          FrontCrawl          FrontCrawl
# 13172         v_CliffDiving_g05_c02         CliffDiving         CliffDiving
# 13173         v_BlowDryHair_g19_c04         BlowDryHair         BlowDryHair
# 13174             v_Haircut_g08_c06             Haircut             Haircut
# 13175             v_Rafting_g03_c02             Rafting             Rafting
# 13176               v_Punch_g12_c05               Punch               Punch
# 13177   v_VolleyballSpiking_g24_c02   VolleyballSpiking   VolleyballSpiking
# 13178             v_Surfing_g07_c02             Surfing             Surfing
# 13179      v_SoccerJuggling_g01_c01      SoccerJuggling      SoccerJuggling
# 13180              v_Skiing_g04_c07              Skiing              Skiing
# 13181                v_YoYo_g03_c03                YoYo                YoYo
# 13182        v_ParallelBars_g16_c04        ParallelBars        ParallelBars
# 13183            v_Kayaking_g16_c03            Kayaking            Kayaking
# 13184      v_BasketballDunk_g05_c04      BasketballDunk      BasketballDunk
# 13185        v_PlayingCello_g16_c02        PlayingCello        PlayingCello
# 13186          v_BenchPress_g04_c05          BenchPress          BenchPress
# 13187       v_SumoWrestling_g07_c04       SumoWrestling       SumoWrestling
# 13188         v_BalanceBeam_g17_c02         BalanceBeam         BalanceBeam
# 13189    v_HandstandWalking_g13_c03    HandstandWalking    HandstandWalking
# 13190         v_WallPushups_g16_c07         WallPushups         WallPushups
# 13191       v_BrushingTeeth_g05_c01       BrushingTeeth       BrushingTeeth
# 13192           v_SkyDiving_g18_c05           SkyDiving           SkyDiving
# 13193   v_TrampolineJumping_g12_c03   TrampolineJumping   TrampolineJumping
# 13195         v_HammerThrow_g03_c04         HammerThrow         HammerThrow
# 13196          v_Basketball_g23_c03          Basketball          Basketball
# 13197        v_BabyCrawling_g13_c05        BabyCrawling        BabyCrawling
# 13199              v_Rowing_g10_c01              Rowing              Rowing
# 13200         v_JumpingJack_g05_c06         JumpingJack         JumpingJack
# 13201            v_HulaHoop_g02_c01            HulaHoop            HulaHoop
# 13202         v_HeadMassage_g14_c02         HeadMassage         HeadMassage
# 13203    v_BodyWeightSquats_g18_c04    BodyWeightSquats    BodyWeightSquats
# 13204         v_CricketShot_g06_c02         CricketShot         CricketShot
# 13205         v_PommelHorse_g02_c04         PommelHorse         PommelHorse
# 13207      v_BasketballDunk_g08_c05      BasketballDunk      BasketballDunk
# 13208       v_SumoWrestling_g17_c02       SumoWrestling       SumoWrestling
# 13209            v_HighJump_g16_c02            HighJump            HighJump
# 13210      v_WritingOnBoard_g05_c03      WritingOnBoard      WritingOnBoard
# 13211       v_JugglingBalls_g01_c01       JugglingBalls       JugglingBalls
# 13212           v_PoleVault_g23_c02           PoleVault           PoleVault
# 13213          v_FrontCrawl_g05_c04          FrontCrawl          FrontCrawl
# 13214              v_Biking_g15_c03              Biking              Biking
# 13215            v_LongJump_g05_c02            LongJump            LongJump
# 13216              v_Skiing_g20_c07              Skiing              Skiing
# 13217           v_Nunchucks_g20_c02           Nunchucks           Nunchucks
# 13218       v_SkateBoarding_g23_c02       SkateBoarding       SkateBoarding
# 13219      v_CricketBowling_g18_c04      CricketBowling      CricketBowling
# 13220          v_BenchPress_g08_c06          BenchPress          BenchPress
# 13221             v_Archery_g05_c03             Archery             Archery
# 13222     v_TableTennisShot_g14_c02     TableTennisShot     TableTennisShot
# 13223             v_Bowling_g25_c05             Bowling             Bowling
# 13224          v_UnevenBars_g24_c03          UnevenBars          UnevenBars
# 13226        v_PlayingTabla_g23_c03        PlayingTabla        PlayingTabla
# 13228             v_Archery_g12_c03             Archery             Archery
# 13229      v_MilitaryParade_g14_c05      MilitaryParade      MilitaryParade
# 13230           v_SkyDiving_g07_c02           SkyDiving           SkyDiving
# 13231          v_PlayingDaf_g10_c03          PlayingDaf          PlayingDaf
# 13232                v_YoYo_g01_c02                YoYo                YoYo
# 13233       v_PlayingGuitar_g05_c01       PlayingGuitar       PlayingGuitar
# 13234              v_Lunges_g19_c01              Lunges              Lunges
# 13236   v_VolleyballSpiking_g14_c04   VolleyballSpiking   VolleyballSpiking
# 13237         v_CliffDiving_g22_c06         CliffDiving         CliffDiving
# 13238         v_ThrowDiscus_g02_c03         ThrowDiscus         ThrowDiscus
# 13239           v_SkyDiving_g21_c01           SkyDiving           SkyDiving
# 13240        v_ShavingBeard_g13_c01        ShavingBeard        ShavingBeard
# 13241         v_ThrowDiscus_g01_c01         ThrowDiscus         ThrowDiscus
# 13243      v_ApplyEyeMakeup_g25_c07      ApplyEyeMakeup      ApplyEyeMakeup
# 13244              v_Skiing_g18_c03              Skiing              Skiing
# 13245      v_BlowingCandles_g04_c02      BlowingCandles      BlowingCandles
# 13246         v_HeadMassage_g23_c06         HeadMassage         HeadMassage
# 13247              v_TaiChi_g01_c02              TaiChi              TaiChi
# 13248          v_FrontCrawl_g04_c06          FrontCrawl          FrontCrawl
# 13249           v_Nunchucks_g05_c04           Nunchucks           Nunchucks
# 13250       v_SkateBoarding_g12_c02       SkateBoarding       SkateBoarding
# 13251        v_PlayingPiano_g12_c04        PlayingPiano        PlayingPiano
# 13252      v_WalkingWithDog_g25_c02      WalkingWithDog      WalkingWithDog
# 13253       v_PlayingGuitar_g10_c06       PlayingGuitar       PlayingGuitar
# 13254           v_Hammering_g19_c01           Hammering           Hammering
# 13255            v_JumpRope_g20_c05            JumpRope            JumpRope
# 13256         v_CricketShot_g21_c04         CricketShot         CricketShot
# 13257           v_Hammering_g03_c01           Hammering           Hammering
# 13258           v_Billiards_g14_c04           Billiards           Billiards
# 13260      v_ApplyEyeMakeup_g09_c06      ApplyEyeMakeup      ApplyEyeMakeup
# 13261        v_BandMarching_g02_c05        BandMarching        BandMarching
# 13262      v_BoxingSpeedBag_g20_c05      BoxingSpeedBag      BoxingSpeedBag
# 13263      v_MilitaryParade_g17_c02      MilitaryParade      MilitaryParade
# 13264             v_Bowling_g06_c01             Bowling             Bowling
# 13265     v_FloorGymnastics_g12_c01     FloorGymnastics     FloorGymnastics
# 13266              v_Typing_g02_c05              Typing              Typing
# 13267          v_PlayingDaf_g20_c01          PlayingDaf          PlayingDaf
# 13268    v_HandstandWalking_g01_c04    HandstandWalking    HandstandWalking
# 13270      v_WalkingWithDog_g05_c04      WalkingWithDog      WalkingWithDog
# 13271          v_Basketball_g09_c03          Basketball          Basketball
# 13272         v_HorseRiding_g25_c04         HorseRiding         HorseRiding
# 13273         v_CliffDiving_g25_c04         CliffDiving         CliffDiving
# 13274          v_StillRings_g11_c01          StillRings          StillRings
# 13275    v_BodyWeightSquats_g05_c01    BodyWeightSquats    BodyWeightSquats
# 13276              v_Rowing_g07_c03              Rowing              Rowing
# 13277             v_Surfing_g04_c01             Surfing             Surfing
# 13278             v_Fencing_g25_c04             Fencing             Fencing
# 13279             v_Surfing_g15_c03             Surfing             Surfing
# 13280              v_Rowing_g14_c05              Rowing              Rowing
# 13281           v_Hammering_g17_c01           Hammering           Hammering
# 13282           v_Billiards_g02_c07           Billiards           Billiards
# 13283              v_Skiing_g11_c04              Skiing              Skiing
# 13284      v_SoccerJuggling_g19_c06      SoccerJuggling      SoccerJuggling
# 13285           v_Nunchucks_g22_c03           Nunchucks           Nunchucks
# 13286         v_BalanceBeam_g15_c02         BalanceBeam         BalanceBeam
# 13287      v_MilitaryParade_g03_c01      MilitaryParade      MilitaryParade
# 13288  v_FieldHockeyPenalty_g23_c04  FieldHockeyPenalty  FieldHockeyPenalty
# 13289             v_Archery_g18_c02             Archery             Archery
# 13290             v_Rafting_g08_c01             Rafting             Rafting
# 13291         v_HeadMassage_g16_c04         HeadMassage         HeadMassage
# 13292         v_PlayingDhol_g05_c06         PlayingDhol         PlayingDhol
# 13294   v_VolleyballSpiking_g09_c06   VolleyballSpiking   VolleyballSpiking
# 13295   v_BoxingPunchingBag_g03_c03   BoxingPunchingBag   BoxingPunchingBag
# 13296         v_PlayingDhol_g25_c05         PlayingDhol         PlayingDhol
# 13297       v_SoccerPenalty_g06_c06       SoccerPenalty       SoccerPenalty
# 13298       v_BrushingTeeth_g03_c03       BrushingTeeth       BrushingTeeth
# 13299    v_HandstandPushups_g13_c01    HandstandPushups    HandstandPushups
# 13300           v_SkyDiving_g19_c02           SkyDiving           SkyDiving
# 13301          v_BenchPress_g12_c01          BenchPress          BenchPress
# 13302            v_Kayaking_g16_c05            Kayaking            Kayaking
# 13303           v_Nunchucks_g25_c04           Nunchucks           Nunchucks
# 13304    v_BodyWeightSquats_g01_c02    BodyWeightSquats    BodyWeightSquats
# 13305            v_HulaHoop_g03_c03            HulaHoop            HulaHoop
# 13306             v_Bowling_g16_c02             Bowling             Bowling
# 13307             v_Bowling_g09_c06             Bowling             Bowling
# 13308        v_PlayingPiano_g15_c03        PlayingPiano        PlayingPiano
# 13309             v_Shotput_g20_c03             Shotput             Shotput
# 13310       v_PlayingGuitar_g23_c02       PlayingGuitar       PlayingGuitar
# 13311         v_BlowDryHair_g07_c01         BlowDryHair         BlowDryHair
# 13312          v_StillRings_g10_c03          StillRings          StillRings
# 13313   v_BoxingPunchingBag_g08_c05   BoxingPunchingBag   BoxingPunchingBag
# 13314            v_JumpRope_g15_c01            JumpRope            JumpRope
# 13315       v_PlayingGuitar_g20_c04       PlayingGuitar       PlayingGuitar
# 13317        v_PlayingSitar_g23_c05        PlayingSitar        PlayingSitar
# 13318      v_BasketballDunk_g19_c03      BasketballDunk      BasketballDunk
# 13319            v_Drumming_g03_c04            Drumming            Drumming
#
# [12444 rows x 3 columns]

# %%
N = len(df)
N_correct = len(df_correct)
N_mistake = len(df_mistakes)

print('total videos: {}'.format(N))
print('Accuracy: {:.2f}%'.format(N_correct/N * 100))
# Out:
# total videos: 13320
# Accuracy: 93.42%
